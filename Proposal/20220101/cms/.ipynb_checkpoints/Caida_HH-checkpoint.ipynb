# %% [markdown]
# # CMS for caida srcip

# %%
# caida
# track Top-k element all the time
import sys
sys.path.append("..")
from cms.CountMinSketch import CountMinSketch
import sys
import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import re

import time
import os
from pympler import asizeof
dataset='caida'
total_count=0
heavy_ratio=1/5000

# =============================dataset path and file=============================
filepath=r"..\..\dataset\caida"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='srcip\caida_ground_truth.csv'
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path
# =============================Initialize=============================
w=512
d=8
size=710
topk=710
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)
Top_dict=dict()

# =============================Stream processing=============================
#item_count=1000
start=time.time()
for datafile in filelist[:]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'rb') as file:
         #以binary讀取，資料型態也為byte
        while True:
            e=file.read(13)
            if len(e)<13:
                print('EOF')
                break
            else:
                total_count+=1
                #item_count-=1
                e=str(e[:4])
                # =================read src ip field only===================
                item=DS.Tail(e,1)
                cms.Add_CMS(item)
                count=cms.Estimate_CMS(item)
                if len(Top_dict)<TC.size:                
                    if count>total_count*heavy_ratio:
                        Top_dict[item.ID]=count
                else:
                    min_ele = min(Top_dict, key=Top_dict.get)
                        # find e_min
                    if count >Top_dict[min_ele]:
                        Top_dict[item.ID]=count
                        Top_dict.pop(min_ele)

end=time.time()

# =============================Print and Plot result=============================
Top_dict=dict(sorted(Top_dict.items(), key=lambda item: item[1],reverse=True))
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{} in CMS-{}*{}".format(TC.topk,TC.depth,TC.width))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top_dict:
    if Top_dict[item]>total_count*heavy_ratio:
        HH[item]=Top_dict[item]
HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# Memory usage
sk0=asizeof.asizeof(Top_dict)
sk1=asizeof.asizeof(cms)
print("Top_dict with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} bytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

print("\nFor copy")
print("Top-{}".format(TC.size))
print("Top_dict with {} kbytes.".format(asizeof.asizeof(Top_dict)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Count ARE/AAE in Top
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
#print("{} item found in SS[{}] compare with true Top-{}".format(len(tp_set),Config.size,topk))
endx=time.time()

print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

TF.Plot_hh_compare(temp,HH,"CountMin Sketch")

'''
# result to csv
import pandas as pd
path="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# Top_dict to csv
filename='CM_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(Top_dict.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)
'''
# Out:
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# Execution time:2491.802 seconds.
# Top-710 in CMS-8*512
# Top_dict with 107792 bytes.
# Sketch with 16960 bytes.
# Total size 121.828125 bytes,
#
# For copy
# Top-710
# Top_dict with 105.265625 kbytes.
# Find 0.307 of Heavy Hitters
# Execution time:2491.802 seconds.
# Find:218
# Top_ARE: 2.1704
# Top_AAE: 34563.1606
# Estimate time:  0.372 seconds.
# '\n# result to csv\nimport pandas as pd\npath="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# Top_dict to csv\nfilename=\'CM_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(Top_dict.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n'

# %%
# caida
# track Top-k element all the time
import sys
sys.path.append("..")
from cms.CountMinSketch import CountMinSketch
import sys
import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import re

import time
import os
from pympler import asizeof
dataset='caida'
total_count=0
heavy_ratio=1/5000

# =============================dataset path and file=============================
filepath=r"..\..\dataset\caida"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='srcip\caida_ground_truth.csv'
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path
# =============================Initialize=============================
w=2048
d=8
size=710
topk=710
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)
Top_dict=dict()

# =============================Stream processing=============================
#item_count=1000
start=time.time()
for datafile in filelist[:]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'rb') as file:
         #以binary讀取，資料型態也為byte
        while True:
            e=file.read(13)
            if len(e)<13:
                print('EOF')
                break
            else:
                total_count+=1
                #item_count-=1
                e=str(e[:4])
                # =================read src ip field only===================
                item=DS.Tail(e,1)
                cms.Add_CMS(item)
                count=cms.Estimate_CMS(item)
                if len(Top_dict)<TC.size:                
                    if count>total_count*heavy_ratio:
                        Top_dict[item.ID]=count
                else:
                    min_ele = min(Top_dict, key=Top_dict.get)
                        # find e_min
                    if count >Top_dict[min_ele]:
                        Top_dict[item.ID]=count
                        Top_dict.pop(min_ele)

end=time.time()

# =============================Print and Plot result=============================
Top_dict=dict(sorted(Top_dict.items(), key=lambda item: item[1],reverse=True))
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{} in CMS-{}*{}".format(TC.topk,TC.depth,TC.width))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top_dict:
    if Top_dict[item]>total_count*heavy_ratio:
        HH[item]=Top_dict[item]
HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# Memory usage
sk0=asizeof.asizeof(Top_dict)
sk1=asizeof.asizeof(cms)
print("Top_dict with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} bytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

print("\nFor copy")
print("Top-{}".format(TC.size))
print("Top_dict with {} kbytes.".format(asizeof.asizeof(Top_dict)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Count ARE/AAE in Top
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
#print("{} item found in SS[{}] compare with true Top-{}".format(len(tp_set),Config.size,topk))
endx=time.time()

print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

TF.Plot_hh_compare(temp,HH,"CountMin Sketch")

'''
# result to csv
import pandas as pd
path="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# Top_dict to csv
filename='CM_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(Top_dict.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)
'''
# Out:
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# Execution time:1913.161 seconds.
# Top-710 in CMS-8*2048
# Top_dict with 107392 bytes.
# Sketch with 66112 bytes.
# Total size 169.4375 bytes,
#
# For copy
# Top-710
# Top_dict with 104.875 kbytes.
# Find 0.830 of Heavy Hitters
# Execution time:1913.161 seconds.
# Find:589
# Top_ARE: 0.4938
# Top_AAE: 5339.3447
# Estimate time:  0.393 seconds.
# '\n# result to csv\nimport pandas as pd\npath="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# Top_dict to csv\nfilename=\'CM_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(Top_dict.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n'

# %%
# caida
# track Top-k element all the time
import sys
sys.path.append("..")
from cms.CountMinSketch import CountMinSketch
import sys
import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import re

import time
import os
from pympler import asizeof
dataset='caida'
total_count=0
heavy_ratio=1/5000

# =============================dataset path and file=============================
filepath=r"..\..\dataset\caida"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='srcip\caida_ground_truth.csv'
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path
# =============================Initialize=============================
w=5500
d=8
size=710
topk=710
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)
Top_dict=dict()

# =============================Stream processing=============================
#item_count=1000
start=time.time()
for datafile in filelist[:]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'rb') as file:
         #以binary讀取，資料型態也為byte
        while True:
            e=file.read(13)
            if len(e)<13:
                print('EOF')
                break
            else:
                total_count+=1
                #item_count-=1
                e=str(e[:4])
                # =================read src ip field only===================
                item=DS.Tail(e,1)
                cms.Add_CMS(item)
                count=cms.Estimate_CMS(item)
                if len(Top_dict)<TC.size:                
                    if count>total_count*heavy_ratio:
                        Top_dict[item.ID]=count
                else:
                    min_ele = min(Top_dict, key=Top_dict.get)
                        # find e_min
                    if count >Top_dict[min_ele]:
                        Top_dict[item.ID]=count
                        Top_dict.pop(min_ele)

end=time.time()

# =============================Print and Plot result=============================
Top_dict=dict(sorted(Top_dict.items(), key=lambda item: item[1],reverse=True))
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{} in CMS-{}*{}".format(TC.topk,TC.depth,TC.width))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top_dict:
    if Top_dict[item]>total_count*heavy_ratio:
        HH[item]=Top_dict[item]
HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# Memory usage
sk0=asizeof.asizeof(Top_dict)
sk1=asizeof.asizeof(cms)
print("Top_dict with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} bytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

print("\nFor copy")
print("Top-{}".format(TC.size))
print("Top_dict with {} kbytes.".format(asizeof.asizeof(Top_dict)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Count ARE/AAE in Top
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
#print("{} item found in SS[{}] compare with true Top-{}".format(len(tp_set),Config.size,topk))
endx=time.time()

print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

TF.Plot_hh_compare(temp,HH,"CountMin Sketch")

'''
# result to csv
import pandas as pd
path="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# Top_dict to csv
filename='CM_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(Top_dict.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)
'''
# Out:
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# Execution time:1235.688 seconds.
# Top-710 in CMS-8*5500
# Top_dict with 107480 bytes.
# Sketch with 176576 bytes.
# Total size 277.3984375 bytes,
#
# For copy
# Top-710
# Top_dict with 104.9609375 kbytes.
# Find 0.956 of Heavy Hitters
# Execution time:1235.688 seconds.
# Find:679
# Top_ARE: 0.1310
# Top_AAE: 1299.4138
# Estimate time:  0.383 seconds.
# '\n# result to csv\nimport pandas as pd\npath="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# Top_dict to csv\nfilename=\'CM_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(Top_dict.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n'

# %%
# caida
# track Top-k element all the time
import sys
sys.path.append("..")
from cms.CountMinSketch import CountMinSketch
import sys
import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import re

import time
import os
from pympler import asizeof
dataset='caida'
total_count=0
heavy_ratio=1/5000

# =============================dataset path and file=============================
filepath=r"..\..\dataset\caida"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='srcip\caida_ground_truth.csv'
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path
# =============================Initialize=============================
w=8900
d=8
size=710
topk=710
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)
Top_dict=dict()

# =============================Stream processing=============================
#item_count=1000
start=time.time()
for datafile in filelist[:]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'rb') as file:
         #以binary讀取，資料型態也為byte
        while True:
            e=file.read(13)
            if len(e)<13:
                print('EOF')
                break
            else:
                total_count+=1
                #item_count-=1
                e=str(e[:4])
                # =================read src ip field only===================
                item=DS.Tail(e,1)
                cms.Add_CMS(item)
                count=cms.Estimate_CMS(item)
                if len(Top_dict)<TC.size:                
                    if count>total_count*heavy_ratio:
                        Top_dict[item.ID]=count
                else:
                    min_ele = min(Top_dict, key=Top_dict.get)
                        # find e_min
                    if count >Top_dict[min_ele]:
                        Top_dict[item.ID]=count
                        Top_dict.pop(min_ele)

end=time.time()

# =============================Print and Plot result=============================
Top_dict=dict(sorted(Top_dict.items(), key=lambda item: item[1],reverse=True))
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{} in CMS-{}*{}".format(TC.topk,TC.depth,TC.width))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top_dict:
    if Top_dict[item]>total_count*heavy_ratio:
        HH[item]=Top_dict[item]
HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# Memory usage
sk0=asizeof.asizeof(Top_dict)
sk1=asizeof.asizeof(cms)
print("Top_dict with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} bytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

print("\nFor copy")
print("Top-{}".format(TC.size))
print("Top_dict with {} kbytes.".format(asizeof.asizeof(Top_dict)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Count ARE/AAE in Top
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
#print("{} item found in SS[{}] compare with true Top-{}".format(len(tp_set),Config.size,topk))
endx=time.time()

print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

TF.Plot_hh_compare(temp,HH,"CountMin Sketch")

'''
# result to csv
import pandas as pd
path="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# Top_dict to csv
filename='CM_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(Top_dict.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)
'''
# Out:
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# Execution time:1156.354 seconds.
# Top-710 in CMS-8*8900
# Top_dict with 107528 bytes.
# Sketch with 285376 bytes.
# Total size 383.6953125 bytes,
#
# For copy
# Top-710
# Top_dict with 105.0078125 kbytes.
# Find 0.982 of Heavy Hitters
# Execution time:1156.354 seconds.
# Find:697
# Top_ARE: 0.0653
# Top_AAE: 644.0875
# Estimate time:  0.376 seconds.
# '\n# result to csv\nimport pandas as pd\npath="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# Top_dict to csv\nfilename=\'CM_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(Top_dict.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n'

# %%
# caida
# track Top-k element all the time
import sys
sys.path.append("..")
from cms.CountMinSketch import CountMinSketch
import sys
import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import re

import time
import os
from pympler import asizeof
dataset='caida'
total_count=0
heavy_ratio=1/5000

# =============================dataset path and file=============================
filepath=r"..\..\dataset\caida"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='srcip\caida_ground_truth.csv'
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path
# =============================Initialize=============================
w=12300
d=8
size=710
topk=710
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)
Top_dict=dict()

# =============================Stream processing=============================
#item_count=1000
start=time.time()
for datafile in filelist[:]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'rb') as file:
         #以binary讀取，資料型態也為byte
        while True:
            e=file.read(13)
            if len(e)<13:
                print('EOF')
                break
            else:
                total_count+=1
                #item_count-=1
                e=str(e[:4])
                # =================read src ip field only===================
                item=DS.Tail(e,1)
                cms.Add_CMS(item)
                count=cms.Estimate_CMS(item)
                if len(Top_dict)<TC.size:                
                    if count>total_count*heavy_ratio:
                        Top_dict[item.ID]=count
                else:
                    min_ele = min(Top_dict, key=Top_dict.get)
                        # find e_min
                    if count >Top_dict[min_ele]:
                        Top_dict[item.ID]=count
                        Top_dict.pop(min_ele)

end=time.time()

# =============================Print and Plot result=============================
Top_dict=dict(sorted(Top_dict.items(), key=lambda item: item[1],reverse=True))
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{} in CMS-{}*{}".format(TC.topk,TC.depth,TC.width))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top_dict:
    if Top_dict[item]>total_count*heavy_ratio:
        HH[item]=Top_dict[item]
HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# Memory usage
sk0=asizeof.asizeof(Top_dict)
sk1=asizeof.asizeof(cms)
print("Top_dict with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} bytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

print("\nFor copy")
print("Top-{}".format(TC.size))
print("Top_dict with {} kbytes.".format(asizeof.asizeof(Top_dict)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Count ARE/AAE in Top
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
#print("{} item found in SS[{}] compare with true Top-{}".format(len(tp_set),Config.size,topk))
endx=time.time()

print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

TF.Plot_hh_compare(temp,HH,"CountMin Sketch")

'''
# result to csv
import pandas as pd
path="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# Top_dict to csv
filename='CM_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(Top_dict.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)
'''
# Out:
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# Execution time:1116.678 seconds.
# Top-710 in CMS-8*12300
# Top_dict with 107488 bytes.
# Sketch with 394176 bytes.
# Total size 489.90625 bytes,
#
# For copy
# Top-710
# Top_dict with 104.96875 kbytes.
# Find 0.983 of Heavy Hitters
# Execution time:1116.678 seconds.
# Find:698
# Top_ARE: 0.0396
# Top_AAE: 396.2493
# Estimate time:  0.400 seconds.
# '\n# result to csv\nimport pandas as pd\npath="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# Top_dict to csv\nfilename=\'CM_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(Top_dict.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n'

# %%
# caida
# track Top-k element all the time
import sys
sys.path.append("..")
from cms.CountMinSketch import CountMinSketch
import sys
import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import re

import time
import os
from pympler import asizeof
dataset='caida'
total_count=0
heavy_ratio=1/5000

# =============================dataset path and file=============================
filepath=r"..\..\dataset\caida"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='srcip\caida_ground_truth.csv'
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path
# =============================Initialize=============================
w=15700
d=8
size=710
topk=710
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)
Top_dict=dict()

# =============================Stream processing=============================
#item_count=1000
start=time.time()
for datafile in filelist[:]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'rb') as file:
         #以binary讀取，資料型態也為byte
        while True:
            e=file.read(13)
            if len(e)<13:
                print('EOF')
                break
            else:
                total_count+=1
                #item_count-=1
                e=str(e[:4])
                # =================read src ip field only===================
                item=DS.Tail(e,1)
                cms.Add_CMS(item)
                count=cms.Estimate_CMS(item)
                if len(Top_dict)<TC.size:                
                    if count>total_count*heavy_ratio:
                        Top_dict[item.ID]=count
                else:
                    min_ele = min(Top_dict, key=Top_dict.get)
                        # find e_min
                    if count >Top_dict[min_ele]:
                        Top_dict[item.ID]=count
                        Top_dict.pop(min_ele)

end=time.time()

# =============================Print and Plot result=============================
Top_dict=dict(sorted(Top_dict.items(), key=lambda item: item[1],reverse=True))
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{} in CMS-{}*{}".format(TC.topk,TC.depth,TC.width))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top_dict:
    if Top_dict[item]>total_count*heavy_ratio:
        HH[item]=Top_dict[item]
HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# Memory usage
sk0=asizeof.asizeof(Top_dict)
sk1=asizeof.asizeof(cms)
print("Top_dict with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} bytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

print("\nFor copy")
print("Top-{}".format(TC.size))
print("Top_dict with {} kbytes.".format(asizeof.asizeof(Top_dict)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Count ARE/AAE in Top
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
#print("{} item found in SS[{}] compare with true Top-{}".format(len(tp_set),Config.size,topk))
endx=time.time()

print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

TF.Plot_hh_compare(temp,HH,"CountMin Sketch")

'''
# result to csv
import pandas as pd
path="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# Top_dict to csv
filename='CM_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(Top_dict.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)
'''
# Out:
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# Execution time:1116.533 seconds.
# Top-710 in CMS-8*15700
# Top_dict with 107496 bytes.
# Sketch with 502976 bytes.
# Total size 596.1640625 bytes,
#
# For copy
# Top-710
# Top_dict with 104.9765625 kbytes.
# Find 0.993 of Heavy Hitters
# Execution time:1116.533 seconds.
# Find:705
# Top_ARE: 0.0269
# Top_AAE: 269.1035
# Estimate time:  0.378 seconds.
# '\n# result to csv\nimport pandas as pd\npath="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# Top_dict to csv\nfilename=\'CM_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(Top_dict.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n'

# %%
# caida
# track Top-k element all the time
import sys
sys.path.append("..")
from cms.CountMinSketch import CountMinSketch
import sys
import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import re

import time
import os
from pympler import asizeof
dataset='caida'
total_count=0
heavy_ratio=1/5000

# =============================dataset path and file=============================
filepath=r"..\..\dataset\caida"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='srcip\caida_ground_truth.csv'
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path
# =============================Initialize=============================
w=19100
d=8
size=710
topk=710
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)
Top_dict=dict()

# =============================Stream processing=============================
#item_count=1000
start=time.time()
for datafile in filelist[:]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'rb') as file:
         #以binary讀取，資料型態也為byte
        while True:
            e=file.read(13)
            if len(e)<13:
                print('EOF')
                break
            else:
                total_count+=1
                #item_count-=1
                e=str(e[:4])
                # =================read src ip field only===================
                item=DS.Tail(e,1)
                cms.Add_CMS(item)
                count=cms.Estimate_CMS(item)
                if len(Top_dict)<TC.size:                
                    if count>total_count*heavy_ratio:
                        Top_dict[item.ID]=count
                else:
                    min_ele = min(Top_dict, key=Top_dict.get)
                        # find e_min
                    if count >Top_dict[min_ele]:
                        Top_dict[item.ID]=count
                        Top_dict.pop(min_ele)

end=time.time()

# =============================Print and Plot result=============================
Top_dict=dict(sorted(Top_dict.items(), key=lambda item: item[1],reverse=True))
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{} in CMS-{}*{}".format(TC.topk,TC.depth,TC.width))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top_dict:
    if Top_dict[item]>total_count*heavy_ratio:
        HH[item]=Top_dict[item]
HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# Memory usage
sk0=asizeof.asizeof(Top_dict)
sk1=asizeof.asizeof(cms)
print("Top_dict with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} bytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

print("\nFor copy")
print("Top-{}".format(TC.size))
print("Top_dict with {} kbytes.".format(asizeof.asizeof(Top_dict)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Count ARE/AAE in Top
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
#print("{} item found in SS[{}] compare with true Top-{}".format(len(tp_set),Config.size,topk))
endx=time.time()

print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

TF.Plot_hh_compare(temp,HH,"CountMin Sketch")

'''
# result to csv
import pandas as pd
path="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# Top_dict to csv
filename='CM_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(Top_dict.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)
'''
# Out:
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# Execution time:1100.981 seconds.
# Top-710 in CMS-8*19100
# Top_dict with 107400 bytes.
# Sketch with 611776 bytes.
# Total size 702.3203125 bytes,
#
# For copy
# Top-710
# Top_dict with 104.8828125 kbytes.
# Find 0.994 of Heavy Hitters
# Execution time:1100.981 seconds.
# Find:706
# Top_ARE: 0.0204
# Top_AAE: 198.8612
# Estimate time:  0.392 seconds.
# '\n# result to csv\nimport pandas as pd\npath="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# Top_dict to csv\nfilename=\'CM_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(Top_dict.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n'

# %%
# caida
# track Top-k element all the time
import sys
sys.path.append("..")
from cms.CountMinSketch import CountMinSketch
import sys
import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import re

import time
import os
from pympler import asizeof
dataset='caida'
total_count=0
heavy_ratio=1/5000

# =============================dataset path and file=============================
filepath=r"..\..\dataset\caida"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='srcip\caida_ground_truth.csv'
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path
# =============================Initialize=============================
w=22500
d=8
size=710
topk=710
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)
Top_dict=dict()

# =============================Stream processing=============================
#item_count=1000
start=time.time()
for datafile in filelist[:]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'rb') as file:
         #以binary讀取，資料型態也為byte
        while True:
            e=file.read(13)
            if len(e)<13:
                print('EOF')
                break
            else:
                total_count+=1
                #item_count-=1
                e=str(e[:4])
                # =================read src ip field only===================
                item=DS.Tail(e,1)
                cms.Add_CMS(item)
                count=cms.Estimate_CMS(item)
                if len(Top_dict)<TC.size:                
                    if count>total_count*heavy_ratio:
                        Top_dict[item.ID]=count
                else:
                    min_ele = min(Top_dict, key=Top_dict.get)
                        # find e_min
                    if count >Top_dict[min_ele]:
                        Top_dict[item.ID]=count
                        Top_dict.pop(min_ele)

end=time.time()

# =============================Print and Plot result=============================
Top_dict=dict(sorted(Top_dict.items(), key=lambda item: item[1],reverse=True))
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{} in CMS-{}*{}".format(TC.topk,TC.depth,TC.width))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top_dict:
    if Top_dict[item]>total_count*heavy_ratio:
        HH[item]=Top_dict[item]
HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# Memory usage
sk0=asizeof.asizeof(Top_dict)
sk1=asizeof.asizeof(cms)
print("Top_dict with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} bytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

print("\nFor copy")
print("Top-{}".format(TC.size))
print("Top_dict with {} kbytes.".format(asizeof.asizeof(Top_dict)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Count ARE/AAE in Top
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
#print("{} item found in SS[{}] compare with true Top-{}".format(len(tp_set),Config.size,topk))
endx=time.time()

print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

TF.Plot_hh_compare(temp,HH,"CountMin Sketch")

'''
# result to csv
import pandas as pd
path="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# Top_dict to csv
filename='CM_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(Top_dict.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)
'''
# Out:
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# Execution time:1089.163 seconds.
# Top-710 in CMS-8*22500
# Top_dict with 107392 bytes.
# Sketch with 720576 bytes.
# Total size 808.5625 bytes,
#
# For copy
# Top-710
# Top_dict with 104.875 kbytes.
# Find 0.992 of Heavy Hitters
# Execution time:1089.163 seconds.
# Find:704
# Top_ARE: 0.0158
# Top_AAE: 155.4872
# Estimate time:  0.361 seconds.
# '\n# result to csv\nimport pandas as pd\npath="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# Top_dict to csv\nfilename=\'CM_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(Top_dict.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n'

# %%
# caida
# track Top-k element all the time
import sys
sys.path.append("..")
from cms.CountMinSketch import CountMinSketch
import sys
import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import re

import time
import os
from pympler import asizeof
dataset='caida'
total_count=0
heavy_ratio=1/5000

# =============================dataset path and file=============================
filepath=r"..\..\dataset\caida"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='srcip\caida_ground_truth.csv'
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path
# =============================Initialize=============================
w=25900
d=8
size=710
topk=710
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)
Top_dict=dict()

# =============================Stream processing=============================
#item_count=1000
start=time.time()
for datafile in filelist[:]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'rb') as file:
         #以binary讀取，資料型態也為byte
        while True:
            e=file.read(13)
            if len(e)<13:
                print('EOF')
                break
            else:
                total_count+=1
                #item_count-=1
                e=str(e[:4])
                # =================read src ip field only===================
                item=DS.Tail(e,1)
                cms.Add_CMS(item)
                count=cms.Estimate_CMS(item)
                if len(Top_dict)<TC.size:                
                    if count>total_count*heavy_ratio:
                        Top_dict[item.ID]=count
                else:
                    min_ele = min(Top_dict, key=Top_dict.get)
                        # find e_min
                    if count >Top_dict[min_ele]:
                        Top_dict[item.ID]=count
                        Top_dict.pop(min_ele)

end=time.time()

# =============================Print and Plot result=============================
Top_dict=dict(sorted(Top_dict.items(), key=lambda item: item[1],reverse=True))
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{} in CMS-{}*{}".format(TC.topk,TC.depth,TC.width))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top_dict:
    if Top_dict[item]>total_count*heavy_ratio:
        HH[item]=Top_dict[item]
HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# Memory usage
sk0=asizeof.asizeof(Top_dict)
sk1=asizeof.asizeof(cms)
print("Top_dict with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} bytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

print("\nFor copy")
print("Top-{}".format(TC.size))
print("Top_dict with {} kbytes.".format(asizeof.asizeof(Top_dict)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Count ARE/AAE in Top
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
#print("{} item found in SS[{}] compare with true Top-{}".format(len(tp_set),Config.size,topk))
endx=time.time()

print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

TF.Plot_hh_compare(temp,HH,"CountMin Sketch")

'''
# result to csv
import pandas as pd
path="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# Top_dict to csv
filename='CM_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(Top_dict.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)
'''
# Out:
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# Execution time:1095.931 seconds.
# Top-710 in CMS-8*25900
# Top_dict with 107392 bytes.
# Sketch with 829376 bytes.
# Total size 914.8125 bytes,
#
# For copy
# Top-710
# Top_dict with 104.875 kbytes.
# Find 0.993 of Heavy Hitters
# Execution time:1095.931 seconds.
# Find:705
# Top_ARE: 0.0126
# Top_AAE: 125.6723
# Estimate time:  0.384 seconds.
# '\n# result to csv\nimport pandas as pd\npath="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# Top_dict to csv\nfilename=\'CM_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(Top_dict.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n'

# %%
# caida
# track Top-k element all the time
import sys
sys.path.append("..")
from cms.CountMinSketch import CountMinSketch
import sys
import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import re

import time
import os
from pympler import asizeof
dataset='caida'
total_count=0
heavy_ratio=1/5000

# =============================dataset path and file=============================
filepath=r"..\..\dataset\caida"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='srcip\caida_ground_truth.csv'
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path
# =============================Initialize=============================
w=29300
d=8
size=710
topk=710
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)
Top_dict=dict()

# =============================Stream processing=============================
#item_count=1000
start=time.time()
for datafile in filelist[:]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'rb') as file:
         #以binary讀取，資料型態也為byte
        while True:
            e=file.read(13)
            if len(e)<13:
                print('EOF')
                break
            else:
                total_count+=1
                #item_count-=1
                e=str(e[:4])
                # =================read src ip field only===================
                item=DS.Tail(e,1)
                cms.Add_CMS(item)
                count=cms.Estimate_CMS(item)
                if len(Top_dict)<TC.size:                
                    if count>total_count*heavy_ratio:
                        Top_dict[item.ID]=count
                else:
                    min_ele = min(Top_dict, key=Top_dict.get)
                        # find e_min
                    if count >Top_dict[min_ele]:
                        Top_dict[item.ID]=count
                        Top_dict.pop(min_ele)

end=time.time()

# =============================Print and Plot result=============================
Top_dict=dict(sorted(Top_dict.items(), key=lambda item: item[1],reverse=True))
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{} in CMS-{}*{}".format(TC.topk,TC.depth,TC.width))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top_dict:
    if Top_dict[item]>total_count*heavy_ratio:
        HH[item]=Top_dict[item]
HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# Memory usage
sk0=asizeof.asizeof(Top_dict)
sk1=asizeof.asizeof(cms)
print("Top_dict with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} bytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

print("\nFor copy")
print("Top-{}".format(TC.size))
print("Top_dict with {} kbytes.".format(asizeof.asizeof(Top_dict)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Count ARE/AAE in Top
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
#print("{} item found in SS[{}] compare with true Top-{}".format(len(tp_set),Config.size,topk))
endx=time.time()

print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

TF.Plot_hh_compare(temp,HH,"CountMin Sketch")

'''
# result to csv
import pandas as pd
path="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# Top_dict to csv
filename='CM_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(Top_dict.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)
'''
# Out:
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# EOF
# Execution time:1092.878 seconds.
# Top-710 in CMS-8*29300
# Top_dict with 107408 bytes.
# Sketch with 938176 bytes.
# Total size 1021.078125 bytes,
#
# For copy
# Top-710
# Top_dict with 104.890625 kbytes.
# Find 0.994 of Heavy Hitters
# Execution time:1092.878 seconds.
# Find:706
# Top_ARE: 0.0103
# Top_AAE: 102.4788
# Estimate time:  0.382 seconds.
# '\n# result to csv\nimport pandas as pd\npath="..\\result\\CM\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# Top_dict to csv\nfilename=\'CM_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(Top_dict.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n'
