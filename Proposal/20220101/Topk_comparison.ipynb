# %% [markdown]
# # Kosarak

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

field=['Precision','Execution','TopARE','TopAAE']
'''
field1='Memory'
field2='Precision'
field3='Execution'
field4='TopARE'
field5='TopAAE'
'''
# =============================read csv files=============================
path=r"result"
dataset='kosarak'
arrival=990002

# Space saving
ssfile='SS\\'+dataset+'\\SS_result.csv'
ss=pd.read_csv(os.path.join(path,ssfile))
SSspace_usage=ss['Memory'].tolist()

#CMS
cmfile='CM\\'+dataset+'\\CM_result.csv'
cm=pd.read_csv(os.path.join(path,cmfile))
CMSspace_usage=cm['Memory'].tolist()

# Elastic
elafile='Ela\\'+dataset+'\\Ela_result.csv'
ela=pd.read_csv(os.path.join(path,elafile))
Elaspace_usage=ela['Memory'].tolist()

# Heavy Guardian
hgfile='HG\\'+dataset+'\\HG_result.csv'
hg=pd.read_csv(os.path.join(path,hgfile))
HGspace_usage=hg['Memory'].tolist()

#Cyclic-sketch
cssfile='CS\\'+dataset+'\\CS_result.csv'
cs_s=pd.read_csv(os.path.join(path,cssfile))
CSSspace_usage=cs_s['Memory'].tolist()

#Cyclic-T
cstfile='CS\\'+dataset+'\\add_t\\CS_result.csv'
cs_t=pd.read_csv(os.path.join(path,cstfile))
CSTspace_usage=cs_t['Memory'].tolist()

for findex in field:
    plt.figure()
    plt.xticks([j for j in range(200,1100,100)])
    # Memory usage, 200kb~1MB
    plt.xlabel('Space Usage (KB)')
    if findex=='Precision':
        # initialize Figure
        plt.yticks([j for j in range(0,110,10)])
            # precision: 0~100   
        plt.ylabel('Precision (%), Top-1024')
        plt.ylim(0,100)
    elif findex=='Execution':
        # throughput
        min_time=min(min(ss[findex].tolist(),cm[findex].tolist(),
                 ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        max_throughput=int(arrival/min_time)
        plt.yticks([j for j in range(0,int(max_throughput*1.1),int(max_throughput*1.1/10))])
        plt.ylabel('Throughtput (item/s)')
        plt.ylim(0,int(max_throughput*1.1))
    elif findex=='TopARE':
        #plt.figure(3)
        max_are=max(max(ss[findex].tolist(),cm[findex].tolist(),
                        ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        plt.yticks([j for j in range(0,int(max_are+1)*100,int(max_are+1)*10)])
            # ARE: 0~2
        plt.ylabel('Top-1024 ARE (%)')
        plt.ylim(0,int(max_are*110))
    elif findex=='TopAAE':
        #plt.figure(4)
        max_aae=max(max(ss[findex].tolist(),cm[findex].tolist(),
                        ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        plt.yticks([j/10 for j in range(0,int(max_aae))])
        plt.yticks([j for j in range(0,int(max_aae+1),int(max_aae/10))]) 
        plt.ylabel('Top-1024 AAE')
        plt.ylim(0,int(max_aae*1.1))

    # PLOT
    if findex=='Precision' or findex=='TopARE':
        SS_y=(ss[findex]*100).tolist()
        CM_y=(cm[findex]*100).tolist()
        Ela_y=(ela[findex]*100).tolist()
        HG_y=(hg[findex]*100).tolist()
        CSs_y=(cs_s[findex]*100).tolist()
        CSt_y=(cs_t[findex]*100).tolist()        
    elif findex=='Execution':
        # throughput
        SS_y=(arrival/ss[findex]).tolist()
        CM_y=(arrival/cm[findex]).tolist() 
        Ela_y=(arrival/ela[findex]).tolist()
        HG_y=(arrival/hg[findex]).tolist()
        CSs_y=(arrival/cs_s[findex]).tolist()
        CSt_y=(arrival/cs_t[findex]).tolist()        
    elif findex=='TopAAE':
        SS_y=(ss[findex]).tolist()
        CM_y=(cm[findex]).tolist() 
        Ela_y=(ela[findex]).tolist()
        HG_y=(hg[findex]).tolist()
        CSs_y=(cs_s[findex]).tolist()
        CSt_y=(cs_t[findex]).tolist()        
        
    SS,=plt.plot(SSspace_usage,SS_y,'-g^',label='SS')   
    CM,=plt.plot(CMSspace_usage,CM_y,'-bo',label='CMS')          
    Ela,=plt.plot(Elaspace_usage,Ela_y,'-cs',label='Ela')     
    HG,=plt.plot(HGspace_usage,HG_y,'-mp',label='HG')
    Cyc_s,=plt.plot(CSSspace_usage,CSs_y,'-r*',label='Cyc-s')
    Cyc_t,=plt.plot(CSTspace_usage,CSt_y,'-kx',label='Cyc-t')    

    # Legend
    plt.legend(handles=[Cyc_s,Cyc_t,CM,SS,Ela,HG],loc='best')

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

field=['Precision','Execution','TopARE','TopAAE']
'''
field1='Memory'
field2='Precision'
field3='Execution'
field4='TopARE'
field5='TopAAE'
'''
# =============================read csv files=============================
path=r"result"
dataset='kosarak'
arrival=990002
# =============================read csv files=============================

# Space saving
ssfile='SS\\'+dataset+'\\SS_result.csv'
ss=pd.read_csv(os.path.join(path,ssfile))
SSspace_usage=ss['Memory'].tolist()

#CMS
cmfile='CM\\'+dataset+'\\CM_result.csv'
cm=pd.read_csv(os.path.join(path,cmfile))
CMSspace_usage=cm['Memory'].tolist()

# Elastic
elafile='Ela\\'+dataset+'\\Ela_result.csv'
ela=pd.read_csv(os.path.join(path,elafile))
Elaspace_usage=ela['Memory'].tolist()

# Heavy Guardian
hgfile='HG\\'+dataset+'\\HG_result.csv'
hg=pd.read_csv(os.path.join(path,hgfile))
HGspace_usage=hg['Memory'].tolist()

#Cyclic-sketch
cssfile='CS\\'+dataset+'\\CS_result.csv'
cs_s=pd.read_csv(os.path.join(path,cssfile))
CSSspace_usage=cs_s['Memory'].tolist()

#Cyclic-T
cstfile='CS\\'+dataset+'\\add_t\\CS_result.csv'
cs_t=pd.read_csv(os.path.join(path,cstfile))
CSTspace_usage=cs_t['Memory'].tolist()

for findex in field:
    plt.figure()
    plt.xticks([j for j in range(200,1100,100)])
    # Memory usage, 200kb~1MB
    plt.xlabel('Space Usage (KB)')
    if findex=='Precision':
        # initialize Figure
        plt.yticks([j for j in range(0,110,10)])
            # precision: 0~100   
        plt.ylabel('Precision (%), Top-1024')
        plt.ylim(0,100)
    elif findex=='Execution':
        # throughput
        min_time=min(min(ss[findex].tolist(),cm[findex].tolist(),
                 ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        max_throughput=int(arrival/min_time)
        plt.yticks([j for j in range(0,int(max_throughput*1.1),int(max_throughput*1.1/10))])
        plt.ylabel('Throughtput (item/s)')
        plt.ylim(0,int(max_throughput*1.1))
    elif findex=='TopARE':
        #plt.figure(3)
        max_are=max(max(ss[findex].tolist(),cm[findex].tolist(),
                        ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        #1.57
        max_are=np.log2(int(max_are+1)*1000)
        #log2(2000)
        plt.yticks([j for j in range(0,int(max_are)+1)])
        
        '''
        plt.yticks([j/100 for j in range(0,int(max_are+1)*100,int(max_are+1)*10)])
            # ARE: 0~2        
        plt.ylabel('Top-1024 ARE (%)')
        plt.ylim(0,int(max_are+1))        
        '''
        plt.ylabel('Top-1024 ARE (log2(x%*1000)')
        plt.ylim(0,int(max_are+1))

    elif findex=='TopAAE':
        #plt.figure(4)
        max_aae=max(max(ss[findex].tolist(),cm[findex].tolist(),
                        ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        max_aae=np.log2(max_aae)
        plt.yticks([j for j in range(0,int(max_aae)+1)])
        plt.ylabel('Top-1024 AAE in log 2')
        plt.ylim(0,int(max_aae)+1)

    # PLOT
    if findex=='Precision':
        SS_y=(ss[findex]*100).tolist()
        CM_y=(cm[findex]*100).tolist()
        Ela_y=(ela[findex]*100).tolist()
        HG_y=(hg[findex]*100).tolist()
        CSs_y=(cs_s[findex]*100).tolist()
        CSt_y=(cs_t[findex]*100).tolist()           
    elif findex=='TopARE':
        SS_y=(np.log2(ss[findex]*1000)).tolist()
        CM_y=(np.log2(cm[findex]*1000)).tolist() 
        Ela_y=(np.log2(ela[findex]*1000)).tolist()
        HG_y=(np.log2(hg[findex]*1000)).tolist()
        CSs_y=(np.log2(cs_s[findex]*1000)).tolist()
        CSt_y=(np.log2(cs_t[findex]*1000)).tolist()   
        '''
        SS_y=(ss[findex]).tolist()
        CM_y=(cm[findex]).tolist()
        Ela_y=(ela[findex]).tolist()
        HG_y=(hg[findex]).tolist()
        CSs_y=(cs_s[findex]).tolist()
        CSt_y=(cs_t[findex]).tolist()         
        
        '''
    elif findex=='Execution':
        # throughput
        SS_y=(arrival/ss[findex]).tolist()
        CM_y=(arrival/cm[findex]).tolist() 
        Ela_y=(arrival/ela[findex]).tolist()
        HG_y=(arrival/hg[findex]).tolist()
        CSs_y=(arrival/cs_s[findex]).tolist()
        CSt_y=(arrival/cs_t[findex]).tolist()        
    elif findex=='TopAAE':
        SS_y=(np.log2(ss[findex])).tolist()
        CM_y=(np.log2(cm[findex])).tolist() 
        Ela_y=(np.log2(ela[findex])).tolist()
        HG_y=(np.log2(hg[findex])).tolist()
        CSs_y=(np.log2(cs_s[findex])).tolist()
        CSt_y=(np.log2(cs_t[findex])).tolist() 
        '''
        SS_y=(ss[findex]).tolist()
        CM_y=(cm[findex]).tolist() 
        Ela_y=(ela[findex]).tolist()
        HG_y=(hg[findex]).tolist()
        CSs_y=(cs_s[findex]).tolist()
        CSt_y=(cs_t[findex]).tolist()          
        
        '''
    SS,=plt.plot(SSspace_usage,SS_y,'-g^',label='SS')   
    CM,=plt.plot(CMSspace_usage,CM_y,'-bo',label='CMS')          
    Ela,=plt.plot(Elaspace_usage,Ela_y,'-cs',label='Ela')     
    HG,=plt.plot(HGspace_usage,HG_y,'-mp',label='HG')
    Cyc_s,=plt.plot(CSSspace_usage,CSs_y,'-r*',label='Cyc-s')
    Cyc_t,=plt.plot(CSTspace_usage,CSt_y,'-kx',label='Cyc-t')    

    # Legend
    plt.legend(handles=[Cyc_s,Cyc_t,CM,SS,Ela,HG],loc='best')

# %% [markdown]
# # Caida srcip

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

field=['Precision','Execution','TopARE','TopAAE']
'''
field1='Memory'
field2='Precision'
field3='Execution'
field4='TopARE'
field5='TopAAE'
'''
path=r"result"
dataset='caida'
arrival=27553679
# =============================read csv files=============================

# Space saving
ssfile='SS\\'+dataset+'\\SS_result.csv'
ss=pd.read_csv(os.path.join(path,ssfile))
SSspace_usage=ss['Memory'].tolist()

#CMS
cmfile='CM\\'+dataset+'\\CM_result.csv'
cm=pd.read_csv(os.path.join(path,cmfile))
CMSspace_usage=cm['Memory'].tolist()

# Elastic
elafile='Ela\\'+dataset+'\\Ela_result.csv'
ela=pd.read_csv(os.path.join(path,elafile))
Elaspace_usage=ela['Memory'].tolist()

# Heavy Guardian
hgfile='HG\\'+dataset+'\\HG_result.csv'
hg=pd.read_csv(os.path.join(path,hgfile))
HGspace_usage=hg['Memory'].tolist()

#Cyclic-sketch
cssfile='CS\\'+dataset+'\\CS_result.csv'
cs_s=pd.read_csv(os.path.join(path,cssfile))
CSSspace_usage=cs_s['Memory'].tolist()

#Cyclic-T
cstfile='CS\\'+dataset+'\\add_t\\CS_result.csv'
cs_t=pd.read_csv(os.path.join(path,cstfile))
CSTspace_usage=cs_t['Memory'].tolist()

for findex in field:
    plt.figure()
    plt.xticks([j for j in range(200,1100,100)])
    # Memory usage, 200kb~1MB
    plt.xlabel('Space Usage (KB)')
    if findex=='Precision':
        # initialize Figure
        plt.yticks([j for j in range(0,110,10)])
            # precision: 0~100   
        plt.ylabel('Precision (%), Top-1024')
        plt.ylim(0,100)
    elif findex=='Execution':
        # throughput
        min_time=min(min(ss[findex].tolist(),cm[findex].tolist(),
                 ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        max_throughput=int(arrival/min_time)
        plt.yticks([j for j in range(0,int(max_throughput*1.1),int(max_throughput*1.1/10))])
        plt.ylabel('Throughtput (item/s)')
        plt.ylim(0,int(max_throughput*1.1))
    elif findex=='TopARE':
        #plt.figure(3)
        max_are=max(max(ss[findex].tolist(),cm[findex].tolist(),
                        ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        #1.57
        max_are=np.log2(int(max_are+1)*1000)
        #log2(2000)
        plt.yticks([j for j in range(0,int(max_are)+1)])
        
        '''
        plt.yticks([j/100 for j in range(0,int(max_are+1)*100,int(max_are+1)*10)])
            # ARE: 0~2        
        plt.ylabel('Top-1024 ARE (%)')
        plt.ylim(0,int(max_are+1))        
        '''
        plt.ylabel('Top-1024 ARE (log2(x%*1000)')
        plt.ylim(0,int(max_are+1))

    elif findex=='TopAAE':
        #plt.figure(4)
        max_aae=max(max(ss[findex].tolist(),cm[findex].tolist(),
                        ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        max_aae=np.log2(max_aae)
        plt.yticks([j for j in range(0,int(max_aae)+1)])
        plt.ylabel('Top-1024 AAE in log 2')
        plt.ylim(0,int(max_aae)+1)

    # PLOT
    if findex=='Precision':
        SS_y=(ss[findex]*100).tolist()
        CM_y=(cm[findex]*100).tolist()
        Ela_y=(ela[findex]*100).tolist()
        HG_y=(hg[findex]*100).tolist()
        CSs_y=(cs_s[findex]*100).tolist()
        CSt_y=(cs_t[findex]*100).tolist()           
    elif findex=='TopARE':
        SS_y=(np.log2(ss[findex]*1000)).tolist()
        CM_y=(np.log2(cm[findex]*1000)).tolist() 
        Ela_y=(np.log2(ela[findex]*1000)).tolist()
        HG_y=(np.log2(hg[findex]*1000)).tolist()
        CSs_y=(np.log2(cs_s[findex]*1000)).tolist()
        CSt_y=(np.log2(cs_t[findex]*1000)).tolist()   
        '''
        SS_y=(ss[findex]).tolist()
        CM_y=(cm[findex]).tolist()
        Ela_y=(ela[findex]).tolist()
        HG_y=(hg[findex]).tolist()
        CSs_y=(cs_s[findex]).tolist()
        CSt_y=(cs_t[findex]).tolist()         
        
        '''
    elif findex=='Execution':
        # throughput
        SS_y=(arrival/ss[findex]).tolist()
        CM_y=(arrival/cm[findex]).tolist() 
        Ela_y=(arrival/ela[findex]).tolist()
        HG_y=(arrival/hg[findex]).tolist()
        CSs_y=(arrival/cs_s[findex]).tolist()
        CSt_y=(arrival/cs_t[findex]).tolist()        
    elif findex=='TopAAE':
        SS_y=(np.log2(ss[findex])).tolist()
        CM_y=(np.log2(cm[findex])).tolist() 
        Ela_y=(np.log2(ela[findex])).tolist()
        HG_y=(np.log2(hg[findex])).tolist()
        CSs_y=(np.log2(cs_s[findex])).tolist()
        CSt_y=(np.log2(cs_t[findex])).tolist() 
        '''
        SS_y=(ss[findex]).tolist()
        CM_y=(cm[findex]).tolist() 
        Ela_y=(ela[findex]).tolist()
        HG_y=(hg[findex]).tolist()
        CSs_y=(cs_s[findex]).tolist()
        CSt_y=(cs_t[findex]).tolist()          
        
        '''
    SS,=plt.plot(SSspace_usage,SS_y,'-g^',label='SS')   
    CM,=plt.plot(CMSspace_usage,CM_y,'-bo',label='CMS')          
    Ela,=plt.plot(Elaspace_usage,Ela_y,'-cs',label='Ela')     
    HG,=plt.plot(HGspace_usage,HG_y,'-mp',label='HG')
    Cyc_s,=plt.plot(CSSspace_usage,CSs_y,'-r*',label='Cyc-s')
    Cyc_t,=plt.plot(CSTspace_usage,CSt_y,'-kx',label='Cyc-t')    

    # Legend
    plt.legend(handles=[Cyc_s,Cyc_t,CM,SS,Ela,HG],loc='best')

# %% [markdown]
# # Webdocs (1/20)

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

field=['Precision','Execution','TopARE','TopAAE']
'''
field1='Memory'
field2='Precision'
field3='Execution'
field4='TopARE'
field5='TopAAE'
'''
path=r"result"
dataset='webdocs'
arrival=15487894

# =============================read csv files=============================

# Space saving
ssfile='SS\\'+dataset+'\\SS_result.csv'
ss=pd.read_csv(os.path.join(path,ssfile))
SSspace_usage=ss['Memory'].tolist()

#CMS
cmfile='CM\\'+dataset+'\\CM_result.csv'
cm=pd.read_csv(os.path.join(path,cmfile))
CMSspace_usage=cm['Memory'].tolist()

# Elastic
elafile='Ela\\'+dataset+'\\Ela_result.csv'
ela=pd.read_csv(os.path.join(path,elafile))
Elaspace_usage=ela['Memory'].tolist()

# Heavy Guardian
hgfile='HG\\'+dataset+'\\HG_result.csv'
hg=pd.read_csv(os.path.join(path,hgfile))
HGspace_usage=hg['Memory'].tolist()

#Cyclic-sketch
cssfile='CS\\'+dataset+'\\CS_result.csv'
cs_s=pd.read_csv(os.path.join(path,cssfile))
CSSspace_usage=cs_s['Memory'].tolist()

#Cyclic-T
cstfile='CS\\'+dataset+'\\add_t\\CS_result.csv'
cs_t=pd.read_csv(os.path.join(path,cstfile))
CSTspace_usage=cs_t['Memory'].tolist()

for findex in field:
    plt.figure()
    plt.xticks([j for j in range(200,1100,100)])
    # Memory usage, 200kb~1MB
    plt.xlabel('Space Usage (KB)')
    if findex=='Precision':
        # initialize Figure
        plt.yticks([j for j in range(0,110,10)])
            # precision: 0~100   
        plt.ylabel('Precision (%), Top-1024')
        plt.ylim(0,100)
    elif findex=='Execution':
        # throughput
        min_time=min(min(ss[findex].tolist()),min(cm[findex].tolist()),
                     min(ela[findex].tolist()),min(hg[findex].tolist()),min(cs_s[findex].tolist()),min(cs_t[findex].tolist()))
        max_throughput=int(arrival/min_time)
        plt.yticks([j for j in range(0,int(max_throughput*1.1),int(max_throughput*1.1/10))])
        plt.ylabel('Throughtput (item/s)')
        plt.ylim(0,int(max_throughput*1.1))
    elif findex=='TopARE':
        #plt.figure(3)
        max_are=max(max(ss[findex].tolist(),cm[findex].tolist(),
                        ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        plt.yticks([j for j in range(0,int(max_are+1)*100,int(max_are+1)*10)])
            # ARE: 0~2
        plt.ylabel('Top-1024 ARE (%)')
        plt.ylim(0,int(max_are*110))
    elif findex=='TopAAE':
        #plt.figure(4)
        max_aae=max(max(ss[findex].tolist(),cm[findex].tolist(),
                        ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        plt.yticks([j/10 for j in range(0,int(max_aae))])
        plt.yticks([j for j in range(0,int(max_aae+1),int(max_aae/10))]) 
        plt.ylabel('Top-1024 AAE')
        plt.ylim(0,int(max_aae*1.1))

    # PLOT
    if findex=='Precision' or findex=='TopARE':
        SS_y=(ss[findex]*100).tolist()
        CM_y=(cm[findex]*100).tolist()
        Ela_y=(ela[findex]*100).tolist()
        HG_y=(hg[findex]*100).tolist()
        CSs_y=(cs_s[findex]*100).tolist()
        CSt_y=(cs_t[findex]*100).tolist()        
    elif findex=='Execution':
        # throughput
        SS_y=(arrival/ss[findex]).tolist()
        CM_y=(arrival/cm[findex]).tolist() 
        Ela_y=(arrival/ela[findex]).tolist()
        HG_y=(arrival/hg[findex]).tolist()
        CSs_y=(arrival/cs_s[findex]).tolist()
        CSt_y=(arrival/cs_t[findex]).tolist()        
    elif findex=='TopAAE':
        SS_y=(ss[findex]).tolist()
        CM_y=(cm[findex]).tolist() 
        Ela_y=(ela[findex]).tolist()
        HG_y=(hg[findex]).tolist()
        CSs_y=(cs_s[findex]).tolist()
        CSt_y=(cs_t[findex]).tolist()        
        
    SS,=plt.plot(SSspace_usage,SS_y,'-g^',label='SS')   
    CM,=plt.plot(CMSspace_usage,CM_y,'-bo',label='CMS')          
    Ela,=plt.plot(Elaspace_usage,Ela_y,'-cs',label='Ela')     
    HG,=plt.plot(HGspace_usage,HG_y,'-mp',label='HG')
    Cyc_s,=plt.plot(CSSspace_usage,CSs_y,'-r*',label='Cyc-s')
    Cyc_t,=plt.plot(CSTspace_usage,CSt_y,'-kx',label='Cyc-t')    

    # Legend
    plt.legend(handles=[Cyc_s,Cyc_t,CM,SS,Ela,HG],loc='best')

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

field=['Precision','Execution','TopARE','TopAAE']
'''
field1='Memory'
field2='Precision'
field3='Execution'
field4='TopARE'
field5='TopAAE'
'''
path=r"result"
dataset='webdocs'
arrival=15487894

# =============================read csv files=============================

# Space saving
ssfile='SS\\'+dataset+'\\SS_result.csv'
ss=pd.read_csv(os.path.join(path,ssfile))
SSspace_usage=ss['Memory'].tolist()

#CMS
cmfile='CM\\'+dataset+'\\CM_result.csv'
cm=pd.read_csv(os.path.join(path,cmfile))
CMSspace_usage=cm['Memory'].tolist()

# Elastic
elafile='Ela\\'+dataset+'\\Ela_result.csv'
ela=pd.read_csv(os.path.join(path,elafile))
Elaspace_usage=ela['Memory'].tolist()

# Heavy Guardian
hgfile='HG\\'+dataset+'\\HG_result.csv'
hg=pd.read_csv(os.path.join(path,hgfile))
HGspace_usage=hg['Memory'].tolist()

#Cyclic-sketch
cssfile='CS\\'+dataset+'\\CS_result.csv'
cs_s=pd.read_csv(os.path.join(path,cssfile))
CSSspace_usage=cs_s['Memory'].tolist()

#Cyclic-T
cstfile='CS\\'+dataset+'\\add_t\\CS_result.csv'
cs_t=pd.read_csv(os.path.join(path,cstfile))
CSTspace_usage=cs_t['Memory'].tolist()

for findex in field:
    plt.figure()
    plt.xticks([j for j in range(200,1100,100)])
    # Memory usage, 200kb~1MB
    plt.xlabel('Space Usage (KB)')
    if findex=='Precision':
        # initialize Figure
        plt.yticks([j for j in range(0,110,10)])
            # precision: 0~100   
        plt.ylabel('Precision (%), Top-1024')
        plt.ylim(0,100)
    elif findex=='Execution':
        # throughput
        min_time=min(min(ss[findex].tolist(),cm[findex].tolist(),
                 ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        max_throughput=int(arrival/min_time)
        plt.yticks([j for j in range(0,int(max_throughput*1.1),int(max_throughput*1.1/10))])
        plt.ylabel('Throughtput (item/s)')
        plt.ylim(0,int(max_throughput*1.1))
    elif findex=='TopARE':
        #plt.figure(3)
        max_are=max(max(ss[findex].tolist(),cm[findex].tolist(),
                        ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        #1.57
        max_are=np.log2(int(max_are+1)*10000)
        #log2(2000)
        plt.yticks([j for j in range(1,int(max_are)+1)])
        
        '''
        plt.yticks([j/100 for j in range(0,int(max_are+1)*100,int(max_are+1)*10)])
            # ARE: 0~2        
        plt.ylabel('Top-1024 ARE (%)')
        plt.ylim(0,int(max_are+1))        
        '''
        plt.ylabel('Top-1024 ARE (log2(x%*1000)')
        plt.ylim(0,int(max_are+1))

    elif findex=='TopAAE':
        #plt.figure(4)
        max_aae=max(max(ss[findex].tolist(),cm[findex].tolist(),
                        ela[findex].tolist(),hg[findex].tolist(),cs_s[findex].tolist(),cs_t[findex].tolist()))
        max_aae=np.log2(max_aae)
        plt.yticks([j for j in range(0,int(max_aae)+1)])
        plt.ylabel('Top-1024 AAE in log 2')
        plt.ylim(0,int(max_aae)+1)

    # PLOT
    if findex=='Precision':
        SS_y=(ss[findex]*100).tolist()
        CM_y=(cm[findex]*100).tolist()
        Ela_y=(ela[findex]*100).tolist()
        HG_y=(hg[findex]*100).tolist()
        CSs_y=(cs_s[findex]*100).tolist()
        CSt_y=(cs_t[findex]*100).tolist()           
    elif findex=='TopARE':
        SS_y=(np.log2(ss[findex]*10000)).tolist()
        CM_y=(np.log2(cm[findex]*10000)).tolist() 
        Ela_y=(np.log2(ela[findex]*10000)).tolist()
        HG_y=(np.log2(hg[findex]*10000)).tolist()
        CSs_y=(np.log2(cs_s[findex]*10000)).tolist()
        CSt_y=(np.log2(cs_t[findex]*10000)).tolist()   
        '''
        SS_y=(ss[findex]).tolist()
        CM_y=(cm[findex]).tolist()
        Ela_y=(ela[findex]).tolist()
        HG_y=(hg[findex]).tolist()
        CSs_y=(cs_s[findex]).tolist()
        CSt_y=(cs_t[findex]).tolist()         
        
        '''
    elif findex=='Execution':
        # throughput
        SS_y=(arrival/ss[findex]).tolist()
        CM_y=(arrival/cm[findex]).tolist() 
        Ela_y=(arrival/ela[findex]).tolist()
        HG_y=(arrival/hg[findex]).tolist()
        CSs_y=(arrival/cs_s[findex]).tolist()
        CSt_y=(arrival/cs_t[findex]).tolist()        
    elif findex=='TopAAE':
        SS_y=(np.log2(ss[findex])).tolist()
        CM_y=(np.log2(cm[findex])).tolist() 
        Ela_y=(np.log2(ela[findex])).tolist()
        HG_y=(np.log2(hg[findex])).tolist()
        CSs_y=(np.log2(cs_s[findex])).tolist()
        CSt_y=(np.log2(cs_t[findex])).tolist() 
        '''
        SS_y=(ss[findex]).tolist()
        CM_y=(cm[findex]).tolist() 
        Ela_y=(ela[findex]).tolist()
        HG_y=(hg[findex]).tolist()
        CSs_y=(cs_s[findex]).tolist()
        CSt_y=(cs_t[findex]).tolist()          
        
        '''
    SS,=plt.plot(SSspace_usage,SS_y,'-g^',label='SS')   
    CM,=plt.plot(CMSspace_usage,CM_y,'-bo',label='CMS')          
    Ela,=plt.plot(Elaspace_usage,Ela_y,'-cs',label='Ela')     
    HG,=plt.plot(HGspace_usage,HG_y,'-mp',label='HG')
    Cyc_s,=plt.plot(CSSspace_usage,CSs_y,'-r*',label='Cyc-s')
    Cyc_t,=plt.plot(CSTspace_usage,CSt_y,'-kx',label='Cyc-t')    

    # Legend
    plt.legend(handles=[Cyc_s,Cyc_t,CM,SS,Ela,HG],loc='best')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
