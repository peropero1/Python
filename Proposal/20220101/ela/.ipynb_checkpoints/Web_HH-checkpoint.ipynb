# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=512
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*512
# Execution time: 227.040 seconds.
# Top_list with 123960 bytes.
# Sketch with 16960 bytes.
# Total size 137.6171875 kbytes,
# Find:563
# Top_ARE: 0.4255
# Top_AAE: 2525.3481
# Estimate time:  0.438 seconds.
#
# For copy:
# Execution time: 227.040 seconds.
# Top-825,CMS:8*512
# Top_list with 123960 bytes.
# Sketch with 16960 bytes.
# Total size 137.6171875 kbytes,
# Find 0.545 of Heavy Hitters
# Top_ARE: 0.4255
# Top_AAE: 2525.3481
# Estimate time:  0.438 seconds.
# seed:[3775924291, 3625935437, 3348007679, 2901800501, 2301629111, 4244705033, 2624508661, 3800571409]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'

# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=2048
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*2048
# Execution time: 229.127 seconds.
# Top_list with 123960 bytes.
# Sketch with 66112 bytes.
# Total size 185.6171875 kbytes,
# Find:563
# Top_ARE: 0.0724
# Top_AAE: 394.8064
# Estimate time:  0.430 seconds.
#
# For copy:
# Execution time: 229.127 seconds.
# Top-675,CMS:8*2048
# Top_list with 123960 bytes.
# Sketch with 66112 bytes.
# Total size 185.6171875 kbytes,
# Find 0.545 of Heavy Hitters
# Top_ARE: 0.0724
# Top_AAE: 394.8064
# Estimate time:  0.430 seconds.
# seed:[3566260991, 3394972429, 2903655187, 2416210541, 3940967011, 2770554851, 3315171239, 4061262319]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'

# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=5500
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*5500
# Execution time: 238.584 seconds.
# Top_list with 123960 bytes.
# Sketch with 176576 bytes.
# Total size 293.4921875 kbytes,
# Find:585
# Top_ARE: 0.0156
# Top_AAE: 89.7214
# Estimate time:  0.430 seconds.
#
# For copy:
# Execution time: 238.584 seconds.
# Top-600,CMS:8*5500
# Top_list with 123960 bytes.
# Sketch with 176576 bytes.
# Total size 293.4921875 kbytes,
# Find 0.566 of Heavy Hitters
# Top_ARE: 0.0156
# Top_AAE: 89.7214
# Estimate time:  0.430 seconds.
# seed:[3588247027, 3293360243, 2257893529, 3351900473, 2343787081, 3908033399, 2755641599, 2965505233]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'

# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=8900
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*8900
# Execution time: 263.945 seconds.
# Top_list with 123960 bytes.
# Sketch with 285376 bytes.
# Total size 399.7421875 kbytes,
# Find:569
# Top_ARE: 0.0088
# Top_AAE: 45.9930
# Estimate time:  0.484 seconds.
#
# For copy:
# Execution time: 263.945 seconds.
# Top-577,CMS:8*8900
# Top_list with 123960 bytes.
# Sketch with 285376 bytes.
# Total size 399.7421875 kbytes,
# Find 0.551 of Heavy Hitters
# Top_ARE: 0.0088
# Top_AAE: 45.9930
# Estimate time:  0.484 seconds.
# seed:[3839808187, 3577492111, 3573755531, 2343706759, 3394145707, 3657757427, 3638403623, 4109302733]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'

# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=12000
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*12000
# Execution time: 229.020 seconds.
# Top_list with 123960 bytes.
# Sketch with 384576 bytes.
# Total size 496.6171875 kbytes,
# Find:575
# Top_ARE: 0.0054
# Top_AAE: 29.6643
# Estimate time:  0.411 seconds.
#
# For copy:
# Execution time: 229.020 seconds.
# Top-582,CMS:8*12000
# Top_list with 123960 bytes.
# Sketch with 384576 bytes.
# Total size 496.6171875 kbytes,
# Find 0.557 of Heavy Hitters
# Top_ARE: 0.0054
# Top_AAE: 29.6643
# Estimate time:  0.411 seconds.
# seed:[4267665971, 2833972327, 4255617911, 3372875353, 2838409907, 3180201527, 2448673673, 2667479657]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'

# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=15100
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*15100
# Execution time: 216.025 seconds.
# Top_list with 123960 bytes.
# Sketch with 483776 bytes.
# Total size 593.4921875 kbytes,
# Find:595
# Top_ARE: 0.0038
# Top_AAE: 21.3395
# Estimate time:  0.446 seconds.
#
# For copy:
# Execution time: 216.025 seconds.
# Top-596,CMS:8*15100
# Top_list with 123960 bytes.
# Sketch with 483776 bytes.
# Total size 593.4921875 kbytes,
# Find 0.576 of Heavy Hitters
# Top_ARE: 0.0038
# Top_AAE: 21.3395
# Estimate time:  0.446 seconds.
# seed:[3113096927, 2559533857, 3349512233, 3189030301, 3760294861, 3121248167, 2172530669, 2315501809]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'

# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=15200
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*15200
# Execution time: 219.061 seconds.
# Top_list with 123960 bytes.
# Sketch with 486976 bytes.
# Total size 596.6171875 kbytes,
# Find:583
# Top_ARE: 0.0032
# Top_AAE: 17.6226
# Estimate time:  0.492 seconds.
#
# For copy:
# Execution time: 219.061 seconds.
# Top-586,CMS:8*15200
# Top_list with 123960 bytes.
# Sketch with 486976 bytes.
# Total size 596.6171875 kbytes,
# Find 0.564 of Heavy Hitters
# Top_ARE: 0.0032
# Top_AAE: 17.6226
# Estimate time:  0.492 seconds.
# seed:[4134314479, 2833478023, 2866387939, 2687676581, 3204867383, 2427241169, 2228262467, 2821884839]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'

# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=18400
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*18400
# Execution time: 230.998 seconds.
# Top_list with 123960 bytes.
# Sketch with 589376 bytes.
# Total size 696.6171875 kbytes,
# Find:589
# Top_ARE: 0.0027
# Top_AAE: 15.6978
# Estimate time:  0.468 seconds.
#
# For copy:
# Execution time: 230.998 seconds.
# Top-591,CMS:8*18400
# Top_list with 123960 bytes.
# Sketch with 589376 bytes.
# Total size 696.6171875 kbytes,
# Find 0.570 of Heavy Hitters
# Top_ARE: 0.0027
# Top_AAE: 15.6978
# Estimate time:  0.468 seconds.
# seed:[3671196227, 4221364097, 3147846749, 3199713091, 2801051321, 2593066961, 3288947303, 2715071867]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'

# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=21600
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*21600
# Execution time: 228.591 seconds.
# Top_list with 123960 bytes.
# Sketch with 691776 bytes.
# Total size 796.6171875 kbytes,
# Find:571
# Top_ARE: 0.0025
# Top_AAE: 13.6795
# Estimate time:  0.431 seconds.
#
# For copy:
# Execution time: 228.591 seconds.
# Top-572,CMS:8*21600
# Top_list with 123960 bytes.
# Sketch with 691776 bytes.
# Total size 796.6171875 kbytes,
# Find 0.553 of Heavy Hitters
# Top_ARE: 0.0025
# Top_AAE: 13.6795
# Estimate time:  0.431 seconds.
# seed:[3059460169, 3969477199, 3820878709, 3564512527, 4055094619, 3708116681, 2483969987, 4075882009]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'

# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=24800
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*24800
# Execution time: 237.510 seconds.
# Top_list with 123960 bytes.
# Sketch with 794176 bytes.
# Total size 896.6171875 kbytes,
# Find:585
# Top_ARE: 0.0015
# Top_AAE: 8.6701
# Estimate time:  0.429 seconds.
#
# For copy:
# Execution time: 237.510 seconds.
# Top-587,CMS:8*24800
# Top_list with 123960 bytes.
# Sketch with 794176 bytes.
# Total size 896.6171875 kbytes,
# Find 0.566 of Heavy Hitters
# Top_ARE: 0.0015
# Top_AAE: 8.6701
# Estimate time:  0.429 seconds.
# seed:[3838216831, 2425465319, 3297320141, 4283936263, 3604084079, 2926503817, 3960542413, 3298286237]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'

# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=28000
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*28000
# Execution time: 257.146 seconds.
# Top_list with 123960 bytes.
# Sketch with 896576 bytes.
# Total size 996.6171875 kbytes,
# Find:562
# Top_ARE: 0.0015
# Top_AAE: 8.3167
# Estimate time:  0.449 seconds.
#
# For copy:
# Execution time: 257.146 seconds.
# Top-564,CMS:8*28000
# Top_list with 123960 bytes.
# Sketch with 896576 bytes.
# Total size 996.6171875 kbytes,
# Find 0.544 of Heavy Hitters
# Top_ARE: 0.0015
# Top_AAE: 8.3167
# Estimate time:  0.449 seconds.
# seed:[2953958827, 3310190467, 3891386633, 2542277183, 2771287229, 2210906953, 2426771681, 4151245717]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'

# %%
import sys
sys.path.append("..")

import Tools.Config as TC
import Tools.Func as TF
import Node.DS as DS
import numpy as np
import time
import os
import hyperloglog
from pympler import asizeof
import re

from cms.CountMinSketch import CountMinSketch

dataset='webdocs'
total_count=0
heavy_ratio=1/5000
# =============================dataset path and file=============================
filepath='..\..\dataset\webdocs'
pattern='out_.*'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='webdocs_00_ground_truth.csv'        
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# =============================Initialize=============================
threshold=16
w=2400
d=8
size=1033
topk=1033
TC.Set_default(w,d,size,topk)
cms=CountMinSketch(TC.width,TC.depth)    
Top=[None]*TC.size
total_count=0


# =============================Stream processing=============================
item_count=True
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'r') as file:
        while True:
            e=file.readline().strip('\n')
            if not e:
                print("EOF")
                break
            else:     
                #item_count-=1
                total_count+=1
                index=TF.positionES(DS.Tail(e,1),1)
                    # one hash only              
                #print("index:{}".format(index))
                if Top[index]==None:
                    # bucket is empty
                    Top[index]=DS.esNode(e)
                else:
                    if Top[index].ID ==e:
                        # hit in Top
                        Top[index].vote_pos+=1
                    elif Top[index].ID !=e:
                        # e ollisions with e' at Top
                        Top[index].vote_neg+=1
                        vote_threshold=Top[index].vote_neg/Top[index].vote_pos
                        if vote_threshold<threshold:
                            # less than threshold: send (e,1) to CMS 
                            cms.Add_CMS(DS.Tail(e,1))
                        else:
                            # larger than threshold, evict e' to CMS and set (e,1,T,1)
                            cms.Add_CMS(DS.Tail(Top[index].ID,Top[index].vote_pos))
                            #cms.Add_CMS(e,Top[index].vote_pos)
                            Top[index]=DS.esNode(e,1,True,1)
end=time.time()

# =============================Print and Plot result=============================
#Topli=list(sorted(Top, key=lambda item: item.vote_pos,reverse=True))
    # sorted
print("Top-{},Sketch:{}*{}".format(size,d,w))
print("Execution time:{:8.3f} seconds.".format(end-start))

# Memory usage
id_mem=0
flag_mem=0
votep_mem=0
voten_mem=0
for item in Top:
    id_mem+=asizeof.asizeof(item.ID)
    flag_mem+=asizeof.asizeof(item.vote_pos)
    votep_mem+=asizeof.asizeof(item.vote_neg)
    voten_mem=0    

heavy_mem=id_mem+flag_mem+votep_mem+voten_mem

sk0=heavy_mem
sk1=asizeof.asizeof(cms)
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))

# =============================heavy hitter from result=============================
HH=dict()
for item in Top:
    temp_count=TF.esQuery(item.ID,Top,cms)
    if temp_count>int(total_count*heavy_ratio):
        HH[item.ID]=temp_count

HH=dict(sorted(HH.items(), key=lambda item: item[1],reverse=True))

# =============================heavy hitter from ground truth=============================
# read ground truth
import pandas as pd
df=pd.read_csv(gr_path)
df['Element']=df['Element'].astype('str')
temp=df[df['Count']>=int(total_count*heavy_ratio)]

gr_set=set(temp['Element'])
result=set(HH.keys())
tp_set=gr_set & result

# Count ARE/AAE
startx=time.time()
top_are,top_aae=TF.Get_ARE_AAE(gr_path,HH,tp_set)
print("Find:{}".format(len(tp_set)))
endx=time.time()
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 

print("\nFor copy:")
print("Execution time:{:8.3f} seconds.".format(end-start))
print("Top-{},CMS:{}*{}".format(len(HH),TC.depth,TC.width))
print("Top_list with {} bytes.".format(sk0))
print("Sketch with {} bytes.".format(sk1))
print("Total size {} kbytes, ".format((sk0+sk1)/1024))
print("Find {:.3f} of Heavy Hitters".format(len(tp_set)/len(gr_set)))
print("Top_ARE: {:6.4f}".format(top_are))
print("Top_AAE: {:6.4f}".format(top_aae))
print("Estimate time:{:7.3f} seconds.".format(endx-startx)) 
print("seed:{}".format(TC.seed))

TF.Plot_hh_compare(temp,HH,"Elastic Sketch")

'''
# =============================result to csv=============================
import pandas as pd
path="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)
# HH to csv
filename='Ela_HH_'+str(len(gr_set))+'.csv'
topdf=pd.DataFrame(HH.items(),columns=['Element','Count'])
topdf.to_csv(os.path.join(path,filename),index=False)

'''
# Out:
# EOF
# Top-1033,Sketch:8*2400
# Execution time: 211.968 seconds.
# Top_list with 123960 bytes.
# Sketch with 77376 bytes.
# Total size 196.6171875 kbytes,
# Find:563
# Top_ARE: 0.0556
# Top_AAE: 316.9503
# Estimate time:  0.405 seconds.
#
# For copy:
# Execution time: 211.968 seconds.
# Top-637,CMS:8*2400
# Top_list with 123960 bytes.
# Sketch with 77376 bytes.
# Total size 196.6171875 kbytes,
# Find 0.545 of Heavy Hitters
# Top_ARE: 0.0556
# Top_AAE: 316.9503
# Estimate time:  0.405 seconds.
# seed:[4221418639, 2472285883, 2332525801, 4019023121, 2537028899, 3042629237, 2560526921, 3204196049]
# '\n# =============================result to csv=============================\nimport pandas as pd\npath="..\\result\\Ela\\"+dataset+"\\HH\\"+str(TC.depth)+"_"+str(TC.width)\n# HH to csv\nfilename=\'Ela_HH_\'+str(len(gr_set))+\'.csv\'\ntopdf=pd.DataFrame(HH.items(),columns=[\'Element\',\'Count\'])\ntopdf.to_csv(os.path.join(path,filename),index=False)\n\n'
