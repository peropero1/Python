# %% [markdown]
# ## Ground Truth

# %%
# count distinct element frequency
import pandas as pd
import os 
import re

datapath=r"X:\NTU\ML-sketch\dataset\caida2016"
#filename='caida_0.dat'
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(datapath)))

num_line=0
count=0
itemdict={}

for item in filelist:
    src_data=os.path.join(datapath,item)
    with open(src_data, 'rb') as file:
        while True:
            line=str(file.read(13))
            if len(line)<13:
                break
            else:
                num_line+=1
                if line not in itemdict:
                    itemdict[line]=1
                else:
                    itemdict[line]+=1

df=pd.DataFrame(list(itemdict.items()),columns=['Element', 'Count'])
df=df.reset_index(drop=True)
df=df.sort_values('Count',ascending=False)

print("Distinct element: {}".format(len(itemdict)))
print("Number of incomming element: {}".format(num_line))
print(df.head(20))

grname="caida_ground_truth.csv"
df.to_csv(os.path.join(datapath,grname),index=False)
# Out:
# Distinct element: 1030031
# Number of incomming element: 27553679
#                                                   Element   Count
# 58            b'\xd2\x1d9\xfa\x00P\x0f\x13I\x9a\xf89\x06'  168765
# 6877       b'\xb7\xf6h\xd0\xc1\x8b+\xfc\xe1\x08\x00P\x06'  106016
# 274        b'E.\x1c)\xa4\xb2\x89\xb6\x06\xba\xd2\xad\x06'   96390
# 706                 b'V+x\xe8\x00Po\xcd\xe4\xde\xccw\x06'   85947
# 1227         b'\x01l|\xff\x8f\r\x01l\xc5\xc8\x01\xbb\x06'   78816
# 2050       b'\x01l$\xce\x0e\xad\x01l\xc5\xc6\x01\xbb\x06'   77412
# 216810        b'\x01l$\x98\xb0~\x01l\xc5\xc6\x01\xbb\x06'   67938
# 1161       b'\x01l|\xec\xcc\x1b\x01l\xc5\xc8\x01\xbb\x06'   58305
# 359     b'\x90\xbcT\x17\xc3\xba\x01 \x8a\x0c\x01\xbb\x06'   55356
# 1075    b'\x05\x06\x1b\xd0\xcb\xa4h\xef\x88\xf3\x1f\x9...   46031
# 285374           b'\xc9W\xf7#\x00P\x01-3\xc6\xbe\xeb\x06'   44121
# 1198       b'e\x86\xc2d\xfd\x84h\xef\x88\x96\x1f\x90\x11'   42023
# 79084   b'\x1d\xb9\x7f\xd3_\x85\xdd\xc3\xe7&\x00\x14\x06'   39025
# 53494         b'+?\x82\xd6\xafok\x1f\x9a\xaf\x01\xbb\x06'   38425
# 2965          b'E\x0c\xd5\xf7\xd7(\xdd.\xdc\xec\x00P\x06'   38005
# 15         b'I\x95\xba\xfb\xcc\xcco\xcd\xe4r\x1f\x90\x11'   34607
# 28         b'\x91\xdc\xd6\x91\x00Pf\x03\xc7\xad\xd2&\x06'   34260
# 32      b'\xd0\xfd=\x0e\xad\x92\xdd\xc3\xe7#\x00\x14\x06'   33001
# 64                  b'p\xe01\xdd\xd2P\x01`\xe64\x00P\x06'   32893
# 529           b'\x05?\xc10\xf6mo\xcd\xe4\xd7\x1f\x90\x11'   32472

# %% [markdown]
# ## full version, counting and estimate frequency for all arriving elements

# %%
# count-min sketch webdocs, top-1024, cms 1024*4, full read
import sys
import os
import time
from probables import (CountMinSketch)
import pandas as pd

def find(e,element_list):
    # return index of e in element_list
    try:
        index=[ele[0] for ele in element_list].index(e)
    except:
        index=-99
    return index

#==================== main =============================
Top=[]
w=1024
d=8
size=256
# item_count=100
cms = CountMinSketch(width=w, depth=d)

# filepath="..\\dataset\\"
# filename='caida_0.dat'
# src_data=os.path.join(filepath,filename)
datapath=r"X:\NTU\ML-sketch\dataset\caida2016"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(datapath)))

start=time.time()
# if os.path.exists(os.path.join(datapath,datali)):
for datafile in filelist:
    src_data=os.path.join(datapath,datafile)
    if os.path.exists(src_data):
        with open(src_data,'rb') as file:
            while True:
                line=str(file.read(13))
                if len(line)<13:
                    print('EOF')
                    break
                else:
                    #item_count-=1
                    #print("read {}th element: {}".format(item_count,line[:10]))
                    cms.add(line)
                    count=cms.check(line)
                    index=find(line,Top)
                    if index >=0:
                        Top[index][1]=count
                    else:
                        # e not in Top
                        if len(Top)<size:
                            # Top is not full
                            Top.append([line,count])
                            index=len(Top)-1
                            #print("id of iindex:{}".format(id(index)))
                        else:
                            # Top if full
                            if count< Top[-1][1]:
                                pass
                            else:
                                Top.append([line,count])
                                Top=sorted(Top,key = lambda Top:Top[1],reverse=True)
                                Top.pop()
                                #rint("Top after pop:{}\n".format(Top))
                    Top=sorted(Top,key = lambda Top:Top[1],reverse=True)
                    #rint("Top after insert:{}\n".format(Top))
        # print(Top[:20],len(Top))
    else:
        print("file doesn't exist")
end=time.time()
print("Total memory {3} bytes :Top-{0} with size {1} bytes+ CMS with size {2} bytes.".format(len(Top),sys.getsizeof(Top),
      sys.getsizeof(cms._bins),sys.getsizeof(cms._bins)+sys.getsizeof(Top)))
print("Execution time:{:8.3f} seconds.".format(end-start))
#====================Top to csv=============================
templi=[[i[0],i[1]] for i in Top]

df=pd.DataFrame(templi,columns=['ID', 'Count'])
name="CMS_caida0_Top-"+str(size)+'_'+str(d)+'_'+str(w)+'.csv'
df.to_csv(os.path.join('result',name),index=False)

# ====================precision====================
# path="..\\Caida0\\"
gr_path='..\\dataset\\caida'
gr_file_name='caida_ground_truth.csv'
grtruth=pd.read_csv(os.path.join(gr_path,gr_file_name))
    # compare with Top-k and groundtruth[k]
CMS_result=pd.read_csv(os.path.join('result',name))

# precision
gt_set=set(grtruth['Element'][:size])
cms_set=set(CMS_result['ID'])
precision=len(gt_set & cms_set)/len(cms_set)
    # &: set 交集運算
    # precision= tp/tp+fp=tp/size
print("Precision: {}".format(precision))


# ====================ARE/AAE for all====================
gt_dict=dict(grtruth.values.tolist())
top_are=0
top_aae=0
all_are=0
all_aae=0

read=0
startx=time.time()

for item in grtruth['Element']:
    count=cms.check(str(item))    
    if read<size:
        top_are+=abs(count-gt_dict[item])/gt_dict[item]
        top_aae+=abs(count-gt_dict[item])
        read+=1
    all_are+=abs(count-gt_dict[item])/gt_dict[item]
    all_aae+=abs(count-gt_dict[item])
endx=time.time()
distinct=len(gt_dict)
top_are/=size
all_are/=distinct
all_aae/=distinct 
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.3f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.3f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx))
# Out:
# EOF
# Total memory 2520 bytes :Top-256 with size 2416 bytes              + CMS with size 65600 bytes.
# Execution time:578.582679271698 seconds.
# EOF
# Total memory 2520 bytes :Top-256 with size 2416 bytes              + CMS with size 65600 bytes.
# Execution time:1173.4497451782227 seconds.
# EOF
# Total memory 2520 bytes :Top-256 with size 2416 bytes              + CMS with size 65600 bytes.
# Execution time:1773.2477660179138 seconds.
# EOF
# Total memory 2520 bytes :Top-256 with size 2416 bytes              + CMS with size 65600 bytes.
# Execution time:2369.533388853073 seconds.
# EOF
# Total memory 2520 bytes :Top-256 with size 2416 bytes              + CMS with size 65600 bytes.
# Execution time:2909.5455253124237 seconds.
# EOF
# Total memory 2520 bytes :Top-256 with size 2416 bytes              + CMS with size 65600 bytes.
# Execution time:3475.071834087372 seconds.
# EOF
# Total memory 2520 bytes :Top-256 with size 2416 bytes              + CMS with size 65600 bytes.
# Execution time:4040.5272421836853 seconds.
# EOF
# Total memory 2520 bytes :Top-256 with size 2416 bytes              + CMS with size 65600 bytes.
# Execution time:4616.115540027618 seconds.
# EOF
# Total memory 2520 bytes :Top-256 with size 2416 bytes              + CMS with size 65600 bytes.
# Execution time:5193.100462675095 seconds.
# EOF
# Total memory 2520 bytes :Top-256 with size 2416 bytes              + CMS with size 65600 bytes.
# Execution time
e2\\x1a\\x00P\\x06'", 36095], ['b"\'\\xd8\\xbaK\\xbd\\xbbo\\xcd\\xe4Z\\x9c\\xcb\\x11"', 36046], ["b'\\x80-!\\x1e\\xbd`\\x01`\\xa7g\\x01\\xbb\\x06'", 35970], ["b'\\x0c+\\x188\\xc2\\xc2+\\xfc\\xe1P\\x00P\\x06'", 35867], ["b'{\\xecL\\x9b\\xd1\\xc1+\\xfc\\xe0\\x9b\\x00P\\x06'", 35641], ["b'\\x92\\xc1\\x17\\xca\\x90\\xb6o\\xcd\\x19\\xda\\xa1\\x06\\x11'", 35508], ["b'\\x ...

# %% [markdown]
# ## count and compare error after read all elements

# %%
# count-min sketch webdocs, top-1024, cms 1024*4, full read
import sys
import os
import time
from probables import (CountMinSketch)
import pandas as pd

start=time.time()
topk=[]
w=128
d=4
size=256

item_count=0
cms = CountMinSketch(width=w, depth=d)

filename='caida_0.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)

# if os.path.exists(os.path.join(datapath,datali)):
if os.path.exists(src_data):
    with open(src_data,'rb') as file:
        while True:
            line=str(file.read(13))
            if len(line)<13:
                print('EOF')
                break
            else:
                # item_count+=1
                # print("read {}th element: {}".format(item_count,element))
                cms.add(line)
    end=time.time()
    print("Execution time:{} seconds.".format(str(end-start)))
    print("Total memory {} bytes.".format(sys.getsizeof(cms._bins)))
else:
    print("file doesn't exist")    
    

#==================== count and check error of top k=============================
path="..\\Caida0\\"
groundtruth='caida_0_ground_truth.csv'
grtruth=pd.read_csv(os.path.join(path,groundtruth))
gli = grtruth.values.tolist()

gt_dict=dict(grtruth.values.tolist())
top_are=0
top_aae=0
all_are=0
all_aae=0

read=0
startx=time.time()
for item in grtruth['Element']:
    count=cms.check(str(item))    
    if read<size:
        top_are+=abs(count-gt_dict[item])/gt_dict[item]
        top_aae+=abs(count-gt_dict[item])
        read+=1
    all_are+=abs(count-gt_dict[item])/gt_dict[item]
    all_aae+=abs(count-gt_dict[item])
endx=time.time() 
distinct=len(gt_dict)
top_are/=256
all_are/=distinct
all_aae/=distinct 
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.3f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.3f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx))
# Out:
# EOF
# Execution time:221.2558970451355 seconds.
# Total memory 4160 bytes.
# Top_ARE: 2415.749480
# Top_AAE: 4002099.000
# all_ARE: 7654.682936
# all_AAE: 15692.637
# Estimate time:  16.880 seconds.

# %%
#==================== count and check error of top k=============================
path="..\\Caida0\\"
groundtruth='caida_0_ground_truth.csv'
grtruth=pd.read_csv(os.path.join(path,groundtruth))
gli = grtruth.values.tolist()

gt_dict=dict(grtruth.values.tolist())
top_are=0
top_aae=0
all_are=0
all_aae=0
read=0

startx=time.time()
for item in grtruth['Element']:
    count=cms.check(str(item))    
    if read<256:
        top_are+=abs(count-gt_dict[item])/gt_dict[item]
        top_aae+=abs(count-gt_dict[item])
        read+=1
    all_are+=abs(count-gt_dict[item])/gt_dict[item]
    all_aae+=abs(count-gt_dict[item])
endx=time.time() 

distinct=len(gt_dict)
top_are/=256
all_are/=distinct
all_aae/=distinct 
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.3f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.3f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx))
# Out:
# Top_ARE: 9.436521
# Top_AAE: 4002099.000
# all_ARE: 7654.682936
# all_AAE: 15692.637
# Estimate time:  16.753 seconds.
