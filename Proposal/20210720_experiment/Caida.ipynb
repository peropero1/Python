# %%
from Node import DS
from Tools import Func
from Tools import Config
import pandas as pd
import numpy as np
import os
import time
import operator
import sys

import re

# set dataset and ground truth file path    
filepath=r"..\dataset\caida"
pattern='\w+.dat$'
r=re.compile(pattern)
filelist=list(filter(r.match,os.listdir(filepath)))    
    # dataset file list

gr_file_name='caida_0_ground_truth.csv'
gr_path=os.path.join(filepath,gr_file_name)
    # ground truth path

# Top and Sketch parameter config
w=128
d=64
size=1024
Config.Set_default(w,d,size)
    # set width, depth, size of Sk, random seed of hash,e_max

# Initialize Top, Sketch and Sk_head
Sk_head=[DS.Head(0) for j in range(Config.depth)]
Sketch=np.zeros((Config.depth,Config.width),dtype='int32')
Top_dict=dict()
e_min=DS.Tail("",1)

# Stream processing
start=time.time()
for datafile in filelist[:1]:
    src_data=os.path.join(filepath,datafile)
    with open(src_data,'rb') as file:
         #以binary讀取，資料型態也為byte
        while True:
            e=str(file.read(13))
            if len(e)<13:
                print('EOF')
                break
            else:    
                item=DS.Tail(e,1)
                if Top_dict.get(item.ID):
                    # e in Top
                    Top_dict[item.ID]+=1
                else:
                    if len(Top_dict)<Config.size:
                        Top_dict[item.ID]=1
                    else:
                        Func.UpdateSk(item,Sk_head,Sketch)
            if Config.e_max.count>e_min.count:
                min_ele = min(Top_dict, key=Top_dict.get)
                    # 找dict中的最小key元素
                e_min=DS.Tail(min_ele,Top_dict[min_ele])
                Func.BringBack(e_min,Top_dict,Sk_head,Sketch)
end=time.time()
print("Top-{},Sketch:{}*{}".format(Config.size,Config.depth,Config.width))
print("Execution time:{:8.3f} seconds.".format(end-start))
Top_dict=dict(sorted(Top_dict.items(), key=lambda item: item[1],reverse=True))

# Element-Precision
tp_set,precision=Func.Get_precision(gr_path,Top_dict)

# Count ARE/AAE

'''
startx=time.time()
print("\n")
top_are,top_aae,all_are,all_aae,tp,fp=Func.Get_ARE_AAE(gr_path,Top_dict,Sk_head,Sketch,5)
endx=time.time()
print("Find:{}, TP:{}, FP:{}".format(len(tp_set),tp,fp))
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.6f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.6f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx))

startx=time.time()
print("\n")
top_are,top_aae,all_are,all_aae,tp,fp=Func.Get_ARE_AAE(gr_path,Top_dict,Sk_head,Sketch,6)
endx=time.time()
print("Find:{}, TP:{}, FP:{}".format(len(tp_set),tp,fp))
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.6f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.6f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx)) 

startx=time.time()
print("\n")
top_are,top_aae,all_are,all_aae,tp,fp=Func.Get_ARE_AAE(gr_path,Top_dict,Sk_head,Sketch,4)
endx=time.time()
print("Find:{}, TP:{}, FP:{}".format(len(tp_set),tp,fp))
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.6f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.6f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx))



startx=time.time()
print("\n")
top_are,top_aae,all_are,all_aae,tp,fp=Func.Get_ARE_AAE(gr_path,Top_dict,Sk_head,Sketch,7)
endx=time.time()
print("Find:{}, TP:{}, FP:{}".format(len(tp_set),tp,fp))
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.6f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.6f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx)) 


'''


startx=time.time()
print("\n")
top_are,top_aae,all_are,all_aae,tp,fp=Func.Get_ARE_AAE(gr_path,Top_dict,Sk_head,Sketch,9)
endx=time.time()
print("Find:{}, TP:{}, FP:{}".format(len(tp_set),tp,fp))
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.6f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.6f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx)) 

startx=time.time()
print("\n")
top_are,top_aae,all_are,all_aae,tp,fp=Func.Get_ARE_AAE(gr_path,Top_dict,Sk_head,Sketch,10)
endx=time.time()
print("Find:{}, TP:{}, FP:{}".format(len(tp_set),tp,fp))
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.6f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.6f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx))
# Out:
# EOF
# Top-1024,Sketch:64*128
# Execution time:  41.137 seconds.
# Precision:   0.8428
#
#
# lhh_are:1.4474112796357355,lhh_aae:181.296875
# lhh over_estimate:320, lhh under_estimate:11283
# sketch over_estimate:36725, sketch under_estimate:1370031
# Find:863, TP:863, FP:161
# Top_ARE: 0.035524
# Top_AAE: 19.808806
# all_ARE: 0.514605
# all_AAE: 7.971554
# Estimate time:   2.855 seconds.
#
#
# lhh_are:5.842428090588382,lhh_aae:114.6328125
# lhh over_estimate:4718.5, lhh under_estimate:2618.0
# sketch over_estimate:860696, sketch under_estimate:877291
# Find:863, TP:863, FP:161
# Top_ARE: 0.035524
# Top_AAE: 19.808806
# all_ARE: 3.294365
# all_AAE: 9.848514
# Estimate time:   4.341 seconds.

# %%
print(Sk_head)
# Out:
# [[total count: 23831, distinct: 2741, max: b'lw\x01\xf1\xb9\xe6\x01`\xf7\xb9\x01\xbb\x06', keep: 6], [total count: 22615, distinct: 2800, max: b"u_\x9d\x8a\xea\xe0+\xfc\xe2'\x00P\x06", keep: 19], [total count: 24250, distinct: 2695, max: b"'\x06\xbfm\xf9\xaao\xcd\xe4\x86\x1f\x90\x11", keep: 2], [total count: 23116, distinct: 2831, max: b'\xd4N\x1f)\xa7r\x01`\xdf\xa6\x01\xbb\x06', keep: 0], [total count: 26629, distinct: 2812, max: b'\xb7\xa8\xc4c\xc9\xab+\xfc\xe2\x04\x00P\x06', keep: 9], [total count: 23574, distinct: 2769, max: b'\xcb"\xce\x96\xcc\x85+\xfc\xe2\x10\x00P\x06', keep: 0], [total count: 23742, distinct: 2782, max: b'\xb7\xe3R\xec\xe2\t+\xfc\xe2\x06\x00P\x06', keep: 6], [total count: 22877, distinct: 2799, max: b'\xb7\x93\x08\xa0\xf8\xeb+\xec`\x14\x01\xbb\x06', keep: 3], [total count: 22762, distinct: 2727, max: b'lw\x01\xef\xb5\x17\x01`\xc1$\x01\xbb\x06', keep: 5], [total count: 23646, distinct: 2761, max: b'\x05\xe7d\xe3\x00P\x89#\xb1\x85\xc7\xb1\x06', keep: 16], [total count: 23613, distinct: 2772, max: b'p,Q"\xe3u\x99\xc1.\xd9\x00P\x06', keep: 8], [total count: 24630, distinct: 2823, max: b'\xcc\xd5f\xd9\xf7b\x01`\x96"\x00P\x06', keep: 17], [total count: 24097, distinct: 2823, max: b'o\xe7R\xcf\xa2\x17\x05\xfcdE\x1fF\x06', keep: 2], [total count: 24042, distinct: 2774, max: b'\xc6X\xda\x88\x94\x84\xc6X\xdb04$\x11', keep: 16], [total count: 21457, distinct: 2778, max: b'c\x8d\x9a6\x13]+\xfc\xe0F\x01\xbb\x06', keep: 1], [total count: 22692, distinct: 2761, max: b'p\x97\xa1\xb6\x9c\xb4\x01`\x90Z\x00P\x06', keep: 2], [total count: 23608, distinct: 2803, max: b'o\xcd;\xdc\xf9\xd0+\x96\xa5\xfb\x00P\x06', keep: 3], [total count: 23099, distinct: 2667, max: b'$07I\xf2\x15\x03\xed\xa0%\x01\xbb\x06', keep: 1], [total count: 23736, distinct: 2800, max: b'\x01l|\xb5\xfbQk\x1c<p\x00P\x06', keep: 4], [total count: 25371, distinct: 2817, max: b'\x94\xe9>\x84\xdf\xd2+\xfc\xe05\x01\xbb\x06', keep: 1], [total count: 24651, distinct: 2774, max: b'\xcf\x88\xc7\xc2\x9c\xe2\x01`\xa6\xcc\x01\xbb\x06', keep: 67], [total count: 24154, distinct: 2782, max: b'\x808\xea#\xe2\xd3\x01`\xa7\xda\x01\xbb\x06', keep: 15], [total count: 24063, distinct: 2760, max: b'\x89/J%\x00\x16\xd2l\x7f\xfa\xce\xdb\x06', keep: 7], [total count: 24115, distinct: 2707, max: b'p\xe3\xd1r\x1e\xc5+\xfc\xe0\xb6\x01\xbb\x06', keep: 2], [total count: 24265, distinct: 2812, max: b'B\xf3\xc2\x7f\xc5M\xc6U\x10\xee\x00P\x06', keep: 2], [total count: 24742, distinct: 2829, max: b"'o\xc0\x90\xcf\x8f\xdd.\xdd\xdb#R\x11", keep: 10], [total count: 23061, distinct: 2766, max: b'\xc6X\xdd,y\x88\xc6X\xdb0\xfc\x8a\x11', keep: 3], [total count: 23141, distinct: 2721, max: b'\x83WS{\xa8R\x03\x89\x9b\xdf\x00P\x06', keep: 6], [total count: 22875, distinct: 2807, max: b'\xb7\xb2M~\xce"\x01`\xde\xf4\x01\xbb\x06', keep: 49], [total count: 23372, distinct: 2786, max: b'\x99\xc1\x96I\x94\xb1\xdd.\xdc\xf2\x00P\x06', keep: 21], [total count: 21680, distinct: 2780, max: b'\x94\xea=\xb6\xc9\x0b\xd2\xef66\x01\xbb\x06', keep: 1], [total count: 24921, distinct: 2765, max: b'\x84; \x17KV\xc6X\xdbq\xff\xb0\x11', keep: 16], [total count: 24461, distinct: 2736, max: b'c9\xbb\xeb\xb3\x15\x01g\xbb5${\x06', keep: 5], [total count: 23321, distinct: 2702, max: b'\xd4\xa8*\xf7\x9fBk\x1e\x9f\xfa\x01\xbb\x06', keep: 1], [total count: 24647, distinct: 2777, max: b'pp\xd0#\x15\x1b\x01`\xa7\t\x01\xbb\x06', keep: 16], [total count: 25780, distinct: 2795, max: b'pn\x18\xa0)b\x01`\xa7O\x01\xbb\x06', keep: 31], [total count: 22848, distinct: 2716, max: b'w\xe68\xed\xc6P\x01`\xa7\\\x01\xbb\x06', keep: 79], [total count: 26473, distinct: 2856, max: b'\xd8\xf2\x08\xf4\xb5X\xdd\xc3\xe7"\x00\x15\x06', keep: 0], [total count: 21809, distinct: 2756, max: b'D\x81U\xfb\xfd\xbao\xcd\xe4\x91\x1f\x90\x11', keep: 1], [total count: 25156, distinct: 2784, max: b'\x84; \x136@\xc6X\xdb1\xa6\xb8\x11', keep: 5], [total count: 23902, distinct: 2809, max: b'\xc6X\xda\x88\xd9\xc2\xc6X\xdbq\xe3\xf4\x11', keep: 20], [total count: 23801, ...

# %%
for i in range(Config.depth):
    print(sum(Sketch[i]))
# Out:
# 23831
# 22615
# 24250
# 23116
# 26629
# 23574
# 23742
# 22877
# 22762
# 23646
# 23613
# 24630
# 24097
# 24042
# 21457
# 22692
# 23608
# 23099
# 23736
# 25371
# 24651
# 24154
# 24063
# 24115
# 24265
# 24742
# 23061
# 23141
# 22875
# 23372
# 21680
# 24921
# 24461
# 23321
# 24647
# 25780
# 22848
# 26473
# 21809
# 25156
# 23902
# 23801
# 25487
# 23636
# 25050
# 23198
# 21728
# 22619
# 24590
# 25166
# 26252
# 24938
# 24416
# 23856
# 23619
# 24239
# 25677
# 22513
# 23896
# 23472
# 23269
# 22439
# 24106
# 24005

# %%
print(Sketch[0])
# Out:
# [ 99 125 173 161  88 179  64 143 121 352  57 237  84 273  79  89 522 267
#   98 321  40  93 233 151 142  60 112  92 145  80 101 143 174 307 268 236
#  404 119 144 189 379 131 422 105 426 461 176 127 314 175  92 449 104 116
#   77 135 139 163 172 256 224 149  60  96 101  85 171  75  50 150 226  67
#  407 168 150 207 124  69  98  79 238 164 134 106 135 149 322  94 202 223
#  283 222 219 481 299 229 202 178 128 246 144 229  71 282 440  82  99 486
#  199 186 360  86 298 132 107 215 266 126 103 168 330 173 251 338 182  90
#  124  70]
