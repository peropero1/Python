# %%
import pandas as pd
import os

filename='compare.csv'
df=pd.read_csv(filename)
df
# Out:
#     Unnamed: 0 method  TOP-k  Sketch_depth  Sketch_width  Memory_Top  \
# 0            0     my    512          64.0         128.0        4272
# 1            1     my    512         128.0         128.0        4272
# 2            2     ss    512           NaN           NaN        4272
# 3            3     ss   1024           NaN           NaN        9024
# 4            4     my   1024          64.0         256.0        9024
# 5            5     my    512          64.0         256.0        4272
# 6            6     my    512         128.0         256.0        4272
# 7            7     my    512         256.0         256.0        4272
# 8            8     my   1024          64.0         128.0        9024
# 9            9     my   1024         128.0         256.0        9024
# 10          10     my   1024         256.0         256.0        9024
#
#     Memory_Sketch  Executio_ time  Find  Precision_Top  ARE(Top)     AAE(Top)  \
# ...

# %%
import matplotlib.pyplot as plt
# Out:
#    method  TOP-k  Sketch_depth  Sketch_width  Memory_Top  Memory_Sketch  \
# 0      my    512          64.0         128.0        4272        36352.0
# 1      my    512         128.0         128.0        4272        72704.0
# 2      ss    512           NaN           NaN        4272            NaN
# 3      ss   1024           NaN           NaN        9024            NaN
# 4      my   1024          64.0         256.0        9024        69120.0
# 5      my    512          64.0         256.0        4272        69120.0
# 6      my    512         128.0         256.0        4272       138240.0
# 7      my    512         256.0         256.0        4272       265728.0
# 8      my   1024          64.0         128.0        9024        36352.0
# 9      my   1024         128.0         256.0        9024       134656.0
# 10     my   1024         256.0         256.0        9024       265728.0
#
#     Executio_ time  Find  Precision_Top  ARE(Top)     AAE(Top)  ARE(All)  \
# ...
