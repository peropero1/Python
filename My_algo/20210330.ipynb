# %%
import ds
import spookyhash
import mmh3
from numpy import random
import os
import time
import operator
import hyperloglog

# ==========================data structure==========================
class Node():
    def __init__(self,count=0):
        self.count=count
    def add_count(self,count=1):
        self.count+=count
    def __str__(self):
        return 'count: {}'.format(self.count)
    def __repr__(self):
        return ''

class Head(Node):
    def __init__(self,count=1):
        super().__init__(count)
        self.distinct = hyperloglog.HyperLogLog(0.01)
        self.maxID=''
    def __str__(self):
        return '[total count: {}, distinct: {}, max: {}]'.format(self.count,len(self.distinct),self.maxID)
    def __repr__(self):
        return '[total count: {}, distinct: {}, max: {}]'.format(self.count,len(self.distinct),self.maxID)

class Tail(Node):
    def __init__(self,ID,count):
        self.ID = ID
        super().__init__(count)
    def __str__(self):
        return '[ID: {}, count: {}]'.format(self.ID,self.count)
    def __repr__(self):
        return '[ID: {}, count: {}]'.format(self.ID,self.count)
# ==========================data structure==========================



# ========================== Update Sketch==========================
def UpdateSk(element,width,depth):
    e_max=get_emax()
    hash1=spookyhash.hash32(bytes(str(element.ID),encoding='utf-8'))
        # input of spooky hash: binary, encoding is parameter of bytes()
        # output of spooky hash: unsigned- 32 bit int
    hash2=mmh3.hash(str(hash1), signed=False)
        # input of mmh3 is str, output unsigned- 32 bit int
    row=hash1 % depth
        # index of row in SK[row]
    ID=hash2 % ((width*3)//2)
        # hash-value(ID) of e
        # range: 2^k *3/2= 3*(2^k-1)
    match=False
        # match= True if e is in Sk[row]
    index=0
    avg=0
    item=Tail(ID, element.count)
        # ID in Sketch is hash value
    print("\t{} -> {},send to Sk[{}]".format(element,item,row))
    # print("id(Sk[{}]):{}".format(row,id(Sk[row])))
    Sk_head[row].count+=item.count
        # total count+=count
    # ==========================update sketch==========================
    if len(Sk[row])==0:
        print("len(Sk[row])<width:{}".format(len(Sk[row])<width))
        # Sk[row] is empty,append e directly  
        Sk[row].append(item)
        Sk_head[row].maxID=element.ID
        match=True
        index=0
    else:
        # Sk[row] is not empty
        index=find(item,Sk[row])
        print("index={}".format(index))
        if index >=0:
            # matched in Sk[row]
            Sk[row][index].count+=item.count
            match=True
        else:
            # doesn't match in Sk[row]
            if len(Sk[row])<width:
                # Sk[row] is not full
                Sk[row].append(item)
                match=True
                index=len(Sk[row])-1
            else:
                # Sk[row] is full
                count_sum=sum(Sk[row][i].count for i in range(len(Sk[row])))
                print("count_sum={}".format(count_sum))
                print("total count={}".format(Sk_head[row].count))
                if Sk_head[row].count==count_sum:
                    # no element in other
                    # print("no element in Other, send to distinct")
                    Sk_head[row].distinct.add(element.ID)
                    match=False
                elif Sk_head[row].count>count_sum:
                    if len(Sk_head[row].distinct)>0:
                        avg=(Sk_head[row].count-count_sum)//len(Sk_head[row].distinct)
                        print("avg:{}".format(avg))
                        if avg>Sk[row][-1].count:
                            # print("avg>last one, update Sk[{}]".format(row))
                            Sk[row][-1].ID=item.ID
                            Sk[row][-1].count=avg
                            match=True
                            index=-1
                        else:
                            Sk_head[row].distinct.add(element.ID)
                            # print("avg< last one,send to distinct")
                            match=False
            
                        
    # now we have:
    #  index: incoming e in Sk[row]
    #  match: whether e is in Sk[row]
    #  ID: hash(e)
    #  
    # ==========================update e_max==========================
    print("\nUpdate e_max in UpdateSK():")
    print("Sk_head[{}]: {}".format(row,Sk_head[row]))
    print("e_max before update:{}".format(e_max))
    # Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
    
    # update local max

    # update global max 
    h1=spookyhash.hash32(bytes(str(Sk_head[row].maxID),encoding='utf-8'))
    h2=mmh3.hash(str(h1), signed=False)
    max_id=h2 % ((width*3)//2)
    max_id_index=find(Tail(max_id,1),Sk[row])
    print("Sk[{}]:{} before update e_max".format(row,Sk[row]))
    print("index:{},max_id:{}, max_id_index:{}, in Sk[{}]".format(index,max_id,max_id_index,row))
    print("match={}".format(match))
    if max_id_index>=0:
        if match:
            # incoming element in Sk[row]:
            print("Sk_head[{}].maxID: {}".format(row,Sk_head[row].maxID))
            if Sk_head[row].maxID=="":
                Sk_head[row].maxID=element.ID
            elif element.ID==Sk_head[row].maxID:
                # update e_max
                if Sk[row][index].count>e_max.count:
                    e_max.ID=element.ID
                    e_max.count=Sk[row][index].count
                else:
                    pass
                # element.ID ≠ maxID
            if Sk[row][index].count>=Sk[row][max_id_index].count:
                Sk_head[row].maxID=element.ID
                if Sk[row][index].count>e_max.count:
                    e_max.ID=element.ID
                    e_max.count=Sk[row][index].count
        else:
            # e not in Sk[row]
            if avg>Sk[row][max_id_index].count:
                Sk_head[row].maxID=element.ID
                if avg>e_max.count:
                    e_max.ID=element.ID
                    e_max.count=avg
    else:
        Sk_head[row].maxID=element.ID

    Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
    
    # print("after sorting id(Sk[{}]):{}".format(row,id(Sk[row])))

    for i in range(len(Sk)):
        print("Sk[{}]:{},{}".format(i,Sk_head[i],Sk[i]))
    print("e_max:{} after UpdateSK()".format(e_max))

# ========================== Update Sketch==========================

def Update_emax(head_list):
    print("\nIn Update_emax(Sk_head):")
    print("\t{}".format(head_list))
    e_max=get_emax()
    print("id(e_max):{}".format(id(e_max)))
    for item in head_list:
        print("item in Sk_head[]:{}".format(item))
        if item.maxID !='':
            hash1=spookyhash.hash32(bytes(str(item.maxID),encoding='utf-8'))
            hash2=mmh3.hash(str(hash1), signed=False)
            ID=hash2 % ((width*3)//2)
            row=hash1 % depth
            index=find(Tail(ID,1),Sk[row])
            print("row:{}".format(row))
            print("Sk[{}]:{}".format(row,Sk[row]))
            print("id of local max:{}".format(ID))
            print("index of local max:{}".format(index))
            if Sk[row][index].count >e_max.count:
                e_max.ID=item.maxID
                e_max.count=Sk[row][index].count
        else:
            pass
        

# ========================== BringBack=========================
def BringBack(e_min,e_max):
    print("\nIn BringBack({},{})".format(e_min,e_max))
    e_max=get_emax()
    # print('e_max at first Bringback:{},id(e_max):{}'.format(e_max,id(e_max)))
    temp=Tail(e_min.ID,e_min.count)
    Top[-1].ID=e_max.ID
    Top[-1].count=e_max.count
    Top.sort(key=operator.attrgetter('count'),reverse=True)
    print('Top after BringBack:\n\t{}'.format(Top))
    DeleteSk(e_max)
    # update e_max in Sk[row]
    Update_emax(Sk_head)
    print("e_max after delete:{},id(e_max):{}".format(e_max,id(e_max)))
    UpdateSk(temp,width,depth)
    
    # print("Sk[] after Update {}:\n\t{}".format(e_min,Sk))

# ========================== BringBack=========================
# ==========================DeleteSk=========================
def DeleteSk(element):
    # 刪除e_max in Sk[row]，update local max
    e_max=get_emax()
    print("\nIn DeleteSK({})".format(element))
    hash1=spookyhash.hash32(bytes(str(element.ID),encoding='utf-8'))
    hash2=mmh3.hash(str(hash1), signed=False)
    ID=hash2 % ((width*3)//2)
    row=hash1 % depth
    print("row:{},ID:{}".format(row,ID))
    Sk_head[row].count-=element.count
    print("Sk[{}]:{}".format(row,Sk[row]))
    index=find(Tail(ID,1),Sk[row])
    print("index:{}".format(index))
    if index<0:
        pass
    else:
        Sk[row].pop(index)
        Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
        Sk_head[row].maxID=""
    e_max.ID=""
    e_max.count=0
    
    print("e_max After DeleteSk(element):{},id(e_max):{}".format(e_max,id(e_max)))
    '''
    print("index:{}".format(index))
    print('After pop:')
    print("\tSk[{}]={}".format(row,Sk[row]))
    print("Top:\n\t{}".format(Top))
    '''
# ==========================Tools=========================
def get_emax():
    return e_max

def find(e,element_list):
    try:
        # type(element_list[i].ID):int
        # print("e:{}".format(e))
        # print("element_list[1:]: {}".format(element_list[1:]))
        index=[ele.ID for ele in element_list].index(e.ID)
    except:
        # print("raise error")
        index=-99
    return index

# ========================main==============================

start=time.time()
filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)
depth=4
width=4
size=8

Top=[]
Sk_head=[Head(0) for j in range(depth)]
Sk=[[] for i in range(depth)]
item_count=150
i=0
e_max=Tail('',0)

with open(src_data,'r') as file:
    while item_count:
        element=file.readline().strip('\n')
        if not element:
            break
        else:
            i+=1
            print("\nread {}-th element: {}".format(i,element))
            item_count-=1
            item=Tail(element,1)
            if len(Top)==0:
                Top.append(item)
                # print("len(Top)==0, Top append:{}".format(Top))
            else:
                index=find(item,Top)
                # print("index={}".format(index))
                if index<0:
                    if len(Top)<size:
                        Top.append(item)
                        # print("index={},Top after append: {},\nlen(Top):{}".format(index,Top,len(Top)))
                    else:
                        print("send {} into Sk".format(element))
                        UpdateSk(item,width,depth)
                else:
                    # print("update Top[{}]:".format(index))
                    Top[index].count+=1
            print("Top after read {}:\n\t{}\n".format(element,Top))
            Top.sort(key=operator.attrgetter('count'),reverse=True)
            if e_max.count>Top[-1].count:
                BringBack(Top[-1],e_max)
                # print('Top after BringBack: \n\t{}'.format(Top))            
            # print("TOP:{}".format(Top))
end=time.time()
print("e_max:{}".format(e_max))
print("Execution time:{} seconds.".format(str(end-start)))
# Out:
# read 1-th element: 1 2 3
# Top after read 1 2 3:
# 	[[ID: 1 2 3, count: 1]]
#
#
# read 2-th element: 1
# Top after read 1:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1]]
#
#
# read 3-th element: 4 5 6 7
# Top after read 4 5 6 7:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1]]
#
#
# read 4-th element: 1 8
# Top after read 1 8:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1]]
#
#
# read 5-th element: 9 10
# Top after read 9 10:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1]]
#
#
# read 6-th element: 11 6 12 13 14 15 16
# Top after read 11 6 12 13 14 15 16:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1]]
#
#
# read 7-th element: 1 3 7
# Top after read 1 3 7:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1]]
#
#
# read 8-th element: 17 18
# Top after read 17 18:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1], [ID: 17 18, count: 1]]
#
#
# read 9-th element: 11 6 19 20 21 22 23 24
# send 11 6 19 20 21 22 23 24 into Sk
# 	[ID: 11 6 19 20 21 22 23 24, count: 1] -> [ID: 2, count: 1],send to Sk[2]
# len(Sk[row])<width:True
#
# Update e_max in UpdateSK():
# Sk_head[2]: [total count: 1, distinct: 0, max: 11 6 19 20 21 22 23 24]
# e_max before update:[ID: , count: 0]
# Sk[2]:[[ID: 2, count: 1]] before update e_max
# index:0,max_id:2, max_id_index:0, in Sk[2]
# match=True
# Sk_head[2].maxID: 11 6 19 20 21 22 23 24
# Sk[0]:[total count: 0, distinct: 0, max: ],[]
# Sk[1]:[total count: 0, distinct: 0, max: ],[]
# Sk[2]:[total count: 1, distinct: 0, max: 11 6 19 20 21 22 23 24],[[ID: 2, count: 1]]
# Sk[3]:[total count: 0, distinct: 0, max: ],[]
# e_max:[ID: 11 6 19 20 21 22 23 24, count: 1] after UpdateSK()
# Top after read 11 6 19 20 21 22 23 24:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1], [ID: 17 18, count: 1]]
#
#
# read 10-th element: 1 25 3
# send 1 25 3 into Sk
# 	[ID: 1 25 3, count: 1] -> [ID: 1, count: 1],send to Sk[0]
# len(Sk[row])<width:True
#
# Update e_max in UpdateSK():
# Sk_head[0]: [total count: 1, distinct: 0, max: 1 25 3]
# e_max before update:[ID: 11 6 19 20 21 22 23 24, count: 1]
# Sk[0]:[[ID: 1, count: 1]] before update e_max
# index:0,max_id:1, max_id_index:0, in Sk[0]
# match=True
# Sk_head[0].maxID: 1 25 3
# Sk[0]:[total count: 1, distinct: 0, max: 1 25 3],[[ID: 1, count: 1]]
# Sk[1]:[total count: 0, distinct: 0, max: ],[]
# Sk[2]:[total count: 1, distinct: 0, max: 11 6 19 20 21 22 23 24],[[ID: 2, count: 1]]
# Sk[3]:[total count: 0, distinct: 0, max: ],[]
# e_max:[ID: 11 6 19 20 21 22 23 24, count: 1] after UpdateSK()
# Top after read 1 25 3:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1], [ID: 17 18, count: 1]]
#
#
# read 11-th element: 26 3
# send 26 3 into Sk
# 	[ID: 26 3, count: 1] -> [ID: 3, count: 1],send to Sk[2]
# index=-99
# len(Sk[2]<width:True,length=1
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[2]: [total count: 2, distinct: 0, max: 11 6 19 20 21 22 23 24]
# e_max before update:[ID: 11 6 19 20 21 22 23 24, count: 1]
# Sk[2]:[[ID: 2, count: 1], [ID: 3, count: 1]] before update e_max
# index:1,max_id:2, max_id_index:0, in Sk[2]
# match=True
# Sk_head[2].maxID: 11 6 19 20 21 22 23 24
# Sk[0]:[total count: 1, distinct: 0, max: 1 25 3],[[ID: 1, count: 1]]
# Sk[1]:[total count: 0, distinct: 0, max: ],[]
# Sk[2]:[total count: 2, distinct: 0, max: 26 3],[[ID: 2, count: 1], [ID: 3, count: 1]]
# Sk[3]:[total count: 0, distinct: 0, max: ],[]
# e_max:[ID: 11 6 19 20 21 22 23 24, count: 1] after UpdateSK()
# Top after read 26 3:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1], [ID: 17 18, count: 1]]
#
#
# read 12-th element: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37
# send 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37 into Sk
# 	[ID: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count: 1] -> [ID: 4, count: 1],send to Sk[1]
# len(Sk[row])<width:True
#
# Update e_max in UpdateSK():
# Sk_head[1]: [total count: 1, distinct: 0, max: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# e_max before update:[ID: 11 6 19 20 21 22 23 24, count: 1]
# Sk[1]:[[ID: 4, count: 1]] before update e_max
# index:0,max_id:4, max_id_index:0, in Sk[1]
# match=True
# Sk_head[1].maxID: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37
# Sk[0]:[total count: 1, distinct: 0, max: 1 25 3],[[ID: 1, count: 1]]
# Sk[1]:[total count: 1, distinct: 0, max: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID: 4, count: 1]]
# Sk[2]:[total count: 2, distinct: 0, max: 26 3],[[ID: 2, count: 1], [ID: 3, count: 1]]
# Sk[3]:[total count: 0, distinct: 0, max: ],[]
# e_max:[ID: 11 6 19 20 21 22 23 24, count: 1] after UpdateSK()
# Top after read 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1], [ID: 17 18, count: 1]]
#
#
# read 13-th element: 6 2 38
# send 6 2 38 into Sk
# 	[ID: 6 2 38, count: 1] -> [ID: 5, count: 1],send to Sk[1]
# index=-99
# len(Sk[1]<width:True,length=1
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[1]: [total count: 2, distinct: 0, max: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# e_max before update:[ID: 11 6 19 20 21 22 23 24, count: 1]
# Sk[1]:[[ID: 4, count: 1], [ID: 5, count: 1]] before update e_max
# index:1,max_id:4, max_id_index:0, in Sk[1]
# match=True
# Sk_head[1].maxID: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37
# Sk[0]:[total count: 1, distinct: 0, max: 1 25 3],[[ID: 1, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 6 2 38],[[ID: 4, count: 1], [ID: 5, count: 1]]
# Sk[2]:[total count: 2, distinct: 0, max: 26 3],[[ID: 2, count: 1], [ID: 3, count: 1]]
# Sk[3]:[total count: 0, distinct: 0, max: ],[]
# e_max:[ID: 11 6 19 20 21 22 23 24, count: 1] after UpdateSK()
# Top after read 6 2 38:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1], [ID: 17 18, count: 1]]
#
#
# read 14-th element: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51
# send 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51 into Sk
# 	[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 1] -> [ID: 3, count: 1],send to Sk[2]
# index=1
#
# Update e_max in UpdateSK():
# Sk_head[2]: [total count: 3, distinct: 0, max: 26 3]
# e_max before update:[ID: 11 6 19 20 21 22 23 24, count: 1]
# Sk[2]:[[ID: 2, count: 1], [ID: 3, count: 2]] before update e_max
# index:1,max_id:3, max_id_index:1, in Sk[2]
# match=True
# Sk_head[2].maxID: 26 3
# Sk[0]:[total count: 1, distinct: 0, max: 1 25 3],[[ID: 1, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 6 2 38],[[ID: 4, count: 1], [ID: 5, count: 1]]
# Sk[2]:[total count: 3, distinct: 0, max: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51],[[ID: 3, count: 2], [ID: 2, count: 1]]
# Sk[3]:[total count: 0, distinct: 0, max: ],[]
# e_max:[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2] after UpdateSK()
# Top after read 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51:
# 	[[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1], [ID: 17 18, count: 1]]
#
#
# In BringBack([ID: 17 18, count: 1],[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2])
# Top after BringBack:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1]]
#
# In DeleteSK([ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2])
# row:2,ID:3
# Sk[2]:[[ID: 3, count: 2], [ID: 2, count: 1]]
# index:0
# e_max After DeleteSk(element):[ID: , count: 0],id(e_max):2196014014360
#
# In Update_emax(Sk_head):
# 	[[total count: 1, distinct: 0, max: 1 25 3], [total count: 2, distinct: 0, max: 6 2 38], [total count: 1, distinct: 0, max: ], [total count: 0, distinct: 0, max: ]]
# id(e_max):2196014014360
# item in Sk_head[]:[total count: 1, distinct: 0, max: 1 25 3]
# row:0
# Sk[0]:[[ID: 1, count: 1]]
# id of local max:1
# index of local max:0
# item in Sk_head[]:[total count: 2, distinct: 0, max: 6 2 38]
# row:1
# Sk[1]:[[ID: 4, count: 1], [ID: 5, count: 1]]
# id of local max:5
# index of local max:1
# item in Sk_head[]:[total count: 1, distinct: 0, max: ]
# item in Sk_head[]:[total count: 0, distinct: 0, max: ]
# e_max after delete:[ID: 1 25 3, count: 1],id(e_max):2196014014360
# 	[ID: 17 18, count: 1] -> [ID: 1, count: 1],send to Sk[3]
# len(Sk[row])<width:True
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 1, distinct: 0, max: 17 18]
# e_max before update:[ID: 1 25 3, count: 1]
# Sk[3]:[[ID: 1, count: 1]] before update e_max
# index:0,max_id:1, max_id_index:0, in Sk[3]
# match=True
# Sk_head[3].maxID: 17 18
# Sk[0]:[total count: 1, distinct: 0, max: 1 25 3],[[ID: 1, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 6 2 38],[[ID: 4, count: 1], [ID: 5, count: 1]]
# Sk[2]:[total count: 1, distinct: 0, max: ],[[ID: 2, count: 1]]
# Sk[3]:[total count: 1, distinct: 0, max: 17 18],[[ID: 1, count: 1]]
# e_max:[ID: 1 25 3, count: 1] after UpdateSK()
#
# read 15-th element: 52 6 3 53
# send 52 6 3 53 into Sk
# 	[ID: 52 6 3 53, count: 1] -> [ID: 2, count: 1],send to Sk[0]
# index=-99
# len(Sk[0]<width:True,length=1
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[0]: [total count: 2, distinct: 0, max: 1 25 3]
# e_max before update:[ID: 1 25 3, count: 1]
# Sk[0]:[[ID: 1, count: 1], [ID: 2, count: 1]] before update e_max
# index:1,max_id:1, max_id_index:0, in Sk[0]
# match=True
# Sk_head[0].maxID: 1 25 3
# Sk[0]:[total count: 2, distinct: 0, max: 52 6 3 53],[[ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 6 2 38],[[ID: 4, count: 1], [ID: 5, count: 1]]
# Sk[2]:[total count: 1, distinct: 0, max: ],[[ID: 2, count: 1]]
# Sk[3]:[total count: 1, distinct: 0, max: 17 18],[[ID: 1, count: 1]]
# e_max:[ID: 1 25 3, count: 1] after UpdateSK()
# Top after read 52 6 3 53:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1]]
#
#
# read 16-th element: 54 1 6 55
# send 54 1 6 55 into Sk
# 	[ID: 54 1 6 55, count: 1] -> [ID: 5, count: 1],send to Sk[2]
# index=-99
# len(Sk[2]<width:True,length=1
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[2]: [total count: 2, distinct: 0, max: ]
# e_max before update:[ID: 1 25 3, count: 1]
# Sk[2]:[[ID: 2, count: 1], [ID: 5, count: 1]] before update e_max
# index:1,max_id:2, max_id_index:0, in Sk[2]
# match=True
# Sk_head[2].maxID:
# Sk[0]:[total count: 2, distinct: 0, max: 52 6 3 53],[[ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 6 2 38],[[ID: 4, count: 1], [ID: 5, count: 1]]
# Sk[2]:[total count: 2, distinct: 0, max: 54 1 6 55],[[ID: 2, count: 1], [ID: 5, count: 1]]
# Sk[3]:[total count: 1, distinct: 0, max: 17 18],[[ID: 1, count: 1]]
# e_max:[ID: 1 25 3, count: 1] after UpdateSK()
# Top after read 54 1 6 55:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1]]
#
#
# read 17-th element: 11 6 56 57 58 59 60 61 62 63 64
# send 11 6 56 57 58 59 60 61 62 63 64 into Sk
# 	[ID: 11 6 56 57 58 59 60 61 62 63 64, count: 1] -> [ID: 4, count: 1],send to Sk[1]
# index=0
#
# Update e_max in UpdateSK():
# Sk_head[1]: [total count: 3, distinct: 0, max: 6 2 38]
# e_max before update:[ID: 1 25 3, count: 1]
# Sk[1]:[[ID: 4, count: 2], [ID: 5, count: 1]] before update e_max
# index:0,max_id:5, max_id_index:1, in Sk[1]
# match=True
# Sk_head[1].maxID: 6 2 38
# Sk[0]:[total count: 2, distinct: 0, max: 52 6 3 53],[[ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[1]:[total count: 3, distinct: 0, max: 11 6 56 57 58 59 60 61 62 63 64],[[ID: 4, count: 2], [ID: 5, count: 1]]
# Sk[2]:[total count: 2, distinct: 0, max: 54 1 6 55],[[ID: 2, count: 1], [ID: 5, count: 1]]
# Sk[3]:[total count: 1, distinct: 0, max: 17 18],[[ID: 1, count: 1]]
# e_max:[ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2] after UpdateSK()
# Top after read 11 6 56 57 58 59 60 61 62 63 64:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1], [ID: 1 3 7, count: 1]]
#
#
# In BringBack([ID: 1 3 7, count: 1],[ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2])
# Top after BringBack:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1]]
#
# In DeleteSK([ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2])
# row:1,ID:4
# Sk[1]:[[ID: 4, count: 2], [ID: 5, count: 1]]
# index:0
# e_max After DeleteSk(element):[ID: , count: 0],id(e_max):2196014014360
#
# In Update_emax(Sk_head):
# 	[[total count: 2, distinct: 0, max: 52 6 3 53], [total count: 1, distinct: 0, max: ], [total count: 2, distinct: 0, max: 54 1 6 55], [total count: 1, distinct: 0, max: 17 18]]
# id(e_max):2196014014360
# item in Sk_head[]:[total count: 2, distinct: 0, max: 52 6 3 53]
# row:0
# Sk[0]:[[ID: 1, count: 1], [ID: 2, count: 1]]
# id of local max:2
# index of local max:1
# item in Sk_head[]:[total count: 1, distinct: 0, max: ]
# item in Sk_head[]:[total count: 2, distinct: 0, max: 54 1 6 55]
# row:2
# Sk[2]:[[ID: 2, count: 1], [ID: 5, count: 1]]
# id of local max:5
# index of local max:1
# item in Sk_head[]:[total count: 1, distinct: 0, max: 17 18]
# row:3
# Sk[3]:[[ID: 1, count: 1]]
# id of local max:1
# index of local max:0
# e_max after delete:[ID: 52 6 3 53, count: 1],id(e_max):2196014014360
# 	[ID: 1 3 7, count: 1] -> [ID: 5, count: 1],send to Sk[3]
# index=-99
# len(Sk[3]<width:True,length=1
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 2, distinct: 0, max: 17 18]
# e_max before update:[ID: 52 6 3 53, count: 1]
# Sk[3]:[[ID: 1, count: 1], [ID: 5, count: 1]] before update e_max
# index:1,max_id:1, max_id_index:0, in Sk[3]
# match=True
# Sk_head[3].maxID: 17 18
# Sk[0]:[total count: 2, distinct: 0, max: 52 6 3 53],[[ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[1]:[total count: 1, distinct: 0, max: ],[[ID: 5, count: 1]]
# Sk[2]:[total count: 2, distinct: 0, max: 54 1 6 55],[[ID: 2, count: 1], [ID: 5, count: 1]]
# Sk[3]:[total count: 2, distinct: 0, max: 1 3 7],[[ID: 1, count: 1], [ID: 5, count: 1]]
# e_max:[ID: 52 6 3 53, count: 1] after UpdateSK()
#
# read 18-th element: 3
# send 3 into Sk
# 	[ID: 3, count: 1] -> [ID: 0, count: 1],send to Sk[3]
# index=-99
# len(Sk[3]<width:True,length=2
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 3, distinct: 0, max: 1 3 7]
# e_max before update:[ID: 52 6 3 53, count: 1]
# Sk[3]:[[ID: 1, count: 1], [ID: 5, count: 1], [ID: 0, count: 1]] before update e_max
# index:2,max_id:5, max_id_index:1, in Sk[3]
# match=True
# Sk_head[3].maxID: 1 3 7
# Sk[0]:[total count: 2, distinct: 0, max: 52 6 3 53],[[ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[1]:[total count: 1, distinct: 0, max: ],[[ID: 5, count: 1]]
# Sk[2]:[total count: 2, distinct: 0, max: 54 1 6 55],[[ID: 2, count: 1], [ID: 5, count: 1]]
# Sk[3]:[total count: 3, distinct: 0, max: 3],[[ID: 1, count: 1], [ID: 5, count: 1], [ID: 0, count: 1]]
# e_max:[ID: 52 6 3 53, count: 1] after UpdateSK()
# Top after read 3:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1]]
#
#
# read 19-th element: 1 65 66 67 68 3
# send 1 65 66 67 68 3 into Sk
# 	[ID: 1 65 66 67 68 3, count: 1] -> [ID: 0, count: 1],send to Sk[1]
# index=-99
# len(Sk[1]<width:True,length=1
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[1]: [total count: 2, distinct: 0, max: ]
# e_max before update:[ID: 52 6 3 53, count: 1]
# Sk[1]:[[ID: 5, count: 1], [ID: 0, count: 1]] before update e_max
# index:1,max_id:2, max_id_index:-99, in Sk[1]
# match=True
# Sk[0]:[total count: 2, distinct: 0, max: 52 6 3 53],[[ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 1 65 66 67 68 3],[[ID: 5, count: 1], [ID: 0, count: 1]]
# Sk[2]:[total count: 2, distinct: 0, max: 54 1 6 55],[[ID: 2, count: 1], [ID: 5, count: 1]]
# Sk[3]:[total count: 3, distinct: 0, max: 3],[[ID: 1, count: 1], [ID: 5, count: 1], [ID: 0, count: 1]]
# e_max:[ID: 52 6 3 53, count: 1] after UpdateSK()
# Top after read 1 65 66 67 68 3:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1]]
#
#
# read 20-th element: 69 11 1 6
# send 69 11 1 6 into Sk
# 	[ID: 69 11 1 6, count: 1] -> [ID: 5, count: 1],send to Sk[3]
# index=1
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 4, distinct: 0, max: 3]
# e_max before update:[ID: 52 6 3 53, count: 1]
# Sk[3]:[[ID: 1, count: 1], [ID: 5, count: 2], [ID: 0, count: 1]] before update e_max
# index:1,max_id:0, max_id_index:2, in Sk[3]
# match=True
# Sk_head[3].maxID: 3
# Sk[0]:[total count: 2, distinct: 0, max: 52 6 3 53],[[ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 1 65 66 67 68 3],[[ID: 5, count: 1], [ID: 0, count: 1]]
# Sk[2]:[total count: 2, distinct: 0, max: 54 1 6 55],[[ID: 2, count: 1], [ID: 5, count: 1]]
# Sk[3]:[total count: 4, distinct: 0, max: 69 11 1 6],[[ID: 5, count: 2], [ID: 1, count: 1], [ID: 0, count: 1]]
# e_max:[ID: 69 11 1 6, count: 2] after UpdateSK()
# Top after read 69 11 1 6:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1], [ID: 11 6 12 13 14 15 16, count: 1]]
#
#
# In BringBack([ID: 11 6 12 13 14 15 16, count: 1],[ID: 69 11 1 6, count: 2])
# Top after BringBack:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1]]
#
# In DeleteSK([ID: 69 11 1 6, count: 2])
# row:3,ID:5
# Sk[3]:[[ID: 5, count: 2], [ID: 1, count: 1], [ID: 0, count: 1]]
# index:0
# e_max After DeleteSk(element):[ID: , count: 0],id(e_max):2196014014360
#
# In Update_emax(Sk_head):
# 	[[total count: 2, distinct: 0, max: 52 6 3 53], [total count: 2, distinct: 0, max: 1 65 66 67 68 3], [total count: 2, distinct: 0, max: 54 1 6 55], [total count: 2, distinct: 0, max: ]]
# id(e_max):2196014014360
# item in Sk_head[]:[total count: 2, distinct: 0, max: 52 6 3 53]
# row:0
# Sk[0]:[[ID: 1, count: 1], [ID: 2, count: 1]]
# id of local max:2
# index of local max:1
# item in Sk_head[]:[total count: 2, distinct: 0, max: 1 65 66 67 68 3]
# row:1
# Sk[1]:[[ID: 5, count: 1], [ID: 0, count: 1]]
# id of local max:0
# index of local max:1
# item in Sk_head[]:[total count: 2, distinct: 0, max: 54 1 6 55]
# row:2
# Sk[2]:[[ID: 2, count: 1], [ID: 5, count: 1]]
# id of local max:5
# index of local max:1
# item in Sk_head[]:[total count: 2, distinct: 0, max: ]
# e_max after delete:[ID: 52 6 3 53, count: 1],id(e_max):2196014014360
# 	[ID: 11 6 12 13 14 15 16, count: 1] -> [ID: 1, count: 1],send to Sk[0]
# index=0
#
# Update e_max in UpdateSK():
# Sk_head[0]: [total count: 3, distinct: 0, max: 52 6 3 53]
# e_max before update:[ID: 52 6 3 53, count: 1]
# Sk[0]:[[ID: 1, count: 2], [ID: 2, count: 1]] before update e_max
# index:0,max_id:2, max_id_index:1, in Sk[0]
# match=True
# Sk_head[0].maxID: 52 6 3 53
# Sk[0]:[total count: 3, distinct: 0, max: 11 6 12 13 14 15 16],[[ID: 1, count: 2], [ID: 2, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 1 65 66 67 68 3],[[ID: 5, count: 1], [ID: 0, count: 1]]
# Sk[2]:[total count: 2, distinct: 0, max: 54 1 6 55],[[ID: 2, count: 1], [ID: 5, count: 1]]
# Sk[3]:[total count: 2, distinct: 0, max: ],[[ID: 1, count: 1], [ID: 0, count: 1]]
# e_max:[ID: 11 6 12 13 14 15 16, count: 2] after UpdateSK()
#
# read 21-th element: 11 70 6
# send 11 70 6 into Sk
# 	[ID: 11 70 6, count: 1] -> [ID: 2, count: 1],send to Sk[2]
# index=0
#
# Update e_max in UpdateSK():
# Sk_head[2]: [total count: 3, distinct: 0, max: 54 1 6 55]
# e_max before update:[ID: 11 6 12 13 14 15 16, count: 2]
# Sk[2]:[[ID: 2, count: 2], [ID: 5, count: 1]] before update e_max
# index:0,max_id:5, max_id_index:1, in Sk[2]
# match=True
# Sk_head[2].maxID: 54 1 6 55
# Sk[0]:[total count: 3, distinct: 0, max: 11 6 12 13 14 15 16],[[ID: 1, count: 2], [ID: 2, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 1 65 66 67 68 3],[[ID: 5, count: 1], [ID: 0, count: 1]]
# Sk[2]:[total count: 3, distinct: 0, max: 11 70 6],[[ID: 2, count: 2], [ID: 5, count: 1]]
# Sk[3]:[total count: 2, distinct: 0, max: ],[[ID: 1, count: 1], [ID: 0, count: 1]]
# e_max:[ID: 11 6 12 13 14 15 16, count: 2] after UpdateSK()
# Top after read 11 70 6:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1], [ID: 9 10, count: 1]]
#
#
# In BringBack([ID: 9 10, count: 1],[ID: 11 6 12 13 14 15 16, count: 2])
# Top after BringBack:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1]]
#
# In DeleteSK([ID: 11 6 12 13 14 15 16, count: 2])
# row:0,ID:1
# Sk[0]:[[ID: 1, count: 2], [ID: 2, count: 1]]
# index:0
# e_max After DeleteSk(element):[ID: , count: 0],id(e_max):2196014014360
#
# In Update_emax(Sk_head):
# 	[[total count: 1, distinct: 0, max: ], [total count: 2, distinct: 0, max: 1 65 66 67 68 3], [total count: 3, distinct: 0, max: 11 70 6], [total count: 2, distinct: 0, max: ]]
# id(e_max):2196014014360
# item in Sk_head[]:[total count: 1, distinct: 0, max: ]
# item in Sk_head[]:[total count: 2, distinct: 0, max: 1 65 66 67 68 3]
# row:1
# Sk[1]:[[ID: 5, count: 1], [ID: 0, count: 1]]
# id of local max:0
# index of local max:1
# item in Sk_head[]:[total count: 3, distinct: 0, max: 11 70 6]
# row:2
# Sk[2]:[[ID: 2, count: 2], [ID: 5, count: 1]]
# id of local max:2
# index of local max:0
# item in Sk_head[]:[total count: 2, distinct: 0, max: ]
# e_max after delete:[ID: 11 70 6, count: 2],id(e_max):2196014014360
# 	[ID: 9 10, count: 1] -> [ID: 1, count: 1],send to Sk[2]
# index=-99
# len(Sk[2]<width:True,length=2
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[2]: [total count: 4, distinct: 0, max: 11 70 6]
# e_max before update:[ID: 11 70 6, count: 2]
# Sk[2]:[[ID: 2, count: 2], [ID: 5, count: 1], [ID: 1, count: 1]] before update e_max
# index:2,max_id:2, max_id_index:0, in Sk[2]
# match=True
# Sk_head[2].maxID: 11 70 6
# Sk[0]:[total count: 1, distinct: 0, max: ],[[ID: 2, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 1 65 66 67 68 3],[[ID: 5, count: 1], [ID: 0, count: 1]]
# Sk[2]:[total count: 4, distinct: 0, max: 11 70 6],[[ID: 2, count: 2], [ID: 5, count: 1], [ID: 1, count: 1]]
# Sk[3]:[total count: 2, distinct: 0, max: ],[[ID: 1, count: 1], [ID: 0, count: 1]]
# e_max:[ID: 11 70 6, count: 2] after UpdateSK()
#
# read 22-th element: 6 3 71
# send 6 3 71 into Sk
# 	[ID: 6 3 71, count: 1] -> [ID: 5, count: 1],send to Sk[1]
# index=0
#
# Update e_max in UpdateSK():
# Sk_head[1]: [total count: 3, distinct: 0, max: 1 65 66 67 68 3]
# e_max before update:[ID: 11 70 6, count: 2]
# Sk[1]:[[ID: 5, count: 2], [ID: 0, count: 1]] before update e_max
# index:0,max_id:0, max_id_index:1, in Sk[1]
# match=True
# Sk_head[1].maxID: 1 65 66 67 68 3
# Sk[0]:[total count: 1, distinct: 0, max: ],[[ID: 2, count: 1]]
# Sk[1]:[total count: 3, distinct: 0, max: 6 3 71],[[ID: 5, count: 2], [ID: 0, count: 1]]
# Sk[2]:[total count: 4, distinct: 0, max: 11 70 6],[[ID: 2, count: 2], [ID: 5, count: 1], [ID: 1, count: 1]]
# Sk[3]:[total count: 2, distinct: 0, max: ],[[ID: 1, count: 1], [ID: 0, count: 1]]
# e_max:[ID: 11 70 6, count: 2] after UpdateSK()
# Top after read 6 3 71:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1]]
#
#
# In BringBack([ID: 1 8, count: 1],[ID: 11 70 6, count: 2])
# Top after BringBack:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 11 70 6, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1]]
#
# In DeleteSK([ID: 11 70 6, count: 2])
# row:2,ID:2
# Sk[2]:[[ID: 2, count: 2], [ID: 5, count: 1], [ID: 1, count: 1]]
# index:0
# e_max After DeleteSk(element):[ID: , count: 0],id(e_max):2196014014360
#
# In Update_emax(Sk_head):
# 	[[total count: 1, distinct: 0, max: ], [total count: 3, distinct: 0, max: 6 3 71], [total count: 2, distinct: 0, max: ], [total count: 2, distinct: 0, max: ]]
# id(e_max):2196014014360
# item in Sk_head[]:[total count: 1, distinct: 0, max: ]
# item in Sk_head[]:[total count: 3, distinct: 0, max: 6 3 71]
# row:1
# Sk[1]:[[ID: 5, count: 2], [ID: 0, count: 1]]
# id of local max:5
# index of local max:0
# item in Sk_head[]:[total count: 2, distinct: 0, max: ]
# item in Sk_head[]:[total count: 2, distinct: 0, max: ]
# e_max after delete:[ID: 6 3 71, count: 2],id(e_max):2196014014360
# 	[ID: 1 8, count: 1] -> [ID: 2, count: 1],send to Sk[2]
# index=-99
# len(Sk[2]<width:True,length=2
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[2]: [total count: 3, distinct: 0, max: ]
# e_max before update:[ID: 6 3 71, count: 2]
# Sk[2]:[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]] before update e_max
# index:2,max_id:2, max_id_index:2, in Sk[2]
# match=True
# Sk_head[2].maxID:
# Sk[0]:[total count: 1, distinct: 0, max: ],[[ID: 2, count: 1]]
# Sk[1]:[total count: 3, distinct: 0, max: 6 3 71],[[ID: 5, count: 2], [ID: 0, count: 1]]
# Sk[2]:[total count: 3, distinct: 0, max: 1 8],[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 2, distinct: 0, max: ],[[ID: 1, count: 1], [ID: 0, count: 1]]
# e_max:[ID: 6 3 71, count: 2] after UpdateSK()
#
# read 23-th element: 72 6 73
# send 72 6 73 into Sk
# 	[ID: 72 6 73, count: 1] -> [ID: 5, count: 1],send to Sk[3]
# index=-99
# len(Sk[3]<width:True,length=2
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 3, distinct: 0, max: ]
# e_max before update:[ID: 6 3 71, count: 2]
# Sk[3]:[[ID: 1, count: 1], [ID: 0, count: 1], [ID: 5, count: 1]] before update e_max
# index:2,max_id:2, max_id_index:-99, in Sk[3]
# match=True
# Sk[0]:[total count: 1, distinct: 0, max: ],[[ID: 2, count: 1]]
# Sk[1]:[total count: 3, distinct: 0, max: 6 3 71],[[ID: 5, count: 2], [ID: 0, count: 1]]
# Sk[2]:[total count: 3, distinct: 0, max: 1 8],[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 3, distinct: 0, max: 72 6 73],[[ID: 1, count: 1], [ID: 0, count: 1], [ID: 5, count: 1]]
# e_max:[ID: 6 3 71, count: 2] after UpdateSK()
# Top after read 72 6 73:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 11 70 6, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1]]
#
#
# In BringBack([ID: 4 5 6 7, count: 1],[ID: 6 3 71, count: 2])
# Top after BringBack:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 11 70 6, count: 2], [ID: 6 3 71, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1]]
#
# In DeleteSK([ID: 6 3 71, count: 2])
# row:1,ID:5
# Sk[1]:[[ID: 5, count: 2], [ID: 0, count: 1]]
# index:0
# e_max After DeleteSk(element):[ID: , count: 0],id(e_max):2196014014360
#
# In Update_emax(Sk_head):
# 	[[total count: 1, distinct: 0, max: ], [total count: 1, distinct: 0, max: ], [total count: 3, distinct: 0, max: 1 8], [total count: 3, distinct: 0, max: 72 6 73]]
# id(e_max):2196014014360
# item in Sk_head[]:[total count: 1, distinct: 0, max: ]
# item in Sk_head[]:[total count: 1, distinct: 0, max: ]
# item in Sk_head[]:[total count: 3, distinct: 0, max: 1 8]
# row:2
# Sk[2]:[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# id of local max:2
# index of local max:2
# item in Sk_head[]:[total count: 3, distinct: 0, max: 72 6 73]
# row:3
# Sk[3]:[[ID: 1, count: 1], [ID: 0, count: 1], [ID: 5, count: 1]]
# id of local max:5
# index of local max:2
# e_max after delete:[ID: 1 8, count: 1],id(e_max):2196014014360
# 	[ID: 4 5 6 7, count: 1] -> [ID: 2, count: 1],send to Sk[0]
# index=0
#
# Update e_max in UpdateSK():
# Sk_head[0]: [total count: 2, distinct: 0, max: ]
# e_max before update:[ID: 1 8, count: 1]
# Sk[0]:[[ID: 2, count: 2]] before update e_max
# index:0,max_id:2, max_id_index:0, in Sk[0]
# match=True
# Sk_head[0].maxID:
# Sk[0]:[total count: 2, distinct: 0, max: 4 5 6 7],[[ID: 2, count: 2]]
# Sk[1]:[total count: 1, distinct: 0, max: ],[[ID: 0, count: 1]]
# Sk[2]:[total count: 3, distinct: 0, max: 1 8],[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 3, distinct: 0, max: 72 6 73],[[ID: 1, count: 1], [ID: 0, count: 1], [ID: 5, count: 1]]
# e_max:[ID: 4 5 6 7, count: 2] after UpdateSK()
#
# read 24-th element: 74
# send 74 into Sk
# 	[ID: 74, count: 1] -> [ID: 2, count: 1],send to Sk[0]
# index=0
#
# Update e_max in UpdateSK():
# Sk_head[0]: [total count: 3, distinct: 0, max: 4 5 6 7]
# e_max before update:[ID: 4 5 6 7, count: 2]
# Sk[0]:[[ID: 2, count: 3]] before update e_max
# index:0,max_id:2, max_id_index:0, in Sk[0]
# match=True
# Sk_head[0].maxID: 4 5 6 7
# Sk[0]:[total count: 3, distinct: 0, max: 74],[[ID: 2, count: 3]]
# Sk[1]:[total count: 1, distinct: 0, max: ],[[ID: 0, count: 1]]
# Sk[2]:[total count: 3, distinct: 0, max: 1 8],[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 3, distinct: 0, max: 72 6 73],[[ID: 1, count: 1], [ID: 0, count: 1], [ID: 5, count: 1]]
# e_max:[ID: 74, count: 3] after UpdateSK()
# Top after read 74:
# 	[[ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 11 70 6, count: 2], [ID: 6 3 71, count: 2], [ID: 1 2 3, count: 1], [ID: 1, count: 1]]
#
#
# In BringBack([ID: 1, count: 1],[ID: 74, count: 3])
# Top after BringBack:
# 	[[ID: 74, count: 3], [ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 11 70 6, count: 2], [ID: 6 3 71, count: 2], [ID: 1 2 3, count: 1]]
#
# In DeleteSK([ID: 74, count: 3])
# row:0,ID:2
# Sk[0]:[[ID: 2, count: 3]]
# index:0
# e_max After DeleteSk(element):[ID: , count: 0],id(e_max):2196014014360
#
# In Update_emax(Sk_head):
# 	[[total count: 0, distinct: 0, max: ], [total count: 1, distinct: 0, max: ], [total count: 3, distinct: 0, max: 1 8], [total count: 3, distinct: 0, max: 72 6 73]]
# id(e_max):2196014014360
# item in Sk_head[]:[total count: 0, distinct: 0, max: ]
# item in Sk_head[]:[total count: 1, distinct: 0, max: ]
# item in Sk_head[]:[total count: 3, distinct: 0, max: 1 8]
# row:2
# Sk[2]:[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# id of local max:2
# index of local max:2
# item in Sk_head[]:[total count: 3, distinct: 0, max: 72 6 73]
# row:3
# Sk[3]:[[ID: 1, count: 1], [ID: 0, count: 1], [ID: 5, count: 1]]
# id of local max:5
# index of local max:2
# e_max after delete:[ID: 1 8, count: 1],id(e_max):2196014014360
# 	[ID: 1, count: 1] -> [ID: 4, count: 1],send to Sk[1]
# index=-99
# len(Sk[1]<width:True,length=1
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[1]: [total count: 2, distinct: 0, max: ]
# e_max before update:[ID: 1 8, count: 1]
# Sk[1]:[[ID: 0, count: 1], [ID: 4, count: 1]] before update e_max
# index:1,max_id:2, max_id_index:-99, in Sk[1]
# match=True
# Sk[0]:[total count: 0, distinct: 0, max: ],[]
# Sk[1]:[total count: 2, distinct: 0, max: 1],[[ID: 0, count: 1], [ID: 4, count: 1]]
# Sk[2]:[total count: 3, distinct: 0, max: 1 8],[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 3, distinct: 0, max: 72 6 73],[[ID: 1, count: 1], [ID: 0, count: 1], [ID: 5, count: 1]]
# e_max:[ID: 1 8, count: 1] after UpdateSK()
#
# read 25-th element: 75 76
# send 75 76 into Sk
# 	[ID: 75 76, count: 1] -> [ID: 0, count: 1],send to Sk[3]
# index=1
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 4, distinct: 0, max: 72 6 73]
# e_max before update:[ID: 1 8, count: 1]
# Sk[3]:[[ID: 1, count: 1], [ID: 0, count: 2], [ID: 5, count: 1]] before update e_max
# index:1,max_id:5, max_id_index:2, in Sk[3]
# match=True
# Sk_head[3].maxID: 72 6 73
# Sk[0]:[total count: 0, distinct: 0, max: ],[]
# Sk[1]:[total count: 2, distinct: 0, max: 1],[[ID: 0, count: 1], [ID: 4, count: 1]]
# Sk[2]:[total count: 3, distinct: 0, max: 1 8],[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 4, distinct: 0, max: 75 76],[[ID: 0, count: 2], [ID: 1, count: 1], [ID: 5, count: 1]]
# e_max:[ID: 75 76, count: 2] after UpdateSK()
# Top after read 75 76:
# 	[[ID: 74, count: 3], [ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 11 70 6, count: 2], [ID: 6 3 71, count: 2], [ID: 1 2 3, count: 1]]
#
#
# In BringBack([ID: 1 2 3, count: 1],[ID: 75 76, count: 2])
# Top after BringBack:
# 	[[ID: 74, count: 3], [ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 11 70 6, count: 2], [ID: 6 3 71, count: 2], [ID: 75 76, count: 2]]
#
# In DeleteSK([ID: 75 76, count: 2])
# row:3,ID:0
# Sk[3]:[[ID: 0, count: 2], [ID: 1, count: 1], [ID: 5, count: 1]]
# index:0
# e_max After DeleteSk(element):[ID: , count: 0],id(e_max):2196014014360
#
# In Update_emax(Sk_head):
# 	[[total count: 0, distinct: 0, max: ], [total count: 2, distinct: 0, max: 1], [total count: 3, distinct: 0, max: 1 8], [total count: 2, distinct: 0, max: ]]
# id(e_max):2196014014360
# item in Sk_head[]:[total count: 0, distinct: 0, max: ]
# item in Sk_head[]:[total count: 2, distinct: 0, max: 1]
# row:1
# Sk[1]:[[ID: 0, count: 1], [ID: 4, count: 1]]
# id of local max:4
# index of local max:1
# item in Sk_head[]:[total count: 3, distinct: 0, max: 1 8]
# row:2
# Sk[2]:[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# id of local max:2
# index of local max:2
# item in Sk_head[]:[total count: 2, distinct: 0, max: ]
# e_max after delete:[ID: 1, count: 1],id(e_max):2196014014360
# 	[ID: 1 2 3, count: 1] -> [ID: 4, count: 1],send to Sk[0]
# len(Sk[row])<width:True
#
# Update e_max in UpdateSK():
# Sk_head[0]: [total count: 1, distinct: 0, max: 1 2 3]
# e_max before update:[ID: 1, count: 1]
# Sk[0]:[[ID: 4, count: 1]] before update e_max
# index:0,max_id:4, max_id_index:0, in Sk[0]
# match=True
# Sk_head[0].maxID: 1 2 3
# Sk[0]:[total count: 1, distinct: 0, max: 1 2 3],[[ID: 4, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 1],[[ID: 0, count: 1], [ID: 4, count: 1]]
# Sk[2]:[total count: 3, distinct: 0, max: 1 8],[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 2, distinct: 0, max: ],[[ID: 1, count: 1], [ID: 5, count: 1]]
# e_max:[ID: 1, count: 1] after UpdateSK()
#
# read 26-th element: 6 3 77
# send 6 3 77 into Sk
# 	[ID: 6 3 77, count: 1] -> [ID: 2, count: 1],send to Sk[3]
# index=-99
# len(Sk[3]<width:True,length=2
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 3, distinct: 0, max: ]
# e_max before update:[ID: 1, count: 1]
# Sk[3]:[[ID: 1, count: 1], [ID: 5, count: 1], [ID: 2, count: 1]] before update e_max
# index:2,max_id:2, max_id_index:2, in Sk[3]
# match=True
# Sk_head[3].maxID:
# Sk[0]:[total count: 1, distinct: 0, max: 1 2 3],[[ID: 4, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 1],[[ID: 0, count: 1], [ID: 4, count: 1]]
# Sk[2]:[total count: 3, distinct: 0, max: 1 8],[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 3, distinct: 0, max: 6 3 77],[[ID: 1, count: 1], [ID: 5, count: 1], [ID: 2, count: 1]]
# e_max:[ID: 1, count: 1] after UpdateSK()
# Top after read 6 3 77:
# 	[[ID: 74, count: 3], [ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 11 70 6, count: 2], [ID: 6 3 71, count: 2], [ID: 75 76, count: 2]]
#
#
# read 27-th element: 78 79 80 81
# send 78 79 80 81 into Sk
# 	[ID: 78 79 80 81, count: 1] -> [ID: 3, count: 1],send to Sk[0]
# index=-99
# len(Sk[0]<width:True,length=1
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[0]: [total count: 2, distinct: 0, max: 1 2 3]
# e_max before update:[ID: 1, count: 1]
# Sk[0]:[[ID: 4, count: 1], [ID: 3, count: 1]] before update e_max
# index:1,max_id:4, max_id_index:0, in Sk[0]
# match=True
# Sk_head[0].maxID: 1 2 3
# Sk[0]:[total count: 2, distinct: 0, max: 78 79 80 81],[[ID: 4, count: 1], [ID: 3, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 1],[[ID: 0, count: 1], [ID: 4, count: 1]]
# Sk[2]:[total count: 3, distinct: 0, max: 1 8],[[ID: 5, count: 1], [ID: 1, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 3, distinct: 0, max: 6 3 77],[[ID: 1, count: 1], [ID: 5, count: 1], [ID: 2, count: 1]]
# e_max:[ID: 1, count: 1] after UpdateSK()
# Top after read 78 79 80 81:
# 	[[ID: 74, count: 3], [ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 11 70 6, count: 2], [ID: 6 3 71, count: 2], [ID: 75 76, count: 2]]
#
#
# read 28-th element: 82 6 83 7 84 85 86 87 88
# send 82 6 83 7 84 85 86 87 88 into Sk
# 	[ID: 82 6 83 7 84 85 86 87 88, count: 1] -> [ID: 1, count: 1],send to Sk[2]
# index=1
#
# Update e_max in UpdateSK():
# Sk_head[2]: [total count: 4, distinct: 0, max: 1 8]
# e_max before update:[ID: 1, count: 1]
# Sk[2]:[[ID: 5, count: 1], [ID: 1, count: 2], [ID: 2, count: 1]] before update e_max
# index:1,max_id:2, max_id_index:2, in Sk[2]
# match=True
# Sk_head[2].maxID: 1 8
# Sk[0]:[total count: 2, distinct: 0, max: 78 79 80 81],[[ID: 4, count: 1], [ID: 3, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 1],[[ID: 0, count: 1], [ID: 4, count: 1]]
# Sk[2]:[total count: 4, distinct: 0, max: 82 6 83 7 84 85 86 87 88],[[ID: 1, count: 2], [ID: 5, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 3, distinct: 0, max: 6 3 77],[[ID: 1, count: 1], [ID: 5, count: 1], [ID: 2, count: 1]]
# e_max:[ID: 82 6 83 7 84 85 86 87 88, count: 2] after UpdateSK()
# Top after read 82 6 83 7 84 85 86 87 88:
# 	[[ID: 74, count: 3], [ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 11 70 6, count: 2], [ID: 6 3 71, count: 2], [ID: 75 76, count: 2]]
#
#
# read 29-th element: 11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137
# send 11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137 into Sk
# 	[ID: 11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count: 1] -> [ID: 1, count: 1],send to Sk[3]
# index=0
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 4, distinct: 0, max: 6 3 77]
# e_max before update:[ID: 82 6 83 7 84 85 86 87 88, count: 2]
# Sk[3]:[[ID: 1, count: 2], [ID: 5, count: 1], [ID: 2, count: 1]] before update e_max
# index:0,max_id:2, max_id_index:2, in Sk[3]
# match=True
# Sk_head[3].maxID: 6 3 77
# Sk[0]:[total count: 2, distinct: 0, max: 78 79 80 81],[[ID: 4, count: 1], [ID: 3, count: 1]]
# Sk[1]:[total count: 2, distinct: 0, max: 1],[[ID: 0, count: 1], [ID: 4, count: 1]]
# Sk[2]:[total count: 4, distinct: 0, max: 82 6 83 7 84 85 86 87 88],[[ID: 1, count: 2], [ID: 5, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 4, distinct: 0, max: 11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137],[[ID: 1, count: 2], [ID: 5, count: 1], [ID: 2, count: 1]]
# e_max:[ID: 82 6 83 7 84 85 86 87 88, count: 2] after UpdateSK()
# Top after read 11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137:
# 	[[ID: 74, count: 3], [ID: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count: 2], [ID: 11 6 56 57 58 59 60 61 62 63 64, count: 2], [ID: 69 11 1 6, count: 2], [ID: 11 6 12 13 14 15 16, count: 2], [ID: 11 70 6, count: 2], [ID: 6 3 71, count: 2], [ID: 75 76, count: 2]]
#
#
ID: 5, count: 1], [ID: 2, count: 1]]
# Sk[3]:[total count: 6, distinct: 0, max: 75 76],[[ID: 1, count: 2], [ID: 0, count: 2], [ID: 5, count: 1], [ID: 2, count: 1]]
# e_max:[ID: 6 138, count: 2] after UpdateSK()
#
# read 32-th element: 6 3
# send 6 3 into Sk
# 	[ID: 6 3, count: 1] -> [ID: 1, count: 1],send to Sk[3]
# index=0
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 7, distinct: 0, max: 75 76]
# e_max before update:[ID: 6 138, count: 2]
# Sk[3]:[[ID: 1, count: 3], [ID: 0, count: 2], [ID: 5, count: 1], [ID: 2, count: 1]] before update e_max
# index:0,max_id:0, max_id_index:1, in Sk[3]
# match=True
# Sk_head[3].maxID: 75 76
# ...
# id of local max:4
# index of local max:1
# item in Sk_head[]:[total count: 17, distinct: 0, max: ]
# e_max after delete:[ID: 1 6 91 594, count: 5],id(e_max):2196014014360
# 	[ID: 487 6 3, count: 5] -> [ID: 1, count: 5],send to Sk[2]
# index=2
#
# Update e_max in UpdateSK():
# Sk_head[2]: [total count: 27, distinct: 0, max: 69 11 6 55]
# e_max before update:[ID: 1 6 91 594, count: 5]
# Sk[2]:[[ID: 5, count: 5], [ID: 4, count: 5], [ID: 1, count: 9], [ID: 3, count: 2]] before update e_max
# index:2,max_id:4, max_id_index:1, in Sk[2]
# match=True
# Sk_head[2].maxID: 69 11 6 55
# Sk[0]:[total count: 23, distinct: 0, max: 1 6 91 594],[[ID: 1, count: 5], [ID: 3, count: 4], [ID: 2, count: 3], [ID: 5, count: 1]]
# Sk[1]:[total count: 26, distinct: 0, max: 11 6 3 7],[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 1]]
# Sk[2]:[total count: 27, distinct: 0, max: 487 6 3],[[ID: 1, count: 9], [ID: 5, count: 5], [ID: 4, count: 5], [ID: 3, count: 2]]
# Sk[3]:[total count: 17, distinct: 0, max: ],[[ID: 2, count: 5], [ID: 3, count: 3]]
# e_max:[ID: 487 6 3, count: 9] after UpdateSK()
#
# read 145-th element: 598 3 7
# send 598 3 7 into Sk
# 	[ID: 598 3 7, count: 1] -> [ID: 1, count: 1],send to Sk[3]
# index=-99
# len(Sk[3]<width:True,length=2
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 18, distinct: 0, max: ]
# e_max before update:[ID: 487 6 3, count: 9]
# Sk[3]:[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 1, count: 1]] before update e_max
# index:2,max_id:2, max_id_index:0, in Sk[3]
# match=True
# Sk_head[3].maxID:
# Sk[0]:[total count: 23, distinct: 0, max: 1 6 91 594],[[ID: 1, count: 5], [ID: 3, count: 4], [ID: 2, count: 3], [ID: 5, count: 1]]
# Sk[1]:[total count: 26, distinct: 0, max: 11 6 3 7],[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 1]]
# Sk[2]:[total count: 27, distinct: 0, max: 487 6 3],[[ID: 1, count: 9], [ID: 5, count: 5], [ID: 4, count: 5], [ID: 3, count: 2]]
# Sk[3]:[total count: 18, distinct: 0, max: 598 3 7],[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 1, count: 1]]
# e_max:[ID: 487 6 3, count: 9] after UpdateSK()
# Top after read 598 3 7:
# 	[[ID: 69 11 218 6 215 228 229 230 231 232 233 234 235 236 237 90 238 239 240 241 242 243 135 148 244 245, count: 8], [ID: 145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499, count: 8], [ID: 6 3, count: 7], [ID: 160 27 161 6 91 3 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 7 205 206 207 208 209 210 211 212 213 87 88 214 80, count: 6], [ID: 11 1 6 575 576 321, count: 6], [ID: 145 1 6 595 596, count: 6], [ID: 11 6 12 13 14 15 16, count: 5], [ID: 74, count: 5]]
#
#
# In BringBack([ID: 74, count: 5],[ID: 487 6 3, count: 9])
# Top after BringBack:
# 	[[ID: 487 6 3, count: 9], [ID: 69 11 218 6 215 228 229 230 231 232 233 234 235 236 237 90 238 239 240 241 242 243 135 148 244 245, count: 8], [ID: 145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499, count: 8], [ID: 6 3, count: 7], [ID: 160 27 161 6 91 3 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 7 205 206 207 208 209 210 211 212 213 87 88 214 80, count: 6], [ID: 11 1 6 575 576 321, count: 6], [ID: 145 1 6 595 596, count: 6], [ID: 11 6 12 13 14 15 16, count: 5]]
#
# In DeleteSK([ID: 487 6 3, count: 9])
# row:2,ID:1
# Sk[2]:[[ID: 1, count: 9], [ID: 5, count: 5], [ID: 4, count: 5], [ID: 3, count: 2]]
# index:0
# e_max After DeleteSk(element):[ID: , count: 0],id(e_max):2196014014360
#
# In Update_emax(Sk_head):
# 	[[total count: 23, distinct: 0, max: 1 6 91 594], [total count: 26, distinct: 0, max: 11 6 3 7], [total count: 18, distinct: 0, max: ], [total count: 18, distinct: 0, max: 598 3 7]]
# id(e_max):2196014014360
# item in Sk_head[]:[total count: 23, distinct: 0, max: 1 6 91 594]
# row:0
# Sk[0]:[[ID: 1, count: 5], [ID: 3, count: 4], [ID: 2, count: 3], [ID: 5, count: 1]]
# id of local max:1
# index of local max:0
# item in Sk_head[]:[total count: 26, distinct: 0, max: 11 6 3 7]
# row:1
# Sk[1]:[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 1]]
# id of local max:1
# index of local max:1
# item in Sk_head[]:[total count: 18, distinct: 0, max: ]
# item in Sk_head[]:[total count: 18, distinct: 0, max: 598 3 7]
# row:3
# Sk[3]:[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 1, count: 1]]
# id of local max:1
# index of local max:2
# e_max after delete:[ID: 1 6 91 594, count: 5],id(e_max):2196014014360
# 	[ID: 74, count: 5] -> [ID: 2, count: 5],send to Sk[0]
# index=2
#
# Update e_max in UpdateSK():
# Sk_head[0]: [total count: 28, distinct: 0, max: 1 6 91 594]
# e_max before update:[ID: 1 6 91 594, count: 5]
# Sk[0]:[[ID: 1, count: 5], [ID: 3, count: 4], [ID: 2, count: 8], [ID: 5, count: 1]] before update e_max
# index:2,max_id:1, max_id_index:0, in Sk[0]
# match=True
# Sk_head[0].maxID: 1 6 91 594
# Sk[0]:[total count: 28, distinct: 0, max: 74],[[ID: 2, count: 8], [ID: 1, count: 5], [ID: 3, count: 4], [ID: 5, count: 1]]
# Sk[1]:[total count: 26, distinct: 0, max: 11 6 3 7],[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 1]]
# Sk[2]:[total count: 18, distinct: 0, max: ],[[ID: 5, count: 5], [ID: 4, count: 5], [ID: 3, count: 2]]
# Sk[3]:[total count: 18, distinct: 0, max: 598 3 7],[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 1, count: 1]]
# e_max:[ID: 74, count: 8] after UpdateSK()
#
# read 146-th element: 131 599
# send 131 599 into Sk
# 	[ID: 131 599, count: 1] -> [ID: 0, count: 1],send to Sk[1]
# index=3
#
# Update e_max in UpdateSK():
# Sk_head[1]: [total count: 27, distinct: 0, max: 11 6 3 7]
# e_max before update:[ID: 74, count: 8]
# Sk[1]:[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 2]] before update e_max
# index:3,max_id:1, max_id_index:1, in Sk[1]
# match=True
# Sk_head[1].maxID: 11 6 3 7
# Sk[0]:[total count: 28, distinct: 0, max: 74],[[ID: 2, count: 8], [ID: 1, count: 5], [ID: 3, count: 4], [ID: 5, count: 1]]
# Sk[1]:[total count: 27, distinct: 0, max: 11 6 3 7],[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 2]]
# Sk[2]:[total count: 18, distinct: 0, max: ],[[ID: 5, count: 5], [ID: 4, count: 5], [ID: 3, count: 2]]
# Sk[3]:[total count: 18, distinct: 0, max: 598 3 7],[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 1, count: 1]]
# e_max:[ID: 74, count: 8] after UpdateSK()
# Top after read 131 599:
# 	[[ID: 487 6 3, count: 9], [ID: 69 11 218 6 215 228 229 230 231 232 233 234 235 236 237 90 238 239 240 241 242 243 135 148 244 245, count: 8], [ID: 145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499, count: 8], [ID: 6 3, count: 7], [ID: 160 27 161 6 91 3 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 7 205 206 207 208 209 210 211 212 213 87 88 214 80, count: 6], [ID: 11 1 6 575 576 321, count: 6], [ID: 145 1 6 595 596, count: 6], [ID: 11 6 12 13 14 15 16, count: 5]]
#
#
# In BringBack([ID: 11 6 12 13 14 15 16, count: 5],[ID: 74, count: 8])
# Top after BringBack:
# 	[[ID: 487 6 3, count: 9], [ID: 69 11 218 6 215 228 229 230 231 232 233 234 235 236 237 90 238 239 240 241 242 243 135 148 244 245, count: 8], [ID: 145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499, count: 8], [ID: 74, count: 8], [ID: 6 3, count: 7], [ID: 160 27 161 6 91 3 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 7 205 206 207 208 209 210 211 212 213 87 88 214 80, count: 6], [ID: 11 1 6 575 576 321, count: 6], [ID: 145 1 6 595 596, count: 6]]
#
# In DeleteSK([ID: 74, count: 8])
# row:0,ID:2
# Sk[0]:[[ID: 2, count: 8], [ID: 1, count: 5], [ID: 3, count: 4], [ID: 5, count: 1]]
# index:0
# e_max After DeleteSk(element):[ID: , count: 0],id(e_max):2196014014360
#
# In Update_emax(Sk_head):
# 	[[total count: 20, distinct: 0, max: ], [total count: 27, distinct: 0, max: 11 6 3 7], [total count: 18, distinct: 0, max: ], [total count: 18, distinct: 0, max: 598 3 7]]
# id(e_max):2196014014360
# item in Sk_head[]:[total count: 20, distinct: 0, max: ]
# item in Sk_head[]:[total count: 27, distinct: 0, max: 11 6 3 7]
# row:1
# Sk[1]:[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 2]]
# id of local max:1
# index of local max:1
# item in Sk_head[]:[total count: 18, distinct: 0, max: ]
# item in Sk_head[]:[total count: 18, distinct: 0, max: 598 3 7]
# row:3
# Sk[3]:[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 1, count: 1]]
# id of local max:1
# index of local max:2
# e_max after delete:[ID: 11 6 3 7, count: 5],id(e_max):2196014014360
# 	[ID: 11 6 12 13 14 15 16, count: 5] -> [ID: 1, count: 5],send to Sk[0]
# index=0
#
# Update e_max in UpdateSK():
# Sk_head[0]: [total count: 25, distinct: 0, max: ]
# e_max before update:[ID: 11 6 3 7, count: 5]
# Sk[0]:[[ID: 1, count: 10], [ID: 3, count: 4], [ID: 5, count: 1]] before update e_max
# index:0,max_id:2, max_id_index:-99, in Sk[0]
# match=True
# Sk[0]:[total count: 25, distinct: 0, max: 11 6 12 13 14 15 16],[[ID: 1, count: 10], [ID: 3, count: 4], [ID: 5, count: 1]]
# Sk[1]:[total count: 27, distinct: 0, max: 11 6 3 7],[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 2]]
# Sk[2]:[total count: 18, distinct: 0, max: ],[[ID: 5, count: 5], [ID: 4, count: 5], [ID: 3, count: 2]]
# Sk[3]:[total count: 18, distinct: 0, max: 598 3 7],[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 1, count: 1]]
# e_max:[ID: 11 6 3 7, count: 5] after UpdateSK()
#
# read 147-th element: 11 4 6 600
# send 11 4 6 600 into Sk
# 	[ID: 11 4 6 600, count: 1] -> [ID: 5, count: 1],send to Sk[3]
# index=-99
# len(Sk[3]<width:True,length=3
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 19, distinct: 0, max: 598 3 7]
# e_max before update:[ID: 11 6 3 7, count: 5]
# Sk[3]:[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 1, count: 1], [ID: 5, count: 1]] before update e_max
# index:3,max_id:1, max_id_index:2, in Sk[3]
# match=True
# Sk_head[3].maxID: 598 3 7
# Sk[0]:[total count: 25, distinct: 0, max: 11 6 12 13 14 15 16],[[ID: 1, count: 10], [ID: 3, count: 4], [ID: 5, count: 1]]
# Sk[1]:[total count: 27, distinct: 0, max: 11 6 3 7],[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 2]]
# Sk[2]:[total count: 18, distinct: 0, max: ],[[ID: 5, count: 5], [ID: 4, count: 5], [ID: 3, count: 2]]
# Sk[3]:[total count: 19, distinct: 0, max: 11 4 6 600],[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 1, count: 1], [ID: 5, count: 1]]
# e_max:[ID: 11 6 3 7, count: 5] after UpdateSK()
# Top after read 11 4 6 600:
# 	[[ID: 487 6 3, count: 9], [ID: 69 11 218 6 215 228 229 230 231 232 233 234 235 236 237 90 238 239 240 241 242 243 135 148 244 245, count: 8], [ID: 145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499, count: 8], [ID: 74, count: 8], [ID: 6 3, count: 7], [ID: 160 27 161 6 91 3 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 7 205 206 207 208 209 210 211 212 213 87 88 214 80, count: 6], [ID: 11 1 6 575 576 321, count: 6], [ID: 145 1 6 595 596, count: 6]]
#
#
# read 148-th element: 601
# send 601 into Sk
# 	[ID: 601, count: 1] -> [ID: 5, count: 1],send to Sk[3]
# index=3
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 20, distinct: 0, max: 11 4 6 600]
# e_max before update:[ID: 11 6 3 7, count: 5]
# Sk[3]:[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 1, count: 1], [ID: 5, count: 2]] before update e_max
# index:3,max_id:5, max_id_index:3, in Sk[3]
# match=True
# Sk_head[3].maxID: 11 4 6 600
# Sk[0]:[total count: 25, distinct: 0, max: 11 6 12 13 14 15 16],[[ID: 1, count: 10], [ID: 3, count: 4], [ID: 5, count: 1]]
# Sk[1]:[total count: 27, distinct: 0, max: 11 6 3 7],[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 2]]
# Sk[2]:[total count: 18, distinct: 0, max: ],[[ID: 5, count: 5], [ID: 4, count: 5], [ID: 3, count: 2]]
# Sk[3]:[total count: 20, distinct: 0, max: 601],[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 5, count: 2], [ID: 1, count: 1]]
# e_max:[ID: 11 6 3 7, count: 5] after UpdateSK()
# Top after read 601:
# 	[[ID: 487 6 3, count: 9], [ID: 69 11 218 6 215 228 229 230 231 232 233 234 235 236 237 90 238 239 240 241 242 243 135 148 244 245, count: 8], [ID: 145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499, count: 8], [ID: 74, count: 8], [ID: 6 3, count: 7], [ID: 160 27 161 6 91 3 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 7 205 206 207 208 209 210 211 212 213 87 88 214 80, count: 6], [ID: 11 1 6 575 576 321, count: 6], [ID: 145 1 6 595 596, count: 6]]
#
#
# read 149-th element: 602 3
# send 602 3 into Sk
# 	[ID: 602 3, count: 1] -> [ID: 2, count: 1],send to Sk[0]
# index=-99
# len(Sk[0]<width:True,length=3
# width=4
#
# Update e_max in UpdateSK():
# Sk_head[0]: [total count: 26, distinct: 0, max: 11 6 12 13 14 15 16]
# e_max before update:[ID: 11 6 3 7, count: 5]
# Sk[0]:[[ID: 1, count: 10], [ID: 3, count: 4], [ID: 5, count: 1], [ID: 2, count: 1]] before update e_max
# index:3,max_id:1, max_id_index:0, in Sk[0]
# match=True
# Sk_head[0].maxID: 11 6 12 13 14 15 16
# Sk[0]:[total count: 26, distinct: 0, max: 11 6 12 13 14 15 16],[[ID: 1, count: 10], [ID: 3, count: 4], [ID: 5, count: 1], [ID: 2, count: 1]]
# Sk[1]:[total count: 27, distinct: 0, max: 11 6 3 7],[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 2]]
# Sk[2]:[total count: 18, distinct: 0, max: ],[[ID: 5, count: 5], [ID: 4, count: 5], [ID: 3, count: 2]]
# Sk[3]:[total count: 20, distinct: 0, max: 601],[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 5, count: 2], [ID: 1, count: 1]]
# e_max:[ID: 11 6 3 7, count: 5] after UpdateSK()
# Top after read 602 3:
# 	[[ID: 487 6 3, count: 9], [ID: 69 11 218 6 215 228 229 230 231 232 233 234 235 236 237 90 238 239 240 241 242 243 135 148 244 245, count: 8], [ID: 145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499, count: 8], [ID: 74, count: 8], [ID: 6 3, count: 7], [ID: 160 27 161 6 91 3 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 7 205 206 207 208 209 210 211 212 213 87 88 214 80, count: 6], [ID: 11 1 6 575 576 321, count: 6], [ID: 145 1 6 595 596, count: 6]]
#
#
# read 150-th element: 603 6 604
# send 603 6 604 into Sk
# 	[ID: 603 6 604, count: 1] -> [ID: 1, count: 1],send to Sk[3]
# index=3
#
# Update e_max in UpdateSK():
# Sk_head[3]: [total count: 21, distinct: 0, max: 601]
# e_max before update:[ID: 11 6 3 7, count: 5]
# Sk[3]:[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 5, count: 2], [ID: 1, count: 2]] before update e_max
# index:3,max_id:5, max_id_index:2, in Sk[3]
# match=True
# Sk_head[3].maxID: 601
# Sk[0]:[total count: 26, distinct: 0, max: 11 6 12 13 14 15 16],[[ID: 1, count: 10], [ID: 3, count: 4], [ID: 5, count: 1], [ID: 2, count: 1]]
# Sk[1]:[total count: 27, distinct: 0, max: 11 6 3 7],[[ID: 2, count: 5], [ID: 1, count: 5], [ID: 5, count: 4], [ID: 0, count: 2]]
# Sk[2]:[total count: 18, distinct: 0, max: ],[[ID: 5, count: 5], [ID: 4, count: 5], [ID: 3, count: 2]]
# Sk[3]:[total count: 21, distinct: 0, max: 603 6 604],[[ID: 2, count: 5], [ID: 3, count: 3], [ID: 5, count: 2], [ID: 1, count: 2]]
# e_max:[ID: 11 6 3 7, count: 5] after UpdateSK()
# Top after read 603 6 604:
# 	[[ID: 487 6 3, count: 9], [ID: 69 11 218 6 215 228 229 230 231 232 233 234 235 236 237 90 238 239 240 241 242 243 135 148 244 245, count: 8], [ID: 145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499, count: 8], [ID: 74, count: 8], [ID: 6 3, count: 7], [ID: 160 27 161 6 91 3 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 7 205 206 207 208 209 210 211 212 213 87 88 214 80, count: 6], [ID: 11 1 6 575 576 321, count: 6], [ID: 145 1 6 595 596, count: 6]]
#
# e_max:[ID: 11 6 3 7, count: 5]
# Execution time:0.7981142997741699 seconds.

# %%
import spookyhash
import mmh3
from numpy import random
import os
import time
import operator
import hyperloglog

# ==========================data structure==========================
class Node():
    def __init__(self,count=0):
        self.count=count
    def add_count(self,count=1):
        self.count+=count
    def __str__(self):
        return 'count: {}'.format(self.count)
    def __repr__(self):
        return ''

class Head(Node):
    def __init__(self,count=1):
        super().__init__(count)
        self.distinct = hyperloglog.HyperLogLog(0.01)
        self.maxID=''
    def __str__(self):
        return '[total count: {}, distinct: {}, max: {}]'.format(self.count,len(self.distinct),self.maxID)
    def __repr__(self):
        return '[total count: {}, distinct: {}, max: {}]'.format(self.count,len(self.distinct),self.maxID)

class Tail(Node):
    def __init__(self,ID,count):
        self.ID = ID
        super().__init__(count)
    def __str__(self):
        return '[ID: {}, count: {}]'.format(self.ID,self.count)
    def __repr__(self):
        return '[ID: {}, count: {}]'.format(self.ID,self.count)
# ==========================data structure==========================


# ==========================UpdateSk==========================
def UpdateSk(element,width,depth):
    e_max=get_emax()
    hash1=spookyhash.hash32(bytes(str(element.ID),encoding='utf-8'))
        # input of spooky hash: binary, encoding is parameter of bytes()
        # output of spooky hash: unsigned- 32 bit int
    hash2=mmh3.hash(str(hash1), signed=False)
        # input of mmh3 is str, output unsigned- 32 bit int
    row=hash1 % depth
        # index of row in SK[row]
    ID=hash2 % ((width*3)//2)
        # hash-value(ID) of e
        # range: 2^k *3/2= 3*(2^k-1)
    match=False
        # match= True if e is in Sk[row]
    index=0
    avg=0
    item=Tail(ID, element.count)
        # ID in Sketch is hash value
    print("{} -> {},send to Sk[{}]".format(element,item,row))

    # ==========================update sketch==========================
    index=find(item,Sk[row])
        # 先find
    if index >=0:
        # e matches in Sk[row]
        Sk[row][index].count+=item.count
        match=True
    else:
        # e doesn't match in Sk[row]
        if len(Sk[row])==0:
            Sk[row].append(item)
            index=0
            Sk_head[row].maxID=element.ID
            match=True
        elif len(Sk[row])<width:
            # Sk[row] is not full
            Sk[row].append(item)
            index=len(Sk[row])-1            
            match=True
        else:
            # Sk[row] is full
            count_sum=sum(Sk[row][i].count for i in range(len(Sk[row])))
            if Sk_head[row].count==count_sum:
                # no other, send e into Other
                Sk_head[row].distinct.add(element.ID)
                match=False
            else:
                # something in other and total count > sum
                if len(Sk_head[row].distinct)>0:
                    avg=(Sk_head[row].count-count_sum)//len(Sk_head[row].distinct)
                    print("avg:{}".format(avg))
                else:
                    Sk_head[row].distinct.add(element.ID)
                    # print("avg< last one,send to distinct")
                    match=False
    Sk_head[row].count+=item.count
        # total count最後再+1 因為要compare distinct
    # ==========================update local max==========================
    Update_local_max(Sk_head[row],Sk[row],avg,element,index)
    # Sk[row].sort(key=operator.attrgetter('count'),reverse=True)

    # ==========================update e_max==========================
    Update_emax(Sk_head[row],Sk[row],e_max,element)
    
    Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
    for i in range(len(Sk)):
        print("Sk[{}]:{},{}".format(i,Sk_head[i],Sk[i]))
# ==========================update local max==========================    
def Update_local_max(head_item,element_list,avg,incoming_element,index):
    # Sk_head[row],Sk[row],avg
    print("In Update_local_max")
    local_max_ID=mmh3.hash(str(spookyhash.hash32(bytes(str(head_item.maxID),encoding='utf-8'))), signed=False) % ((width*3)//2)
    #print("local_max_ID:{}".format(local_max_ID))
    local_max_index=find(Tail(local_max_ID,1),element_list)
    #print("local_max_index:{}".format(local_max_index))
    # 此處當hashed ID相同時暫不更新 local max
    if local_max_index>=0:
        # local max exists
        if index>=0:
            if element_list[index].count>element_list[local_max_index].count:
                head_item.maxID=incoming_element.ID
        else:
            if avg>element_list[local_max_index].count:
                head_item.maxID=incoming_element.ID
    else:
        # local max doesn't exists
        head_item.maxID=incoming_element.ID
    

# ==========================update e_max==========================
def Update_emax(head_item,element_list,e_max,incoming_element):
    # Sk_head[row],Sk[row],e_max
    local_max_ID=""
    local_max_index=""
    print("e_max before update:{}".format(e_max))
    print("Sk_head:{}".format(head_item))
    print("Sk[row]:{}".format(element_list))
    if head_item.maxID=="":
        pass
    else:
        local_max_ID=mmh3.hash(str(spookyhash.hash32(bytes(str(head_item.maxID),encoding='utf-8'))), signed=False) % ((width*3)//2)
        #print("local_max_ID:{}".format(local_max_ID))
        local_max_index=find(Tail(local_max_ID,1),element_list)        
        #print("local_max_index:{}".format(local_max_index))
        if local_max_index>=0:
            if element_list[local_max_index].count>e_max.count:
                e_max.ID=head_item.maxID
                e_max.count=element_list[local_max_index].count
        else:
            pass
    print("e_max after update:{}".format(e_max))

# starts here, BringBack, DeleteSK的參數和Update_emax有衝突
# ========================== BringBack=========================
def BringBack(e_min,e_max,element_list,head_list):
    # Top[-1],e_max,Sk,Sk_head
    print("\nIn BringBack({},{})".format(e_min,e_max))
    e_max=get_emax()
    # print('e_max at first Bringback:{},id(e_max):{}'.format(e_max,id(e_max)))
    temp=Tail(e_min.ID,e_min.count)
    Top[-1].ID=e_max.ID
    Top[-1].count=e_max.count
    #Top.sort(key=operator.attrgetter('count'),reverse=True)
    print('Top after BringBack:\n\t{}'.format(Top))
    DeleteSk(e_max,element_list,head_list)
    # update e_max in Sk[row]
    Update_emax(head_list,element_list,e_max,incoming_element)
    print("e_max after delete:{},id(e_max):{}".format(e_max,id(e_max)))
    UpdateSk(temp,width,depth)
    
    # print("Sk[] after Update {}:\n\t{}".format(e_min,Sk))

# ========================== BringBack=========================
# ==========================DeleteSk=========================
def DeleteSk(element,element_list):
    # e_max, Sk[row]
    # 刪除e_max in Sk[row]，update local max
    e_max=get_emax()
    print("\nIn DeleteSK({}):".format(element))
    hash1=spookyhash.hash32(bytes(str(element.ID),encoding='utf-8'))
    hash2=mmh3.hash(str(hash1), signed=False)
    ID=hash2 % ((width*3)//2)
    row=hash1 % depth
    print("row:{},ID:{}".format(row,ID))
    Sk_head[row].count-=element.count
    print("Sk[{}]:{}".format(row,element_list[row]))
    index=find(Tail(ID,1),element_list[row])
    print("index:{}".format(index))
    if index<0:
        pass
    else:
        element_list[row].pop(index)
        element_list[row].sort(key=operator.attrgetter('count'),reverse=True)
        head_list[row].maxID=""
    e_max.ID=""
    e_max.count=0
    
    print("e_max After DeleteSk(element):{},id(e_max):{}".format(e_max,id(e_max)))
    '''
    print("index:{}".format(index))
    print('After pop:')
    print("\tSk[{}]={}".format(row,Sk[row]))
    print("Top:\n\t{}".format(Top))
    '''
# ==========================Tools=========================    
def get_emax():
    return e_max

def find(e,element_list):
    try:
        # type(element_list[i].ID):int
        # print("e:{}".format(e))
        # print("element_list[1:]: {}".format(element_list[1:]))
        index=[ele.ID for ele in element_list].index(e.ID)
    except:
        # print("raise error")
        index=-99
    return index                        


# ==========================main=========================   
        
start=time.time()

filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)
depth=4
width=4
size=4

Top=[]
Sk_head=[Head(0) for j in range(depth)]
Sk=[[] for i in range(depth)]
item_count=70
i=0
e_max=Tail('',0)

with open(src_data,'r') as file:
    while item_count:
        element=file.readline().strip('\n')
        if not element:
            break
        else:
            i+=1
            print("\nread {}-th element: {}".format(i,element))
            item_count-=1
            item=Tail(element,1)
            if len(Top)==0:
                Top.append(item)
                # print("len(Top)==0, Top append:{}".format(Top))
            else:
                index=find(item,Top)
                # print("index={}".format(index))
                if index<0:
                    if len(Top)<size:
                        Top.append(item)
                        # print("index={},Top after append: {},\nlen(Top):{}".format(index,Top,len(Top)))
                    else:
                        UpdateSk(item,width,depth)
                else:
                    # print("update Top[{}]:".format(index))
                    Top[index].count+=1
            # print("Top after read {}:\n{}\n".format(element,Top))
            Top.sort(key=operator.attrgetter('count'),reverse=True)
            if e_max.count>Top[-1].count:
                BringBack(Top[-1],e_max,Sk)
                # print('Top after BringBack: \n\t{}'.format(Top))            
            # print("TOP:{}".format(Top))


end=time.time()

print("e_max:{}".format(e_max))
print("Execution time:{} seconds.".format(str(end-start)))
# Out:
# read 1-th element: 1 2 3
#
# read 2-th element: 1
#
# read 3-th element: 4 5 6 7
#
# read 4-th element: 1 8
#
# read 5-th element: 9 10
# [ID: 9 10, count: 1] -> [ID: 1, count: 1],send to Sk[2]
# In Update_local_max
# e_max before update:[ID: , count: 0]
# Sk_head:[total count: 1, distinct: 0, max: 9 10]
# Sk[row]:[[ID: 1, count: 1]]
# e_max after update:[ID: 9 10, count: 1]
# Sk[0]:[total count: 0, distinct: 0, max: ],[]
# Sk[1]:[total count: 0, distinct: 0, max: ],[]
# Sk[2]:[total count: 1, distinct: 0, max: 9 10],[[ID: 1, count: 1]]
# Sk[3]:[total count: 0, distinct: 0, max: ],[]
#
# read 6-th element: 11 6 12 13 14 15 16
# [ID: 11 6 12 13 14 15 16, count: 1] -> [ID: 1, count: 1],send to Sk[0]
# In Update_local_max
# e_max before update:[ID: 9 10, count: 1]
# Sk_head:[total count: 1, distinct: 0, max: 11 6 12 13 14 15 16]
# Sk[row]:[[ID: 1, count: 1]]
# e_max after update:[ID: 9 10, count: 1]
# Sk[0]:[total count: 1, distinct: 0, max: 11 6 12 13 14 15 16],[[ID: 1, count: 1]]
# Sk[1]:[total count: 0, distinct: 0, max: ],[]
# Sk[2]:[total count: 1, distinct: 0, max: 9 10],[[ID: 1, count: 1]]
# Sk[3]:[total count: 0, distinct: 0, max: ],[]
#
# read 7-th element: 1 3 7
# [ID: 1 3 7, count: 1] -> [ID: 5, count: 1],send to Sk[3]
# In Update_local_max
# e_max before update:[ID: 9 10, count: 1]
# Sk_head:[total count: 1, distinct: 0, max: 1 3 7]
# Sk[row]:[[ID: 5, count: 1]]
# e_max after update:[ID: 9 10, count: 1]
# Sk[0]:[total count: 1, distinct: 0, max: 11 6 12 13 14 15 16],[[ID: 1, count: 1]]
# Sk[1]:[total count: 0, distinct: 0, max: ],[]
# Sk[2]:[total count: 1, distinct: 0, max: 9 10],[[ID: 1, count: 1]]
# Sk[3]:[total count: 1, distinct: 0, max: 1 3 7],[[ID: 5, count: 1]]
#
# read 8-th element: 17 18
# [ID: 17 18, count: 1] -> [ID: 1, count: 1],send to Sk[3]
# In Update_local_max
# e_max before update:[ID: 9 10, count: 1]
# Sk_head:[total count: 2, distinct: 0, max: 1 3 7]
# Sk[row]:[[ID: 5, count:
[ID: 0, count: 7], [ID: 1, count: 6], [ID: 5, count: 4], [ID: 2, count: 1]]
# e_max after update:[ID: 11 216 3, count: 7]
# Sk[0]:[total count: 16, distinct: 1, max: 11 216 3],[[ID: 1, count: 7], [ID: 2, count: 4], [ID: 3, count: 3], [ID: 4, count: 1]]
# Sk[1]:[total count: 9, distinct: 1, max: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID: 4, count: 3], [ID: 5, count: 2], [ID: 0, count: 1], [ID: 2, count: 1]]
# Sk[2]:[total count: 18, distinct: 1, max: 27 1 6 3],[[ID: 2, count: 6], [ID: 3, count: 5], [ID: 1, count: 4], [ID: 5, count: 2]]
# Sk[3]:[total count: 19, distinct: 1, max: 3],[[ID: 0, count: 7], [ID: 1, count: 6], [ID: 5, count: 4], [ID: 2, count: 1]]
#
# read 67-th element: 293 6 294 3
# [ID: 293 6 294 3, count: 1] -> [ID: 3, count: 1],send to Sk[3]
# avg:1
# In Update_local_max
# e_max before update:[ID: 11 216 3, count: 7]
# Sk_head:[total count: 20, distinct: 1, max: 3]
# Sk[row]:[[ID: 0, count: 7], [ID: 1, count: 6], [ID: 5, count: 4], [ID: 2, count: 1]]
# e_max after update:[ID: 11 216 3, count: 7]
# Sk[0]:[total count: 16, distinct: 1, max: 11 216 3],[[ID: 1, count: 7], [ID: 2, count: 4], [ID: 3, count: 3], [ID: 4, count: 1]]
# Sk[1]:[total count: 9, distinct: 1, max: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID: 4, count: 3], [ID: 5, count: 2], [ID: 0, count: 1], [ID: 2, count: 1]]
# Sk[2]:[total count: 18, distinct: 1, max: 27 1 6 3],[[ID: 2, count: 6], [ID: 3, count: 5], [ID: 1, count: 4], [ID: 5, count: 2]]
# Sk[3]:[total count: 20, distinct: 1, max: 3],[[ID: 0, count: 7], [ID: 1, count: 6], [ID: 5, count: 4], [ID: 2, count: 1]]
#
# read 68-th element: 295 6 55 278
# [ID: 295 6 55 278, count: 1] -> [ID: 4, count: 1],send to Sk[3]
# avg:2
# In Update_local_max
# e_max before update:[ID: 11 216 3, count: 7]
# Sk_head:[total count: 21, distinct: 1, max: 3]
# Sk[row]:[[ID: 0, count: 7], [ID: 1, count: 6], [ID: 5, count: 4], [ID: 2, count: 1]]
# e_max after update:[ID: 11 216 3, count: 7]
# Sk[0]:[total count: 16, distinct: 1, max: 11 216 3],[[ID: 1, count: 7], [ID: 2, count: 4], [ID: 3, count: 3], [ID: 4, count: 1]]
# Sk[1]:[total count: 9, distinct: 1, max: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID: 4, count: 3], [ID: 5, count: 2], [ID: 0, count: 1], [ID: 2, count: 1]]
# Sk[2]:[total count: 18, distinct: 1, max: 27 1 6 3],[[ID: 2, count: 6], [ID: 3, count: 5], [ID: 1, count: 4], [ID: 5, count: 2]]
# Sk[3]:[total count: 21, distinct: 1, max: 3],[[ID: 0, count: 7], [ID: 1, count: 6], [ID: 5, count: 4], [ID: 2, count: 1]]
#
# read 69-th element: 55 3
# [ID: 55 3, count: 1] -> [ID: 4, count: 1],send to Sk[1]
# In Update_local_max
# e_max before update:[ID: 11 216 3, count: 7]
# Sk_head:[total count: 10, distinct: 1, max: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# Sk[row]:[[ID: 4, count: 4], [ID: 5, count: 2], [ID: 0, count: 1], [ID: 2, count: 1]]
# e_max after update:[ID: 11 216 3, count: 7]
# Sk[0]:[total count: 16, distinct: 1, max: 11 216 3],[[ID: 1, count: 7], [ID: 2, count: 4], [ID: 3, count: 3], [ID: 4, count: 1]]
# Sk[1]:[total count: 10, distinct: 1, max: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID: 4, count: 4], [ID: 5, count: 2], [ID: 0, count: 1], [ID: 2, count: 1]]
# Sk[2]:[total count: 18, distinct: 1, max: 27 1 6 3],[[ID: 2, count: 6], [ID: 3, count: 5], [ID: 1, count: 4], [ID: 5, count: 2]]
# Sk[3]:[total count: 21, distinct: 1, max: 3],[[ID: 0, count: 7], [ID: 1, count: 6], [ID: 5, count: 4], [ID: 2, count: 1]]
#
# read 70-th element: 269 11 6 296 38 297 298 299 300 301 302 303 141 304 305 306 307 308 309 273 3 310 311 312 313
# [ID: 269 11 6 296 38 297 298 299 300 301 302 303 141 304 305 306 307 308 309 273 3 310 311 312 313, count: 1] -> [ID: 1, count: 1],send to Sk[0]
# In Update_local_max
# e_max before update:[ID: 11 216 3, count: 7]
# Sk_head:[total count: 17, distinct: 1, max: 11 216 3]
# Sk[row]:[[ID: 1, count: 8], [ID: 2, count: 4], [ID: 3, count: 3], [ID: 4, count: 1]]
# e_max after update:[ID: 11 216 3, count: 8]
# Sk[0]:[total count: 17, distinct: 1, max: 11 216 3],[[ID: 1, count: 8], [ID: 2, count: 4], [ID: 3, count: 3], [ID: 4, count: 1]]
# Sk[1]:[total count: 10, distinct: 1, max: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID: 4, count: 4], [ID: 5, count: 2], [ID: 0, count: 1], [ID: 2, count: 1]]
# Sk[2]:[total count: 18, distinct: 1, max: 27 1 6 3],[[ID: 2, count: 6], [ID: 3, count: 5], [ID: 1, count: 4], [ID: 5, count: 2]]
# Sk[3]:[total count: 21, distinct: 1, max: 3],[[ID: 0, count: 7], [ID: 1, count: 6], [ID: 5, count: 4], [ID: 2, count: 1]]
# e_max:[ID: 11 216 3, count: 8]
# Execution time:0.07495379447937012 seconds.

# %%
print(Top)
# Out:
# [[ID: 1 2 3, count: 1], [ID: 1, count: 1], [ID: 4 5 6 7, count: 1], [ID: 1 8, count: 1]]

# %%
s='1 3 7'
mmh3.hash(str(spookyhash.hash32(bytes(s,encoding='utf-8'))), signed=False) % ((width*3)//2)
# Out:
# 5
