# %% [markdown]
# ## About Kosarak
# - Distinct element: 606770
# - Number of incomming element: 990002
# - Top-10 frequent element and count:
#
# | element | frquent |
# | :----- | :----- |
# | 3 | 36133 |
# | 6 | 30225 |
# | 6 3 | 21139 |
# | 11 6 | 12769 |
# | 1 | 9766 |
# | 11 6 3 | 9083 |
# | 1 3 | 6002 |
# | 11 | 5374 |
# | 1 6 | 5046 |
# | 4 | 4290 |

# %%
# Ground Truth
import pandas as pd
import os

filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)

num_line=0
item_count=100000
itemdict={}
with open(src_data,'r') as file:
    while True:
        line=file.readline().strip('\n')
        if not line:
            break
        else:
            #item_count-=1
            num_line+=1
            if line not in itemdict:
                itemdict[line]=1
            else:
                itemdict[line]+=1

df=pd.DataFrame(list(itemdict.items()),columns=['Element', 'Count'])
df=df.reset_index(drop=True)
df=df.sort_values('Count',ascending=False)

print("Distinct element: {}".format(len(itemdict)))
print("Number of incomming element: {}".format(num_line))
print(df.head(20))

df.to_csv("..\\result\\kosarak\\kosarak_ground_truth.csv",index=False)
# Out:
# Distinct element: 606770
# Number of incomming element: 990002
#        Element  Count
# 17           3  36133
# 111          6  30225
# 31         6 3  21139
# 94        11 6  12769
# 1            1   9766
# 85      11 6 3   9083
# 271        1 3   6002
# 253         11   5374
# 37         1 6   5046
# 279          4   4290
# 86        11 3   3756
# 241         55   3561
# 466      1 6 3   3510
# 233        4 3   3000
# 64        55 3   2377
# 195     11 1 6   2375
# 1525       4 6   2340
# 742      4 6 3   1758
# 250   11 1 6 3   1753
# 89        6 55   1749

# %% [markdown]
# ## Count-min sketch
# - Top-1024+ 4*1024 CMS
#     - Total memory 9432 bytes :Top-1024 with size 9328 bytes+ CMS with size 104 bytes.
#     - Execution time:319.18891406059265 seconds
#     - built-in index search is fastest

# %%
# Count-Min sketch with built-in index search
# Top-1024+ 4*1024 CMS
# Total memory 9432 bytes :Top-1024 with size 9328 bytes+ CMS with size 104 bytes.
# Execution time:319.18891406059265 seconds.
# Find:339,TP:0,FP:339

import sys
import os
import time
from probables import (CountMinSketch)
import pandas as pd

def find(e,Topk):
    try:
        index = [ele for ele,i in Topk].index(e)
        return index
    except:
        index=-99
    return index

start=time.time()
filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)
topk=[]
size=1024
# item_count=10000
cms = CountMinSketch(width=1024, depth=4)

if os.path.exists(src_data):
    with open(src_data,'r') as file:
        while True:
            line=file.readline().strip('\n')
            if not line:
                print('EOF')
                break
            else:
                # item_count-=1
                # print("read {}th element: {}".format(item_count,element))
                cms.add(line)
                count=cms.check(line)
                if len(topk)==0:
                    topk.append([line,count])
                else:
                    index=find(line,topk)
                    if index<0:
                        #  element not in topk
                        if len(topk)<size:
                            topk.append([line,count])
                        else:
                            topk[-1][0]=line
                            topk[-1][1]=count
                    else:
                        topk[index][1]=count
                topk=sorted(topk,key = lambda topk:topk[1],reverse=True)
                    
    end=time.time()
    print(topk[:50],len(topk))
    print("Total memory {3} bytes :Top-{0} with size {1} bytes+ CMS with size {2} bytes.".format(len(topk),sys.getsizeof(topk),sys.getsizeof(cms),sys.getsizeof(cms)+sys.getsizeof(topk)))
    print("Execution time:{} seconds.".format(str(end-start)))
else:
    print("file doesn't exist")
#　conver Top into df    
templi=[]
for i in topk:
    templi.append([i[0],i[1]])

df=pd.DataFrame(templi,columns=['ID', 'Count'])
df.to_csv("..\\result\\kosarak\\CM_kosarak.csv",index=False)
df.head(50)
# Out:
# EOF
# [['3', 36826], ['6', 30906], ['6 3', 21876], ['11 6', 13465], ['1', 10512], ['11 6 3', 9726], ['1 3', 6663], ['11', 6049], ['1 6', 5695], ['4', 4969], ['11 3', 4564], ['55', 4269], ['1 6 3', 4156], ['4 3', 3666], ['55 3', 3050], ['11 1 6', 3005], ['4 6', 2992], ['4 6 3', 2441], ['11 1 6 3', 2437], ['6 55', 2430], ['2', 2310], ['294', 2276], ['6 55 3', 2004], ['490', 1981], ['2 3', 1946], ['27', 1822], ['7', 1770], ['294 3', 1759], ['218', 1717], ['11 4 6', 1594], ['490 3', 1578], ['11 1', 1554], ['6 2', 1540], ['6 294', 1534], ['64', 1521], ['73', 1495], ['11 4 6 3', 1488], ['91', 1488], ['4 1', 1438], ['218 3', 1434], ['11 6 55', 1412], ['11 6 55 3', 1409], ['6 2 3', 1389], ['3 7', 1373], ['490 6', 1365], ['6 7', 1365], ['6 294 3', 1354], ['27 3', 1349], ['218 6', 1324], ['77', 1311]] 1024
# Total memory 9432 bytes :Top-1024 with size 9328 bytes+ CMS with size 104 bytes.
# Execution time:466.54557752609253 seconds.
#            ID  Count
# 0           3  36826
# 1           6  30906
# 2         6 3  21876
# 3        11 6  13465
# 4           1  10512
# 5      11 6 3   9726
# 6         1 3   6663
# 7          11   6049
# 8         1 6   5695
# 9           4   4969
# 10       11 3   4564
# 11         55   4269
# 12      1 6 3   4156
# 13        4 3   3666
# 14       55 3   3050
# 15     11 1 6   3005
# 16        4 6   2992
# 17      4 6 3   2441
# 18   11 1 6 3   2437
# 19       6 55   2430
# 20          2   2310
# 21        294   2276
# 22     6 55 3   2004
# 23        490   1981
# 24        2 3   1946
# 25         27   1822
# 26          7   1770
# 27      294 3   1759
# 28        218   1717
# 29     11 4 6   1594
# 30      490 3   1578
# 31       11 1   1554
# 32        6 2   1540
# 33      6 294   1534
# 34         64   1521
# 35         73   1495
# 36   11 4 6 3   1488
# 37         91   1488
# 38        4 1   1438
# 39      218 3   1434
# 40    11 6 55   1412
# 41  11 6 55 3   1409
# 42      6 2 3   1389
# 43        3 7   1373
# 44      490 6   1365
# 45        6 7   1365
# 46    6 294 3   1354
# 47       27 3   1349
# 48      218 6   1324
# 49         77   1311

# %%
# CMS Result compare
import pandas as pd
import os
path='..\\result\\kosarak'
groundtruth='kosarak_ground_truth.csv'
final='CM_kosarak.csv'

grtruth=pd.read_csv(os.path.join(path,groundtruth))
My_result1=pd.read_csv(os.path.join(path,final))

gli = grtruth.values.tolist()
li1= My_result1.values.tolist()

tp=0
fp=0
find=0
err=[]
error=0
for item in li1:
    for element in gli[:1024]:
        if item[0]==element[0]:
            # print("{},{} vs. {},{}".format(item[0],item[1],element[0],element[1]))
            find+=1
            if item[1]==element[1]:
                tp+=1
            else:
                fp+=1
                error+=abs(item[1]-element[1])
print("Find:{},TP:{},FP:{}".format(find,tp,fp))
print("avg error:{}".format(error/512))
# Out:
# Find:339,TP:0,FP:339
# avg error:461.703125

# %%
## ARE

import pandas as pd
import os
path='..\\result\\kosarak'
groundtruth='kosarak_ground_truth.csv'
final='CM_kosarak.csv'

grtruth=pd.read_csv(os.path.join(path,groundtruth))
My_result1=pd.read_csv(os.path.join(path,final))

gli = grtruth.values.tolist()
li= My_result1.values.tolist()

err=0
for item in li:
    index=[j[0] for j in gli[:]].index(item[0])
    # print("index of {}:{}".format(item,))
    err+=abs(item[1]-gli[index][1])/item[1]
print(err/606770)
# Out:
# 0.0015354806018180271

# %% [markdown]
# ## Space-Saving

# %%
# Space-Saving 1024 stream summary with class+index search
# Total memory 9024 bytes :Top-1024 with size 9024 bytes.
# Execution time:251.02409100532532 seconds.
# Find:158,TP:26,FP:132

import sys
import os
import time
import operator
import pandas as pd

class Node():
    def __init__(self,count=0):
        self.count=count
    def add_count(self,count=1):
        self.count+=count
    def __str__(self):
        return 'ID: {}, count: {}'.format(self.ID,self.count)
    def __repr__(self):
        return ''

class Head(Node):
    def __init__(self):
        super().__init__()
        self.distinct = hyperloglog.HyperLogLog(0.01)
    def __str__(self):
        return 'total count: {}, distinct element: {}'.format(self.count,len(self.distinct))
    def __repr__(self):
        return '[count: {}, distinct: {}]'.format(self.count,len(self.distinct))

class Tail(Node):
    def __init__(self,ID,count):
        self.ID = ID
        super().__init__(count)
    def __str__(self):
        return 'ID: {}, count: {}'.format(self.ID,self.count)
    def __repr__(self):
        return "'{}', count: {}".format(self.ID,self.count)

def find(e,element_list):
    try:
        index = [ele.ID for ele in element_list].index(e.ID)
    except:
        index=-99
    return index  
    
    
start=time.time()

filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)

size=1024
Top=[]
# item_count=100000

with open(src_data,'r') as file:
    while True:
        element=file.readline().strip('\n')
        if not element:
            print('EOF')
            break
        else:
            item=Tail(element,1)
            # item_count-=1
            # print("read {}th element: {}".format(item_count,element))
            if len(Top)==0:
                Top.append(item)
            else:
                index=find(item,Top)
                if index<0:
                    if len(Top)<size:
                        Top.append(item)
                    else:
                        # replace last element with count 
                        Top[-1].ID=item.ID
                        Top[-1].count+=1
                else:
                    Top[index].count+=1
            Top.sort(key=operator.attrgetter('count'),reverse=True)

end=time.time()
print(Top[:20],len(Top))
print("Total memory {0} bytes :Top-{1} with size {0} bytes.".format(sys.getsizeof(Top),size))
print("Execution time:{} seconds.".format(str(end-start)))


#　conver Top into df    
templi=[]
for i in Top:
    templi.append([i.ID,i.count])

df=pd.DataFrame(templi,columns=['ID', 'Count'])
df.to_csv("..\\result\\kosarak\\SS_class_kosarak.csv",index=False)
df.head(20)
# Out:
# EOF
# ['3', count: 36133, '6', count: 30225, '6 3', count: 21139, '11 6', count: 12769, '1', count: 9766, '11 6 3', count: 9083, '1 3', count: 6002, '11', count: 5374, '1 6', count: 5046, '4', count: 4290, '11 3', count: 3756, '55', count: 3561, '1 6 3', count: 3510, '4 3', count: 3000, '55 3', count: 2377, '11 1 6', count: 2375, '4 6', count: 2341, '4 6 3', count: 1758, '11 1 6 3', count: 1753, '6 55', count: 1749] 1024
# Total memory 9024 bytes :Top-1024 with size 9024 bytes.
# Execution time:358.75895404815674 seconds.
#           ID  Count
# 0          3  36133
# 1          6  30225
# 2        6 3  21139
# 3       11 6  12769
# 4          1   9766
# 5     11 6 3   9083
# 6        1 3   6002
# 7         11   5374
# 8        1 6   5046
# 9          4   4290
# 10      11 3   3756
# 11        55   3561
# 12     1 6 3   3510
# 13       4 3   3000
# 14      55 3   2377
# 15    11 1 6   2375
# 16       4 6   2341
# 17     4 6 3   1758
# 18  11 1 6 3   1753
# 19      6 55   1749

# %%
# SS Result compare
import pandas as pd
import os
path='..\\result\\kosarak'
groundtruth='kosarak_ground_truth.csv'
final='SS_class_kosarak.csv'

grtruth=pd.read_csv(os.path.join(path,groundtruth))
My_result1=pd.read_csv(os.path.join(path,final))

gli = grtruth.values.tolist()
li1= My_result1.values.tolist()

tp=0
fp=0
find=0
err=[]
error=0
for item in li1:
    for element in gli[:1024]:
        if item[0]==element[0]:
            print("{},{} vs. {},{}".format(item[0],item[1],element[0],element[1]))
            find+=1
            if item[1]==element[1]:
                tp+=1
            else:
                fp+=1
                error+=abs(item[1]-element[1])
print("Find:{},TP:{},FP:{}".format(find,tp,fp))
print("avg error:{}".format(error/512))
# Out:
# 3,36133 vs. 3,36133
# 6,30225 vs. 6,30225
# 6 3,21139 vs. 6 3,21139
# 11 6,12769 vs. 11 6,12769
# 1,9766 vs. 1,9766
# 11 6 3,9083 vs. 11 6 3,9083
# 1 3,6002 vs. 1 3,6002
# 11,5374 vs. 11,5374
# 1 6,5046 vs. 1 6,5046
# 4,4290 vs. 4,4290
# 11 3,3756 vs. 11 3,3756
# 55,3561 vs. 55,3561
# 1 6 3,3510 vs. 1 6 3,3510
# 4 3,3000 vs. 4 3,3000
# 55 3,2377 vs. 55 3,2377
# 11 1 6,2375 vs. 11 1 6,2375
# 4 6,2341 vs. 4 6,2340
# 4 6 3,1758 vs. 4 6 3,1758
# 11 1 6 3,1753 vs. 11 1 6 3,1753
# 6 55,1749 vs. 6 55,1749
# 294,1653 vs. 294,1653
# 2,1601 vs. 2,1601
# 6 55 3,1375 vs. 6 55 3,1374
# 490,1226 vs. 490,1225
# 27,1168 vs. 27,1167
# 294 3,1162 vs. 294 3,1161
# 2 3,1152 vs. 2 3,1152
# 7,1100 vs. 7,1100
# 218,1056 vs. 218,1055
# 11 4 6,954 vs. 11 4 6,954
# 64,915 vs. 64,907
# 6 294,893 vs. 6 294,890
# 6 2,882 vs. 6 2,882
# 11 1,880 vs. 11 1,880
# 91,866 vs. 91,838
# 73,853 vs. 73,849
# 490 3,846 vs. 490 3,799
# 11 4 6 3,828 vs. 11 4 6 3,809
# 6 294 3,823 vs. 6 294 3,743
# 4 1,821 vs. 4 1,754
# 6 2 3,821 vs. 6 2 3,673
# 3 73,820 vs. 3 73,642
# 27 6 3,820 vs. 27 6 3,473
# 27 3,819 vs. 27 3,730
# 6 7,819 vs. 6 7,667
# 11 6 55,819 vs. 11 6 55,761
# 4 1 3,818 vs. 4 1 3,486
# 218 3,818 vs. 218 3,743
# 3 7,818 vs. 3 7,734
# 316,818 vs. 316,628
# 18,818 vs. 18,345
# 11 6 55 3,817 vs. 11 6 55 3,620
# 11 218 6 3,817 vs. 11 218 6 3,234
# 4 55 3,817 vs. 4 55 3,198
# 278,817 vs. 278,390
# 584,817 vs. 584,61
# 6 91,817 vs. 6 91,409
# 6 504 3,817 vs. 6 504 3,83
# 1056,817 vs. 1056,87
# 4 1 6,816 vs. 4 1 6,395
# 1 55,816 vs. 1 55,582
# 11 1 3,816 vs. 11 1 3,588
# 667,816 vs. 667,73
# 1 218,816 vs. 1 218,182
# 799 6 3,816 vs. 799 6 3,35
# 55 3 316,816 vs. 55 3 316,31
# 512,816 vs. 512,38
# 11 6 737,816 vs. 11 6 737,153
# 1779,816 vs. 1779,124
# 138 3,816 vs. 138 3,390
# 1 6 446,816 vs. 1 6 446,43
# 1 6 3 77,816 vs. 1 6 3 77,48
# 11 6 83,816 vs. 11 6 83,138
# 69 11 1 6 3,816 vs. 69 11 1 6 3,35
# 4 55,816 vs. 4 55,238
# 11 77,816 vs. 11 77,69
# 5,816 vs. 5,386
# 484,816 vs. 484,105
# 11 6 90,816 vs. 11 6 90,55
# 323 6,816 vs. 323 6,44
# 69 11 6,816 vs. 69 11 6,242
# 2344 6,816 vs. 2344 6,67
# 11 6 56,816 vs. 11 6 56,45
# 11 3 73,816 vs. 11 3 73,73
# 303,816 vs. 303,251
# 607 6,816 vs. 607 6,47
# 3356 6,816 vs. 3356 6,32
# 69,816 vs. 69,235
# 1 73,816 vs. 1 73,150
# 77,816 vs. 77,648
# 11 1 218 6 3,816 vs. 11 1 218 6 3,41
# 11 218,816 vs. 11 218,84
# 6 278,816 vs. 6 278,217
# 11 1751,816 vs. 11 1751,30
# 11 648 6,816 vs. 11 648 6,85
# 11 6 138,816 vs. 11 6 138,296
# 1164 6 3,816 vs. 1164 6 3,38
# 11 6 2,816 vs. 11 6 2,422
# 314,816 vs. 314,121
# 1777,816 vs. 1777,95
# 11 490 3,816 vs. 11 490 3,86
# 1 504,816 vs. 1 504,32
# 2895 3,816 vs. 2895 3,77
# 314 3,816 vs. 314 3,98
# 635 6 3,816 vs. 635 6 3,37
# 6 3 77,816 vs. 6 3 77,311
# 361 3,816 vs. 361 3,32
# 4 490 3,816 vs. 4 490 3,67
# 269 11 6,816 vs. 269 11 6,94
# 1 1751,816 vs. 1 1751,60
# 3 316,816 vs. 3 316,463
# 1105 3,816 vs. 1105 3,66
# 11 4 3,816 vs. 11 4 3,290
# 4035 6,816 vs. 4035 6,58
# 2186 6 3,816 vs. 2186 6 3,40
# 3181 6,816 vs. 3181 6,51
# 1 590,816 vs. 1 590,65
# 6 18 3,816 vs. 6 18 3,119
# 246 3,816 vs. 246 3,210
# 27 1 6 3,816 vs. 27 1 6 3,63
# 11 4 1 6,816 vs. 11 4 1 6,183
# 490 55,816 vs. 490 55,65
# 2186,816 vs. 2186,112
# 11 6 3 438,816 vs. 11 6 3 438,70
# 622 6,816 vs. 622 6,60
# 1 136,816 vs. 1 136,36
# 273,816 vs. 273,214
# 2081 3,816 vs. 2081 3,75
# 6 3 446,816 vs. 6 3 446,197
# 11 6 294,816 vs. 11 6 294,390
# 52 6,816 vs. 52 6,54
# 1 6 91 3,816 vs. 1 6 91 3,44
# 6 3 7,816 vs. 6 3 7,538
# 3764 6,816 vs. 3764 6,51
# 1 6 3 7,816 vs. 1 6 3 7,95
# 880 6 3,816 vs. 880 6 3,41
# 145 3,816 vs. 145 3,227
# 3589,816 vs. 3589,117
# 1 6 294,816 vs. 1 6 294,146
# 1524,816 vs. 1524,34
# 6 55 3 7,816 vs. 6 55 3 7,31
# 11 218 6,816 vs. 11 218 6,299
# 11 6 438,816 vs. 11 6 438,82
# 11 6 361,816 vs. 11 6 361,39
# 138,815 vs. 138,666
# 485,815 vs. 485,97
# 11 490 6,815 vs. 11 490 6,275
# 11 6 3 64,815 vs. 11 6 3 64,211
# 1 6 138,815 vs. 1 6 138,104
# 11 6 215 3,815 vs. 11 6 215 3,101
# 4315 3,815 vs. 4315 3,56
# 1490 3,815 vs. 1490 3,61
# 6 303 3,815 vs. 6 303 3,93
# 246 1 3,815 vs. 246 1 3,33
# 11 4 6 3 7,815 vs. 11 4 6 3 7,34
# 11 3 446,815 vs. 11 3 446,32
# 3 446,815 vs. 3 446,290
# 251,815 vs. 251,83
# Find:158,TP:26,FP:132
# avg error:142.55078125

# %%
import pandas as pd
import os
path='..\\result\\kosarak'
groundtruth='kosarak_ground_truth.csv'
final='SS_class_kosarak.csv'

grtruth=pd.read_csv(os.path.join(path,groundtruth))
My_result1=pd.read_csv(os.path.join(path,final))

gli = grtruth.values.tolist()
li= My_result1.values.tolist()

err=0
for item in li:
    index=[j[0] for j in gli[:]].index(item[0])
    # print("index of {}:{}".format(item,))
    err+=abs(item[1]-gli[index][1])/item[1]
print(err/606770)
# Out:
# 0.0015706283973142764

# %% [markdown]
# ## My algo

# %%
import spookyhash
import mmh3
from numpy import random
import os
import time
import operator
import hyperloglog
import sys
import pandas as pd


# ==========================data structure==========================
class Node():
    def __init__(self,count=0):
        self.count=count
    def add_count(self,count=1):
        self.count+=count
    def __str__(self):
        return 'count: {}'.format(self.count)
    def __repr__(self):
        return ''

class Head(Node):
    def __init__(self,count=1):
        super().__init__(count)
        self.distinct = hyperloglog.HyperLogLog(0.01)
        self.maxID=''
    def __str__(self):
        return '[total:{}, dist:{}, max:{}]'.format(self.count,len(self.distinct),self.maxID)
    def __repr__(self):
        return '[total:{}, dist:{}, max:{}]'.format(self.count,len(self.distinct),self.maxID)

class Tail(Node):
    def __init__(self,ID,count):
        self.ID = ID
        super().__init__(count)
    def __str__(self):
        return '[ID:{}, count:{}]'.format(self.ID,self.count)
    def __repr__(self):
        return '[ID:{}, count:{}]'.format(self.ID,self.count)
# ==========================data structure==========================


# ==========================UpdateSk==========================
def UpdateSk(element,Sk_head,Sk):
    # print("In UpdateSk()")
    e_max=get_emax()
    ID,row=position(element)
        # row position of e and ID=h(e) in Sketch 
    avg=0
    item=Tail(ID, element.count)
        # ID in Sketch is hash value
    # print("{} -> {},send to Sk[{}]".format(element,item,row))
    # ==========================update sketch==========================
    index=find(item,Sk[row])
        # find index of e in Sk[row]
    if index >=0:
        # e matches in Sk[row]
        Sk[row][index].count+=item.count
    else:
        # e doesn't match in Sk[row]
        if len(Sk[row])==0:
            Sk[row].append(item)
            index=0
            Sk_head[row].maxID=element.ID
                # unhashed ID
        elif len(Sk[row])<width:
            # Sk[row] is not full
            Sk[row].append(item)
            index=len(Sk[row])-1      
            # match=True
        else:
            # Sk[row] is full
            count_sum=sum(Sk[row][i].count for i in range(len(Sk[row])))
            if Sk_head[row].count==count_sum:
                # no other, send e to Other
                Sk_head[row].distinct.add(element.ID)
                # match=False
            else:
                # something in other and total count > sum
                if len(Sk_head[row].distinct)>0:
                    Sk_head[row].distinct.add(element.ID)
                    avg=(Sk_head[row].count-count_sum)//len(Sk_head[row].distinct)
                    # print("avg:{}".format(avg))
                else:
                    Sk_head[row].distinct.add(element.ID)
                    # print("distinct element:{}".format(len(Sk_head[row].distinct)))
                    # print("avg< last one,send to distinct")
                    # match=False
    Sk_head[row].count+=item.count
        # total count最後再+1 在line 82要compare distinct
    # now we have:
    # ID: h2(h1(e)), hash value of e
    # row: h1(e), row index of e
    # index: column index of e
    # Sk_head[row].count: total count of Sk[row]
    # Sk_head[row].maxID: local max count element of Sk[row]
    # Sk_head[row].distinct: estimated element of Other part in Sk[row]
    # count_sum: sum of count in Sketch[row]
    # avg: average count of Other part in Sk[row]
    # ==========================update local max==========================
    Update_local_max(Sk_head[row],Sk[row],avg,element,index)
    # Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
    
    # ==========================update e_max==========================
    Update_emax(Sk_head[row],Sk[row],element,avg)
    
    Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
    # print("e_max:{}".format(e_max))
    # print("Sk_head[{}]:{}".format(row,Sk_head[row]))
    '''
    for i in range(len(Sk)):
        print("Sk[{}]:{},{}".format(i,Sk_head[i],Sk[i]))
    '''


# ==========================update local max==========================    
def Update_local_max(head_item,element_list,avg,incoming_element,index):
    # Sk_head[row],Sk[row],avg
    # print("In Update_local_max():")
    numertor,denominator=get_fraction()
    width,depth=get_width_depth()
    if head_item.maxID=='':
        head_item.maxID=incoming_element.ID
    else:
        local_max_ID=mmh3.hash(str(spookyhash.hash32(bytes(str(head_item.maxID),encoding='utf-8'))), signed=False) % ((width*numertor)//denominator)
        #print("local_max_ID:{}".format(local_max_ID))
        local_max_index=find(Tail(local_max_ID,1),element_list)
        #print("local_max_index:{}".format(local_max_index))
        # 此處當hashed ID相同時暫不更新 local max
        if local_max_index>=0:
            # local max exists
            if index>=0:
                # e in Sk[row]
                if element_list[index].count>element_list[local_max_index].count:
                    head_item.maxID=incoming_element.ID
            else:
                # e in Other
                if avg>element_list[local_max_index].count:
                    head_item.maxID=incoming_element.ID
        else:
            # local max doesn't exists
            head_item.maxID=incoming_element.ID

# ==========================update e_max==========================
def Update_emax(head_item,element_list,incoming_element,avg_count):
    # Sk_head[row],Sk[row],e_max
    # print("In Update_emax():")
    e_max=get_emax()
    numerator,denominator=get_fraction()
    # local_max_ID=""
    # local_max_index=""
    # print("e_max before update:{}".format(e_max))
    # print("Sk_head:{}".format(head_item))
    width,depth=get_width_depth()
    if head_item.maxID!="":
        local_max_ID=mmh3.hash(str(spookyhash.hash32(bytes(str(head_item.maxID),encoding='utf-8'))), signed=False) % ((width*numerator)//denominator)
        # print("local_max_ID:{}".format(local_max_ID))
        local_max_index=find(Tail(local_max_ID,1),element_list)        
        # print("local_max_index:{}".format(local_max_index))
        if local_max_index>=0:
            if element_list[local_max_index].count>e_max.count:
                e_max.ID=head_item.maxID
                e_max.count=element_list[local_max_index].count
        else:
            if avg_count>e_max.count:
                e_max.ID=head_item.maxID
                e_max.count=avg_count
    #print("e_max after update:{}".format(e_max))

# ========================== BringBack=========================
def BringBack(e_min,head,sketch):
    # Bring e_max back into Top
    # Sk_head,Sk[row]
    e_max=get_emax()
    # print("\nIn BringBack():")
    temp=Tail(e_min.ID,e_min.count)
    e_min.ID=e_max.ID
    e_min.count=e_max.count
    # print('Top after BringBack:\n\t{}'.format(Top))
    DeleteSk(e_max,head,sketch)
    # update e_max in Sk[row]
    # print("e_max after delete:{},id(e_max):{}".format(e_max,id(e_max)))
    UpdateSk(temp,head,sketch)
    # print("Sk[] after Update {}:\n\t{}".format(e_min,Sk))

# ========================== BringBack=========================
# ==========================DeleteSk=========================
def DeleteSk(element,head,sketch):
    # 刪除e_max in Sk[row]
    # print("\nIn DeleteSK({}):".format(element))
    width,depth=get_width_depth()
    ID,row=position(element)
    # print("row:{},ID:{} of e_max".format(row,ID))
    head[row].count-=element.count
        # total_count=total_count-e_max.count
    # print("Sk[{}]:{}".format(row,sketch[row]))
    index=find(Tail(ID,1),sketch[row])
    # print("index:{} in Sk[{}]".format(index,row))
    if index>=0:
        sketch[row].pop(index)
        # element_list[row].sort(key=operator.attrgetter('count'),reverse=True)
        head[row].maxID=""

    element.ID=""
    element.count=0
    # print("e_max After DeleteSk(element):{},id(e_max):{}".format(e_max,id(e_max)))
# ==========================Tools=========================    
def get_emax():
    return e_max
def get_width_depth():
    return width,depth

def find(e,element_list):
    # return index of e in element_list
    try:
        index=[ele.ID for ele in element_list].index(e.ID)
    except:
        index=-99
    return index

def position(element):
    numertor,denominator=get_fraction()
    width,depth=get_width_depth()
    hash1=spookyhash.hash32(bytes(str(element.ID),encoding='utf-8'))
        # input of spooky: byte
        # output of spooky:unsigned- 32 bit int
    hash2=mmh3.hash(str(hash1), signed=False)
        # input of mmh: str
        # output: unsigned- 32 bit int
    ID=hash2 % ((width*numertor)//denominator)
    row=hash1 % depth    
    return ID,row
def get_fraction():
    return numerator,denominator

# ==========================main=========================   
        
start=time.time()

filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)
depth=4
width=128
size=1024
numerator=12
denominator=10
    # numerator/denominator decides ratio of Other+Sketch /Sketch


Top=[]
Sk_head=[Head(0) for j in range(depth)]
Sk=[[] for i in range(depth)]
item_count=1000
i=0
e_max=Tail('',0)

with open(src_data,'r') as file:
    while True:
        element=file.readline().strip('\n')
        if not element:
            break
        else:
            # i+=1
            # print("\nread {}-th element: {}".format(i,element))
            # item_count-=1
            item=Tail(element,1)
            if len(Top)==0:
                Top.append(item)
                # print("len(Top)==0, Top append:{}".format(Top))
            else:
                index=find(item,Top)
                # print("index={}".format(index))
                if index<0:
                    if len(Top)<size:
                        Top.append(item)
                        # print("index={},Top after append: {},\nlen(Top):{}".format(index,Top,len(Top)))
                    else:
                        UpdateSk(item,Sk_head,Sk)
                else:
                    # print("update Top[{}]:".format(index))
                    Top[index].count+=1
            Top.sort(key=operator.attrgetter('count'),reverse=True)
            # ID,row=position(Top[-1])
            if e_max.count>Top[-1].count:
                BringBack(Top[-1],Sk_head,Sk)
                # print('Top after BringBack: \n\t{}'.format(Top))            


end=time.time()
print("Sk_head:{}".format(Sk_head))
print("TOP[20]:{}".format(Top[:20]))
# print("\nSketch:{}".format(Sk))
print("Total memory {} bytes".format(sys.getsizeof(Top)+sys.getsizeof(Sk)+sys.getsizeof(Sk_head)))
print("Top:{} bytes, Sketch:{} bytes, Sketch_head:{} bytes.".format(sys.getsizeof(Top),sys.getsizeof(Sk),sys.getsizeof(Sk_head)))
print("Execution time:{} seconds.".format(str(end-start)))

#　conver Top into df    
templi=[]
for i in Top:
    templi.append([i.ID,i.count])

df=pd.DataFrame(templi,columns=['ID', 'Count'])
df.to_csv("..\\result\\kosarak\\Myalgo_kosarak_100k_count.csv",index=False)
df.head(20)
# Out:
# Sk_head:[[total:116739, dist:24752, max:11 4 218 6 1800 2196], [total:117342, dist:24809, max:11 1 6 2413 584 644], [total:124638, dist:24692, max:3 1956], [total:117649, dist:24675, max:288 1]]
# TOP[20]:[[ID:3, count:36133], [ID:6, count:30225], [ID:6 3, count:21139], [ID:11 6, count:12769], [ID:1, count:9766], [ID:11 6 3, count:9083], [ID:1 3, count:6002], [ID:11, count:5374], [ID:1 6, count:5046], [ID:4, count:4290], [ID:11 3, count:3756], [ID:55, count:3561], [ID:1 6 3, count:3510], [ID:4 3, count:3000], [ID:55 3, count:2377], [ID:11 1 6, count:2375], [ID:4 6, count:2341], [ID:4 6 3, count:1758], [ID:11 1 6 3, count:1753], [ID:6 55, count:1749]]
# Total memory 9216 bytes
# Top:9024 bytes, Sketch:96 bytes, Sketch_head:96 bytes.
# Execution time:1744.9176051616669 seconds.
#           ID  Count
# 0          3  36133
# 1          6  30225
# 2        6 3  21139
# 3       11 6  12769
# 4          1   9766
# 5     11 6 3   9083
# 6        1 3   6002
# 7         11   5374
# 8        1 6   5046
# 9          4   4290
# 10      11 3   3756
# 11        55   3561
# 12     1 6 3   3510
# 13       4 3   3000
# 14      55 3   2377
# 15    11 1 6   2375
# 16       4 6   2341
# 17     4 6 3   1758
# 18  11 1 6 3   1753
# 19      6 55   1749

# %%
print("sum of element in Top: {}".format(sum([i.count for i in Top])))
print("sum of element in Sketch: {}".format(sum([i.count for i in Sk_head])))
for i in range(len(Sk)):
    print("sum of element in Other: {}".format(Sk_head[i].count-sum([j.count for j in Sk[i]])))
print("e_max:{}".format(e_max))

'''
for i in range(len(Sk)):
    print("Sk[{}]:\n{},\n{}".format(i,Sk_head[i],Sk[i]))
'''
# Out:
# sum of element in Top: 513634
# sum of element in Sketch: 476368
# sum of element in Other: 102039
# sum of element in Other: 102194
# sum of element in Other: 108955
# sum of element in Other: 103953
# e_max:[ID:3 1956, count:258]
# '\nfor i in range(len(Sk)):\n    print("Sk[{}]:\n{},\n{}".format(i,Sk_head[i],Sk[i]))\n'

# %%
print(sum([j.count for j in Sk[0]]))
print(len(Sk_head[0].distinct))
print((Sk_head[0].count-sum([j.count for j in Sk[0]]))//len(Sk_head[0].distinct))
print(Sk[0])
# Out:
# 14700
# 24752
# 4
# [[ID:118, count:258], [ID:0, count:256], [ID:53, count:255], [ID:115, count:255], [ID:40, count:254], [ID:68, count:253], [ID:86, count:252], [ID:38, count:248], [ID:23, count:246], [ID:17, count:245], [ID:35, count:235], [ID:76, count:234], [ID:98, count:233], [ID:24, count:233], [ID:51, count:231], [ID:106, count:227], [ID:82, count:225], [ID:89, count:224], [ID:92, count:222], [ID:47, count:220], [ID:127, count:216], [ID:100, count:211], [ID:141, count:211], [ID:85, count:208], [ID:151, count:208], [ID:34, count:203], [ID:122, count:198], [ID:110, count:197], [ID:42, count:196], [ID:109, count:194], [ID:8, count:193], [ID:29, count:193], [ID:150, count:188], [ID:6, count:187], [ID:104, count:183], [ID:139, count:177], [ID:138, count:173], [ID:117, count:173], [ID:48, count:172], [ID:5, count:172], [ID:21, count:168], [ID:83, count:162], [ID:134, count:158], [ID:78, count:142], [ID:71, count:141], [ID:144, count:138], [ID:43, count:137], [ID:136, count:134], [ID:90, count:132], [ID:15, count:122], [ID:50, count:119], [ID:32, count:119], [ID:107, count:117], [ID:126, count:114], [ID:103, count:112], [ID:114, count:112], [ID:9, count:110], [ID:3, count:109], [ID:31, count:108], [ID:63, count:107], [ID:54, count:107], [ID:79, count:106], [ID:140, count:105], [ID:147, count:102], [ID:81, count:98], [ID:28, count:96], [ID:73, count:96], [ID:65, count:95], [ID:87, count:93], [ID:66, count:90], [ID:7, count:90], [ID:60, count:89], [ID:59, count:85], [ID:12, count:84], [ID:95, count:79], [ID:14, count:79], [ID:142, count:78], [ID:96, count:70], [ID:135, count:70], [ID:16, count:69], [ID:111, count:66], [ID:120, count:65], [ID:152, count:62], [ID:77, count:61], [ID:36, count:58], [ID:26, count:58], [ID:97, count:58], [ID:119, count:57], [ID:37, count:56], [ID:130, count:56], [ID:80, count:55], [ID:19, count:53], [ID:22, count:50], [ID:123, count:49], [ID:137, count:49], [ID:74, count:49], [ID:58, count:48], [ID:55, count:47], [ID:45, count:47], [ID:61, count:44], [ID:18, count:44], [ID:145, count:43], [ID:124, count:43], [ID:75, count:42], [ID:13, count:40], [ID:11, count:37], [ID:108, count:37], [ID:94, count:37], [ID:131, count:34], [ID:57, count:32], [ID:113, count:30], [ID:93, count:26], [ID:30, count:25], [ID:88, count:17], [ID:46, count:16], [ID:41, count:15], [ID:10, count:14], [ID:1, count:14], [ID:102, count:13], [ID:116, count:12], [ID:70, count:10], [ID:67, count:9], [ID:105, count:8], [ID:20, count:4], [ID:125, count:4], [ID:25, count:2], [ID:112, count:2], [ID:84, count:1]]

# %%
h,r=position(Tail('6 7871 3',0))

try:
    print([j.ID for j in Sk[r]].index(h))
    print(Sk[r][[j.ID for j in Sk[r]].index(h)])
    print(Sk[r])
except:
    print((Sk_head[r].count-sum([j.count for j in Sk[r]]))//len(Sk_head[r].distinct))
# Out:
# 4

# %%
# Result compare
# ARE: (1/distinct element)*(abs(f-f*)/f)

import pandas as pd
import os
path='..\\result\\kosarak'
groundtruth='kosarak_ground_truth.csv'
final='Myalgo_kosarak_100k_count.csv'

grtruth=pd.read_csv(os.path.join(path,groundtruth))
My_result1=pd.read_csv(os.path.join(path,final))

gli = grtruth.values.tolist()
li1= My_result1.values.tolist()

tp=0
fp=0
find=0
err=[]
error=0
for item in li1:
    for element in gli:
        if item[0]==element[0]:
            # print("{},{} vs. {},{}".format(item[0],item[1],element[0],element[1]))
            find+=1
            if item[1]==element[1]:
                tp+=1
            else:
                fp+=1
                error+=abs(item[1]-element[1])/item[1]
print("Find:{},TP:{},FP:{}".format(find,tp,fp))
print("ARE:{}".format(error/606770))
# Out:
# Find:1024,TP:34,FP:990
# ARE:0.4676549598694728

# %%
## ARE

import pandas as pd
import os
path='..\\result\\kosarak'
groundtruth='kosarak_ground_truth.csv'
final='Myalgo_kosarak_100k_count.csv'

grtruth=pd.read_csv(os.path.join(path,groundtruth))
My_result1=pd.read_csv(os.path.join(path,final))

gli = grtruth.values.tolist()
li= My_result1.values.tolist()

err=0
for item in li:
    index=[j[0] for j in gli[:]].index(item[0])
    # print("index of {}:{}".format(item,))
    err+=abs(item[1]-gli[index][1])/item[1]
print(err/606770)
# Out:
# 0.0014390220928959746

# %%
# precision
import pandas as pd
import os
path='..\\result\\kosarak'
groundtruth='kosarak_ground_truth.csv'
final='Myalgo_kosarak_100k_count.csv'

grtruth=pd.read_csv(os.path.join(path,groundtruth))
My_result1=pd.read_csv(os.path.join(path,final))

gli = grtruth.values.tolist()
li= My_result1.values.tolist()
for item in li:
    index=[j[0] for j in gli[:1024]].index(item[0])

# %%
# ver. no-print

import spookyhash
import mmh3
from numpy import random
import os
import time
import operator
import hyperloglog
import sys
import pandas as pd
import cProfile

# ==========================data structure==========================
class Node():
    def __init__(self,count=0):
        self.count=count
    def add_count(self,count=1):
        self.count+=count
    def __str__(self):
        return 'count: {}'.format(self.count)
    def __repr__(self):
        return ''

class Head(Node):
    def __init__(self,count=1):
        super().__init__(count)
        self.distinct = hyperloglog.HyperLogLog(0.01)
        self.maxID=''
    def __str__(self):
        return '[total:{}, dist:{}, max:{}]'.format(self.count,len(self.distinct),self.maxID)
    def __repr__(self):
        return '[total:{}, dist:{}, max:{}]'.format(self.count,len(self.distinct),self.maxID)

class Tail(Node):
    def __init__(self,ID,count):
        self.ID = ID
        super().__init__(count)
    def __str__(self):
        return '[ID:{}, count:{}]'.format(self.ID,self.count)
    def __repr__(self):
        return '[ID:{}, count:{}]'.format(self.ID,self.count)
# ==========================data structure==========================


# ==========================UpdateSk==========================
def UpdateSk(element,Sk_head,Sk):
    print("In UpdateSk()")
    e_max=get_emax()
    ID,row=position(element)
        # row position of e and ID=h(e) in Sketch 
    avg=0
    item=Tail(ID, element.count)
        # ID in Sketch is hash value
    print("{} -> {},send to Sk[{}]".format(element,item,row))
    # ==========================update sketch==========================
    index=find(item,Sk[row])
        # find index of e in Sk[row]
    if index >=0:
        # e matches in Sk[row]
        Sk[row][index].count+=item.count
    else:
        # e doesn't match in Sk[row]
        if len(Sk[row])==0:
            Sk[row].append(item)
            index=0
            Sk_head[row].maxID=element.ID
                # unhashed ID
        elif len(Sk[row])<width:
            # Sk[row] is not full
            Sk[row].append(item)
            index=len(Sk[row])-1      
            # match=True
        else:
            # Sk[row] is full
            count_sum=sum(Sk[row][i].count for i in range(len(Sk[row])))
            if Sk_head[row].count==count_sum:
                # no other, send e to Other
                Sk_head[row].distinct.add(element.ID)
                # match=False
            else:
                # something in other and total count > sum
                if len(Sk_head[row].distinct)>0:
                    Sk_head[row].distinct.add(element.ID)
                    avg=(Sk_head[row].count-count_sum)//len(Sk_head[row].distinct)
                    # print("avg:{}".format(avg))
                else:
                    Sk_head[row].distinct.add(element.ID)
                    # print("distinct element:{}".format(len(Sk_head[row].distinct)))
                    # print("avg< last one,send to distinct")
                    # match=False
    Sk_head[row].count+=item.count
        # total count最後再+1 在line 82要compare distinct
    # now we have:
    # ID: h2(h1(e)), hash value of e
    # row: h1(e), row index of e
    # index: column index of e
    # Sk_head[row].count: total count of Sk[row]
    # Sk_head[row].maxID: local max count element of Sk[row]
    # Sk_head[row].distinct: estimated element of Other part in Sk[row]
    # count_sum: sum of count in Sketch[row]
    # avg: average count of Other part in Sk[row]
    # ==========================update local max==========================
    Update_local_max(Sk_head[row],Sk[row],avg,element,index)
    # Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
    
    # ==========================update e_max==========================
    Update_emax(Sk_head[row],Sk[row],element,avg)
    
    Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
    print("e_max:{}".format(e_max))
    print("Sk_head[{}]:{}".format(row,Sk_head[row]))
    for i in range(len(Sk)):
        print("Sk[{}]:{},{}".format(i,Sk_head[i],Sk[i]))


# ==========================update local max==========================    
def Update_local_max(head_item,element_list,avg,incoming_element,index):
    # Sk_head[row],Sk[row],avg
    print("In Update_local_max():")
    numertor,denominator=get_fraction()
    width,depth=get_width_depth()
    if head_item.maxID=='':
        head_item.maxID=incoming_element.ID
    else:
        local_max_ID=mmh3.hash(str(spookyhash.hash32(bytes(str(head_item.maxID),encoding='utf-8'))), signed=False) % ((width*numertor)//denominator)
        #print("local_max_ID:{}".format(local_max_ID))
        local_max_index=find(Tail(local_max_ID,1),element_list)
        #print("local_max_index:{}".format(local_max_index))
        # 此處當hashed ID相同時暫不更新 local max
        if local_max_index>=0:
            # local max exists
            if index>=0:
                # e in Sk[row]
                if element_list[index].count>element_list[local_max_index].count:
                    head_item.maxID=incoming_element.ID
            else:
                # e in Other
                if avg>element_list[local_max_index].count:
                    head_item.maxID=incoming_element.ID
        else:
            # local max doesn't exists
            head_item.maxID=incoming_element.ID

# ==========================update e_max==========================
def Update_emax(head_item,element_list,incoming_element,avg_count):
    # Sk_head[row],Sk[row],e_max
    print("In Update_emax():")
    e_max=get_emax()
    numerator,denominator=get_fraction()
    # local_max_ID=""
    # local_max_index=""
    print("e_max before update:{}".format(e_max))
    print("Sk_head:{}".format(head_item))
    width,depth=get_width_depth()
    if head_item.maxID!="":
        local_max_ID=mmh3.hash(str(spookyhash.hash32(bytes(str(head_item.maxID),encoding='utf-8'))), signed=False) % ((width*numerator)//denominator)
        # print("local_max_ID:{}".format(local_max_ID))
        local_max_index=find(Tail(local_max_ID,1),element_list)        
        # print("local_max_index:{}".format(local_max_index))
        if local_max_index>=0:
            if element_list[local_max_index].count>e_max.count:
                e_max.ID=head_item.maxID
                e_max.count=element_list[local_max_index].count
        else:
            if avg_count>e_max.count:
                e_max.ID=head_item.maxID
                e_max.count=avg_count
    print("e_max after update:{}".format(e_max))

# ========================== BringBack=========================
def BringBack(e_min,head,sketch):
    # Bring e_max back into Top
    # Sk_head,Sk[row]
    e_max=get_emax()
    print("\nIn BringBack():")
    temp=Tail(e_min.ID,e_min.count)
    e_min.ID=e_max.ID
    e_min.count=e_max.count
    # print('Top after BringBack:\n\t{}'.format(Top))
    DeleteSk(e_max,head,sketch)
    # update e_max in Sk[row]
    # print("e_max after delete:{},id(e_max):{}".format(e_max,id(e_max)))
    UpdateSk(temp,head,sketch)
    # print("Sk[] after Update {}:\n\t{}".format(e_min,Sk))

# ========================== BringBack=========================
# ==========================DeleteSk=========================
def DeleteSk(element,head,sketch):
    # 刪除e_max in Sk[row]
    print("\nIn DeleteSK({}):".format(element))
    width,depth=get_width_depth()
    ID,row=position(element)
    # print("row:{},ID:{} of e_max".format(row,ID))
    head[row].count-=element.count
        # total_count=total_count-e_max.count
    # print("Sk[{}]:{}".format(row,sketch[row]))
    index=find(Tail(ID,1),sketch[row])
    # print("index:{} in Sk[{}]".format(index,row))
    if index>=0:
        sketch[row].pop(index)
        # element_list[row].sort(key=operator.attrgetter('count'),reverse=True)
        head[row].maxID=""

    element.ID=""
    element.count=0
    # print("e_max After DeleteSk(element):{},id(e_max):{}".format(e_max,id(e_max)))
# ==========================Tools=========================    
def get_emax():
    return e_max
def get_width_depth():
    return width,depth

def find(e,element_list):
    # return index of e in element_list
    try:
        index=[ele.ID for ele in element_list].index(e.ID)      
    except:
        index=-99
    return index

def position(element):
    numertor,denominator=get_fraction()
    width,depth=get_width_depth()
    hash1=spookyhash.hash32(bytes(str(element.ID),encoding='utf-8'))
        # input of spooky: byte
        # output of spooky:unsigned- 32 bit int
    hash2=mmh3.hash(str(hash1), signed=False)
        # input of mmh: str
        # output: unsigned- 32 bit int
    ID=hash2 % ((width*numertor)//denominator)
    row=hash1 % depth    
    return ID,row
def get_fraction():
    return numerator,denominator

# ==========================main=========================   
        
start=time.time()

filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)
depth=4
width=4
size=8
numerator=12
denominator=10
    # numerator/denominator decides ratio of Other+Sketch /Sketch


Top=[]
Sk_head=[Head(0) for j in range(depth)]
Sk=[[] for i in range(depth)]
item_count=1000
i=0
e_max=Tail('',0)

with open(src_data,'r') as file:
    while item_count:
        element=file.readline().strip('\n')
        if not element:
            break
        else:
            i+=1
            print("\nread {}-th element: {}".format(i,element))
            item_count-=1
            item=Tail(element,1)
            if len(Top)==0:
                Top.append(item)
                # print("len(Top)==0, Top append:{}".format(Top))
            else:
                index=find(item,Top)
                # print("index={}".format(index))
                if index<0:
                    if len(Top)<size:
                        Top.append(item)
                        # print("index={},Top after append: {},\nlen(Top):{}".format(index,Top,len(Top)))
                    else:
                        UpdateSk(item,Sk_head,Sk)
                else:
                    # print("update Top[{}]:".format(index))
                    Top[index].count+=1
            Top.sort(key=operator.attrgetter('count'),reverse=True)
            # ID,row=position(Top[-1])
            if e_max.count>Top[-1].count:
                BringBack(Top[-1],Sk_head,Sk)
                print('Top after BringBack: \n\t{}'.format(Top))            


end=time.time()
print("Sk_head:{}".format(Sk_head))
print("TOP[20]:{}".format(Top[:20]))
# print("\nSketch:{}".format(Sk))
print("Total memory {} bytes".format(sys.getsizeof(Top)+sys.getsizeof(Sk)+sys.getsizeof(Sk_head)))
print("Top:{} bytes, Sketch:{} bytes, Sketch_head:{} bytes.".format(sys.getsizeof(Top),sys.getsizeof(Sk),sys.getsizeof(Sk_head)))
print("Execution time:{} seconds.".format(str(end-start)))

#　conver Top into df    
templi=[]
for i in Top:
    templi.append([i.ID,i.count])

df=pd.DataFrame(templi,columns=['ID', 'Count'])
df.to_csv("..\\result\\kosarak\\Myalgo_kosarak_100k_count.csv",index=False)
df.head(20)

# %%
# https://blog.csdn.net/asukasmallriver/article/details/74356771
'''
ncalls：表示函数调用的次数；
tottime：表示指定函数的总的运行时间，除掉函数中调用子函数的运行时间；
percall：（第一个percall）等于 tottime/ncalls；
cumtime：表示该函数及其所有子函数的调用运行的时间，即函数开始调用到返回的时间；
percall：（第二个percall）即函数运行一次的平均时间，等于 cumtime/ncalls；
filename:lineno(function)：每个函数调用的具体信息；
'''

import pstats

# 创建Stats对象
p = pstats.Stats("0406result.out")

# strip_dirs(): 去掉无关的路径信息
# sort_stats(): 排序，支持的方式和上述的一致
# print_stats(): 打印分析结果，可以指定打印前几行

# 和直接运行cProfile.run("test()")的结果是一样的
p.strip_dirs().sort_stats(-1).print_stats()
# Out:
# Tue Apr  6 10:20:28 2021    0406result.out
#
#          4127199756 function calls (4127068204 primitive calls) in 2643.356 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    9.407    9.407 2643.356 2643.356 0406.py:1(<module>)
#    785317    6.529    0.000   25.304    0.000 0406.py:118(Update_local_max)
#         1    0.000    0.000    0.000    0.000 0406.py:13(Node)
#   3367982    1.083    0.000    1.083    0.000 0406.py:14(__init__)
#    785317    6.012    0.000   23.526    0.000 0406.py:146(Update_emax)
#     22024    0.087    0.000   35.558    0.002 0406.py:172(BringBack)
#     22024    0.106    0.000    0.709    0.000 0406.py:189(DeleteSk)
#   1592658    0.368    0.000    0.368    0.000 0406.py:209(get_emax)
#   2399999    0.753    0.000    0.753    0.000 0406.py:211(get_width_depth)
#   3345952   10.902    0.000  210.973    0.000 0406.py:214(find)
#   3345952  171.083    0.000  171.083    0.000 0406.py:217(<listcomp>)
#    807341    5.388    0.000    7.941    0.000 0406.py:222(position)
#         1    0.000    0.000    0.000    0.000 0406.py:23(Head)
#   2377975    0.738    0.000    0.738    0.000 0406.py:234(get_fraction)
#         4    0.000    0.000    0.003    0.001 0406.py:24(__init__)
#         1    0.000    0.000    0.003    0.003 0406.py:253(<listcomp>)
#         1    0.000    0.000    0.000    0.000 0406.py:254(<listcomp>)
#         4    0.000    0.000    0.116    0.029 0406.py:30(__repr__)
#         1    0.000    0.000    0.000    0.000 0406.py:33(Tail)
#   3367978    5.617    0.000    6.700    0.000 0406.py:34(__init__)
#        20    0.000    0.000    0.000    0.000 0406.py:39(__repr__)
#    785317    7.984    0.000 2295.396    0.003 0406.py:45(UpdateSk)
#  14547588    4.656    0.000    4.656    0.000 0406.py:74(<genexpr>)
#      1186    0.003    0.000    0.003    0.000 <frozen importlib._bootstrap>:103(release)
#       634    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#       634    0.001    0.000    0.012    0.000 <frozen importlib._bootstrap>:147(__enter__)
#       634    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap>:151(__exit__)
#      1186    0.004    0.000    0.010    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#       627    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:176(cb)
#       552    0.001    0.000    0.005    0.000 <frozen importlib._bootstrap>:194(_lock_unlock_module)
#    675/12    0.001    0.000    2.392    0.199 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#      4604    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#        19    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:232(_requires_builtin_wrapper)
#       433    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#       433    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#       433    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap>:318(__exit__)
#      1732    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#       355    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:35(_new_module)
#       562    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:369(__init__)
#       769    0.001    0.000    0.009    0.000 <frozen importlib._bootstrap>:403(cached)
#       683    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:416(parent)
#       433    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#        20    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:433(spec_from_loader)
#       433    0.003    0.000    0.015    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#   433/408    0.001    0.000    1.405    0.003 <frozen importlib._bootstrap>:564(module_from_spec)
#       627    0.001    0.000    0.005    0.000 <frozen importlib._bootstrap>:58(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:622(_load_backward_compatible)
#     434/7    0.003    0.000    2.404    0.343 <frozen importlib._bootstrap>:651(_load_unlocked)
#       561    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:707(find_spec)
#        19    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:728(create_module)
#        19    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:736(exec_module)
#        19    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:753(is_package)
#      1186    0.004    0.000    0.004    0.000 <frozen importlib._bootstrap>:78(acquire)
#       542    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:780(find_spec)
#      1768    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:843(__enter__)
#      1768    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:847(__exit__)
#       123    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:861(_find_spec_legacy)
#       561    0.006    0.000    0.259    0.000 <frozen importlib._bootstrap>:870(_find_spec)
#    634/11    0.003    0.000    2.417    0.220 <frozen importlib._bootstrap>:936(_find_and_load_unlocked)
#    634/11    0.007    0.000    2.417    0.220 <frozen importlib._bootstrap>:966(_find_and_load)
# 2232/1195    0.002    0.000    1.317    0.001 <frozen importlib._bootstrap>:997(_handle_fromlist)
#        51    0.005    0.000    0.010    0.000 <frozen importlib._bootstrap_external>:1067(_path_hooks)
#       981    0.001    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:1080(_path_importer_cache)
#       542    0.003    0.000    0.248    0.000 <frozen importlib._bootstrap_external>:1117(_get_spec)
#       542    0.001    0.000    0.249    0.000 <frozen importlib._bootstrap_external>:1149(find_spec)
#        51    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1196(__init__)
#       408    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1202(<genexpr>)
#       414    0.001    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:1228(_get_spec)
#       889    0.012    0.000    0.233    0.000 <frozen importlib._bootstrap_external>:1233(find_spec)
#        52    0.001    0.000    0.012    0.000 <frozen importlib._bootstrap_external>:1281(_fill_cache)
#        52    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1310(<setcomp>)
#        51    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:1322(path_hook_for_FileFinder)
#       710    0.003    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:263(cache_from_source)
#       414    0.001    0.000    0.008    0.000 <frozen importlib._bootstrap_external>:361(_get_cached)
#       889    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:37(_relax_case)
#       355    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:393(_check_name_wrapper)
#       355    0.007    0.000    0.009    0.000 <frozen importlib._bootstrap_external>:430(_validate_bytecode_header)
#       355    0.001    0.000    0.077    0.000 <frozen importlib._bootstrap_external>:485(_compile_bytecode)
#       710    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:52(_r_long)
#       414    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:524(spec_from_file_location)
#      4273    0.005    0.000    0.013    0.000 <frozen importlib._bootstrap_external>:57(_path_join)
#      4273    0.004    0.000    0.007    0.000 <frozen importlib._bootstrap_external>:59(<listcomp>)
#       710    0.002    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:63(_path_split)
#       355    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:669(create_module)
#     355/6    0.002    0.000    2.359    0.393 <frozen importlib._bootstrap_external>:672(exec_module)
#       355    0.004    0.000    0.483    0.001 <frozen importlib._bootstrap_external>:743(get_code)
#      1819    0.002    0.000    0.218    0.000 <frozen importlib._bootstrap_external>:75(_path_stat)
#       355    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:800(__init__)
#       355    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:825(get_filename)
#       355    0.239    0.001    0.364    0.001 <frozen importlib._bootstrap_external>:830(get_data)
#       355    0.001    0.000    0.025    0.000 <frozen importlib._bootstrap_external>:840(path_stats)
#       575    0.001    0.000    0.129    0.000 <frozen importlib._bootstrap_external>:85(_path_is_mode_type)
#        59    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:908(__init__)
#     59/43    0.000    0.000    1.388    0.032 <frozen importlib._bootstrap_external>:919(create_module)
#        59    0.000    0.000    0.016    0.000 <frozen importlib._bootstrap_external>:927(exec_module)
#       524    0.001    0.000    0.126    0.000 <frozen importlib._bootstrap_external>:94(_path_isfile)
#        51    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:99(_path_isdir)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#        48    0.000    0.000    0.000    0.000 <string>:12(__new__)
#         1    0.000    0.000    0.000    0.000 <string>:2(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:2(AsyncContextManager)
#         1    0.000    0.000    0.000    0.000 <string>:5(ArgInfo)
#         1    0.000    0.000    0.000    0.000 <string>:5(ArgSpec)
#         1    0.000    0.000    0.000    0.000 <string>:5(Arguments)
#         1    0.000    0.000    0.000    0.000 <string>:5(Attribute)
#         1    0.000    0.000    0.000    0.000 <string>:5(Boxplot)
#         1    0.000    0.000    0.000    0.000 <string>:5(ClosureVars)
#         1    0.000    0.000    0.000    0.000 <string>:5(Components)
#         1    0.000    0.000    0.000    0.000 <string>:5(DecimalTuple)
#         1    0.000    0.000    0.000    0.000 <string>:5(DefaultVerifyPaths)
#         1    0.000    0.000    0.000    0.000 <string>:5(DefragResult)
#         1    0.000    0.000    0.000    0.000 <string>:5(DeprecatedOption)
#         1    0.000    0.000    0.000    0.000 <string>:5(ExtType)
#         1    0.000    0.000    0.000    0.000 <string>:5(FrameInfo)
#         1    0.000    0.000    0.000    0.000 <string>:5(FullArgSpec)
#         1    0.000    0.000    0.000    0.000 <string>:5(Match)
#         1    0.000    0.000    0.000    0.000 <string>:5(Mismatch)
#         1    0.000    0.000    0.000    0.000 <string>:5(ParseResult)
#         1    0.000    0.000    0.000    0.000 <string>:5(RegisteredOption)
#         1    0.000    0.000    0.000    0.000 <string>:5(SelectorKey)
#         1    0.000    0.000    0.000    0.000 <string>:5(SplitResult)
#         1    0.000    0.000    0.000    0.000 <string>:5(TokenInfo)
#         1    0.000    0.000    0.000    0.000 <string>:5(Traceback)
#         1    0.000    0.000    0.000    0.000 <string>:5(_ASN1Object)
#         1    0.000    0.000    0.000    0.000 <string>:5(_Instruction)
#         1    0.000    0.000    0.000    0.000 <string>:5(_LoggingWatcher)
#         1    0.000    0.000    0.000    0.000 <string>:5(uname_result)
#         1    0.000    0.000    0.000    0.000 <string>:5(usage)
#         1    0.000    0.000    0.001    0.001 __config__.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 __future__.py:48(<module>)
#         1    0.000    0.000    0.000    0.000 __future__.py:78(_Feature)
#         9    0.000    0.000    0.000    0.000 __future__.py:79(__init__)
#        29    0.001    0.000    0.944    0.033 __init__.py:1(<module>)
#         1    0.000    0.000    0.012    0.012 __init__.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:10(PerformanceWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:1008(FileHandler)
#         1    0.000    0.000    0.098    0.098 __init__.py:101(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:104(ParserWarning)
#         1    0.000    0.000    0.016    0.016 __init__.py:1052(rc_params_from_file)
#         1    0.000    0.000    0.604    0.604 __init__.py:106(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1074(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1077(_StderrHandler)
#         1    0.000    0.000    0.000    0.000 __init__.py:1083(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1101(PlaceHolder)
#         1    0.000    0.000    0.000    0.000 __init__.py:1116(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1143(Manager)
#         1    0.000    0.000    0.000    0.000 __init__.py:1148(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:1159(getLogger)
#         3    0.000    0.000    0.000    0.000 __init__.py:1210(_fixupParents)
#         1    0.000    0.000    0.000    0.000 __init__.py:124(lrange)
#         1    0.000    0.000    0.000    0.000 __init__.py:1251(Logger)
#         1    0.000    0.000    0.000    0.000 __init__.py:1260(rc_context)
#         4    0.000    0.000    0.000    0.000 __init__.py:1266(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1274(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 __init__.py:1284(debug)
#        14    0.000    0.000    0.000    0.000 __init__.py:139(_check_size)
#         1    0.000    0.000    0.000    0.000 __init__.py:1419(is_interactive)
#         1    0.000    0.000    0.000    0.000 __init__.py:145(MergeError)
#         1    0.000    0.000    0.020    0.020 __init__.py:15(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:151(py_object)
#         1    0.000    0.000    0.000    0.000 __init__.py:152(NullFrequencyError)
#         8    0.000    0.000    0.000    0.000 __init__.py:1528(getEffectiveLevel)
#         8    0.000    0.000    0.000    0.000 __init__.py:1542(isEnabledFor)
#         1    0.000    0.000    0.000    0.000 __init__.py:1574(RootLogger)
#         1    0.000    0.000    0.000    0.000 __init__.py:1580(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1588(LoggerAdapter)
#         1    0.000    0.000    0.000    0.000 __init__.py:16(DeprecatedTzFormatWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:16(UnsupportedFunctionCall)
#         1    0.000    0.000    0.000    0.000 __init__.py:160(AccessorRegistrationWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:160(c_short)
#         1    0.000    0.000    0.000    0.000 __init__.py:164(AbstractMethodError)
#         1    0.000    0.000    0.000    0.000 __init__.py:164(c_ushort)
#         1    0.000    0.000    0.000    0.000 __init__.py:168(c_long)
#         1    0.000    0.000    0.000    0.000 __init__.py:172(c_ulong)
#         2    0.000    0.000    0.000    0.000 __init__.py:175(compare_versions)
#         1    0.000    0.000    0.000    0.000 __init__.py:1769(Locked)
#         1    0.000    0.000    0.000    0.000 __init__.py:1784(TimeoutError)
#         4    0.000    0.000    0.000    0.000 __init__.py:1836(getLogger)
#         3    0.000    0.000    0.000    0.000 __init__.py:1876(_str_equal)
#         1    0.000    0.000    0.000    0.000 __init__.py:189(c_float)
#        57    0.000    0.000    0.000    0.000 __init__.py:19(__new__)
#         5    0.000    0.000    0.000    0.000 __init__.py:190(_checkLevel)
#         1    0.000    0.000    0.000    0.000 __init__.py:192(UTC)
#         1    0.000    0.000    0.000    0.000 __init__.py:193(c_double)
#         1    0.000    0.000    0.000    0.000 __init__.py:1964(NullHandler)
#         1    0.000    0.000    0.000    0.000 __init__.py:197(c_longdouble)
#         4    0.000    0.000    0.777    0.194 __init__.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:20(__deprecated_private_func)
#         1    0.000    0.000    0.000    0.000 __init__.py:2017(_OrderedSet)
#         1    0.000    0.000    0.001    0.001 __init__.py:204(_sanity_check)
#         6    0.000    0.000    0.000    0.000 __init__.py:205(iteritems)
#         1    0.000    0.000    0.000    0.000 __init__.py:207(c_longlong)
#         1    0.000    0.000    0.000    0.000 __init__.py:211(c_ulonglong)
#       351    0.000    0.000    0.000    0.000 __init__.py:217(bind_method)
#         1    0.000    0.000    0.000    0.000 __init__.py:218(c_ubyte)
#         5    0.000    0.000    0.000    0.000 __init__.py:219(_acquireLock)
#         1    0.000    0.000    0.000    0.000 __init__.py:225(c_byte)
#         1    0.000    0.000    0.000    0.000 __init__.py:225(silent_list)
#         5    0.000    0.000    0.000    0.000 __init__.py:228(_releaseLock)
#         1    0.000    0.000    0.000    0.000 __init__.py:23(UnsortedIndexError)
#         1    0.000    0.000    0.000    0.000 __init__.py:230(c_char)
#         1    0.000    0.000    0.000    0.000 __init__.py:235(c_char_p)
#         1    0.000    0.000    0.000    0.000 __init__.py:239(LogRecord)
#         1    0.000    0.000    0.005    0.005 __init__.py:24(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:241(c_void_p)
#         1    0.000    0.000    0.000    0.000 __init__.py:246(c_bool)
#         1    0.000    0.000    0.105    0.105 __init__.py:25(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:250(IgnoredKeywordWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:251(c_wchar_p)
#         1    0.000    0.000    0.000    0.000 __init__.py:256(c_wchar)
#         1    0.000    0.000    0.000    0.000 __init__.py:259(_reset_cache)
#         8    0.000    0.000    0.000    0.000 __init__.py:259(u)
#        50    0.000    0.000    0.000    0.000 __init__.py:262(u_safe)
#         1    0.000    0.000    0.000    0.000 __init__.py:265(_parse_commandline)
#         1    0.000    0.000    0.000    0.000 __init__.py:286(Verbose)
#         1    0.000    0.000    0.000    0.000 __init__.py:288(_CountryTimezoneDict)
#         1    0.000    0.000    0.000    0.000 __init__.py:292(<dictcomp>)
#       144    0.000    0.000    0.000    0.000 __init__.py:293(set_function_name)
#         3    0.000    0.000    0.270    0.090 __init__.py:3(<module>)
#         2    0.000    0.000    0.000    0.000 __init__.py:302(loads)
#         1    0.000    0.000    0.000    0.000 __init__.py:308(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:311(CDLL)
#         1    0.000    0.000    0.000    0.000 __init__.py:313(set_level)
#         1    0.000    0.000    0.000    0.000 __init__.py:315(Bunch)
#         1    0.000    0.000    0.000    0.000 __init__.py:33(ParserError)
#         2    0.000    0.000    0.000    0.000 __init__.py:332(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:342(_FuncPtr)
#         1    0.000    0.000    0.000    0.000 __init__.py:346(_CountryNameDict)
#         3    0.000    0.000    0.000    0.000 __init__.py:35(__deprecate_private_class)
#        27    0.001    0.000    0.016    0.001 __init__.py:357(namedtuple)
#         1    0.000    0.000    0.000    0.000 __init__.py:358(__getattr__)
#         1    0.000    0.000    0.000    0.000 __init__.py:365(__getitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:371(PyDLL)
#         1    0.000    0.000    0.000    0.000 __init__.py:371(_FixedOffset)
#         1    0.000    0.000    0.000    0.000 __init__.py:378(PercentStyle)
#         1    0.000    0.000    0.000    0.000 __init__.py:380(WinDLL)
#         1    0.000    0.000    0.000    0.000 __init__.py:384(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:387(add_metaclass)
#         1    0.000    0.000    0.000    0.000 __init__.py:389(HRESULT)
#         1    0.000    0.000    0.000    0.000 __init__.py:389(wrapper)
#         1    0.000    0.000    0.000    0.000 __init__.py:39(DtypeWarning)
#         8    0.000    0.000    0.000    0.000 __init__.py:390(_logged_cached)
#         1    0.000    0.000    0.000    0.000 __init__.py:393(StrFormatStyle)
#         1    0.000    0.000    0.283    0.283 __init__.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:402(OleDLL)
#         1    0.000    0.000    0.000    0.000 __init__.py:402(StringTemplateStyle)
#       6/2    0.000    0.000    0.001    0.001 __init__.py:409(wrapper)
#         1    0.000    0.000    0.011    0.011 __init__.py:41(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:411(LibraryLoader)
#         4    0.000    0.000    0.000    0.000 __init__.py:412(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:415(__getattr__)
#         3    0.000    0.000    0.000    0.000 __init__.py:42(private_class)
#       144    0.000    0.000    0.000    0.000 __init__.py:420(<genexpr>)
#       144    0.000    0.000    0.000    0.000 __init__.py:422(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:426(Formatter)
#         2    0.000    0.000    0.086    0.043 __init__.py:45(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:470(__init__)
#         3    0.000    0.000    0.000    0.000 __init__.py:476(PYFUNCTYPE)
#         3    0.000    0.000    0.000    0.000 __init__.py:477(CFunctionType)
#         1    0.000    0.000    0.000    0.000 __init__.py:491(checkdep_ps_distiller)
#         3    0.000    0.000    1.716    0.572 __init__.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:5(HTTPStatus)
#         1    0.000    0.000    0.000    0.000 __init__.py:505(GetRealpathAndStat)
#         1    0.000    0.000    0.000    0.000 __init__.py:525(checkdep_usetex)
#         1    0.000    0.000    0.000    0.000 __init__.py:555(get_home)
#         1    0.000    0.000    0.000    0.000 __init__.py:578(_get_xdg_config_dir)
#         1    0.000    0.000    0.000    0.000 __init__.py:599(BufferingFormatter)
#         1    0.000    0.000    0.001    0.001 __init__.py:602(_get_config_or_cache_dir)
#         1    0.000    0.000    0.000    0.000 __init__.py:609(maxdict)
#         1    0.000    0.000    0.001    0.001 __init__.py:625(get_configdir)
#         1    0.000    0.000    0.000    0.000 __init__.py:629(Stack)
#         1    0.000    0.000    0.000    0.000 __init__.py:641(Filter)
#         1    0.000    0.000    0.000    0.000 __init__.py:656(_get_data_path)
#         2    0.000    0.000    0.000    0.000 __init__.py:666(get_candidate_paths)
#         1    0.000    0.000    0.000    0.000 __init__.py:678(Filterer)
#         5    0.000    0.000    0.000    0.000 __init__.py:683(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:687(get_data_path)
#         2    0.000    0.000    0.080    0.040 __init__.py:7(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:70(_StrongRef)
#         1    0.000    0.000    0.002    0.002 __init__.py:703(matplotlib_fname)
#         3    0.000    0.000    0.000    0.000 __init__.py:73(CFUNCTYPE)
#         4    0.000    0.000    0.001    0.000 __init__.py:734(gen_candidates)
#         1    0.000    0.000    0.000    0.000 __init__.py:750(_addHandlerRef)
#         1    0.000    0.000    0.000    0.000 __init__.py:760(Handler)
#         1    0.000    0.000    0.000    0.000 __init__.py:769(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:783(RcParams)
#         1    0.000    0.000    0.000    0.000 __init__.py:792(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:798(createLock)
#         4    0.000    0.000    0.008    0.002 __init__.py:826(__init__)
#       901    0.001    0.000    0.007    0.000 __init__.py:829(__setitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:867(Grouper)
#         9    0.000    0.000    0.000    0.000 __init__.py:870(__getitem__)
#         1    0.000    0.000    0.028    0.028 __init__.py:88(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:88(CallbackRegistry)
#         2    0.000    0.000    0.009    0.004 __init__.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:9(ExtType)
#       302    0.000    0.000    0.000    0.000 __init__.py:907(__iter__)
#         1    0.000    0.000    0.000    0.000 __init__.py:927(copy)
#         1    0.000    0.000    0.000    0.000 __init__.py:928(<dictcomp>)
#         1    0.000    0.000    0.019    0.019 __init__.py:932(rc_params)
#         1    0.000    0.000    0.000    0.000 __init__.py:949(StreamHandler)
#         1    0.000    0.000    0.000    0.000 __init__.py:952(is_url)
#         2    0.000    0.000    0.010    0.005 __init__.py:957(_open_file_or_url)
#         1    0.000    0.000    0.006    0.006 __init__.py:97(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:97(EmptyDataError)
#         1    0.001    0.001    0.011    0.011 __init__.py:974(_rc_params_in_file)
#         3    0.000    0.000    0.000    0.000 __init__.py:99(CFunctionType)
#         2    0.000    0.000    0.000    0.000 _bootlocale.py:11(getpreferredencoding)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:252(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:349(__subclasshook__)
#        49    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#         5    0.000    0.000    0.000    0.000 _collections_abc.py:657(get)
#         8    0.000    0.000    0.000    0.000 _collections_abc.py:664(__contains__)
#         4    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#         5    0.000    0.000    0.008    0.002 _collections_abc.py:824(update)
#         1    0.000    0.000    0.000    0.000 _color_data.py:1(<module>)
#        11    0.000    0.000    0.000    0.000 _color_data.py:31(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _color_data.py:992(<dictcomp>)
#         1    0.000    0.000    0.001    0.001 _common.py:1(<module>)
#         3    0.000    0.000    0.001    0.000 _common.py:128(_validate_fromutc_inputs)
#         6    0.000    0.000    0.000    0.000 _common.py:13(tzname_in_python2)
#         1    0.000    0.000    0.001    0.001 _common.py:145(_tzinfo)
#         1    0.000    0.000    0.000    0.000 _common.py:263(tzrangebase)
#         1    0.000    0.000    0.000    0.000 _common.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _common.py:6(weekday)
#        14    0.000    0.000    0.000    0.000 _common.py:9(__init__)
#         1    0.000    0.000    0.000    0.000 _compat.py:3(<module>)
#        11    0.000    0.000    0.000    0.000 _compat.py:9(_mpl_version)
#        43    0.000    0.000    0.000    0.000 _compat_pickle.py:165(<genexpr>)
#        86    0.000    0.000    0.000    0.000 _compat_pickle.py:167(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _compat_pickle.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 _compression.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _compression.py:33(DecompressReader)
#         1    0.000    0.000    0.000    0.000 _compression.py:9(BaseStream)
#         1    0.000    0.000    0.153    0.153 _converter.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _converter.py:1065(TimeSeries_DateFormatter)
#         1    0.000    0.000    0.000    0.000 _converter.py:1135(TimeSeries_TimedeltaFormatter)
#         1    0.000    0.000    0.000    0.000 _converter.py:158(TimeConverter)
#         1    0.000    0.000    0.000    0.000 _converter.py:187(TimeFormatter)
#         1    0.000    0.000    0.000    0.000 _converter.py:231(PeriodConverter)
#         1    0.000    0.000    0.000    0.000 _converter.py:291(DatetimeConverter)
#         1    0.000    0.000    0.000    0.000 _converter.py:361(PandasAutoDateFormatter)
#         1    0.000    0.000    0.000    0.000 _converter.py:377(PandasAutoDateLocator)
#         1    0.000    0.000    0.000    0.000 _converter.py:403(MilliSecondLocator)
#         1    0.000    0.000    0.000    0.000 _converter.py:53(get_pairs)
#         1    0.000    0.000    0.000    0.000 _converter.py:65(register)
#         1    0.000    0.000    0.000    0.000 _converter.py:981(TimeSeries_DateLocator)
#         1    0.000    0.000    0.000    0.000 _core.py:1092(AreaPlot)
#         1    0.000    0.000    0.000    0.000 _core.py:1164(BarPlot)
#         1    0.000    0.000    0.000    0.000 _core.py:1288(BarhPlot)
#         1    0.000    0.000    0.000    0.000 _core.py:1310(HistPlot)
#         1    0.000    0.000    0.000    0.000 _core.py:1436(KdePlot)
#         1    0.000    0.000    0.000    0.000 _core.py:1492(PiePlot)
#         1    0.000    0.000    0.001    0.001 _core.py:1558(BoxPlot)
#         1    0.000    0.000    0.000    0.000 _core.py:2703(BasePlotMethods)
#         1    0.000    0.000    0.000    0.000 _core.py:2712(SeriesPlotMethods)
#         1    0.000    0.000    0.000    0.000 _core.py:2911(FramePlotMethods)
#         1    0.000    0.000    0.158    0.158 _core.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _core.py:75(MPLPlot)
#         1    0.000    0.000    0.000    0.000 _core.py:804(PlanePlot)
#         1    0.000    0.000    0.000    0.000 _core.py:837(ScatterPlot)
#         1    0.000    0.000    0.000    0.000 _core.py:901(HexBinPlot)
#         1    0.000    0.000    0.000    0.000 _core.py:933(LinePlot)
#         1    0.000    0.000    0.000    0.000 _datasource.py:138(_FileOpeners)
#         1    0.000    0.000    0.000    0.000 _datasource.py:162(__init__)
#         1    0.000    0.000    0.000    0.000 _datasource.py:265(DataSource)
#         1    0.000    0.000    0.000    0.000 _datasource.py:35(<module>)
#         1    0.000    0.000    0.000    0.000 _datasource.py:621(Repository)
#         1    0.000    0.000    0.022    0.022 _decorators.py:1(<module>)
#         3    0.000    0.000    0.001    0.000 _decorators.py:10(deprecate)
#        20    0.000    0.000    0.000    0.000 _decorators.py:135(_deprecate_kwarg)
#         2    0.000    0.000    0.000    0.000 _decorators.py:183(rewrite_axis_style_signature)
#         2    0.000    0.000    0.000    0.000 _decorators.py:184(decorate)
#         1    0.000    0.000    0.000    0.000 _decorators.py:212(Substitution)
#       158    0.000    0.000    0.000    0.000 _decorators.py:241(__init__)
#       158    0.001    0.000    0.001    0.000 _decorators.py:247(__call__)
#         1    0.000    0.000    0.000    0.000 _decorators.py:273(Appender)
#       547    0.000    0.000    0.000    0.000 _decorators.py:293(__init__)
#       547    0.001    0.000    0.049    0.000 _decorators.py:300(__call__)
#         4    0.000    0.000    0.000    0.000 _decorators.py:308(indent)
#         1    0.000    0.000    0.000    0.000 _decorators.py:344(docstring_wrapper)
#        15    0.000    0.000    0.000    0.000 _decorators.py:60(<genexpr>)
#        20    0.000    0.000    0.000    0.000 _decorators.py:66(deprecate_kwarg)
#         1    0.000    0.000    0.000    0.000 _depr_module.py:10(_DeprecatedModule)
#         5    0.000    0.000    0.000    0.000 _depr_module.py:26(__init__)
#         1    0.000    0.000    0.000    0.000 _depr_module.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 _distributor_init.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 _encoded_words.py:6(<module>)
#         1    0.000    0.000    0.000    0.000 _encoded_words.py:73(_QByteMap)
#         1    0.000    0.000    0.000    0.000 _endian.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _endian.py:23(_swapped_meta)
#         1    0.000    0.000    0.000    0.000 _endian.py:46(BigEndianStructure)
#         1    0.000    0.000    0.000    0.000 _factories.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _factories.py:14(_TzFactory)
#         1    0.000    0.000    0.000    0.000 _factories.py:20(_TzOffsetFactory)
#         1    0.000    0.000    0.000    0.000 _factories.py:21(__init__)
#         1    0.000    0.000    0.000    0.000 _factories.py:37(_TzStrFactory)
#         1    0.000    0.000    0.000    0.000 _factories.py:38(__init__)
#         1    0.000    0.000    0.000    0.000 _factories.py:4(_TzSingleton)
#         1    0.000    0.000    0.000    0.000 _factories.py:5(__init__)
#         1    0.000    0.000    0.000    0.000 _factories.py:9(__call__)
#         1    0.000    0.000    0.000    0.000 _globals.py:17(<module>)
#         1    0.000    0.000    0.000    0.000 _globals.py:33(ModuleDeprecationWarning)
#         1    0.000    0.000    0.000    0.000 _globals.py:45(VisibleDeprecationWarning)
#         1    0.000    0.000    0.000    0.000 _globals.py:55(_NoValueType)
#         1    0.000    0.000    0.000    0.000 _globals.py:63(__new__)
#         9    0.000    0.000    0.000    0.000 _globals.py:73(__repr__)
#         1    0.000    0.000    0.000    0.000 _import_tools.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _import_tools.py:339(PackageLoaderDebug)
#         1    0.000    0.000    0.000    0.000 _import_tools.py:9(PackageLoader)
#       101    0.000    0.000    0.000    0.000 _inspect.py:133(strseq)
#        39    0.000    0.000    0.000    0.000 _inspect.py:142(formatargspec)
#         7    0.000    0.000    0.000    0.000 _inspect.py:144(<lambda>)
#         5    0.000    0.000    0.000    0.000 _inspect.py:145(<lambda>)
#        62    0.000    0.000    0.000    0.000 _inspect.py:146(<lambda>)
#        44    0.000    0.000    0.000    0.000 _inspect.py:15(ismethod)
#        44    0.000    0.000    0.000    0.000 _inspect.py:28(isfunction)
#        39    0.000    0.000    0.000    0.000 _inspect.py:43(iscode)
#        39    0.000    0.000    0.000    0.000 _inspect.py:67(getargs)
#         1    0.000    0.000    0.000    0.000 _inspect.py:7(<module>)
#        44    0.000    0.000    0.000    0.000 _inspect.py:98(getargspec)
#         1    0.000    0.000    0.000    0.000 _internal.py:204(dummy_ctype)
#         1    0.000    0.000    0.000    0.000 _internal.py:216(_getintp_ctype)
#         1    0.000    0.000    0.000    0.000 _internal.py:239(_missing_ctypes)
#         1    0.000    0.000    0.000    0.000 _internal.py:246(_ctypes)
#         1    0.000    0.000    0.030    0.030 _internal.py:6(<module>)
#         1    0.000    0.000    0.000    0.000 _internal.py:683(TooHardError)
#         1    0.000    0.000    0.000    0.000 _internal.py:686(AxisError)
#        51    0.000    0.000    0.000    0.000 _internal.py:715(_ufunc_doc_signature_formatter)
#        78    0.000    0.000    0.000    0.000 _internal.py:726(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _iotools.py:170(LineSplitter)
#         1    0.000    0.000    0.000    0.000 _iotools.py:270(NameValidator)
#         1    0.000    0.000    0.000    0.000 _iotools.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _iotools.py:464(ConverterError)
#         1    0.000    0.000    0.000    0.000 _iotools.py:472(ConverterLockError)
#         1    0.000    0.000    0.000    0.000 _iotools.py:480(ConversionWarning)
#         1    0.000    0.000    0.000    0.000 _iotools.py:493(StringConverter)
#         2    0.000    0.000    0.000    0.000 _methods.py:42(_any)
#         1    0.000    0.000    0.000    0.000 _methods.py:5(<module>)
#         1    0.000    0.000    0.005    0.005 _misc.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _parseaddr.py:203(AddrlistClass)
#         1    0.000    0.000    0.000    0.000 _parseaddr.py:495(AddressList)
#         1    0.000    0.000    0.002    0.002 _parseaddr.py:7(<module>)
#         1    0.000    0.000    0.000    0.000 _parser.py:1359(_tzparser)
#         1    0.000    0.000    0.000    0.000 _parser.py:1361(_result)
#         1    0.000    0.000    0.000    0.000 _parser.py:1366(_attr)
#         1    0.000    0.000    0.000    0.000 _parser.py:1576(UnknownTimezoneWarning)
#         1    0.000    0.000    0.000    0.000 _parser.py:225(_resultbase)
#         1    0.000    0.000    0.000    0.000 _parser.py:247(parserinfo)
#         1    0.000    0.000    0.014    0.014 _parser.py:30(<module>)
#         1    0.000    0.000    0.000    0.000 _parser.py:300(__init__)
#         7    0.000    0.000    0.000    0.000 _parser.py:315(_convert)
#         1    0.000    0.000    0.000    0.000 _parser.py:399(_ymd)
#         1    0.000    0.000    0.000    0.000 _parser.py:573(parser)
#         1    0.000    0.000    0.000    0.000 _parser.py:574(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:58(_timelex)
#         1    0.000    0.000    0.000    0.000 _parser.py:663(_result)
#        10    0.000    0.000    0.000    0.000 _policybase.py:104(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _policybase.py:112(Policy)
#         1    0.000    0.000    0.000    0.000 _policybase.py:18(_PolicyBase)
#         1    0.000    0.000    0.000    0.000 _policybase.py:271(Compat32)
#         1    0.000    0.000    0.025    0.025 _policybase.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 _policybase.py:41(__init__)
#         6    0.000    0.000    0.000    0.000 _policybase.py:94(_append_doc)
#         1    0.000    0.000    0.000    0.000 _policybase.py:99(_extend_docstrings)
#         1    0.000    0.000    0.001    0.001 _polybase.py:19(ABCPolyBase)
#         1    0.000    0.000    0.001    0.001 _polybase.py:8(<module>)
#         1    0.000    0.000    0.000    0.000 _print_versions.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _style.py:107(_Options)
#         2    0.000    0.000    0.000    0.000 _style.py:119(__init__)
#         1    0.000    0.000    0.002    0.002 _style.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _tester.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _tools.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _validators.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 _version.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _version.py:18(NumpyVersion)
#         1    0.000    0.000    0.000    0.000 _version.py:20(get_versions)
#         1    0.000    0.000    0.000    0.000 _version.py:22(get_versions)
#         1    0.000    0.000    0.000    0.000 _version.py:4(<module>)
#         3    0.000    0.000    0.000    0.000 _version.py:7(<module>)
#        78    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#        78    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#        78    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#       390    0.001    0.000    0.001    0.000 _weakrefset.py:36(__init__)
#        78    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#       116    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#       556    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#        94    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#       114    0.001    0.000    0.009    0.000 abc.py:132(__new__)
#       114    0.000    0.000    0.001    0.000 abc.py:135(<setcomp>)
#        16    0.000    0.000    0.001    0.000 abc.py:151(register)
#       266    0.000    0.000    0.002    0.000 abc.py:180(__instancecheck__)
#    125/23    0.001    0.000    0.002    0.000 abc.py:196(__subclasscheck__)
#        94    0.001    0.000    0.001    0.000 abc.py:9(abstractmethod)
#         1    0.000    0.000    0.000    0.000 accessor.py:113(CachedAccessor)
#         6    0.000    0.000    0.000    0.000 accessor.py:125(__init__)
#         1    0.000    0.000    0.000    0.000 accessor.py:13(DirNamesMixin)
#         1    0.000    0.000    0.000    0.000 accessor.py:43(PandasDelegate)
#         9    0.000    0.000    0.000    0.000 accessor.py:56(_add_delegate_accessors)
#         1    0.000    0.000    0.000    0.000 accessor.py:7(<module>)
#        54    0.000    0.000    0.000    0.000 accessor.py:72(_create_delegator_property)
#        36    0.000    0.000    0.000    0.000 accessor.py:86(_create_delegator_method)
#         1    0.000    0.000    0.000    0.000 accessors.py:114(DatetimeProperties)
#         1    0.000    0.000    0.000    0.000 accessors.py:189(TimedeltaProperties)
#         1    0.000    0.000    0.000    0.000 accessors.py:24(Properties)
#         1    0.000    0.000    0.000    0.000 accessors.py:266(PeriodProperties)
#         1    0.000    0.000    0.000    0.000 accessors.py:291(CombinedDatetimelikeProperties)
#         1    0.000    0.000    0.001    0.001 accessors.py:3(<module>)
#         1    0.000    0.000    0.485    0.485 add_newdocs.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 algorithms.py:1070(SelectN)
#         1    0.000    0.000    0.000    0.000 algorithms.py:1096(SelectNSeries)
#         1    0.000    0.000    0.000    0.000 algorithms.py:1157(SelectNFrame)
#        12    0.000    0.000    0.000    0.000 algorithms.py:1253(_view_wrapper)
#         1    0.000    0.000    0.100    0.100 algorithms.py:4(<module>)
#         1    0.000    0.000    0.002    0.002 align.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 align.py:44(_filter_special_cases)
#         1    0.000    0.000    0.278    0.278 api.py:1(<module>)
#         6    0.000    0.000    0.241    0.040 api.py:3(<module>)
#         1    0.000    0.000    0.924    0.924 api.py:5(<module>)
#         3    0.000    0.000    0.000    0.000 api.py:69(outer)
#         1    0.000    0.000    0.000    0.000 api.py:72(TimeGrouper)
#         1    0.000    0.000    0.000    0.000 argparse.py:1005(_HelpAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:1024(_VersionAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:1050(_SubParsersAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:1052(_ChoicesPseudoAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:109(_AttributeHolder)
#         1    0.000    0.000    0.000    0.000 argparse.py:1146(FileType)
#         1    0.000    0.000    0.000    0.000 argparse.py:1200(Namespace)
#         1    0.000    0.000    0.000    0.000 argparse.py:1220(_ActionsContainer)
#         1    0.000    0.000    0.000    0.000 argparse.py:150(HelpFormatter)
#         1    0.000    0.000    0.000    0.000 argparse.py:1527(_ArgumentGroup)
#         1    0.000    0.000    0.000    0.000 argparse.py:1561(_MutuallyExclusiveGroup)
#         1    0.000    0.000    0.000    0.000 argparse.py:1581(ArgumentParser)
#         1    0.000    0.000    0.000    0.000 argparse.py:200(_Section)
#         1    0.000    0.000    0.001    0.001 argparse.py:62(<module>)
#         1    0.000    0.000    0.000    0.000 argparse.py:637(RawDescriptionHelpFormatter)
#         1    0.000    0.000    0.000    0.000 argparse.py:648(RawTextHelpFormatter)
#         1    0.000    0.000    0.000    0.000 argparse.py:659(ArgumentDefaultsHelpFormatter)
#         1    0.000    0.000    0.000    0.000 argparse.py:676(MetavarTypeHelpFormatter)
#         1    0.000    0.000    0.000    0.000 argparse.py:709(ArgumentError)
#         1    0.000    0.000    0.000    0.000 argparse.py:729(ArgumentTypeError)
#         1    0.000    0.000    0.000    0.000 argparse.py:738(Action)
#         1    0.000    0.000    0.000    0.000 argparse.py:829(_StoreAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:864(_StoreConstAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:887(_StoreTrueAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:904(_StoreFalseAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:921(_AppendAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:958(_AppendConstAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:984(_CountAction)
#         1    0.000    0.000    0.000    0.000 array.py:130(SparseArray)
#         1    0.000    0.000    0.025    0.025 array.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 arraypad.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1109(IntegerFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1122(BoolFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1132(ComplexFloatingFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1161(ComplexFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1168(LongComplexFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1176(_TimelikeFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1202(DatetimeFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1234(TimedeltaFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1239(SubArrayFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1249(StructuredVoidFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1286(StructureFormat)
#         2    0.000    0.000    0.000    0.000 arrayprint.py:1506(set_string_function)
#         2    0.000    0.000    0.000    0.000 arrayprint.py:440(_recursive_guard)
#         2    0.000    0.000    0.000    0.000 arrayprint.py:450(decorating_function)
#         1    0.000    0.000    0.001    0.001 arrayprint.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:810(FloatingFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:953(FloatFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:960(LongFloatFormat)
#         1    0.000    0.000    0.000    0.000 arraysetops.py:27(<module>)
#         1    0.000    0.000    0.000    0.000 arrayterator.py:20(Arrayterator)
#         1    0.000    0.000    0.000    0.000 arrayterator.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 ast.py:229(NodeVisitor)
#         1    0.000    0.000    0.000    0.000 ast.py:26(<module>)
#         1    0.000    0.000    0.000    0.000 ast.py:266(NodeTransformer)
#         2    0.000    0.000    0.211    0.106 base.py:1(<module>)
#        56    0.000    0.000    0.000    0.000 base.py:128(_make_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 base.py:131(NoNewAttributesMixin)
#         1    0.000    0.000    0.000    0.000 base.py:1325(nlevels)
#         2    0.000    0.000    0.000    0.000 base.py:1590(is_object)
#         1    0.000    0.000    0.000    0.000 base.py:16(ExtensionArray)
#         1    0.000    0.000    0.000    0.000 base.py:162(GroupByError)
#         1    0.000    0.000    0.000    0.000 base.py:163(InvalidIndexError)
#         1    0.000    0.000    0.000    0.000 base.py:166(DataError)
#         1    0.000    0.000    0.000    0.000 base.py:1695(_convert_slice_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:170(SpecificationError)
#         1    0.000    0.000    0.000    0.000 base.py:174(SelectionMixin)
#         1    0.000    0.000    0.001    0.001 base.py:183(Index)
#         2    0.000    0.000    0.000    0.000 base.py:2067(__getitem__)
#         2    0.000    0.000    0.002    0.001 base.py:2408(to_native_types)
#         2    0.000    0.000    0.001    0.001 base.py:2434(_format_native_types)
#         1    0.000    0.000    0.000    0.000 base.py:2445(equals)
#         1    0.000    0.000    0.000    0.000 base.py:255(__new__)
#         1    0.000    0.000    0.005    0.005 base.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 base.py:37(StringMixin)
#         3    0.000    0.000    0.000    0.000 base.py:4132(_validate_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:4614(_add_comparison_methods)
#         2    0.000    0.000    0.000    0.000 base.py:4624(_add_numeric_methods_add_sub_disabled)
#         5    0.000    0.000    0.000    0.000 base.py:4634(_add_numeric_methods_disabled)
#         4    0.000    0.000    0.000    0.000 base.py:4710(_add_numeric_methods_binary)
#         1    0.000    0.000    0.000    0.000 base.py:473(_simple_new)
#         5    0.000    0.000    0.000    0.000 base.py:4732(_add_numeric_methods_unary)
#        20    0.000    0.000    0.000    0.000 base.py:4736(_make_evaluate_unary)
#         5    0.000    0.000    0.000    0.000 base.py:4752(_add_numeric_methods)
#         4    0.000    0.000    0.001    0.000 base.py:4757(_add_logical_methods)
#         8    0.000    0.000    0.001    0.000 base.py:4839(_make_logical_function)
#         7    0.000    0.000    0.000    0.000 base.py:4862(_add_logical_methods_disabled)
#         8    0.000    0.000    0.001    0.000 base.py:4914(_ensure_index)
#        31    0.000    0.000    0.000    0.000 base.py:61(is_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:615(is_)
#         4    0.000    0.000    0.000    0.000 base.py:635(_reset_identity)
#         7    0.000    0.000    0.000    0.000 base.py:641(__len__)
#         2    0.000    0.000    0.000    0.000 base.py:647(__array__)
# ...
#         8    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
# 1242/1217    0.029    0.000    0.111    0.000 {built-in method builtins.__build_class__}
#    455/51    0.001    0.000    1.739    0.034 {built-in method builtins.__import__}
#        72    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#       190    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#       557    0.001    0.000    0.001    0.000 {built-in method builtins.any}
#        46    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       742    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.delattr}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.dir}
#        45    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#     417/1    0.016    0.000 2643.356 2643.356 {built-in method builtins.exec}
#      9047    0.005    0.000    0.005    0.000 {built-in method builtins.getattr}
#       373    0.000    0.000    0.000    0.000 {built-in method builtins.globals}
#      7282    0.006    0.000    0.006    0.000 {built-in method builtins.hasattr}
#        37    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        58    0.000    0.000    0.000    0.000 {built-in method builtins.id}
# 128023/127915    0.050    0.000    0.052    0.000 {built-in method builtins.isinstance}
# 3147/2996    0.001    0.000    0.003    0.000 {built-in method builtins.issubclass}
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 2518863/2394343    1.161    0.000 2181.989    0.001 {built-in method builtins.len}
#    112869    0.140    0.000    0.140    0.000 {built-in method builtins.max}
#      1357    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#        26    0.000    0.000    0.010    0.000 {built-in method builtins.next}
#      1455    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         5    0.002    0.000    0.002    0.000 {built-in method builtins.print}
#       116    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#    225549    0.562    0.000    0.562    0.000 {built-in method builtins.round}
#      2264    0.001    0.000    0.002    0.000 {built-in method builtins.setattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#    361266  325.729    0.001 2069.558    0.006 {built-in method builtins.sum}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#       730    0.001    0.000    0.001    0.000 {built-in method from_bytes}
#         4    0.029    0.007    0.029    0.007 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method maketrans}
#       355    0.074    0.000    0.074    0.000 {built-in method marshal.loads}
#         4    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 {built-in method math.exp}
#    225546    0.403    0.000    0.403    0.000 {built-in method math.log}
# 2035646464  813.111    0.000  813.111    0.000 {built-in method math.pow}
#         1    0.000    0.000    0.000    0.000 {built-in method math.sqrt}
#   2355951    3.576    0.000    3.576    0.000 {built-in method mmh3.hash}
#         1    0.000    0.000    0.000    0.000 {built-in method nt._isdir}
#         1    0.000    0.000    0.000    0.000 {built-in method nt.access}
#      1154    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#       185    0.000    0.000    0.000    0.000 {built-in method nt.getcwd}
#        52    0.009    0.000    0.009    0.000 {built-in method nt.listdir}
#         1    0.000    0.000    0.000    0.000 {built-in method nt.mkdir}
#         5    0.000    0.000    0.000    0.000 {built-in method nt.putenv}
#      1852    0.220    0.000    0.220    0.000 {built-in method nt.stat}
#       275    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.add_docstring}
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.arange}
#        93    0.001    0.000    0.001    0.000 {built-in method numpy.core.multiarray.array}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.copyto}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.datetime_data}
#        31    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.empty}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.set_string_function}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.set_typeDict}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.zeros}
#        14    0.000    0.000    0.000    0.000 {built-in method numpy.core.umath.geterrobj}
#         7    0.000    0.000    0.000    0.000 {built-in method numpy.core.umath.seterrobj}
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.algos.ensure_object}
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.infer_datetimelike_array}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_bool}
#         5    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_integer}
#        10    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_scalar}
#        67    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getdefaultencoding}
#         6    0.000    0.000    0.000    0.000 {built-in method sys.getsizeof}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getwindowsversion}
#        20    0.000    0.000    0.000    0.000 {built-in method sys.intern}
#         1    0.000    0.000    0.000    0.000 {built-in method time.localtime}
#         3    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {built-in method utcfromtimestamp}
#         1    0.000    0.000    0.000    0.000 {built-in method winreg.ConnectRegistry}
#         1    0.000    0.000    0.000    0.000 {built-in method winreg.OpenKey}
#         1    0.000    0.000    0.000    0.000 {function Random.seed at 0x000002089DA5C7B8}
#         2    0.000    0.000    0.000    0.000 {method 'Close' of 'PyHKEY' objects}
#       261    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#       429    0.001    0.000    0.001    0.000 {method '__reduce_ex__' of 'object' objects}
#        85    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#        21    0.000    0.000    0.000    0.000 {method '__subclasshook__' of 'object' objects}
#         5    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#      1541    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#     34482    0.006    0.000    0.006    0.000 {method 'append' of 'list' objects}
#         2    0.002    0.001    0.002    0.001 {method 'astype' of 'numpy.ndarray' objects}
#    112854    0.044    0.000    0.044    0.000 {method 'bit_length' of 'int' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cast' of 'memoryview' objects}
#        15    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#         7    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy' of 'mappingproxy' objects}
#        30    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#    225540   81.622    0.000   81.622    0.000 {method 'count' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         2    0.000    0.000    0.000    0.000 {method 'deleter' of 'property' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.001    0.001    0.001    0.001 {method 'dot' of 'numpy.ndarray' objects}
#    112779    0.157    0.000    0.157    0.000 {method 'encode' of 'str' objects}
#        25    0.000    0.000    0.000    0.000 {method 'end' of '_sre.SRE_Match' objects}
#      1019    0.001    0.000    0.001    0.000 {method 'endswith' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 {method 'expandtabs' of 'str' objects}
#       372    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#       835    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#       617    0.019    0.000    0.019    0.000 {method 'findall' of '_sre.SRE_Pattern' objects}
# 2144/2120    0.003    0.000    0.120    0.000 {method 'format' of 'str' objects}
#      2876    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#       283    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        22    0.000    0.000    0.000    0.000 {method 'group' of '_sre.SRE_Match' objects}
#        21    0.000    0.000    0.000    0.000 {method 'groupdict' of '_sre.SRE_Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'groups' of '_sre.SRE_Match' objects}
#    112772    0.347    0.000    0.347    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#   3345952   28.988    0.000   28.988    0.000 {method 'index' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       194    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#       136    0.000    0.000    0.000    0.000 {method 'issuperset' of 'frozenset' objects}
#       710    0.000    0.000    0.000    0.000 {method 'isupper' of 'str' objects}
#       166    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#       304    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
# 5904/5900    0.003    0.000    0.004    0.000 {method 'join' of 'str' objects}
#        34    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#      1647    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#       493    0.001    0.000    0.001    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#        20    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#       669    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#        62    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#     22219    0.019    0.000    0.019    0.000 {method 'pop' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       355    0.125    0.000    0.125    0.000 {method 'read' of '_io.FileIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#    990003    1.850    0.000    1.853    0.000 {method 'readline' of '_io.TextIOWrapper' objects}
#         1    0.002    0.002    0.002    0.002 {method 'readlines' of '_io._IOBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         5    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#        10    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        78    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#       459    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        33    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#      3072    0.001    0.000    0.001    0.000 {method 'rpartition' of 'str' objects}
#       716    0.001    0.000    0.001    0.000 {method 'rsplit' of 'str' objects}
#      9260    0.002    0.000    0.002    0.000 {method 'rstrip' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'search' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#        44    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        57    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#   1899587  189.926    0.000  189.926    0.000 {method 'sort' of 'list' objects}
#        29    0.000    0.000    0.000    0.000 {method 'split' of '_sre.SRE_Pattern' objects}
#       803    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#     21012    0.004    0.000    0.004    0.000 {method 'startswith' of 'str' objects}
#        38    0.000    0.000    0.000    0.000 {method 'strftime' of 'datetime.date' objects}
#    991553    0.839    0.000    0.839    0.000 {method 'strip' of 'str' objects}
#       891    0.024    0.000    0.024    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#         2    0.000    0.000    0.000    0.000 {method 'title' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'tolist' of 'memoryview' objects}
#         3    0.000    0.000    0.000    0.000 {method 'toordinal' of 'datetime.date' objects}
#        56    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#       105    0.000    0.000    0.000    0.000 {method 'translate' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#       769    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#        58    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.generic' objects}
#         8    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'writerow' of '_csv.writer' objects}
#         1    0.000    0.000    0.001    0.001 {pandas._libs.lib.clean_index_list}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         2    0.001    0.001    0.001    0.001 {pandas._libs.lib.maybe_convert_objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.to_object_array}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.missing.isnaobj}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.offsets._get_calendar}
#         7    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.offsets.apply_index_wraps}
#         1    0.004    0.004    0.004    0.004 {pandas._libs.writers.write_csv_rows}
#   2355951    1.493    0.000    1.493    0.000 {spookyhash.hash32}

# %%
# 按照函数名排序，只打印前3行函数的信息, 参数还可为小数,表示前百分之几的函数信息 
p.strip_dirs().sort_stats("name").print_stats(3)
# Out:
# Tue Apr  6 10:20:28 2021    0406result.out
#
#          4127199756 function calls (4127068204 primitive calls) in 2643.356 seconds
#
#    Ordered by: function name
#    List reduced from 3049 to 3 due to restriction <3>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       933    0.005    0.000    0.005    0.000 {built-in method __new__ of type object at 0x0000000077F4C430}
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#        31    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}

# %%
# 按照运行时间和函数名进行排序
p.strip_dirs().sort_stats("cumulative", "name").print_stats(0.5)

'''
ncalls：表示函数调用的次数；
tottime：表示指定函数的总的运行时间，除掉函数中调用子函数的运行时间；
percall：（第一个percall）等于 tottime/ncalls；
cumtime：表示该函数及其所有子函数的调用运行的时间，即函数开始调用到返回的时间；
percall：（第二个percall）即函数运行一次的平均时间，等于 cumtime/ncalls；
filename:lineno(function)：每个函数调用的具体信息；
'''
# Out:
# Tue Apr  6 10:20:28 2021    0406result.out
#
#          4127199756 function calls (4127068204 primitive calls) in 2643.356 seconds
#
#    Ordered by: cumulative time, function name
#    List reduced from 3049 to 1525 due to restriction <0.5>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     417/1    0.016    0.000 2643.356 2643.356 {built-in method builtins.exec}
#         1    9.407    9.407 2643.356 2643.356 0406.py:1(<module>)
#    785317    7.984    0.000 2295.396    0.003 0406.py:45(UpdateSk)
# 2518863/2394343    1.161    0.000 2181.989    0.001 {built-in method builtins.len}
#    225540    0.404    0.000 2180.874    0.010 hll.py:136(__len__)
#    225540    1.466    0.000 2179.908    0.010 hll.py:143(card)
#    124246    1.104    0.000 2096.274    0.017 hll.py:139(_Ep)
#    361266  325.729    0.001 2069.558    0.006 {built-in method builtins.sum}
# 2035770710  926.062    0.000 1739.173    0.000 hll.py:140(<genexpr>)
# 2035646464  813.111    0.000  813.111    0.000 {built-in method math.pow}
#   3345952   10.902    0.000  210.973    0.000 0406.py:214(find)
#   1899587  189.926    0.000  189.926    0.000 {method 'sort' of 'list' objects}
#   3345952  171.083    0.000  171.083    0.000 0406.py:217(<listcomp>)
#    225540   81.622    0.000   81.622    0.000 {method 'count' of 'list' objects}
#     22024    0.087    0.000   35.558    0.002 0406.py:172(BringBack)
#    124246    1.378    0.000   33.052    0.000 hll.py:28(estimate_bias)
#    124246    1.017    0.000   31.041    0.000 hll.py:34(get_nearest_neighbors)
#   3345952   28.988    0.000   28.988    0.000 {method 'index' of 'list' objects}
#    124246   26.048    0.000   26.048    0.000 hll.py:35(<listcomp>)
#    785317    6.529    0.000   25.304    0.000 0406.py:118(Update_local_max)
#    785317    6.012    0.000   23.526    0.000 0406.py:146(Update_emax)
#    807341    5.388    0.000    7.941    0.000 0406.py:222(position)
#   3367978    5.617    0.000    6.700    0.000 0406.py:34(__init__)
#  14547588    4.656    0.000    4.656    0.000 0406.py:74(<genexpr>)
#   2355951    3.576    0.000    3.576    0.000 {built-in method mmh3.hash}
#    112772    1.277    0.000    2.724    0.000 hll.py:100(add)
#    634/11    0.007    0.000    2.417    0.220 <frozen importlib._bootstrap>:966(_find_and_load)
#    634/11    0.003    0.000    2.417    0.220 <frozen importlib._bootstrap>:936(_find_and_load_unlocked)
#     434/7    0.003    0.000    2.404    0.343 <frozen importlib._bootstrap>:651(_load_unlocked)
#    675/12    0.001    0.000    2.392    0.199 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#     355/6    0.002    0.000    2.359    0.393 <frozen importlib._bootstrap_external>:672(exec_module)
#    990003    1.850    0.000    1.853    0.000 {method 'readline' of '_io.TextIOWrapper' objects}
#    455/51    0.001    0.000    1.739    0.034 {built-in method builtins.__import__}
#         3    0.000    0.000    1.716    0.572 __init__.py:5(<module>)
#   2355951    1.493    0.000    1.493    0.000 {spookyhash.hash32}
#   433/408    0.001    0.000    1.405    0.003 <frozen importlib._bootstrap>:564(module_from_spec)
#     59/43    0.000    0.000    1.388    0.032 <frozen importlib._bootstrap_external>:919(create_module)
#     59/43    1.324    0.022    1.387    0.032 {built-in method _imp.create_dynamic}
# 2232/1195    0.002    0.000    1.317    0.001 <frozen importlib._bootstrap>:997(_handle_fromlist)
#   3367982    1.083    0.000    1.083    0.000 0406.py:14(__init__)
#        29    0.001    0.000    0.944    0.033 __init__.py:1(<module>)
#         1    0.000    0.000    0.924    0.924 api.py:5(<module>)
#    991553    0.839    0.000    0.839    0.000 {method 'strip' of 'str' objects}
#         4    0.000    0.000    0.777    0.194 __init__.py:2(<module>)
#   2399999    0.753    0.000    0.753    0.000 0406.py:211(get_width_depth)
#         1    0.000    0.000    0.748    0.748 groupby.py:1(<module>)
#   2377975    0.738    0.000    0.738    0.000 0406.py:234(get_fraction)
#     22024    0.106    0.000    0.709    0.000 0406.py:189(DeleteSk)
#         1    0.000    0.000    0.604    0.604 __init__.py:106(<module>)
#    225549    0.562    0.000    0.562    0.000 {built-in method builtins.round}
#         1    0.000    0.000    0.485    0.485 add_newdocs.py:10(<module>)
#       355    0.004    0.000    0.483    0.001 <frozen importlib._bootstrap_external>:743(get_code)
#    112773    0.436    0.000    0.436    0.000 {built-in method _hashlib.openssl_sha1}
#    225546    0.403    0.000    0.403    0.000 {built-in method math.log}
#         1    0.000    0.000    0.390    0.390 frame.py:10(<module>)
#    124246    0.390    0.000    0.390    0.000 hll.py:31(<listcomp>)
#   1592658    0.368    0.000    0.368    0.000 0406.py:209(get_emax)
#       355    0.239    0.001    0.364    0.001 <frozen importlib._bootstrap_external>:830(get_data)
#         1    0.000    0.000    0.355    0.355 type_check.py:3(<module>)
#    112772    0.347    0.000    0.347    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#    112772    0.177    0.000    0.321    0.000 hll.py:56(get_rho)
#         1    0.000    0.000    0.283    0.283 __init__.py:4(<module>)
#         1    0.000    0.000    0.283    0.283 index.py:2(<module>)
#         1    0.000    0.000    0.278    0.278 api.py:1(<module>)
#         3    0.000    0.000    0.270    0.090 __init__.py:3(<module>)
#       561    0.006    0.000    0.259    0.000 <frozen importlib._bootstrap>:870(_find_spec)
#         1    0.000    0.000    0.252    0.252 series.py:3(<module>)
#       542    0.001    0.000    0.249    0.000 <frozen importlib._bootstrap_external>:1149(find_spec)
#       542    0.003    0.000    0.248    0.000 <frozen importlib._bootstrap_external>:1117(_get_spec)
#         6    0.000    0.000    0.241    0.040 api.py:3(<module>)
#       889    0.012    0.000    0.233    0.000 <frozen importlib._bootstrap_external>:1233(find_spec)
#      1852    0.220    0.000    0.220    0.000 {built-in method nt.stat}
#      1819    0.002    0.000    0.218    0.000 <frozen importlib._bootstrap_external>:75(_path_stat)
#         2    0.000    0.000    0.211    0.106 base.py:1(<module>)
#    124246    0.177    0.000    0.177    0.000 hll.py:37(<listcomp>)
#         1    0.000    0.000    0.158    0.158 _core.py:3(<module>)
#    112779    0.157    0.000    0.157    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.153    0.153 _converter.py:1(<module>)
#    112772    0.100    0.000    0.144    0.000 hll.py:11(bit_length)
#    225540    0.143    0.000    0.143    0.000 hll.py:24(get_treshold)
#    112869    0.140    0.000    0.140    0.000 {built-in method builtins.max}
#       575    0.001    0.000    0.129    0.000 <frozen importlib._bootstrap_external>:85(_path_is_mode_type)
#       524    0.001    0.000    0.126    0.000 <frozen importlib._bootstrap_external>:94(_path_isfile)
#       355    0.125    0.000    0.125    0.000 {method 'read' of '_io.FileIO' objects}
# 2144/2120    0.003    0.000    0.120    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.118    0.118 generic.py:2(<module>)
#         4    0.000    0.000    0.116    0.029 0406.py:30(__repr__)
# 1242/1217    0.029    0.000    0.111    0.000 {built-in method builtins.__build_class__}
#         1    0.000    0.000    0.105    0.105 __init__.py:25(<module>)
#         1    0.000    0.000    0.100    0.100 algorithms.py:4(<module>)
#         1    0.000    0.000    0.098    0.098 __init__.py:101(<module>)
#         2    0.000    0.000    0.086    0.043 __init__.py:45(<module>)
#         2    0.000    0.000    0.080    0.040 __init__.py:7(<module>)
#       355    0.001    0.000    0.077    0.000 <frozen importlib._bootstrap_external>:485(_compile_bytecode)
#       355    0.074    0.000    0.074    0.000 {built-in method marshal.loads}
#         1    0.000    0.000    0.071    0.071 packers.py:39(<module>)
#         1    0.000    0.000    0.064    0.064 index_tricks.py:1(<module>)
#         1    0.000    0.000    0.059    0.059 internals.py:1(<module>)
#         1    0.000    0.000    0.059    0.059 rcsetup.py:15(<module>)
#         2    0.000    0.000    0.059    0.029 generic.py:8893(_add_series_or_dataframe_operations)
#         1    0.000    0.000    0.054    0.054 window.py:7(<module>)
# 128023/127915    0.050    0.000    0.052    0.000 {built-in method builtins.isinstance}
#       617    0.004    0.000    0.052    0.000 textwrap.py:414(dedent)
#         1    0.000    0.000    0.051    0.051 client.py:69(<module>)
#         1    0.000    0.000    0.051    0.051 defmatrix.py:1(<module>)
#         3    0.000    0.000    0.050    0.017 common.py:1(<module>)
#       547    0.001    0.000    0.049    0.000 _decorators.py:300(__call__)
#         1    0.000    0.000    0.048    0.048 interval.py:1(<module>)
#         1    0.000    0.000    0.047    0.047 fontconfig_pattern.py:7(<module>)
#         1    0.000    0.000    0.044    0.044 dates.py:134(<module>)
#    112854    0.044    0.000    0.044    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.043    0.043 linalg.py:10(<module>)
#       847    0.002    0.000    0.043    0.000 re.py:286(_compile)
#         1    0.000    0.000    0.042    0.042 cast.py:1(<module>)
#       117    0.000    0.000    0.041    0.000 re.py:231(compile)
#       112    0.001    0.000    0.039    0.000 sre_compile.py:557(compile)
#         1    0.000    0.000    0.039    0.039 pyparsing.py:76(<module>)
#         1    0.000    0.000    0.038    0.038 ticker.py:165(<module>)
#         1    0.000    0.000    0.037    0.037 reshape.py:3(<module>)
#         1    0.000    0.000    0.034    0.034 transforms.py:30(<module>)
#         1    0.000    0.000    0.033    0.033 offsets.py:2(<module>)
#         1    0.000    0.000    0.031    0.031 parsers.py:3(<module>)
#         1    0.000    0.000    0.031    0.031 pytables.py:4(<module>)
#         1    0.000    0.000    0.030    0.030 _internal.py:6(<module>)
#         1    0.000    0.000    0.029    0.029 parser.py:5(<module>)
#         4    0.029    0.007    0.029    0.007 {built-in method io.open}
#         1    0.000    0.000    0.028    0.028 feedparser.py:20(<module>)
#         1    0.000    0.000    0.028    0.028 __init__.py:88(<module>)
#         1    0.000    0.000    0.026    0.026 testing.py:5(<module>)
#         1    0.000    0.000    0.025    0.025 array.py:3(<module>)
#         1    0.000    0.000    0.025    0.025 _policybase.py:4(<module>)
#       355    0.001    0.000    0.025    0.000 <frozen importlib._bootstrap_external>:840(path_stats)
#         1    0.000    0.000    0.024    0.024 fftpack.py:32(<module>)
#       282    0.001    0.000    0.024    0.000 function_base.py:3895(add_newdoc)
#       891    0.024    0.000    0.024    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.023    0.023 testing.py:1(<module>)
#         1    0.000    0.000    0.023    0.023 frame.py:1653(to_csv)
#         1    0.000    0.000    0.023    0.023 excel.py:3(<module>)
#         1    0.000    0.000    0.022    0.022 ops.py:5(<module>)
#         1    0.000    0.000    0.022    0.022 indexing.py:2(<module>)
#         1    0.000    0.000    0.022    0.022 _decorators.py:1(<module>)
#         1    0.000    0.000    0.021    0.021 hashing.py:3(<module>)
#         1    0.000    0.000    0.021    0.021 utils.py:4(<module>)
#         1    0.000    0.000    0.021    0.021 config_init.py:11(<module>)
#       112    0.001    0.000    0.021    0.000 sre_parse.py:844(parse)
#         1    0.000    0.000    0.020    0.020 __init__.py:15(<module>)
#       617    0.019    0.000    0.019    0.000 {method 'findall' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.019    0.019 __init__.py:932(rc_params)
#     22219    0.019    0.000    0.019    0.000 {method 'pop' of 'list' objects}
#   269/112    0.001    0.000    0.018    0.000 sre_parse.py:407(_parse_sub)
#   323/122    0.006    0.000    0.018    0.000 sre_parse.py:470(_parse)
#       112    0.000    0.000    0.017    0.000 sre_compile.py:542(_code)
#        59    0.000    0.000    0.016    0.000 <frozen importlib._bootstrap_external>:927(exec_module)
#         1    0.000    0.000    0.016    0.016 __init__.py:1052(rc_params_from_file)
#        59    0.000    0.000    0.016    0.000 {built-in method _imp.exec_dynamic}
#        23    0.000    0.000    0.016    0.001 pyparsing.py:1049(_trim_arity)
#        21    0.000    0.000    0.016    0.001 pyparsing.py:1260(setParseAction)
#        27    0.001    0.000    0.016    0.001 __init__.py:357(namedtuple)
#        22    0.000    0.000    0.016    0.001 pyparsing.py:1057(extract_stack)
#        22    0.000    0.000    0.016    0.001 traceback.py:196(extract_stack)
#        22    0.000    0.000    0.016    0.001 traceback.py:313(extract)
#       433    0.003    0.000    0.015    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#         3    0.000    0.000    0.015    0.005 numeric.py:1(<module>)
#         1    0.000    0.000    0.015    0.015 format.py:5(<module>)
#         1    0.000    0.000    0.015    0.015 utils.py:5(<module>)
#   580/112    0.004    0.000    0.014    0.000 sre_compile.py:64(_compile)
#         1    0.000    0.000    0.014    0.014 _parser.py:30(<module>)
#         1    0.000    0.000    0.014    0.014 config.py:49(<module>)
#         1    0.000    0.000    0.014    0.014 typing.py:1(<module>)
#        88    0.000    0.000    0.013    0.000 traceback.py:279(line)
#        66    0.000    0.000    0.013    0.000 linecache.py:15(getline)
#        66    0.000    0.000    0.013    0.000 linecache.py:37(getlines)
#         1    0.000    0.000    0.013    0.013 linecache.py:82(updatecache)
#      4273    0.005    0.000    0.013    0.000 <frozen importlib._bootstrap_external>:57(_path_join)
#         1    0.000    0.000    0.013    0.013 pyparsing.py:5558(pyparsing_common)
#         5    0.000    0.000    0.013    0.003 config.py:769(is_instance_factory)
#         1    0.000    0.000    0.012    0.012 __init__.py:10(<module>)
#        52    0.001    0.000    0.012    0.000 <frozen importlib._bootstrap_external>:1281(_fill_cache)
#        11    0.000    0.000    0.012    0.001 ops.py:800(_create_methods)
#         1    0.000    0.000    0.012    0.012 categorical.py:3(<module>)
#         1    0.000    0.000    0.012    0.012 ssl.py:91(<module>)
#       634    0.001    0.000    0.012    0.000 <frozen importlib._bootstrap>:147(__enter__)
#         1    0.000    0.000    0.011    0.011 case.py:1(<module>)
#         1    0.000    0.000    0.011    0.011 __init__.py:41(<module>)
#         1    0.001    0.001    0.011    0.011 __init__.py:974(_rc_params_in_file)
#       981    0.001    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:1080(_path_importer_cache)
#       710    0.003    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:263(cache_from_source)
#         1    0.000    0.000    0.011    0.011 datetimes.py:2(<module>)
#        80    0.001    0.000    0.011    0.000 typing.py:922(__new__)
#         1    0.000    0.000    0.011    0.011 tokenize.py:448(open)
#         1    0.000    0.000    0.010    0.010 platform.py:10(<module>)
#        26    0.000    0.000    0.010    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.010    0.005 __init__.py:957(_open_file_or_url)
#        13    0.000    0.000    0.010    0.001 contextlib.py:79(__enter__)
#       269    0.000    0.000    0.010    0.000 re.py:184(sub)
#         1    0.000    0.000    0.010    0.010 panel.py:3(<module>)
#         1    0.000    0.000    0.010    0.010 csvs.py:123(save)
#      1186    0.004    0.000    0.010    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#        51    0.005    0.000    0.010    0.000 <frozen importlib._bootstrap_external>:1067(_path_hooks)
#         1    0.000    0.000    0.010    0.010 json.py:2(<module>)
#        52    0.009    0.000    0.009    0.000 {built-in method nt.listdir}
#       114    0.001    0.000    0.009    0.000 abc.py:132(__new__)
#         1    0.000    0.000    0.009    0.009 py3k.py:4(<module>)
#         1    0.000    0.000    0.009    0.009 result.py:1(<module>)
#         1    0.000    0.000    0.009    0.009 socket.py:47(<module>)
#       769    0.001    0.000    0.009    0.000 <frozen importlib._bootstrap>:403(cached)
#         2    0.000    0.000    0.009    0.004 __init__.py:9(<module>)
#         1    0.000    0.000    0.009    0.009 dtypes.py:1(<module>)
#         1    0.000    0.000    0.009    0.009 eval.py:4(<module>)
#        27    0.000    0.000    0.009    0.000 pyparsing.py:2816(__init__)
#         1    0.000    0.000    0.009    0.009 inspect.py:27(<module>)
#       355    0.007    0.000    0.009    0.000 <frozen importlib._bootstrap_external>:430(_validate_bytecode_header)
#         1    0.000    0.000    0.008    0.008 shutil.py:5(<module>)
#       414    0.001    0.000    0.008    0.000 <frozen importlib._bootstrap_external>:361(_get_cached)
#      2640    0.002    0.000    0.008    0.000 enum.py:265(__call__)
#         1    0.000    0.000    0.008    0.008 main.py:1(<module>)
#         5    0.000    0.000    0.008    0.002 _collections_abc.py:824(update)
#         4    0.000    0.000    0.008    0.002 __init__.py:826(__init__)
#         5    0.000    0.000    0.008    0.002 ops.py:927(add_flex_arithmetic_methods)
#         1    0.000    0.000    0.008    0.008 pathlib.py:1(<module>)
#         1    0.000    0.000    0.008    0.008 header.py:5(<module>)
#         1    0.000    0.000    0.007    0.007 csvs.py:270(_save)
#        90    0.000    0.000    0.007    0.000 typing.py:133(__new__)
#         1    0.000    0.000    0.007    0.007 csvs.py:288(_save_chunk)
#       901    0.001    0.000    0.007    0.000 __init__.py:829(__setitem__)
#         1    0.000    0.000    0.007    0.007 npyio.py:1(<module>)
#      4273    0.004    0.000    0.007    0.000 <frozen importlib._bootstrap_external>:59(<listcomp>)
#     55/53    0.000    0.000    0.006    0.000 typing.py:676(inner)
#         1    0.000    0.000    0.006    0.006 tempfile.py:24(<module>)
#         1    0.000    0.000    0.006    0.006 table_schema.py:5(<module>)
#     34482    0.006    0.000    0.006    0.000 {method 'append' of 'list' objects}
#        34    0.000    0.000    0.006    0.000 typing.py:1099(__getitem__)
#         1    0.000    0.000    0.006    0.006 tz.py:9(<module>)
#         1    0.004    0.004    0.006    0.006 getlimits.py:3(<module>)
#      7282    0.006    0.000    0.006    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.006    0.006 series.py:4(<module>)
#      1180    0.002    0.000    0.006    0.000 enum.py:801(__and__)
#        10    0.000    0.000    0.006    0.001 pyparsing.py:4404(__init__)
#         1    0.000    0.000    0.006    0.006 engines.py:3(<module>)
#         1    0.000    0.000    0.006    0.006 __init__.py:97(<module>)
#         1    0.000    0.000    0.006    0.006 traceback.py:1(<module>)
#     33/10    0.000    0.000    0.006    0.001 pyparsing.py:3809(leaveWhitespace)
#         6    0.000    0.000    0.005    0.001 ops.py:875(add_special_arithmetic_methods)
#         1    0.000    0.000    0.005    0.005 _misc.py:3(<module>)
#         1    0.000    0.000    0.005    0.005 frame.py:248(DataFrame)
#      9047    0.005    0.000    0.005    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.005    0.005 request.py:68(<module>)
#       429    0.001    0.000    0.005    0.000 pyparsing.py:1177(copy)
#        12    0.000    0.000    0.005    0.000 enum.py:602(_convert)
#       552    0.001    0.000    0.005    0.000 <frozen importlib._bootstrap>:194(_lock_unlock_module)
#         1    0.000    0.000    0.005    0.005 __init__.py:24(<module>)
#        68    0.000    0.000    0.005    0.000 ops.py:1486(_arith_method_FRAME)
#         1    0.000    0.000    0.005    0.005 random.py:38(<module>)
#         1    0.000    0.000    0.005    0.005 generic.py:102(NDFrame)
#         1    0.000    0.000    0.005    0.005 polynomial.py:56(<module>)
#       249    0.001    0.000    0.005    0.000 sre_compile.py:223(_compile_charset)
#         2    0.000    0.000    0.005    0.002 frame.py:334(__init__)
#       933    0.005    0.000    0.005    0.000 {built-in method __new__ of type object at 0x0000000077F4C430}
#       627    0.001    0.000    0.005    0.000 <frozen importlib._bootstrap>:58(__init__)
#       430    0.001    0.000    0.005    0.000 copy.py:66(copy)
#         1    0.000    0.000    0.005    0.005 base.py:3(<module>)
#        15    0.002    0.000    0.005    0.000 enum.py:124(__new__)
#         1    0.000    0.000    0.005    0.005 hll.py:3(<module>)
#       414    0.001    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:1228(_get_spec)
#         1    0.000    0.000    0.004    0.004 linecache.py:6(<module>)
#         1    0.000    0.000    0.004    0.004 pytables.py:1(<module>)
#        51    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:1322(path_hook_for_FileFinder)
#     58/10    0.000    0.000    0.004    0.000 pyparsing.py:3354(leaveWhitespace)
#    121/59    0.000    0.000    0.004    0.000 pyparsing.py:3429(copy)
#         1    0.000    0.000    0.004    0.004 printing.py:3(<module>)
#       710    0.002    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:63(_path_split)
#         1    0.000    0.000    0.004    0.004 series.py:126(Series)
#     21012    0.004    0.000    0.004    0.000 {method 'startswith' of 'str' objects}
#         1    0.004    0.004    0.004    0.004 {pandas._libs.writers.write_csv_rows}
#         1    0.000    0.000    0.004    0.004 numerictypes.py:81(<module>)
#      1186    0.004    0.000    0.004    0.000 <frozen importlib._bootstrap>:78(acquire)
#         1    0.000    0.000    0.004    0.004 frame.py:4(<module>)
#       249    0.003    0.000    0.004    0.000 sre_compile.py:250(_optimize_charset)
# 5904/5900    0.003    0.000    0.004    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.004    0.004 financial.py:12(<module>)
#        12    0.000    0.000    0.004    0.000 enum.py:364(_create_)
#         1    0.000    0.000    0.004    0.004 colors.py:45(<module>)
#         2    0.000    0.000    0.004    0.002 function_base.py:1(<module>)
#         3    0.000    0.000    0.004    0.001 generic.py:8747(_add_numeric_operations)
#         1    0.000    0.000    0.004    0.004 core.py:21(<module>)
#         1    0.000    0.000    0.004    0.004 message.py:5(<module>)
#         1    0.000    0.000    0.004    0.004 base.py:7(<module>)
#      1260    0.004    0.000    0.004    0.000 {built-in method _thread.allocate_lock}
#        42    0.000    0.000    0.003    0.000 ops.py:1367(_flex_method_SERIES)
#         1    0.000    0.000    0.003    0.003 runner.py:1(<module>)
#        51    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:99(_path_isdir)
#    121/59    0.000    0.000    0.003    0.000 pyparsing.py:3431(<listcomp>)
#      3327    0.001    0.000    0.003    0.000 sre_parse.py:253(get)
#         1    0.000    0.000    0.003    0.003 tokenize.py:21(<module>)
#         1    0.000    0.000    0.003    0.003 pickle.py:24(<module>)
#         1    0.000    0.000    0.003    0.003 datetimelike.py:4(<module>)
#        58    0.000    0.000    0.003    0.000 pyparsing.py:3358(<listcomp>)
#       112    0.001    0.000    0.003    0.000 sre_compile.py:482(_compile_info)
#   925/460    0.003    0.000    0.003    0.000 sre_parse.py:173(getwidth)
# 3147/2996    0.001    0.000    0.003    0.000 {built-in method builtins.issubclass}
#      1186    0.003    0.000    0.003    0.000 <frozen importlib._bootstrap>:103(release)
#         2    0.000    0.000    0.003    0.002 common.py:121(_stringify_path)
#         1    0.000    0.000    0.003    0.003 0406.py:253(<listcomp>)
#         4    0.000    0.000    0.003    0.001 0406.py:24(__init__)
#         4    0.000    0.000    0.003    0.001 hll.py:72(__init__)
#        10    0.000    0.000    0.003    0.000 pyparsing.py:2675(__init__)
#      4032    0.003    0.000    0.003    0.000 codecs.py:280(getstate)
#         4    0.003    0.001    0.003    0.001 hll.py:91(<listcomp>)
#       433    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap>:318(__exit__)
#         7    0.000    0.000    0.003    0.000 pyparsing.py:1630(parseString)
#       634    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap>:151(__exit__)
#       414    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:524(spec_from_file_location)
#         1    0.000    0.000    0.003    0.003 decoder.py:2(<module>)
#         1    0.000    0.000    0.003    0.003 decimal.py:2(<module>)
#         1    0.000    0.000    0.003    0.003 hashlib.py:54(<module>)
#      2628    0.002    0.000    0.003    0.000 enum.py:515(__new__)
#         1    0.000    0.000    0.003    0.003 dis.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 common.py:298(_get_handle)
#         1    0.000    0.000    0.003    0.003 bz2.py:5(<module>)
#      4133    0.003    0.000    0.003    0.000 sre_parse.py:232(__next)
#      2264    0.001    0.000    0.002    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.002    0.002 csvs.py:28(__init__)
#  1043/989    0.002    0.000    0.002    0.000 typing.py:1164(__setattr__)
#         1    0.002    0.002    0.002    0.002 {method 'readlines' of '_io._IOBase' objects}
#         1    0.000    0.000    0.002    0.002 selectors.py:5(<module>)
#      4604    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#         1    0.000    0.000    0.002    0.002 fontconfig_pattern.py:65(__init__)
#         1    0.000    0.000    0.002    0.002 groupby.py:3409(SeriesGroupBy)
#      9260    0.002    0.000    0.002    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.002    0.002 pyparsing.py:5057(makeHTMLTags)
#     188/7    0.001    0.000    0.002    0.000 pyparsing.py:1380(_parseNoCache)
#         1    0.000    0.000    0.002    0.002 pyparsing.py:5028(_makeTags)
#      39/7    0.000    0.000    0.002    0.000 pyparsing.py:3463(parseImpl)
#         1    0.000    0.000    0.002    0.002 parse.py:28(<module>)
#         1    0.000    0.000    0.002    0.002 charset.py:6(<module>)
#         1    0.000    0.000    0.002    0.002 __init__.py:703(matplotlib_fname)
#    125/23    0.001    0.000    0.002    0.000 abc.py:196(__subclasscheck__)
#       162    0.001    0.000    0.002    0.000 functools.py:44(update_wrapper)
#         2    0.002    0.001    0.002    0.001 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.002    0.002 ipaddress.py:9(<module>)
#       457    0.000    0.000    0.002    0.000 re.py:169(match)
#      2195    0.001    0.000    0.002    0.000 sre_parse.py:163(__getitem__)
#         6    0.002    0.000    0.002    0.000 getlimits.py:65(__init__)
#       429    0.001    0.000    0.002    0.000 copy.py:268(_reconstruct)
#         1    0.000    0.000    0.002    0.002 groupby.py:1171(GroupBy)
#         1    0.000    0.000    0.002    0.002 expr.py:2(<module>)
#         1    0.000    0.000    0.002    0.002 signals.py:1(<module>)
#       122    0.000    0.000    0.002    0.000 sre_parse.py:96(closegroup)
#         1    0.000    0.000    0.002    0.002 win.py:2(<module>)
#         1    0.000    0.000    0.002    0.002 frame.py:7453(_to_arrays)
#         1    0.000    0.000    0.002    0.002 frame.py:7547(_list_to_arrays)
#         1    0.000    0.000    0.002    0.002 _style.py:3(<module>)
#         1    0.000    0.000    0.002    0.002 multi.py:3(<module>)
#         1    0.000    0.000    0.002    0.002 _parseaddr.py:7(<module>)
#        87    0.000    0.000    0.002    0.000 rcsetup.py:69(f)
#         1    0.000    0.000    0.002    0.002 string.py:15(<module>)
#         5    0.002    0.000    0.002    0.000 {built-in method builtins.print}
#       627    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:176(cb)
#       266    0.000    0.000    0.002    0.000 abc.py:180(__instancecheck__)
#         2    0.000    0.000    0.002    0.001 pyparsing.py:4916(srange)
#        22    0.000    0.000    0.002    0.000 linecache.py:53(checkcache)
#         1    0.000    0.000    0.002    0.002 fromnumeric.py:3(<module>)
#         1    0.000    0.000    0.002    0.002 function.py:19(<module>)
#         1    0.000    0.000    0.002    0.002 frame.py:7349(_arrays_to_mgr)
#         1    0.000    0.000    0.002    0.002 pickle.py:1(<module>)
#         1    0.000    0.000    0.002    0.002 string.py:65(__init__)
#         1    0.000    0.000    0.002    0.002 version.py:27(<module>)
#         2    0.000    0.000    0.002    0.001 base.py:2408(to_native_types)
#         1    0.000    0.000    0.002    0.002 align.py:2(<module>)
#         4    0.000    0.000    0.001    0.000 base.py:4757(_add_logical_methods)
#         1    0.000    0.000    0.001    0.001 frame.py:7604(_convert_object_array)
#         2    0.000    0.000    0.001    0.001 internals.py:755(to_native_types)
#         1    0.000    0.000    0.001    0.001 frame.py:7621(<listcomp>)
#         2    0.000    0.000    0.001    0.001 frame.py:7615(convert)
#         1    0.000    0.000    0.001    0.001 series.py:39(SparseSeries)
#       108    0.000    0.000    0.001    0.000 rcsetup.py:358(validate_color)
#         2    0.000    0.000    0.001    0.001 base.py:2434(_format_native_types)
#       716    0.001    0.000    0.001    0.000 {method 'rsplit' of 'str' objects}
#        48    0.000    0.000    0.001    0.000 config.py:726(inner)
#         1    0.000    0.000    0.001    0.001 window.py:1428(Rolling)
#         1    0.000    0.000    0.001    0.001 panel.py:107(Panel)
#         1    0.000    0.000    0.001    0.001 base.py:183(Index)
#         1    0.000    0.000    0.001    0.001 window.py:1713(Expanding)
#         1    0.000    0.000    0.001    0.001 multi.py:131(MultiIndex)
#        19    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:728(create_module)
#        18    0.000    0.000    0.001    0.000 rcsetup.py:446(validate_font_properties)
#         1    0.000    0.000    0.001    0.001 numbers.py:6(<module>)
#         1    0.000    0.000    0.001    0.001 lzma.py:9(<module>)
#         1    0.000    0.000    0.001    0.001 console.py:3(<module>)
#       134    0.000    0.000    0.001    0.000 enum.py:795(__or__)
#         5    0.000    0.000    0.001    0.000 fontconfig_pattern.py:113(parse)
#       203    0.001    0.000    0.001    0.000 enum.py:70(__setitem__)
#       269    0.001    0.000    0.001    0.000 enum.py:351(__setattr__)
#       557    0.001    0.000    0.001    0.000 {built-in method builtins.any}
#       390    0.001    0.000    0.001    0.000 _weakrefset.py:36(__init__)
#       710    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:52(_r_long)
#        19    0.001    0.000    0.001    0.000 {built-in method _imp.create_builtin}
#        48    0.001    0.000    0.001    0.000 config.py:414(register_option)
#         1    0.000    0.000    0.001    0.001 encoders.py:5(<module>)
#      1768    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:847(__exit__)
#      3072    0.001    0.000    0.001    0.000 {method 'rpartition' of 'str' objects}
#         1    0.000    0.000    0.001    0.001 scanner.py:2(<module>)
#         4    0.000    0.000    0.001    0.000 __init__.py:734(gen_candidates)
#         1    0.000    0.000    0.001    0.001 nanops.py:1(<module>)
#         8    0.000    0.000    0.001    0.000 base.py:4914(_ensure_index)
#         4    0.000    0.000    0.001    0.000 warnings.py:119(filterwarnings)
#        12    0.000    0.000    0.001    0.000 pyparsing.py:4012(parseImpl)
#        11    0.000    0.000    0.001    0.000 ops.py:861(add_methods)
#         1    0.000    0.000    0.001    0.001 argparse.py:62(<module>)
#         1    0.000    0.000    0.001    0.001 category.py:1(<module>)
#         7    0.000    0.000    0.001    0.000 genericpath.py:16(exists)
#       105    0.000    0.000    0.001    0.000 colors.py:105(is_color_like)
#        66    0.000    0.000    0.001    0.000 pyparsing.py:1843(__add__)
#       6/2    0.000    0.000    0.001    0.001 __init__.py:409(wrapper)
#         1    0.000    0.000    0.001    0.001 internals.py:4869(create_block_manager_from_arrays)
#         1    0.000    0.000    0.001    0.001 groupby.py:4584(DataFrameGroupBy)
#       114    0.000    0.000    0.001    0.000 abc.py:135(<setcomp>)
#         1    0.000    0.000    0.001    0.001 strings.py:1(<module>)
#         2    0.001    0.001    0.001    0.001 {pandas._libs.lib.maybe_convert_objects}
#         1    0.000    0.000    0.001    0.001 base64mime.py:25(<module>)
#        16    0.000    0.000    0.001    0.000 abc.py:151(register)
#         1    0.000    0.000    0.001    0.001 stata.py:11(<module>)
#         1    0.000    0.000    0.001    0.001 relativedelta.py:2(<module>)
#        12    0.000    0.000    0.001    0.000 enum.py:623(<listcomp>)
#         1    0.000    0.000    0.001    0.001 fnmatch.py:11(<module>)
#        83    0.000    0.000    0.001    0.000 pyparsing.py:3326(__init__)
#      1768    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:843(__enter__)
#         1    0.000    0.000    0.001    0.001 error.py:12(<module>)
#         1    0.000    0.000    0.001    0.001 request.py:941(AbstractBasicAuthHandler)
#         1    0.000    0.000    0.001    0.001 loader.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 version.py:93(StrictVersion)
#        67    0.000    0.000    0.001    0.000 pyparsing.py:3456(__init__)
#     22/10    0.000    0.000    0.001    0.000 pyparsing.py:3613(parseImpl)
#         1    0.000    0.000    0.001    0.001 utils.py:1(<module>)
#     40/13    0.000    0.000    0.001    0.000 typing.py:1145(__subclasscheck__)
#         1    0.000    0.000    0.001    0.001 message.py:105(Message)
#        24    0.000    0.000    0.001    0.000 deprecation.py:178(deprecate)
#         1    0.000    0.000    0.001    0.001 difflib.py:27(<module>)
#         1    0.000    0.000    0.001    0.001 strings.py:1882(StringMethods)
#      18/4    0.000    0.000    0.001    0.000 pyparsing.py:3803(parseImpl)
#         3    0.000    0.000    0.001    0.000 _decorators.py:10(deprecate)
#      2062    0.001    0.000    0.001    0.000 sre_parse.py:248(match)
#         1    0.000    0.000    0.001    0.001 generic.py:3915(head)
#        12    0.000    0.000    0.001    0.000 generic.py:9638(_make_cum_function)
#         2    0.000    0.000    0.001    0.000 internals.py:3265(__init__)
#         1    0.000    0.000    0.001    0.001 datetime.py:5(<module>)
#        19    0.000    0.000    0.001    0.000 generic.py:9598(_make_stat_function)
#         1    0.000    0.000    0.001    0.001 {pandas._libs.lib.clean_index_list}
#         1    0.000    0.000    0.001    0.001 indexing.py:1463(__getitem__)
#         8    0.000    0.000    0.001    0.000 base.py:4839(_make_logical_function)
#         1    0.000    0.000    0.001    0.001 indexing.py:2075(_getitem_axis)
#         1    0.000    0.000    0.001    0.001 six.py:21(<module>)
#       683    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:416(parent)
#         1    0.000    0.000    0.001    0.001 category.py:32(CategoricalIndex)
#         1    0.000    0.000    0.001    0.001 indexing.py:2040(_get_slice_axis)
#       112    0.000    0.000    0.001    0.000 sre_parse.py:828(fix_flags)
#         1    0.000    0.000    0.001    0.001 generic.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 window.py:893(_Rolling_and_Expanding)
#         1    0.000    0.000    0.001    0.001 _polybase.py:8(<module>)
#         1    0.000    0.000    0.001    0.001 wintypes.py:2(<module>)
#        23    0.001    0.000    0.001    0.000 generic.py:6(create_pandas_abc_type)
#       542    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:780(find_spec)
#        53    0.000    0.000    0.001    0.000 core.py:893(__init__)
#       355    0.001    0.000    0.001    0.000 {built-in method _imp._fix_co_filename}
#         1    0.001    0.001    0.001    0.001 numbers.py:294(Integral)
#      2876    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#         3    0.000    0.000    0.001    0.000 rcsetup.py:825(validate_cycler)
#      3581    0.001    0.000    0.001    0.000 {built-in method _imp.acquire_lock}
#        87    0.000    0.000    0.001    0.000 rcsetup.py:90(<listcomp>)
#         1    0.000    0.000    0.001    0.001 indexing.py:147(_slice)
#       562    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:369(__init__)
#         1    0.000    0.000    0.001    0.001 base.py:698(IndexOpsMixin)
#         1    0.000    0.000    0.001    0.001 generic.py:2583(_slice)
#         4    0.000    0.000    0.001    0.000 pathlib.py:385(wrapped)
#       769    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#      3581    0.001    0.000    0.001    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.001    0.001 period.py:2(<module>)
#         1    0.000    0.000    0.001    0.001 ipaddress.py:2266(_IPv6Constants)
#         1    0.000    0.000    0.001    0.001 categorical.py:170(Categorical)
#         1    0.000    0.000    0.001    0.001 _polybase.py:19(ABCPolyBase)
#         1    0.000    0.000    0.001    0.001 _common.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 range.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 signal.py:1(<module>)
#        28    0.000    0.000    0.001    0.000 ipaddress.py:2160(__init__)
#       561    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:707(find_spec)
#       158    0.001    0.000    0.001    0.000 _decorators.py:247(__call__)
#        94    0.001    0.000    0.001    0.000 abc.py:9(abstractmethod)
#        51    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1196(__init__)
#       355    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:393(_check_name_wrapper)
#         2    0.000    0.000    0.001    0.000 internals.py:3363(_rebuild_blknos_and_blklocs)
#        12    0.001    0.000    0.001    0.000 ops.py:1296(_bool_method_SERIES)
#         1    0.000    0.000    0.001    0.001 internals.py:4880(form_blocks)
#        44    0.000    0.000    0.001    0.000 core.py:149(get_object_signature)
#        10    0.000    0.000    0.001    0.000 enum.py:758(_missing_)
#       232    0.001    0.000    0.001    0.000 pyparsing.py:1154(__init__)
#         1    0.000    0.000    0.001    0.001 internals.py:3869(get_slice)
#       429    0.001    0.000    0.001    0.000 {method '__reduce_ex__' of 'object' objects}
#       730    0.001    0.000    0.001    0.000 {built-in method from_bytes}
#        10    0.000    0.000    0.001    0.000 enum.py:765(_create_pseudo_member_)
#       192    0.000    0.000    0.001    0.000 colors.py:100(_is_nth_color)
#         3    0.000    0.000    0.001    0.000 _common.py:128(_validate_fromutc_inputs)
#         1    0.000    0.000    0.001    0.001 __init__.py:204(_sanity_check)
#         1    0.000    0.000    0.001    0.001 __init__.py:625(get_configdir)
#      33/5    0.000    0.000    0.001    0.000 pyparsing.py:3385(streamline)
#         1    0.000    0.000    0.001    0.001 _common.py:145(_tzinfo)
#        14    0.000    0.000    0.001    0.000 ops.py:1687(_flex_method_PANEL)
#         4    0.000    0.000    0.001    0.000 missing.py:32(isna)
#         4    0.000    0.000    0.001    0.000 missing.py:112(_isna_new)
#       889    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:37(_relax_case)
#        87    0.000    0.000    0.001    0.000 colors.py:134(to_rgba)
#        26    0.000    0.000    0.001    0.000 core.py:6568(__init__)
#        84    0.000    0.000    0.001    0.000 ops.py:623(_make_flex_doc)
#       493    0.001    0.000    0.001    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.001    0.001 interval.py:135(IntervalIndex)
#        56    0.000    0.000    0.001    0.000 sre_compile.py:376(_mk_bitmap)
#         1    0.000    0.000    0.001    0.001 frame.py:34(SparseDataFrame)
#         1    0.000    0.000    0.001    0.001 ipaddress.py:1559(_IPv4Constants)
#         3    0.000    0.000    0.001    0.000 pathlib.py:1341(is_dir)
#        30    0.000    0.000    0.001    0.000 rcsetup.py:342(validate_color_for_prop_cycle)
#        10    0.000    0.000    0.001    0.000 enum.py:837(_decompose)
#         5    0.000    0.000    0.001    0.000 textwrap.py:342(wrap)
#         1    0.000    0.000    0.001    0.001 encoder.py:2(<module>)
#         3    0.000    0.000    0.001    0.000 pathlib.py:1151(stat)
#         1    0.000    0.000    0.001    0.001 errors.py:5(<module>)
#        26    0.000    0.000    0.001    0.000 core.py:6573(getdoc)
#         2    0.000    0.000    0.001    0.000 util.py:1(<module>)
#       355    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:35(_new_module)
#      1019    0.001    0.000    0.001    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.001    0.001 extras.py:10(<module>)
#        19    0.000    0.000    0.001    0.000 ipaddress.py:1460(__init__)
#         1    0.000    0.000    0.001    0.001 subprocess.py:42(<module>)
#         1    0.000    0.000    0.001    0.001 timedeltas.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 accessors.py:3(<module>)
#        93    0.001    0.000    0.001    0.000 {built-in method numpy.core.multiarray.array}
#        66    0.000    0.000    0.001    0.000 pyparsing.py:3785(__init__)
#         4    0.000    0.000    0.001    0.000 missing.py:189(_isna_ndarraylike)
#         9    0.000    0.000    0.001    0.000 generic.py:9618(_make_stat_function_ddof)
#         1    0.000    0.000    0.001    0.001 window.py:1980(EWM)
#         1    0.000    0.000    0.001    0.001 _core.py:1558(BoxPlot)
#       829    0.000    0.000    0.001    0.000 sre_parse.py:285(tell)
#       985    0.000    0.000    0.001    0.000 sre_parse.py:171(append)
#         1    0.000    0.000    0.001    0.001 dtypes.py:383(DatetimeTZDtype)
#      1357    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#         1    0.001    0.001    0.001    0.001 {method 'dot' of 'numpy.ndarray' objects}
#       226    0.000    0.000    0.001    0.000 sre_compile.py:388(_simple)
#         1    0.000    0.000    0.001    0.001 __config__.py:3(<module>)
#       476    0.000    0.000    0.001    0.000 generic.py:7(_check)
#      2373    0.001    0.000    0.001    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.001    0.001 glob.py:1(<module>)
#         6    0.000    0.000    0.001    0.000 generic.py:9673(_make_logical_function)
#      23/7    0.000    0.000    0.001    0.000 pyparsing.py:3828(streamline)
#         1    0.000    0.000    0.001    0.001 __init__.py:602(_get_config_or_cache_dir)
#         1    0.000    0.000    0.001    0.001 rrule.py:7(<module>)
#         1    0.000    0.000    0.001    0.001 numeric.py:292(Float64Index)
#         5    0.000    0.000    0.001    0.000 generic.py:2456(_create_indexer)
#         1    0.000    0.000    0.001    0.001 period.py:125(PeriodIndex)
#         1    0.000    0.000    0.001    0.001 arrayprint.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:687(get_data_path)
#        12    0.000    0.000    0.000    0.000 pyparsing.py:4156(parseImpl)
#         1    0.000    0.000    0.000    0.000 dates.py:581(DateFormatter)
#         1    0.000    0.000    0.000    0.000 pivot.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:656(_get_data_path)
#        14    0.000    0.000    0.000    0.000 expr.py:150(_filter_nodes)
#         1    0.000    0.000    0.000    0.000 pickle.py:181(<listcomp>)
#         1    0.000    0.000    0.000    0.000 dtypes.py:137(__init__)
#         7    0.000    0.000    0.000    0.000 {built-in method numpy.core.umath.seterrobj}
#         1    0.000    0.000    0.000    0.000 dtypes.py:156(_finalize)
#         1    0.000    0.000    0.000    0.000 numeric.py:2902(_setdef)
#         1    0.000    0.000    0.000    0.000 dtypes.py:278(validate_ordered)
#         4    0.000    0.000    0.000    0.000 cast.py:971(maybe_cast_to_datetime)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_bool}
#         1    0.000    0.000    0.000    0.000 merge.py:3(<module>)
#       542    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#       115    0.000    0.000    0.000    0.000 sre_parse.py:223(__init__)
#       116    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#        16    0.000    0.000    0.000    0.000 pyparsing.py:1970(__or__)
#         3    0.000    0.000    0.000    0.000 expr.py:216(disallowed)
#       133    0.000    0.000    0.000    0.000 ops.py:274(_get_opstr)
#         1    0.000    0.000    0.000    0.000 html.py:4(<module>)
#      1732    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#         1    0.000    0.000    0.000    0.000 window.py:446(Window)
#       126    0.000    0.000    0.000    0.000 expr.py:152(<genexpr>)
#        29    0.000    0.000    0.000    0.000 {method 'split' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.000    0.000 datetimelike.py:99(TimelikeOps)
#       634    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#       372    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 zipfile.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 groupby.py:563(_GroupBy)
#       165    0.000    0.000    0.000    0.000 enum.py:20(_is_descriptor)
#         1    0.000    0.000    0.000    0.000 accessor.py:7(<module>)
#        80    0.000    0.000    0.000    0.000 typing.py:852(_next_in_mro)
#         1    0.000    0.000    0.000    0.000 polynomial.py:4(<module>)
#        16    0.000    0.000    0.000    0.000 pyparsing.py:3606(__init__)
#       433    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#         1    0.000    0.000    0.000    0.000 _color_data.py:1(<module>)
#       351    0.000    0.000    0.000    0.000 __init__.py:217(bind_method)
#         1    0.000    0.000    0.000    0.000 ops.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 csv.py:4(<module>)
#        75    0.000    0.000    0.000    0.000 typing.py:342(_type_vars)
#         1    0.000    0.000    0.000    0.000 __init__.py:5(HTTPStatus)
#         1    0.000    0.000    0.000    0.000 version.py:267(LooseVersion)
#        27    0.000    0.000    0.000    0.000 core.py:920(__init__)
#        26    0.000    0.000    0.000    0.000 contextlib.py:129(contextmanager)
#         9    0.000    0.000    0.000    0.000 enum.py:855(<listcomp>)
#       854    0.000    0.000    0.000    0.000 sre_parse.py:159(__len__)
#         1    0.000    0.000    0.000    0.000 opcode.py:5(<module>)
#         9    0.000    0.000    0.000    0.000 accessor.py:56(_add_delegate_accessors)
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 sql.py:5(<module>)
#       355    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:800(__init__)
#        30    0.000    0.000    0.000    0.000 getlimits.py:70(<lambda>)
#       248    0.000    0.000    0.000    0.000 ops.py:326(_get_op_name)
#       584    0.000    0.000    0.000    0.000 sre_parse.py:111(__init__)
#         4    0.000    0.000    0.000    0.000 core.py:126(doc_note)
#      1154    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         3    0.000    0.000    0.000    0.000 textwrap.py:368(wrap)
#       547    0.000    0.000    0.000    0.000 _decorators.py:293(__init__)
#       122    0.000    0.000    0.000    0.000 sre_parse.py:84(opengroup)
#        39    0.000    0.000    0.000    0.000 _inspect.py:142(formatargspec)
#         1    0.000    0.000    0.000    0.000 frame.py:7644(_homogenize)
#       835    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#         8    0.000    0.000    0.000    0.000 typing.py:875(__extrahook__)
#        51    0.000    0.000    0.000    0.000 _internal.py:715(_ufunc_doc_signature_formatter)
#        18    0.000    0.000    0.000    0.000 core.py:996(__init__)
#   157/155    0.000    0.000    0.000    0.000 pyparsing.py:382(__init__)
#         1    0.000    0.000    0.000    0.000 melt.py:3(<module>)
#         5    0.000    0.000    0.000    0.000 base.py:4752(_add_numeric_methods)
#       174    0.000    0.000    0.000    0.000 sre_parse.py:342(_escape)
# ...
#         1    0.000    0.000    0.000    0.000 arraypad.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1769(Locked)
#         6    0.000    0.000    0.000    0.000 __init__.py:205(iteritems)
#        47    0.000    0.000    0.000    0.000 ipaddress.py:607(__init__)
#         7    0.000    0.000    0.000    0.000 config.py:802(inner)
#         4    0.000    0.000    0.000    0.000 function_base.py:1912(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.copyto}
#         2    0.000    0.000    0.000    0.000 core.py:2905(_update_from)
#         2    0.000    0.000    0.000    0.000 arrayprint.py:1506(set_string_function)
#         1    0.000    0.000    0.000    0.000 parsers.py:713(TextFileReader)
#        33    0.000    0.000    0.000    0.000 typing.py:1019(_abc_negative_cache)
#        22    0.000    0.000    0.000    0.000 typing.py:1033(_abc_negative_cache_version)
#         1    0.000    0.000    0.000    0.000 lazy.py:172(<listcomp>)
#         1    0.000    0.000    0.000    0.000 frozen.py:84(FrozenNDArray)
#         1    0.000    0.000    0.000    0.000 tzfile.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 sql.py:916(SQLDatabase)
#         1    0.000    0.000    0.000    0.000 lazy.py:118(<listcomp>)
#        76    0.000    0.000    0.000    0.000 typing.py:984(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1083(__init__)
#        18    0.000    0.000    0.000    0.000 rcsetup.py:429(validate_fontsize)
#         4    0.000    0.000    0.000    0.000 __init__.py:1266(__init__)
#         5    0.000    0.000    0.000    0.000 warnings.py:449(__enter__)
#         1    0.000    0.000    0.000    0.000 base.py:473(_simple_new)
#        95    0.000    0.000    0.000    0.000 pyparsing.py:213(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _compat.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _style.py:107(_Options)
#         1    0.000    0.000    0.000    0.000 {built-in method winreg.OpenKey}
#         1    0.000    0.000    0.000    0.000 sasreader.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:769(__init__)
#        10    0.000    0.000    0.000    0.000 inference.py:447(is_sequence)
#         1    0.000    0.000    0.000    0.000 pyparsing.py:3127(__init__)
#         1    0.000    0.000    0.000    0.000 numerictypes.py:418(_construct_char_code_lookup)
#         1    0.000    0.000    0.000    0.000 pyparsing.py:3057(__init__)
#         2    0.000    0.000    0.000    0.000 nanops.py:493(_nanminmax)
#         1    0.000    0.000    0.000    0.000 cycler.py:468(cycler)
#         1    0.000    0.000    0.000    0.000 argparse.py:150(HelpFormatter)
#         7    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.offsets.apply_index_wraps}
#         1    0.000    0.000    0.000    0.000 _iotools.py:493(StringConverter)
#         2    0.000    0.000    0.000    0.000 _bootlocale.py:11(getpreferredencoding)
#         3    0.000    0.000    0.000    0.000 numeric.py:2896(__exit__)
#         2    0.000    0.000    0.000    0.000 dtypes.py:459(construct_from_string)
#         1    0.000    0.000    0.000    0.000 typing.py:1290(CallableMeta)
#         2    0.000    0.000    0.000    0.000 internals.py:5020(_asarray_compat)
#         5    0.000    0.000    0.000    0.000 datetime.py:278(_check_date_fields)
#         1    0.000    0.000    0.000    0.000 numerictypes.py:369(_set_up_aliases)
#         1    0.000    0.000    0.000    0.000 pathlib.py:602(PurePath)
#         9    0.000    0.000    0.000    0.000 pathlib.py:691(__str__)
#         3    0.000    0.000    0.000    0.000 rcsetup.py:468(validate_whiskers)
#         7    0.000    0.000    0.000    0.000 typing.py:206(__new__)
#         2    0.000    0.000    0.000    0.000 config.py:78(_get_single_key)
#       101    0.000    0.000    0.000    0.000 enum.py:628(<lambda>)
#         1    0.000    0.000    0.000    0.000 typing.py:1237(TupleMeta)
#         1    0.000    0.000    0.000    0.000 typing.py:835(_Optional)
#         1    0.000    0.000    0.000    0.000 __init__.py:358(__getattr__)
#        90    0.000    0.000    0.000    0.000 typing.py:1096(__hash__)
#         1    0.000    0.000    0.000    0.000 tz.py:36(tzutc)
#         3    0.000    0.000    0.000    0.000 {built-in method _csv.register_dialect}
#         1    0.000    0.000    0.000    0.000 <string>:5(_Instruction)
#         1    0.000    0.000    0.000    0.000 posixpath.py:11(<module>)
#         1    0.000    0.000    0.000    0.000 os.py:44(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.set_string_function}
#         1    0.000    0.000    0.000    0.000 range.py:169(_data)
#        20    0.000    0.000    0.000    0.000 version.py:312(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base64.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 offsets.py:513(BusinessDay)
#         1    0.000    0.000    0.000    0.000 offsets.py:1319(Week)
#         6    0.000    0.000    0.000    0.000 _policybase.py:94(_append_doc)
#         1    0.000    0.000    0.000    0.000 common.py:1043(is_datetime64_any_dtype)
#        47    0.000    0.000    0.000    0.000 enum.py:179(<genexpr>)
#        20    0.000    0.000    0.000    0.000 tokenize.py:112(group)
#         1    0.000    0.000    0.000    0.000 transforms.py:752(Bbox)
#         6    0.000    0.000    0.000    0.000 numeric.py:2592(geterr)
#         3    0.000    0.000    0.000    0.000 pytables.py:1506(__init__)
#         1    0.000    0.000    0.000    0.000 os.py:704(setdefault)
#         1    0.000    0.000    0.000    0.000 pyparsing.py:3434(And)
#         2    0.000    0.000    0.000    0.000 decoder.py:345(raw_decode)
#         1    0.000    0.000    0.000    0.000 cycler.py:529(_cycler)
#         6    0.000    0.000    0.000    0.000 period.py:77(_period_index_cmp)
#        62    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        23    0.000    0.000    0.000    0.000 os.py:728(check_str)
#         4    0.000    0.000    0.000    0.000 dtypes.py:584(is_dtype)
#         1    0.000    0.000    0.000    0.000 pytables.py:2982(Table)
#         2    0.000    0.000    0.000    0.000 common.py:1170(is_datetime_or_timedelta_dtype)
#         6    0.000    0.000    0.000    0.000 {built-in method sys.getsizeof}
#         1    0.000    0.000    0.000    0.000 random.py:87(__init__)
#         6    0.000    0.000    0.000    0.000 timedeltas.py:56(_td_index_cmp)
#         1    0.000    0.000    0.000    0.000 common.py:21(<listcomp>)
#        14    0.000    0.000    0.000    0.000 functools.py:448(lru_cache)
#        48    0.000    0.000    0.000    0.000 rcsetup.py:201(validate_int)
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 dtypes.py:86(CategoricalDtype)
#         1    0.000    0.000    0.000    0.000 case.py:44(_Outcome)
#         6    0.000    0.000    0.000    0.000 datetimes.py:103(_dt_index_cmp)
#         2    0.000    0.000    0.000    0.000 base.py:1590(is_object)
#        44    0.000    0.000    0.000    0.000 _inspect.py:28(isfunction)
#         1    0.000    0.000    0.000    0.000 indexing.py:88(_NDFrameIndexer)
#         3    0.000    0.000    0.000    0.000 __init__.py:1210(_fixupParents)
#        72    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#        24    0.000    0.000    0.000    0.000 tokenize.py:148(<listcomp>)
#        47    0.000    0.000    0.000    0.000 ipaddress.py:553(__eq__)
#        19    0.000    0.000    0.000    0.000 mixins.py:20(_binary_method)
#         5    0.000    0.000    0.000    0.000 sre_parse.py:784(_parse_flags)
#         3    0.000    0.000    0.000    0.000 rcsetup.py:178(validate_axisbelow)
#         1    0.000    0.000    0.000    0.000 groupby.py:2173(BaseGrouper)
#         8    0.000    0.000    0.000    0.000 rrule.py:77(<genexpr>)
#         1    0.000    0.000    0.000    0.000 ipaddress.py:1877(IPv6Address)
#        39    0.000    0.000    0.000    0.000 _inspect.py:43(iscode)
#         2    0.000    0.000    0.000    0.000 {built-in method _locale.setlocale}
#         1    0.000    0.000    0.000    0.000 common.py:1578(is_bool_dtype)
#         1    0.000    0.000    0.000    0.000 argparse.py:1050(_SubParsersAction)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:252(__subclasshook__)
#         8    0.000    0.000    0.000    0.000 core.py:2551(_arraymethod)
#         2    0.000    0.000    0.000    0.000 generic.py:124(__init__)
#        12    0.000    0.000    0.000    0.000 numerictypes.py:181(english_capitalize)
#         8    0.000    0.000    0.000    0.000 __init__.py:1542(isEnabledFor)
#        20    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#         2    0.000    0.000    0.000    0.000 base.py:4624(_add_numeric_methods_add_sub_disabled)
#         1    0.000    0.000    0.000    0.000 random.py:96(seed)
#         1    0.000    0.000    0.000    0.000 cycler.py:191(_from_iter)
#         6    0.000    0.000    0.000    0.000 six.py:80(_import_module)
#         1    0.000    0.000    0.000    0.000 pprint.py:98(PrettyPrinter)
#         1    0.000    0.000    0.000    0.000 typing.py:2129(__new__)
#         1    0.000    0.000    0.000    0.000 base.py:1695(_convert_slice_indexer)
#         1    0.000    0.000    0.000    0.000 scipy_sparse.py:5(<module>)
#         3    0.000    0.000    0.000    0.000 six.py:159(_resolve)
#         1    0.000    0.000    0.000    0.000 threading.py:498(__init__)
#         2    0.000    0.000    0.000    0.000 dtypes.py:401(__new__)
#         1    0.000    0.000    0.000    0.000 datetime.py:1360(datetime)
#         1    0.000    0.000    0.000    0.000 threading.py:512(set)
#         1    0.000    0.000    0.000    0.000 enum.py:848(<listcomp>)
#         1    0.000    0.000    0.000    0.000 pathlib.py:814(with_name)
#         1    0.000    0.000    0.000    0.000 parse.py:142(_NetlocResultMixinBase)
#         1    0.000    0.000    0.000    0.000 pathlib.py:243(gethomedir)
#        10    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 fontconfig_pattern.py:144(_families)
#         7    0.000    0.000    0.000    0.000 pathlib.py:136(splitroot)
#        78    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 sql.py:1342(SQLiteDatabase)
#        44    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 offsets.py:1110(SemiMonthOffset)
#         1    0.000    0.000    0.000    0.000 polynomial.py:934(poly1d)
#         1    0.000    0.000    0.000    0.000 {built-in method time.localtime}
#         1    0.000    0.000    0.000    0.000 pytables.py:2409(GenericFixed)
#         2    0.000    0.000    0.000    0.000 charset.py:211(__init__)
#         1    0.000    0.000    0.000    0.000 align.py:44(_filter_special_cases)
#         5    0.000    0.000    0.000    0.000 textwrap.py:179(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:365(__getitem__)
#         2    0.000    0.000    0.000    0.000 datetime.py:688(__new__)
#         3    0.000    0.000    0.000    0.000 excel.py:245(register_writer)
#         5    0.000    0.000    0.000    0.000 getlimits.py:518(min)
#         1    0.000    0.000    0.000    0.000 offsets.py:1777(FY5253)
#         1    0.000    0.000    0.000    0.000 __init__.py:20(__deprecated_private_func)
#         7    0.000    0.000    0.000    0.000 base.py:4862(_add_logical_methods_disabled)
#         1    0.000    0.000    0.000    0.000 tzinfo.py:18(memorized_timedelta)
#         1    0.000    0.000    0.000    0.000 offsets.py:1585(QuarterOffset)
#         4    0.000    0.000    0.000    0.000 pyparsing.py:430(__setitem__)
#         5    0.000    0.000    0.000    0.000 datetime.py:291(_check_time_fields)
#         1    0.000    0.000    0.000    0.000 generic.py:390(_get_axis)
#        35    0.000    0.000    0.000    0.000 datetime.py:261(_check_int_field)
#         4    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#         1    0.000    0.000    0.000    0.000 testing.py:59(set_testing_mode)
#         1    0.000    0.000    0.000    0.000 _inspect.py:7(<module>)
#        49    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 util.py:73(compose)
#         1    0.000    0.000    0.000    0.000 message.py:945(MIMEPart)
#         1    0.000    0.000    0.000    0.000 numbers.py:32(Complex)
#        16    0.000    0.000    0.000    0.000 typing.py:646(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         1    0.000    0.000    0.000    0.000 ipaddress.py:1445(IPv4Network)
#         2    0.000    0.000    0.000    0.000 pyparsing.py:3265(__init__)
#         9    0.000    0.000    0.000    0.000 pyparsing.py:3994(__str__)
#         1    0.000    0.000    0.000    0.000 calendar.py:50(_localized_month)
#        94    0.000    0.000    0.000    0.000 pyparsing.py:5043(<genexpr>)
#        60    0.000    0.000    0.000    0.000 ops.py:891(_wrap_inplace_method)
#        14    0.000    0.000    0.000    0.000 pyparsing.py:2773(charsAsStr)
#        74    0.000    0.000    0.000    0.000 pyparsing.py:2074(leaveWhitespace)
#         1    0.000    0.000    0.000    0.000 client.py:107(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 generic.py:9005(<listcomp>)
#         2    0.000    0.000    0.000    0.000 range.py:84(_ensure_int)
#         1    0.000    0.000    0.000    0.000 datetime.py:530(__neg__)
#         2    0.000    0.000    0.000    0.000 fontconfig_pattern.py:152(_property)
#         1    0.000    0.000    0.000    0.000 offsets.py:1968(FY5253Quarter)
#         1    0.000    0.000    0.000    0.000 request.py:324(Request)
#        12    0.000    0.000    0.000    0.000 opcode.py:43(name_op)
#         1    0.000    0.000    0.000    0.000 {built-in method _csv.writer}
#         1    0.000    0.000    0.000    0.000 internals.py:1852(ExtensionBlock)
#         1    0.000    0.000    0.000    0.000 offsets.py:1692(YearOffset)
#         1    0.000    0.000    0.000    0.000 offsets.py:521(__init__)
#         1    0.000    0.000    0.000    0.000 offsets.py:953(MonthOffset)
#         1    0.000    0.000    0.000    0.000 ssl.py:718(SSLSocket)
#         1    0.000    0.000    0.000    0.000 defmatrix.py:70(matrix)
#         3    0.000    0.000    0.000    0.000 rcsetup.py:921(validate_webagg_address)
#         5    0.000    0.000    0.000    0.000 textwrap.py:115(__init__)
#         1    0.000    0.000    0.000    0.000 common.py:95(_expand_user)
#        25    0.000    0.000    0.000    0.000 ipaddress.py:433(_ip_int_from_prefix)
#         2    0.000    0.000    0.000    0.000 {built-in method _locale._getdefaultlocale}
#        15    0.000    0.000    0.000    0.000 enum.py:335(__members__)
#        20    0.000    0.000    0.000    0.000 _decorators.py:66(deprecate_kwarg)
#         1    0.000    0.000    0.000    0.000 tz.py:121(tzoffset)
#         1    0.000    0.000    0.000    0.000 client.py:218(HTTPResponse)
#         6    0.000    0.000    0.000    0.000 six.py:126(__init__)
#         4    0.000    0.000    0.000    0.000 mixins.py:55(_unary_method)
#         1    0.000    0.000    0.000    0.000 tz.py:189(tzlocal)
#        12    0.000    0.000    0.000    0.000 rcsetup.py:300(<listcomp>)
#         3    0.000    0.000    0.000    0.000 datetimelike.py:817(_add_datetimelike_methods)
#        33    0.000    0.000    0.000    0.000 cycler.py:227(<genexpr>)
#         1    0.000    0.000    0.000    0.000 terminal.py:13(<module>)
#         2    0.000    0.000    0.000    0.000 datetime.py:1048(__new__)
#         2    0.000    0.000    0.000    0.000 internals.py:3266(<listcomp>)
#         5    0.000    0.000    0.000    0.000 pyparsing.py:4098(__str__)
#         5    0.000    0.000    0.000    0.000 rcsetup.py:249(validate_backend)

# %%
# 如果想知道有哪些函数调用了sum_num
p.print_callers(0.5, "UpdateSk")
# Out:
#    Ordered by: cumulative time, function name
#    List reduced from 3049 to 1525 due to restriction <0.5>
#    List reduced from 1525 to 1 due to restriction <'UpdateSk'>
#
# Function              was called by...
#                           ncalls  tottime  cumtime
# 0406.py:45(UpdateSk)  <-  763293    7.806 2260.682  0406.py:1(<module>)
#                            22024    0.179   34.714  0406.py:172(BringBack)

# %%
# 查看UpdateSk()函数中调用了哪些函数
p.print_callees("UpdateSk")
# Out:
#    Ordered by: cumulative time, function name
#    List reduced from 3049 to 1 due to restriction <'UpdateSk'>
#
# Function              called...
#                           ncalls  tottime  cumtime
# 0406.py:45(UpdateSk)  ->  785317    1.377    1.618  0406.py:34(__init__)
#                           785317    6.529   25.304  0406.py:118(Update_local_max)
#                           785317    6.012   23.526  0406.py:146(Update_emax)
#                           785317    0.191    0.191  0406.py:209(get_emax)
#                           785317    1.700   20.083  0406.py:214(find)
#                           785317    5.275    7.776  0406.py:222(position)
#                           112772    1.277    2.724  hll.py:100(add)
#                           631452    0.551 2181.308  {built-in method builtins.len}
#                           112772    2.587    7.243  {built-in method builtins.sum}
#                            22536    0.005    0.005  {method 'append' of 'list' objects}
#                           785317   17.636   17.636  {method 'sort' of 'list' objects}

# %%
## gpro2dot + graphviz的指令
python -m gprof2dot -f pstats 0406result.out | dot -T png -o pi_profile.png
