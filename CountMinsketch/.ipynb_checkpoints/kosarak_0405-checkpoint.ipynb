# %% [markdown]
# ## About Kosarak
# - Distinct element: 606770
# - Number of incomming element: 990002
# - Top-10 frequent element and count:
#
# | element | frquent |
# | :----- | :----- |
# | 3 | 36133 |
# | 6 | 30225 |
# | 6 3 | 21139 |
# | 11 6 | 12769 |
# | 1 | 9766 |
# | 11 6 3 | 9083 |
# | 1 3 | 6002 |
# | 11 | 5374 |
# | 1 6 | 5046 |
# | 4 | 4290 |

# %%
# Ground Truth
import pandas as pd
import os

filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)

num_line=0
item_count=100000
itemdict={}
with open(src_data,'r') as file:
    while True:
        line=file.readline().strip('\n')
        if not line:
            break
        else:
            #item_count-=1
            num_line+=1
            if line not in itemdict:
                itemdict[line]=1
            else:
                itemdict[line]+=1

df=pd.DataFrame(list(itemdict.items()),columns=['Element', 'Count'])
df=df.reset_index(drop=True)
df=df.sort_values('Count',ascending=False)

print("Distinct element: {}".format(len(itemdict)))
print("Number of incomming element: {}".format(num_line))
print(df.head(20))

df.to_csv("..\\result\\kosarak\\kosarak_ground_truth.csv",index=False)
# Out:
# Distinct element: 606770
# Number of incomming element: 990002
#        Element  Count
# 17           3  36133
# 111          6  30225
# 31         6 3  21139
# 94        11 6  12769
# 1            1   9766
# 85      11 6 3   9083
# 271        1 3   6002
# 253         11   5374
# 37         1 6   5046
# 279          4   4290
# 86        11 3   3756
# 241         55   3561
# 466      1 6 3   3510
# 233        4 3   3000
# 64        55 3   2377
# 195     11 1 6   2375
# 1525       4 6   2340
# 742      4 6 3   1758
# 250   11 1 6 3   1753
# 89        6 55   1749

# %% [markdown]
# ## Count-min sketch
# - Top-1024+ 4*1024 CMS
#     - Total memory 9432 bytes :Top-1024 with size 9328 bytes+ CMS with size 104 bytes.
#     - Execution time:319.18891406059265 seconds
#     - built-in index search is fastest

# %%
# Count-Min sketch with built-in index search
# Top-1024+ 4*1024 CMS
# Total memory 9432 bytes :Top-1024 with size 9328 bytes+ CMS with size 104 bytes.
# Execution time:319.18891406059265 seconds.
# Find:339,TP:0,FP:339

import sys
import os
import time
from probables import (CountMinSketch)
import pandas as pd

def find(e,Topk):
    try:
        index = [ele for ele,i in Topk].index(e)
        return index
    except:
        index=-99
    return index

start=time.time()
filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)
topk=[]
size=1024
# item_count=10000
cms = CountMinSketch(width=1024, depth=4)

if os.path.exists(src_data):
    with open(src_data,'r') as file:
        while True:
            line=file.readline().strip('\n')
            if not line:
                print('EOF')
                break
            else:
                # item_count-=1
                # print("read {}th element: {}".format(item_count,element))
                cms.add(line)
                count=cms.check(line)
                if len(topk)==0:
                    topk.append([line,count])
                else:
                    index=find(line,topk)
                    if index<0:
                        #  element not in topk
                        if len(topk)<size:
                            topk.append([line,count])
                        else:
                            topk[-1][0]=line
                            topk[-1][1]=count
                    else:
                        topk[index][1]=count
                topk=sorted(topk,key = lambda topk:topk[1],reverse=True)
                    
    end=time.time()
    print(topk[:50],len(topk))
    print("Total memory {3} bytes :Top-{0} with size {1} bytes+ CMS with size {2} bytes.".format(len(topk),sys.getsizeof(topk),sys.getsizeof(cms),sys.getsizeof(cms)+sys.getsizeof(topk)))
    print("Execution time:{} seconds.".format(str(end-start)))
else:
    print("file doesn't exist")
#　conver Top into df    
templi=[]
for i in topk:
    templi.append([i[0],i[1]])

df=pd.DataFrame(templi,columns=['ID', 'Count'])
df.to_csv("..\\result\\kosarak\\CM_kosarak.csv",index=False)
df.head(50)
# Out:
# EOF
# [['3', 36826], ['6', 30906], ['6 3', 21876], ['11 6', 13465], ['1', 10512], ['11 6 3', 9726], ['1 3', 6663], ['11', 6049], ['1 6', 5695], ['4', 4969], ['11 3', 4564], ['55', 4269], ['1 6 3', 4156], ['4 3', 3666], ['55 3', 3050], ['11 1 6', 3005], ['4 6', 2992], ['4 6 3', 2441], ['11 1 6 3', 2437], ['6 55', 2430], ['2', 2310], ['294', 2276], ['6 55 3', 2004], ['490', 1981], ['2 3', 1946], ['27', 1822], ['7', 1770], ['294 3', 1759], ['218', 1717], ['11 4 6', 1594], ['490 3', 1578], ['11 1', 1554], ['6 2', 1540], ['6 294', 1534], ['64', 1521], ['73', 1495], ['11 4 6 3', 1488], ['91', 1488], ['4 1', 1438], ['218 3', 1434], ['11 6 55', 1412], ['11 6 55 3', 1409], ['6 2 3', 1389], ['3 7', 1373], ['490 6', 1365], ['6 7', 1365], ['6 294 3', 1354], ['27 3', 1349], ['218 6', 1324], ['77', 1311]] 1024
# Total memory 9432 bytes :Top-1024 with size 9328 bytes+ CMS with size 104 bytes.
# Execution time:548.5681459903717 seconds.
#            ID  Count
# 0           3  36826
# 1           6  30906
# 2         6 3  21876
# 3        11 6  13465
# 4           1  10512
# 5      11 6 3   9726
# 6         1 3   6663
# 7          11   6049
# 8         1 6   5695
# 9           4   4969
# 10       11 3   4564
# 11         55   4269
# 12      1 6 3   4156
# 13        4 3   3666
# 14       55 3   3050
# 15     11 1 6   3005
# 16        4 6   2992
# 17      4 6 3   2441
# 18   11 1 6 3   2437
# 19       6 55   2430
# 20          2   2310
# 21        294   2276
# 22     6 55 3   2004
# 23        490   1981
# 24        2 3   1946
# 25         27   1822
# 26          7   1770
# 27      294 3   1759
# 28        218   1717
# 29     11 4 6   1594
# 30      490 3   1578
# 31       11 1   1554
# 32        6 2   1540
# 33      6 294   1534
# 34         64   1521
# 35         73   1495
# 36   11 4 6 3   1488
# 37         91   1488
# 38        4 1   1438
# 39      218 3   1434
# 40    11 6 55   1412
# 41  11 6 55 3   1409
# 42      6 2 3   1389
# 43        3 7   1373
# 44      490 6   1365
# 45        6 7   1365
# 46    6 294 3   1354
# 47       27 3   1349
# 48      218 6   1324
# 49         77   1311

# %%
# CMS Result compare
import pandas as pd
import os
path='..\\result\\kosarak'
groundtruth='kosarak_ground_truth.csv'
final='CM_kosarak.csv'

grtruth=pd.read_csv(os.path.join(path,groundtruth))
My_result1=pd.read_csv(os.path.join(path,final))

gli = grtruth.values.tolist()
li1= My_result1.values.tolist()

tp=0
fp=0
find=0
err=[]
error=0
for item in li1:
    for element in gli[:1024]:
        if item[0]==element[0]:
            # print("{},{} vs. {},{}".format(item[0],item[1],element[0],element[1]))
            find+=1
            if item[1]==element[1]:
                tp+=1
            else:
                fp+=1
                error+=abs(item[1]-element[1])
print("Find:{},TP:{},FP:{}".format(find,tp,fp))
print("avg error:{}".format(error/512))
# Out:
# Find:339,TP:0,FP:339
# avg error:461.703125

# %% [markdown]
# ## Space-Saving

# %%
# Space-Saving 1024 stream summary with class+index search
# Total memory 9024 bytes :Top-1024 with size 9024 bytes.
# Execution time:251.02409100532532 seconds.
# Find:158,TP:26,FP:132

import sys
import os
import time
import operator
import pandas as pd

class Node():
    def __init__(self,count=0):
        self.count=count
    def add_count(self,count=1):
        self.count+=count
    def __str__(self):
        return 'ID: {}, count: {}'.format(self.ID,self.count)
    def __repr__(self):
        return ''

class Head(Node):
    def __init__(self):
        super().__init__()
        self.distinct = hyperloglog.HyperLogLog(0.01)
    def __str__(self):
        return 'total count: {}, distinct element: {}'.format(self.count,len(self.distinct))
    def __repr__(self):
        return '[count: {}, distinct: {}]'.format(self.count,len(self.distinct))

class Tail(Node):
    def __init__(self,ID,count):
        self.ID = ID
        super().__init__(count)
    def __str__(self):
        return 'ID: {}, count: {}'.format(self.ID,self.count)
    def __repr__(self):
        return "'{}', count: {}".format(self.ID,self.count)

def find(e,element_list):
    try:
        index = [ele.ID for ele in element_list].index(e.ID)
    except:
        index=-99
    return index  
    
    
start=time.time()

filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)

size=1024
Top=[]
# item_count=100000

with open(src_data,'r') as file:
    while True:
        element=file.readline().strip('\n')
        if not element:
            print('EOF')
            break
        else:
            item=Tail(element,1)
            # item_count-=1
            # print("read {}th element: {}".format(item_count,element))
            if len(Top)==0:
                Top.append(item)
            else:
                index=find(item,Top)
                if index<0:
                    if len(Top)<size:
                        Top.append(item)
                    else:
                        # replace last element with count 
                        Top[-1].ID=item.ID
                        Top[-1].count+=1
                else:
                    Top[index].count+=1
            Top.sort(key=operator.attrgetter('count'),reverse=True)

end=time.time()
print(Top[:20],len(Top))
print("Total memory {0} bytes :Top-{1} with size {0} bytes.".format(sys.getsizeof(Top),size))
print("Execution time:{} seconds.".format(str(end-start)))


#　conver Top into df    
templi=[]
for i in Top:
    templi.append([i.ID,i.count])

df=pd.DataFrame(templi,columns=['ID', 'Count'])
df.to_csv("..\\result\\kosarak\\SS_class_kosarak.csv",index=False)
df.head(20)
# Out:
# EOF
# ['3', count: 36133, '6', count: 30225, '6 3', count: 21139, '11 6', count: 12769, '1', count: 9766, '11 6 3', count: 9083, '1 3', count: 6002, '11', count: 5374, '1 6', count: 5046, '4', count: 4290, '11 3', count: 3756, '55', count: 3561, '1 6 3', count: 3510, '4 3', count: 3000, '55 3', count: 2377, '11 1 6', count: 2375, '4 6', count: 2341, '4 6 3', count: 1758, '11 1 6 3', count: 1753, '6 55', count: 1749] 1024
# Total memory 9024 bytes :Top-1024 with size 9024 bytes.
# Execution time:317.9859354496002 seconds.
#           ID  Count
# 0          3  36133
# 1          6  30225
# 2        6 3  21139
# 3       11 6  12769
# 4          1   9766
# 5     11 6 3   9083
# 6        1 3   6002
# 7         11   5374
# 8        1 6   5046
# 9          4   4290
# 10      11 3   3756
# 11        55   3561
# 12     1 6 3   3510
# 13       4 3   3000
# 14      55 3   2377
# 15    11 1 6   2375
# 16       4 6   2341
# 17     4 6 3   1758
# 18  11 1 6 3   1753
# 19      6 55   1749

# %%
# SS Result compare
import pandas as pd
import os
path='..\\result\\kosarak'
groundtruth='kosarak_ground_truth.csv'
final='SS_class_kosarak.csv'

grtruth=pd.read_csv(os.path.join(path,groundtruth))
My_result1=pd.read_csv(os.path.join(path,final))

gli = grtruth.values.tolist()
li1= My_result1.values.tolist()

tp=0
fp=0
find=0
err=[]
error=0
for item in li1:
    for element in gli[:1024]:
        if item[0]==element[0]:
            print("{},{} vs. {},{}".format(item[0],item[1],element[0],element[1]))
            find+=1
            if item[1]==element[1]:
                tp+=1
            else:
                fp+=1
                error+=abs(item[1]-element[1])
print("Find:{},TP:{},FP:{}".format(find,tp,fp))
print("avg error:{}".format(error/512))
# Out:
# 3,36133 vs. 3,36133
# 6,30225 vs. 6,30225
# 6 3,21139 vs. 6 3,21139
# 11 6,12769 vs. 11 6,12769
# 1,9766 vs. 1,9766
# 11 6 3,9083 vs. 11 6 3,9083
# 1 3,6002 vs. 1 3,6002
# 11,5374 vs. 11,5374
# 1 6,5046 vs. 1 6,5046
# 4,4290 vs. 4,4290
# 11 3,3756 vs. 11 3,3756
# 55,3561 vs. 55,3561
# 1 6 3,3510 vs. 1 6 3,3510
# 4 3,3000 vs. 4 3,3000
# 55 3,2377 vs. 55 3,2377
# 11 1 6,2375 vs. 11 1 6,2375
# 4 6,2341 vs. 4 6,2340
# 4 6 3,1758 vs. 4 6 3,1758
# 11 1 6 3,1753 vs. 11 1 6 3,1753
# 6 55,1749 vs. 6 55,1749
# 294,1653 vs. 294,1653
# 2,1601 vs. 2,1601
# 6 55 3,1375 vs. 6 55 3,1374
# 490,1226 vs. 490,1225
# 27,1168 vs. 27,1167
# 294 3,1162 vs. 294 3,1161
# 2 3,1152 vs. 2 3,1152
# 7,1100 vs. 7,1100
# 218,1056 vs. 218,1055
# 11 4 6,954 vs. 11 4 6,954
# 64,915 vs. 64,907
# 6 294,893 vs. 6 294,890
# 6 2,882 vs. 6 2,882
# 11 1,880 vs. 11 1,880
# 91,866 vs. 91,838
# 73,853 vs. 73,849
# 490 3,846 vs. 490 3,799
# 11 4 6 3,828 vs. 11 4 6 3,809
# 6 294 3,823 vs. 6 294 3,743
# 4 1,821 vs. 4 1,754
# 6 2 3,821 vs. 6 2 3,673
# 3 73,820 vs. 3 73,642
# 27 6 3,820 vs. 27 6 3,473
# 27 3,819 vs. 27 3,730
# 6 7,819 vs. 6 7,667
# 11 6 55,819 vs. 11 6 55,761
# 4 1 3,818 vs. 4 1 3,486
# 218 3,818 vs. 218 3,743
# 3 7,818 vs. 3 7,734
# 316,818 vs. 316,628
# 18,818 vs. 18,345
# 11 6 55 3,817 vs. 11 6 55 3,620
# 11 218 6 3,817 vs. 11 218 6 3,234
# 4 55 3,817 vs. 4 55 3,198
# 278,817 vs. 278,390
# 584,817 vs. 584,61
# 6 91,817 vs. 6 91,409
# 6 504 3,817 vs. 6 504 3,83
# 1056,817 vs. 1056,87
# 4 1 6,816 vs. 4 1 6,395
# 1 55,816 vs. 1 55,582
# 11 1 3,816 vs. 11 1 3,588
# 667,816 vs. 667,73
# 1 218,816 vs. 1 218,182
# 799 6 3,816 vs. 799 6 3,35
# 55 3 316,816 vs. 55 3 316,31
# 512,816 vs. 512,38
# 11 6 737,816 vs. 11 6 737,153
# 1779,816 vs. 1779,124
# 138 3,816 vs. 138 3,390
# 1 6 446,816 vs. 1 6 446,43
# 1 6 3 77,816 vs. 1 6 3 77,48
# 11 6 83,816 vs. 11 6 83,138
# 69 11 1 6 3,816 vs. 69 11 1 6 3,35
# 4 55,816 vs. 4 55,238
# 11 77,816 vs. 11 77,69
# 5,816 vs. 5,386
# 484,816 vs. 484,105
# 11 6 90,816 vs. 11 6 90,55
# 323 6,816 vs. 323 6,44
# 69 11 6,816 vs. 69 11 6,242
# 2344 6,816 vs. 2344 6,67
# 11 6 56,816 vs. 11 6 56,45
# 11 3 73,816 vs. 11 3 73,73
# 303,816 vs. 303,251
# 607 6,816 vs. 607 6,47
# 3356 6,816 vs. 3356 6,32
# 69,816 vs. 69,235
# 1 73,816 vs. 1 73,150
# 77,816 vs. 77,648
# 11 1 218 6 3,816 vs. 11 1 218 6 3,41
# 11 218,816 vs. 11 218,84
# 6 278,816 vs. 6 278,217
# 11 1751,816 vs. 11 1751,30
# 11 648 6,816 vs. 11 648 6,85
# 11 6 138,816 vs. 11 6 138,296
# 1164 6 3,816 vs. 1164 6 3,38
# 11 6 2,816 vs. 11 6 2,422
# 314,816 vs. 314,121
# 1777,816 vs. 1777,95
# 11 490 3,816 vs. 11 490 3,86
# 1 504,816 vs. 1 504,32
# 2895 3,816 vs. 2895 3,77
# 314 3,816 vs. 314 3,98
# 635 6 3,816 vs. 635 6 3,37
# 6 3 77,816 vs. 6 3 77,311
# 361 3,816 vs. 361 3,32
# 4 490 3,816 vs. 4 490 3,67
# 269 11 6,816 vs. 269 11 6,94
# 1 1751,816 vs. 1 1751,60
# 3 316,816 vs. 3 316,463
# 1105 3,816 vs. 1105 3,66
# 11 4 3,816 vs. 11 4 3,290
# 4035 6,816 vs. 4035 6,58
# 2186 6 3,816 vs. 2186 6 3,40
# 3181 6,816 vs. 3181 6,51
# 1 590,816 vs. 1 590,65
# 6 18 3,816 vs. 6 18 3,119
# 246 3,816 vs. 246 3,210
# 27 1 6 3,816 vs. 27 1 6 3,63
# 11 4 1 6,816 vs. 11 4 1 6,183
# 490 55,816 vs. 490 55,65
# 2186,816 vs. 2186,112
# 11 6 3 438,816 vs. 11 6 3 438,70
# 622 6,816 vs. 622 6,60
# 1 136,816 vs. 1 136,36
# 273,816 vs. 273,214
# 2081 3,816 vs. 2081 3,75
# 6 3 446,816 vs. 6 3 446,197
# 11 6 294,816 vs. 11 6 294,390
# 52 6,816 vs. 52 6,54
# 1 6 91 3,816 vs. 1 6 91 3,44
# 6 3 7,816 vs. 6 3 7,538
# 3764 6,816 vs. 3764 6,51
# 1 6 3 7,816 vs. 1 6 3 7,95
# 880 6 3,816 vs. 880 6 3,41
# 145 3,816 vs. 145 3,227
# 3589,816 vs. 3589,117
# 1 6 294,816 vs. 1 6 294,146
# 1524,816 vs. 1524,34
# 6 55 3 7,816 vs. 6 55 3 7,31
# 11 218 6,816 vs. 11 218 6,299
# 11 6 438,816 vs. 11 6 438,82
# 11 6 361,816 vs. 11 6 361,39
# 138,815 vs. 138,666
# 485,815 vs. 485,97
# 11 490 6,815 vs. 11 490 6,275
# 11 6 3 64,815 vs. 11 6 3 64,211
# 1 6 138,815 vs. 1 6 138,104
# 11 6 215 3,815 vs. 11 6 215 3,101
# 4315 3,815 vs. 4315 3,56
# 1490 3,815 vs. 1490 3,61
# 6 303 3,815 vs. 6 303 3,93
# 246 1 3,815 vs. 246 1 3,33
# 11 4 6 3 7,815 vs. 11 4 6 3 7,34
# 11 3 446,815 vs. 11 3 446,32
# 3 446,815 vs. 3 446,290
# 251,815 vs. 251,83
# Find:158,TP:26,FP:132
# avg error:142.55078125

# %% [markdown]
# ## My algo

# %%
import spookyhash
import mmh3
from numpy import random
import os
import time
import operator
import hyperloglog
import sys
import pandas as pd
import cProfile

# ==========================data structure==========================
class Node():
    def __init__(self,count=0):
        self.count=count
    def add_count(self,count=1):
        self.count+=count
    def __str__(self):
        return 'count: {}'.format(self.count)
    def __repr__(self):
        return ''

class Head(Node):
    def __init__(self,count=1):
        super().__init__(count)
        self.distinct = hyperloglog.HyperLogLog(0.01)
        self.maxID=''
    def __str__(self):
        return '[total:{}, dist:{}, max:{}]'.format(self.count,len(self.distinct),self.maxID)
    def __repr__(self):
        return '[total:{}, dist:{}, max:{}]'.format(self.count,len(self.distinct),self.maxID)

class Tail(Node):
    def __init__(self,ID,count):
        self.ID = ID
        super().__init__(count)
    def __str__(self):
        return '[ID:{}, count:{}]'.format(self.ID,self.count)
    def __repr__(self):
        return '[ID:{}, count:{}]'.format(self.ID,self.count)
# ==========================data structure==========================


# ==========================UpdateSk==========================
def UpdateSk(element,Sk_head,Sk):
    # print("In UpdateSk()")
    e_max=get_emax()
    ID,row=position(element)
        # row position of e and ID=h(e) in Sketch 
    avg=0
    item=Tail(ID, element.count)
        # ID in Sketch is hash value
    # print("{} -> {},send to Sk[{}]".format(element,item,row))
    # ==========================update sketch==========================
    index=find(item,Sk[row])
        # find index of e in Sk[row]
    if index >=0:
        # e matches in Sk[row]
        Sk[row][index].count+=item.count
    else:
        # e doesn't match in Sk[row]
        if len(Sk[row])==0:
            Sk[row].append(item)
            index=0
            Sk_head[row].maxID=element.ID
                # unhashed ID
        elif len(Sk[row])<width:
            # Sk[row] is not full
            Sk[row].append(item)
            index=len(Sk[row])-1      
            # match=True
        else:
            # Sk[row] is full
            count_sum=sum(Sk[row][i].count for i in range(len(Sk[row])))
            if Sk_head[row].count==count_sum:
                # no other, send e to Other
                Sk_head[row].distinct.add(element.ID)
                # match=False
            else:
                # something in other and total count > sum
                if len(Sk_head[row].distinct)>0:
                    Sk_head[row].distinct.add(element.ID)
                    avg=(Sk_head[row].count-count_sum)//len(Sk_head[row].distinct)
                    # print("avg:{}".format(avg))
                else:
                    Sk_head[row].distinct.add(element.ID)
                    # print("distinct element:{}".format(len(Sk_head[row].distinct)))
                    # print("avg< last one,send to distinct")
                    # match=False
    Sk_head[row].count+=item.count
        # total count最後再+1 在line 82要compare distinct
    # now we have:
    # ID: h2(h1(e)), hash value of e
    # row: h1(e), row index of e
    # index: column index of e
    # Sk_head[row].count: total count of Sk[row]
    # Sk_head[row].maxID: local max count element of Sk[row]
    # Sk_head[row].distinct: estimated element of Other part in Sk[row]
    # count_sum: sum of count in Sketch[row]
    # avg: average count of Other part in Sk[row]
    # ==========================update local max==========================
    Update_local_max(Sk_head[row],Sk[row],avg,element,index)
    # Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
    
    # ==========================update e_max==========================
    Update_emax(Sk_head[row],Sk[row],element,avg)
    
    Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
    # print("e_max:{}".format(e_max))
    # print("Sk_head[{}]:{}".format(row,Sk_head[row]))
    '''
    for i in range(len(Sk)):
        print("Sk[{}]:{},{}".format(i,Sk_head[i],Sk[i]))
    '''


# ==========================update local max==========================    
def Update_local_max(head_item,element_list,avg,incoming_element,index):
    # Sk_head[row],Sk[row],avg
    # print("In Update_local_max():")
    numertor,denominator=get_fraction()
    width,depth=get_width_depth()
    if head_item.maxID=='':
        head_item.maxID=incoming_element.ID
    else:
        local_max_ID=mmh3.hash(str(spookyhash.hash32(bytes(str(head_item.maxID),encoding='utf-8'))), signed=False) % ((width*numertor)//denominator)
        #print("local_max_ID:{}".format(local_max_ID))
        local_max_index=find(Tail(local_max_ID,1),element_list)
        #print("local_max_index:{}".format(local_max_index))
        # 此處當hashed ID相同時暫不更新 local max
        if local_max_index>=0:
            # local max exists
            if index>=0:
                # e in Sk[row]
                if element_list[index].count>element_list[local_max_index].count:
                    head_item.maxID=incoming_element.ID
            else:
                # e in Other
                if avg>element_list[local_max_index].count:
                    head_item.maxID=incoming_element.ID
        else:
            # local max doesn't exists
            head_item.maxID=incoming_element.ID

# ==========================update e_max==========================
def Update_emax(head_item,element_list,incoming_element,avg_count):
    # Sk_head[row],Sk[row],e_max
    # print("In Update_emax():")
    e_max=get_emax()
    numerator,denominator=get_fraction()
    # local_max_ID=""
    # local_max_index=""
    # print("e_max before update:{}".format(e_max))
    # print("Sk_head:{}".format(head_item))
    width,depth=get_width_depth()
    if head_item.maxID!="":
        local_max_ID=mmh3.hash(str(spookyhash.hash32(bytes(str(head_item.maxID),encoding='utf-8'))), signed=False) % ((width*numerator)//denominator)
        # print("local_max_ID:{}".format(local_max_ID))
        local_max_index=find(Tail(local_max_ID,1),element_list)        
        # print("local_max_index:{}".format(local_max_index))
        if local_max_index>=0:
            if element_list[local_max_index].count>e_max.count:
                e_max.ID=head_item.maxID
                e_max.count=element_list[local_max_index].count
        else:
            if avg_count>e_max.count:
                e_max.ID=head_item.maxID
                e_max.count=avg_count
    #print("e_max after update:{}".format(e_max))

# ========================== BringBack=========================
def BringBack(e_min,head,sketch):
    # Bring e_max back into Top
    # Sk_head,Sk[row]
    e_max=get_emax()
    # print("\nIn BringBack():")
    temp=Tail(e_min.ID,e_min.count)
    e_min.ID=e_max.ID
    e_min.count=e_max.count
    # print('Top after BringBack:\n\t{}'.format(Top))
    DeleteSk(e_max,head,sketch)
    # update e_max in Sk[row]
    # print("e_max after delete:{},id(e_max):{}".format(e_max,id(e_max)))
    UpdateSk(temp,head,sketch)
    # print("Sk[] after Update {}:\n\t{}".format(e_min,Sk))

# ========================== BringBack=========================
# ==========================DeleteSk=========================
def DeleteSk(element,head,sketch):
    # 刪除e_max in Sk[row]
    # print("\nIn DeleteSK({}):".format(element))
    width,depth=get_width_depth()
    ID,row=position(element)
    # print("row:{},ID:{} of e_max".format(row,ID))
    head[row].count-=element.count
        # total_count=total_count-e_max.count
    # print("Sk[{}]:{}".format(row,sketch[row]))
    index=find(Tail(ID,1),sketch[row])
    # print("index:{} in Sk[{}]".format(index,row))
    if index>=0:
        sketch[row].pop(index)
        # element_list[row].sort(key=operator.attrgetter('count'),reverse=True)
        head[row].maxID=""

    element.ID=""
    element.count=0
    # print("e_max After DeleteSk(element):{},id(e_max):{}".format(e_max,id(e_max)))
# ==========================Tools=========================    
def get_emax():
    return e_max
def get_width_depth():
    return width,depth

def find(e,element_list):
    # return index of e in element_list
    try:
        index=[ele.ID for ele in element_list].index(e.ID)      
    except:
        index=-99
    return index

def position(element):
    numertor,denominator=get_fraction()
    width,depth=get_width_depth()
    hash1=spookyhash.hash32(bytes(str(element.ID),encoding='utf-8'))
        # input of spooky: byte
        # output of spooky:unsigned- 32 bit int
    hash2=mmh3.hash(str(hash1), signed=False)
        # input of mmh: str
        # output: unsigned- 32 bit int
    ID=hash2 % ((width*numertor)//denominator)
    row=hash1 % depth    
    return ID,row
def get_fraction():
    return numerator,denominator

# ==========================main=========================   
        
start=time.time()

filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)
depth=4
width=128
size=1024
numerator=12
denominator=10
    # numerator/denominator decides ratio of Other+Sketch /Sketch


Top=[]
Sk_head=[Head(0) for j in range(depth)]
Sk=[[] for i in range(depth)]
item_count=1000
i=0
e_max=Tail('',0)

with open(src_data,'r') as file:
    while True:
        element=file.readline().strip('\n')
        if not element:
            break
        else:
            # i+=1
            # print("\nread {}-th element: {}".format(i,element))
            # item_count-=1
            item=Tail(element,1)
            if len(Top)==0:
                Top.append(item)
                # print("len(Top)==0, Top append:{}".format(Top))
            else:
                index=find(item,Top)
                # print("index={}".format(index))
                if index<0:
                    if len(Top)<size:
                        Top.append(item)
                        # print("index={},Top after append: {},\nlen(Top):{}".format(index,Top,len(Top)))
                    else:
                        UpdateSk(item,Sk_head,Sk)
                else:
                    # print("update Top[{}]:".format(index))
                    Top[index].count+=1
            Top.sort(key=operator.attrgetter('count'),reverse=True)
            # ID,row=position(Top[-1])
            if e_max.count>Top[-1].count:
                BringBack(Top[-1],Sk_head,Sk)
                # print('Top after BringBack: \n\t{}'.format(Top))            


end=time.time()
print("Sk_head:{}".format(Sk_head))
print("TOP[20]:{}".format(Top[:20]))
# print("\nSketch:{}".format(Sk))
print("Total memory {} bytes".format(sys.getsizeof(Top)+sys.getsizeof(Sk)+sys.getsizeof(Sk_head)))
print("Top:{} bytes, Sketch:{} bytes, Sketch_head:{} bytes.".format(sys.getsizeof(Top),sys.getsizeof(Sk),sys.getsizeof(Sk_head)))
print("Execution time:{} seconds.".format(str(end-start)))

#　conver Top into df    
templi=[]
for i in Top:
    templi.append([i.ID,i.count])

df=pd.DataFrame(templi,columns=['ID', 'Count'])
df.to_csv("..\\result\\kosarak\\Myalgo_kosarak_100k_count.csv",index=False)
df.head(20)
# Out:
# Sk_head:[[total:116739, dist:24752, max:11 4 218 6 1800 2196], [total:117342, dist:24809, max:11 1 6 2413 584 644], [total:124638, dist:24692, max:3 1956], [total:117649, dist:24675, max:288 1]]
# TOP[20]:[[ID:3, count:36133], [ID:6, count:30225], [ID:6 3, count:21139], [ID:11 6, count:12769], [ID:1, count:9766], [ID:11 6 3, count:9083], [ID:1 3, count:6002], [ID:11, count:5374], [ID:1 6, count:5046], [ID:4, count:4290], [ID:11 3, count:3756], [ID:55, count:3561], [ID:1 6 3, count:3510], [ID:4 3, count:3000], [ID:55 3, count:2377], [ID:11 1 6, count:2375], [ID:4 6, count:2341], [ID:4 6 3, count:1758], [ID:11 1 6 3, count:1753], [ID:6 55, count:1749]]
# Total memory 9216 bytes
# Top:9024 bytes, Sketch:96 bytes, Sketch_head:96 bytes.
# Execution time:1383.219388961792 seconds.
#           ID  Count
# 0          3  36133
# 1          6  30225
# 2        6 3  21139
# 3       11 6  12769
# 4          1   9766
# 5     11 6 3   9083
# 6        1 3   6002
# 7         11   5374
# 8        1 6   5046
# 9          4   4290
# 10      11 3   3756
# 11        55   3561
# 12     1 6 3   3510
# 13       4 3   3000
# 14      55 3   2377
# 15    11 1 6   2375
# 16       4 6   2341
# 17     4 6 3   1758
# 18  11 1 6 3   1753
# 19      6 55   1749

# %%
print("sum of element in Top: {}".format(sum([i.count for i in Top])))
print("sum of element in Sketch: {}".format(sum([i.count for i in Sk_head])))
print("e_max:{}".format(e_max))
for i in range(len(Sk)):
    print("Sk[{}]:\n{},\n{}".format(i,Sk_head[i],Sk[i]))
# Out:
# sum of element in Top: 513634
# sum of element in Sketch: 476368
# e_max:[ID:3 1956, count:258]
# Sk[0]:
# [total:116739, dist:24752, max:11 4 218 6 1800 2196],
# [[ID:118, count:258], [ID:0, count:256], [ID:53, count:255], [ID:115, count:255], [ID:40, count:254], [ID:68, count:253], [ID:86, count:252], [ID:38, count:248], [ID:23, count:246], [ID:17, count:245], [ID:35, count:235], [ID:76, count:234], [ID:98, count:233], [ID:24, count:233], [ID:51, count:231], [ID:106, count:227], [ID:82, count:225], [ID:89, count:224], [ID:92, count:222], [ID:47, count:220], [ID:127, count:216], [ID:100, count:211], [ID:141, count:211], [ID:85, count:208], [ID:151, count:208], [ID:34, count:203], [ID:122, count:198], [ID:110, count:197], [ID:42, count:196], [ID:109, count:194], [ID:8, count:193], [ID:29, count:193], [ID:150, count:188], [ID:6, count:187], [ID:104, count:183], [ID:139, count:177], [ID:138, count:173], [ID:117, count:173], [ID:48, count:172], [ID:5, count:172], [ID:21, count:168], [ID:83, count:162], [ID:134, count:158], [ID:78, count:142], [ID:71, count:141], [ID:144, count:138], [ID:43, count:137], [ID:136, count:134], [ID:90, count:132], [ID:15, count:122], [ID:50, count:119], [ID:32, count:119], [ID:107, count:117], [ID:126, count:114], [ID:103, count:112], [ID:114, count:112], [ID:9, count:110], [ID:3, count:109], [ID:31, count:108], [ID:63, count:107], [ID:54, count:107], [ID:79, count:106], [ID:140, count:105], [ID:147, count:102], [ID:81, count:98], [ID:28, count:96], [ID:73, count:96], [ID:65, count:95], [ID:87, count:93], [ID:66, count:90], [ID:7, count:90], [ID:60, count:89], [ID:59, count:85], [ID:12, count:84], [ID:95, count:79], [ID:14, count:79], [ID:142, count:78], [ID:96, count:70], [ID:135, count:70], [ID:16, count:69], [ID:111, count:66], [ID:120, count:65], [ID:152, count:62], [ID:77, count:61], [ID:36, count:58], [ID:26, count:58], [ID:97, count:58], [ID:119, count:57], [ID:37, count:56], [ID:130, count:56], [ID:80, count:55], [ID:19, count:53], [ID:22, count:50], [ID:123, count:49], [ID:137, count:49], [ID:74, count:49], [ID:58, count:48], [ID:55, count:47], [ID:45, count:47], [ID:61, count:44], [ID:18, count:44], [ID:145, count:43], [ID:124, count:43], [ID:75, count:42], [ID:13, count:40], [ID:11, count:37], [ID:108, count:37], [ID:94, count:37], [ID:131, count:34], [ID:57, count:32], [ID:113, count:30], [ID:93, count:26], [ID:30, count:25], [ID:88, count:17], [ID:46, count:16], [ID:41, count:15], [ID:10, count:14], [ID:1, count:14], [ID:102, count:13], [ID:116, count:12], [ID:70, count:10], [ID:67, count:9], [ID:105, count:8], [ID:20, count:4], [ID:125, count:4], [ID:25, count:2], [ID:112, count:2], [ID:84, count:1]]
# Sk[1]:
# [total:117342, dist:24809, max:11 1 6 2413 584 644],
# [[ID:20, count:256], [ID:86, count:256], [ID:140, count:256], [ID:129, count:253], [ID:11, count:248], [ID:53, count:243], [ID:131, count:241], [ID:93, count:240], [ID:4, count:235], [ID:135, count:221], [ID:79, count:221], [ID:65, count:220], [ID:51, count:219], [ID:145, count:216], [ID:49, count:216], [ID:109, count:215], [ID:97, count:214], [ID:73, count:214], [ID:52, count:214], [ID:59, count:214], [ID:128, count:214], [ID:133, count:212], [ID:14, count:212], [ID:61, count:212], [ID:37, count:208], [ID:88, count:208], [ID:139, count:204], [ID:87, count:202], [ID:16, count:199], [ID:9, count:196], [ID:45, count:196], [ID:1, count:190], [ID:18, count:188], [ID:117, count:182], [ID:96, count:178], [ID:134, count:176], [ID:72, count:175], [ID:35, count:174], [ID:31, count:173], [ID:33, count:166], [ID:69, count:165], [ID:113, count:164], [ID:22, count:161], [ID:130, count:161], [ID:21, count:160], [ID:46, count:160], [ID:29, count:158], [ID:39, count:150], [ID:125, count:149], [ID:58, count:147], [ID:141, count:145], [ID:150, count:143], [ID:80, count:142], [ID:12, count:135], [ID:119, count:134], [ID:146, count:129], [ID:91, count:128], [ID:66, count:126], [ID:27, count:125], [ID:147, count:121], [ID:98, count:121], [ID:149, count:121], [ID:82, count:120], [ID:114, count:117], [ID:5, count:117], [ID:54, count:116], [ID:126, count:109], [ID:7, count:108], [ID:148, count:107], [ID:118, count:107], [ID:8, count:105], [ID:25, count:104], [ID:99, count:102], [ID:151, count:97], [ID:19, count:87], [ID:76, count:87], [ID:136, count:85], [ID:34, count:81], [ID:50, count:80], [ID:74, count:77], [ID:143, count:77], [ID:100, count:76], [ID:3, count:74], [ID:17, count:73], [ID:55, count:71], [ID:108, count:69], [ID:111, count:68], [ID:112, count:68], [ID:142, count:66], [ID:101, count:63], [ID:115, count:60], [ID:78, count:59], [ID:104, count:58], [ID:63, count:54], [ID:2, count:51], [ID:121, count:50], [ID:120, count:49], [ID:10, count:45], [ID:64, count:42], [ID:122, count:40], [ID:102, count:40], [ID:70, count:37], [ID:24, count:33], [ID:47, count:31], [ID:23, count:30], [ID:26, count:28], [ID:13, count:26], [ID:62, count:24], [ID:92, count:24], [ID:44, count:22], [ID:106, count:22], [ID:107, count:21], [ID:123, count:19], [ID:110, count:19], [ID:90, count:18], [ID:124, count:17], [ID:48, count:15], [ID:89, count:14], [ID:152, count:14], [ID:105, count:12], [ID:38, count:10], [ID:56, count:8], [ID:137, count:5], [ID:85, count:5], [ID:0, count:4], [ID:41, count:4], [ID:81, count:3], [ID:30, count:2]]
# Sk[2]:
# [total:124638, dist:24692, max:3 1956],
# [[ID:21, count:258], [ID:131, count:258], [ID:23, count:257], [ID:50, count:256], [ID:66, count:252], [ID:151, count:249], [ID:73, count:248], [ID:140, count:247], [ID:91, count:245], [ID:124, count:243], [ID:45, count:240], [ID:108, count:237], [ID:81, count:234], [ID:53, count:232], [ID:11, count:230], [ID:26, count:226], [ID:77, count:226], [ID:138, count:221], [ID:80, count:221], [ID:85, count:220], [ID:2, count:220], [ID:51, count:218], [ID:1, count:214], [ID:47, count:208], [ID:149, count:206], [ID:15, count:206], [ID:63, count:204], [ID:104, count:204], [ID:5, count:204], [ID:144, count:203], [ID:25, count:202], [ID:103, count:200], [ID:76, count:197], [ID:126, count:191], [ID:43, count:187], [ID:49, count:186], [ID:72, count:185], [ID:56, count:180], [ID:6, count:176], [ID:39, count:169], [ID:34, count:163], [ID:86, count:157], [ID:40, count:156], [ID:93, count:156], [ID:57, count:155], [ID:96, count:154], [ID:24, count:153], [ID:113, count:149], [ID:101, count:148], [ID:58, count:146], [ID:64, count:143], [ID:83, count:143], [ID:115, count:141], [ID:121, count:139], [ID:130, count:139], [ID:89, count:137], [ID:106, count:136], [ID:143, count:132], [ID:102, count:129], [ID:110, count:129], [ID:139, count:126], [ID:44, count:119], [ID:134, count:117], [ID:127, count:113], [ID:19, count:112], [ID:148, count:110], [ID:4, count:109], [ID:22, count:108], [ID:70, count:106], [ID:129, count:102], [ID:62, count:100], [ID:99, count:98], [ID:100, count:91], [ID:3, count:91], [ID:59, count:89], [ID:61, count:89], [ID:75, count:89], [ID:29, count:86], [ID:46, count:85], [ID:145, count:84], [ID:7, count:81], [ID:54, count:80], [ID:120, count:80], [ID:150, count:78], [ID:65, count:78], [ID:95, count:74], [ID:69, count:74], [ID:18, count:69], [ID:137, count:68], [ID:32, count:66], [ID:133, count:66], [ID:123, count:65], [ID:52, count:64], [ID:14, count:63], [ID:88, count:62], [ID:125, count:60], [ID:132, count:53], [ID:31, count:52], [ID:37, count:47], [ID:33, count:47], [ID:105, count:45], [ID:97, count:45], [ID:48, count:45], [ID:84, count:41], [ID:82, count:40], [ID:10, count:39], [ID:122, count:38], [ID:141, count:38], [ID:136, count:34], [ID:90, count:34], [ID:146, count:34], [ID:27, count:33], [ID:68, count:31], [ID:118, count:29], [ID:13, count:27], [ID:55, count:19], [ID:67, count:19], [ID:119, count:17], [ID:112, count:15], [ID:74, count:10], [ID:79, count:8], [ID:116, count:7], [ID:30, count:5], [ID:107, count:5], [ID:94, count:4], [ID:36, count:2], [ID:41, count:2], [ID:0, count:1]]
# Sk[3]:
# [total:117649, dist:24675, max:288 1],
# [[ID:107, count:258], [ID:142, count:256], [ID:9, count:253], [ID:25, count:252], [ID:68, count:246], [ID:66, count:245], [ID:132, count:239], [ID:83, count:235], [ID:31, count:234], [ID:62, count:230], [ID:127, count:224], [ID:35, count:217], [ID:51, count:216], [ID:84, count:207], [ID:88, count:206], [ID:29, count:205], [ID:87, count:203], [ID:136, count:199], [ID:103, count:199], [ID:124, count:198], [ID:28, count:195], [ID:54, count:192], [ID:101, count:189], [ID:85, count:187], [ID:106, count:184], [ID:16, count:182], [ID:105, count:181], [ID:141, count:180], [ID:43, count:178], [ID:24, count:177], [ID:117, count:174], [ID:122, count:172], [ID:81, count:169], [ID:76, count:168], [ID:30, count:164], [ID:73, count:147], [ID:82, count:146], [ID:46, count:146], [ID:113, count:145], [ID:121, count:143], [ID:42, count:142], [ID:36, count:140], [ID:78, count:140], [ID:38, count:138], [ID:92, count:137], [ID:59, count:137], [ID:130, count:136], [ID:60, count:135], [ID:69, count:129], [ID:119, count:128], [ID:52, count:121], [ID:112, count:116], [ID:109, count:116], [ID:7, count:115], [ID:0, count:114], [ID:94, count:113], [ID:129, count:113], [ID:65, count:113], [ID:39, count:112], [ID:57, count:108], [ID:63, count:104], [ID:75, count:101], [ID:79, count:98], [ID:13, count:98], [ID:148, count:97], [ID:143, count:96], [ID:146, count:94], [ID:56, count:93], [ID:150, count:93], [ID:123, count:89], [ID:149, count:86], [ID:108, count:86], [ID:55, count:85], [ID:4, count:85], [ID:17, count:85], [ID:90, count:75], [ID:96, count:75], [ID:144, count:74], [ID:140, count:70], [ID:19, count:68], [ID:32, count:68], [ID:114, count:66], [ID:152, count:66], [ID:126, count:64], [ID:21, count:63], [ID:23, count:60], [ID:70, count:59], [ID:137, count:58], [ID:80, count:55], [ID:11, count:54], [ID:151, count:54], [ID:10, count:52], [ID:27, count:52], [ID:1, count:51], [ID:100, count:51], [ID:61, count:50], [ID:5, count:44], [ID:120, count:36], [ID:134, count:36], [ID:64, count:35], [ID:20, count:35], [ID:145, count:34], [ID:95, count:31], [ID:131, count:26], [ID:135, count:25], [ID:110, count:25], [ID:50, count:25], [ID:133, count:22], [ID:116, count:22], [ID:49, count:22], [ID:37, count:21], [ID:102, count:19], [ID:53, count:19], [ID:89, count:18], [ID:138, count:16], [ID:93, count:10], [ID:99, count:10], [ID:86, count:10], [ID:58, count:8], [ID:48, count:7], [ID:6, count:4], [ID:12, count:4], [ID:34, count:4], [ID:97, count:3], [ID:104, count:2], [ID:147, count:2], [ID:72, count:1], [ID:3, count:1]]

# %%
# Result compare
import pandas as pd
import os
path='..\\result\\kosarak'
groundtruth='kosarak_ground_truth.csv'
final='Myalgo_kosarak_100k_count.csv'

grtruth=pd.read_csv(os.path.join(path,groundtruth))
My_result1=pd.read_csv(os.path.join(path,final))

gli = grtruth.values.tolist()
li1= My_result1.values.tolist()

tp=0
fp=0
find=0
err=[]
error=0
for item in li1:
    for element in gli[:1024]:
        if item[0]==element[0]:
            # print("{},{} vs. {},{}".format(item[0],item[1],element[0],element[1]))
            find+=1
            if item[1]==element[1]:
                tp+=1
            else:
                fp+=1
                error+=abs(item[1]-element[1])
print("Find:{},TP:{},FP:{}".format(find,tp,fp))
print("avg error:{}".format(error/512))
# Out:
# Find:230,TP:34,FP:196
# avg error:54.638671875

# %% [markdown]
# ##  Average Relative Error, ARE

# %%
import spookyhash
import mmh3
from numpy import random
import os
import time
import operator
import hyperloglog
import sys
import pandas as pd
import cProfile

# ==========================data structure==========================
class Node():
    def __init__(self,count=0):
        self.count=count
    def add_count(self,count=1):
        self.count+=count
    def __str__(self):
        return 'count: {}'.format(self.count)
    def __repr__(self):
        return ''

class Head(Node):
    def __init__(self,count=1):
        super().__init__(count)
        self.distinct = hyperloglog.HyperLogLog(0.01)
        self.maxID=''
    def __str__(self):
        return '[total:{}, dist:{}, max:{}]'.format(self.count,len(self.distinct),self.maxID)
    def __repr__(self):
        return '[total:{}, dist:{}, max:{}]'.format(self.count,len(self.distinct),self.maxID)

class Tail(Node):
    def __init__(self,ID,count):
        self.ID = ID
        super().__init__(count)
    def __str__(self):
        return '[ID:{}, count:{}]'.format(self.ID,self.count)
    def __repr__(self):
        return '[ID:{}, count:{}]'.format(self.ID,self.count)
# ==========================data structure==========================


# ==========================UpdateSk==========================
def UpdateSk(element,Sk_head,Sk):
    print("In UpdateSk()")
    e_max=get_emax()
    ID,row=position(element)
        # row position of e and ID=h(e) in Sketch 
    avg=0
    item=Tail(ID, element.count)
        # ID in Sketch is hash value
    print("{} -> {},send to Sk[{}]".format(element,item,row))
    # ==========================update sketch==========================
    index=find(item,Sk[row])
        # find index of e in Sk[row]
    if index >=0:
        # e matches in Sk[row]
        Sk[row][index].count+=item.count
    else:
        # e doesn't match in Sk[row]
        if len(Sk[row])==0:
            Sk[row].append(item)
            index=0
            Sk_head[row].maxID=element.ID
                # unhashed ID
        elif len(Sk[row])<width:
            # Sk[row] is not full
            Sk[row].append(item)
            index=len(Sk[row])-1      
            # match=True
        else:
            # Sk[row] is full
            count_sum=sum(Sk[row][i].count for i in range(len(Sk[row])))
            if Sk_head[row].count==count_sum:
                # no other, send e to Other
                Sk_head[row].distinct.add(element.ID)
                # match=False
            else:
                # something in other and total count > sum
                if len(Sk_head[row].distinct)>0:
                    Sk_head[row].distinct.add(element.ID)
                    avg=(Sk_head[row].count-count_sum)//len(Sk_head[row].distinct)
                    # print("avg:{}".format(avg))
                else:
                    Sk_head[row].distinct.add(element.ID)
                    # print("distinct element:{}".format(len(Sk_head[row].distinct)))
                    # print("avg< last one,send to distinct")
                    # match=False
    Sk_head[row].count+=item.count
        # total count最後再+1 在line 82要compare distinct
    # now we have:
    # ID: h2(h1(e)), hash value of e
    # row: h1(e), row index of e
    # index: column index of e
    # Sk_head[row].count: total count of Sk[row]
    # Sk_head[row].maxID: local max count element of Sk[row]
    # Sk_head[row].distinct: estimated element of Other part in Sk[row]
    # count_sum: sum of count in Sketch[row]
    # avg: average count of Other part in Sk[row]
    # ==========================update local max==========================
    Update_local_max(Sk_head[row],Sk[row],avg,element,index)
    # Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
    
    # ==========================update e_max==========================
    Update_emax(Sk_head[row],Sk[row],element,avg)
    
    Sk[row].sort(key=operator.attrgetter('count'),reverse=True)
    print("e_max:{}".format(e_max))
    print("Sk_head[{}]:{}".format(row,Sk_head[row]))
    for i in range(len(Sk)):
        print("Sk[{}]:{},{}".format(i,Sk_head[i],Sk[i]))


# ==========================update local max==========================    
def Update_local_max(head_item,element_list,avg,incoming_element,index):
    # Sk_head[row],Sk[row],avg
    print("In Update_local_max():")
    numertor,denominator=get_fraction()
    width,depth=get_width_depth()
    if head_item.maxID=='':
        head_item.maxID=incoming_element.ID
    else:
        local_max_ID=mmh3.hash(str(spookyhash.hash32(bytes(str(head_item.maxID),encoding='utf-8'))), signed=False) % ((width*numertor)//denominator)
        #print("local_max_ID:{}".format(local_max_ID))
        local_max_index=find(Tail(local_max_ID,1),element_list)
        #print("local_max_index:{}".format(local_max_index))
        # 此處當hashed ID相同時暫不更新 local max
        if local_max_index>=0:
            # local max exists
            if index>=0:
                # e in Sk[row]
                if element_list[index].count>element_list[local_max_index].count:
                    head_item.maxID=incoming_element.ID
            else:
                # e in Other
                if avg>element_list[local_max_index].count:
                    head_item.maxID=incoming_element.ID
        else:
            # local max doesn't exists
            head_item.maxID=incoming_element.ID

# ==========================update e_max==========================
def Update_emax(head_item,element_list,incoming_element,avg_count):
    # Sk_head[row],Sk[row],e_max
    print("In Update_emax():")
    e_max=get_emax()
    numerator,denominator=get_fraction()
    # local_max_ID=""
    # local_max_index=""
    print("e_max before update:{}".format(e_max))
    print("Sk_head:{}".format(head_item))
    width,depth=get_width_depth()
    if head_item.maxID!="":
        local_max_ID=mmh3.hash(str(spookyhash.hash32(bytes(str(head_item.maxID),encoding='utf-8'))), signed=False) % ((width*numerator)//denominator)
        # print("local_max_ID:{}".format(local_max_ID))
        local_max_index=find(Tail(local_max_ID,1),element_list)        
        # print("local_max_index:{}".format(local_max_index))
        if local_max_index>=0:
            if element_list[local_max_index].count>e_max.count:
                e_max.ID=head_item.maxID
                e_max.count=element_list[local_max_index].count
        else:
            if avg_count>e_max.count:
                e_max.ID=head_item.maxID
                e_max.count=avg_count
    print("e_max after update:{}".format(e_max))

# ========================== BringBack=========================
def BringBack(e_min,head,sketch):
    # Bring e_max back into Top
    # Sk_head,Sk[row]
    e_max=get_emax()
    print("\nIn BringBack():")
    temp=Tail(e_min.ID,e_min.count)
    e_min.ID=e_max.ID
    e_min.count=e_max.count
    # print('Top after BringBack:\n\t{}'.format(Top))
    DeleteSk(e_max,head,sketch)
    # update e_max in Sk[row]
    # print("e_max after delete:{},id(e_max):{}".format(e_max,id(e_max)))
    UpdateSk(temp,head,sketch)
    # print("Sk[] after Update {}:\n\t{}".format(e_min,Sk))

# ========================== BringBack=========================
# ==========================DeleteSk=========================
def DeleteSk(element,head,sketch):
    # 刪除e_max in Sk[row]
    print("\nIn DeleteSK({}):".format(element))
    width,depth=get_width_depth()
    ID,row=position(element)
    # print("row:{},ID:{} of e_max".format(row,ID))
    head[row].count-=element.count
        # total_count=total_count-e_max.count
    # print("Sk[{}]:{}".format(row,sketch[row]))
    index=find(Tail(ID,1),sketch[row])
    # print("index:{} in Sk[{}]".format(index,row))
    if index>=0:
        sketch[row].pop(index)
        # element_list[row].sort(key=operator.attrgetter('count'),reverse=True)
        head[row].maxID=""

    element.ID=""
    element.count=0
    # print("e_max After DeleteSk(element):{},id(e_max):{}".format(e_max,id(e_max)))
# ==========================Tools=========================    
def get_emax():
    return e_max
def get_width_depth():
    return width,depth

def find(e,element_list):
    # return index of e in element_list
    try:
        index=[ele.ID for ele in element_list].index(e.ID)      
    except:
        index=-99
    return index

def position(element):
    numertor,denominator=get_fraction()
    width,depth=get_width_depth()
    hash1=spookyhash.hash32(bytes(str(element.ID),encoding='utf-8'))
        # input of spooky: byte
        # output of spooky:unsigned- 32 bit int
    hash2=mmh3.hash(str(hash1), signed=False)
        # input of mmh: str
        # output: unsigned- 32 bit int
    ID=hash2 % ((width*numertor)//denominator)
    row=hash1 % depth    
    return ID,row
def get_fraction():
    return numerator,denominator

# ==========================main=========================   
        
start=time.time()

filename='kosarak.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)
depth=4
width=4
size=8
numerator=12
denominator=10
    # numerator/denominator decides ratio of Other+Sketch /Sketch


Top=[]
Sk_head=[Head(0) for j in range(depth)]
Sk=[[] for i in range(depth)]
item_count=1000
i=0
e_max=Tail('',0)

with open(src_data,'r') as file:
    while item_count:
        element=file.readline().strip('\n')
        if not element:
            break
        else:
            i+=1
            print("\nread {}-th element: {}".format(i,element))
            item_count-=1
            item=Tail(element,1)
            if len(Top)==0:
                Top.append(item)
                # print("len(Top)==0, Top append:{}".format(Top))
            else:
                index=find(item,Top)
                # print("index={}".format(index))
                if index<0:
                    if len(Top)<size:
                        Top.append(item)
                        # print("index={},Top after append: {},\nlen(Top):{}".format(index,Top,len(Top)))
                    else:
                        UpdateSk(item,Sk_head,Sk)
                else:
                    # print("update Top[{}]:".format(index))
                    Top[index].count+=1
            Top.sort(key=operator.attrgetter('count'),reverse=True)
            # ID,row=position(Top[-1])
            if e_max.count>Top[-1].count:
                BringBack(Top[-1],Sk_head,Sk)
                print('Top after BringBack: \n\t{}'.format(Top))            


end=time.time()
print("Sk_head:{}".format(Sk_head))
print("TOP[20]:{}".format(Top[:20]))
# print("\nSketch:{}".format(Sk))
print("Total memory {} bytes".format(sys.getsizeof(Top)+sys.getsizeof(Sk)+sys.getsizeof(Sk_head)))
print("Top:{} bytes, Sketch:{} bytes, Sketch_head:{} bytes.".format(sys.getsizeof(Top),sys.getsizeof(Sk),sys.getsizeof(Sk_head)))
print("Execution time:{} seconds.".format(str(end-start)))

#　conver Top into df    
templi=[]
for i in Top:
    templi.append([i.ID,i.count])

df=pd.DataFrame(templi,columns=['ID', 'Count'])
df.to_csv("..\\result\\kosarak\\Myalgo_kosarak_100k_count.csv",index=False)
df.head(20)
# Out:
# read 1-th element: 1 2 3
#
# read 2-th element: 1
#
# read 3-th element: 4 5 6 7
#
# read 4-th element: 1 8
#
# read 5-th element: 9 10
#
# read 6-th element: 11 6 12 13 14 15 16
#
# read 7-th element: 1 3 7
#
# read 8-th element: 17 18
#
# read 9-th element: 11 6 19 20 21 22 23 24
# In UpdateSk()
# [ID:11 6 19 20 21 22 23 24, count:1] -> [ID:2, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:1, dist:0, max:11 6 19 20 21 22 23 24]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:11 6 19 20 21 22 23 24, count:1]
# e_max:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head[2]:[total:1, dist:0, max:11 6 19 20 21 22 23 24]
# Sk[0]:[total:0, dist:0, max:],[]
# Sk[1]:[total:0, dist:0, max:],[]
# Sk[2]:[total:1, dist:0, max:11 6 19 20 21 22 23 24],[[ID:2, count:1]]
# Sk[3]:[total:0, dist:0, max:],[]
#
# read 10-th element: 1 25 3
# In UpdateSk()
# [ID:1 25 3, count:1] -> [ID:1, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head:[total:1, dist:0, max:1 25 3]
# local_max_ID:1
# local_max_index:0
# e_max after update:[ID:11 6 19 20 21 22 23 24, count:1]
# e_max:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head[0]:[total:1, dist:0, max:1 25 3]
# Sk[0]:[total:1, dist:0, max:1 25 3],[[ID:1, count:1]]
# Sk[1]:[total:0, dist:0, max:],[]
# Sk[2]:[total:1, dist:0, max:11 6 19 20 21 22 23 24],[[ID:2, count:1]]
# Sk[3]:[total:0, dist:0, max:],[]
#
# read 11-th element: 26 3
# In UpdateSk()
# [ID:26 3, count:1] -> [ID:1, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head:[total:2, dist:0, max:11 6 19 20 21 22 23 24]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:11 6 19 20 21 22 23 24, count:1]
# e_max:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head[2]:[total:2, dist:0, max:11 6 19 20 21 22 23 24]
# Sk[0]:[total:1, dist:0, max:1 25 3],[[ID:1, count:1]]
# Sk[1]:[total:0, dist:0, max:],[]
# Sk[2]:[total:2, dist:0, max:11 6 19 20 21 22 23 24],[[ID:2, count:1], [ID:1, count:1]]
# Sk[3]:[total:0, dist:0, max:],[]
#
# read 12-th element: 11 27 6 3 28 7 29 30 31 32 33 34 35 36 37
# In UpdateSk()
# [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:1] -> [ID:2, count:1],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head:[total:1, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:11 6 19 20 21 22 23 24, count:1]
# e_max:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head[1]:[total:1, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# Sk[0]:[total:1, dist:0, max:1 25 3],[[ID:1, count:1]]
# Sk[1]:[total:1, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:1]]
# Sk[2]:[total:2, dist:0, max:11 6 19 20 21 22 23 24],[[ID:2, count:1], [ID:1, count:1]]
# Sk[3]:[total:0, dist:0, max:],[]
#
# read 13-th element: 6 2 38
# In UpdateSk()
# [ID:6 2 38, count:1] -> [ID:3, count:1],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head:[total:2, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:11 6 19 20 21 22 23 24, count:1]
# e_max:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head[1]:[total:2, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# Sk[0]:[total:1, dist:0, max:1 25 3],[[ID:1, count:1]]
# Sk[1]:[total:2, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:1], [ID:3, count:1]]
# Sk[2]:[total:2, dist:0, max:11 6 19 20 21 22 23 24],[[ID:2, count:1], [ID:1, count:1]]
# Sk[3]:[total:0, dist:0, max:],[]
#
# read 14-th element: 39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51
# In UpdateSk()
# [ID:39 11 27 1 40 6 41 42 43 44 45 46 47 3 48 7 49 50 51, count:1] -> [ID:3, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head:[total:3, dist:0, max:11 6 19 20 21 22 23 24]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:11 6 19 20 21 22 23 24, count:1]
# e_max:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head[2]:[total:3, dist:0, max:11 6 19 20 21 22 23 24]
# Sk[0]:[total:1, dist:0, max:1 25 3],[[ID:1, count:1]]
# Sk[1]:[total:2, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:1], [ID:3, count:1]]
# Sk[2]:[total:3, dist:0, max:11 6 19 20 21 22 23 24],[[ID:2, count:1], [ID:1, count:1], [ID:3, count:1]]
# Sk[3]:[total:0, dist:0, max:],[]
#
# read 15-th element: 52 6 3 53
# In UpdateSk()
# [ID:52 6 3 53, count:1] -> [ID:0, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head:[total:2, dist:0, max:1 25 3]
# local_max_ID:1
# local_max_index:0
# e_max after update:[ID:11 6 19 20 21 22 23 24, count:1]
# e_max:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head[0]:[total:2, dist:0, max:1 25 3]
# Sk[0]:[total:2, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:2, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:1], [ID:3, count:1]]
# Sk[2]:[total:3, dist:0, max:11 6 19 20 21 22 23 24],[[ID:2, count:1], [ID:1, count:1], [ID:3, count:1]]
# Sk[3]:[total:0, dist:0, max:],[]
#
# read 16-th element: 54 1 6 55
# In UpdateSk()
# [ID:54 1 6 55, count:1] -> [ID:3, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 6 19 20 21 22 23 24, count:1]
# Sk_head:[total:4, dist:0, max:54 1 6 55]
# local_max_ID:3
# local_max_index:2
# e_max after update:[ID:54 1 6 55, count:2]
# e_max:[ID:54 1 6 55, count:2]
# Sk_head[2]:[total:4, dist:0, max:54 1 6 55]
# Sk[0]:[total:2, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:2, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:1], [ID:3, count:1]]
# Sk[2]:[total:4, dist:0, max:54 1 6 55],[[ID:3, count:2], [ID:2, count:1], [ID:1, count:1]]
# Sk[3]:[total:0, dist:0, max:],[]
#
# In BringBack():
#
# In DeleteSK([ID:54 1 6 55, count:2]):
# In UpdateSk()
# [ID:17 18, count:1] -> [ID:3, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:1, dist:0, max:17 18]
# local_max_ID:3
# local_max_index:0
# e_max after update:[ID:17 18, count:1]
# e_max:[ID:17 18, count:1]
# Sk_head[3]:[total:1, dist:0, max:17 18]
# Sk[0]:[total:2, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:2, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:1], [ID:3, count:1]]
# Sk[2]:[total:2, dist:0, max:],[[ID:2, count:1], [ID:1, count:1]]
# Sk[3]:[total:1, dist:0, max:17 18],[[ID:3, count:1]]
# Top after BringBack:
# 	[[ID:1 2 3, count:1], [ID:1, count:1], [ID:4 5 6 7, count:1], [ID:1 8, count:1], [ID:9 10, count:1], [ID:11 6 12 13 14 15 16, count:1], [ID:1 3 7, count:1], [ID:54 1 6 55, count:2]]
#
# read 17-th element: 11 6 56 57 58 59 60 61 62 63 64
# In UpdateSk()
# [ID:11 6 56 57 58 59 60 61 62 63 64, count:1] -> [ID:0, count:1],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:17 18, count:1]
# Sk_head:[total:3, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:17 18, count:1]
# e_max:[ID:17 18, count:1]
# Sk_head[1]:[total:3, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# Sk[0]:[total:2, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:3, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:1], [ID:3, count:1], [ID:0, count:1]]
# Sk[2]:[total:2, dist:0, max:],[[ID:2, count:1], [ID:1, count:1]]
# Sk[3]:[total:1, dist:0, max:17 18],[[ID:3, count:1]]
#
# read 18-th element: 3
# In UpdateSk()
# [ID:3, count:1] -> [ID:2, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:17 18, count:1]
# Sk_head:[total:2, dist:0, max:17 18]
# local_max_ID:3
# local_max_index:0
# e_max after update:[ID:17 18, count:1]
# e_max:[ID:17 18, count:1]
# Sk_head[3]:[total:2, dist:0, max:17 18]
# Sk[0]:[total:2, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:3, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:1], [ID:3, count:1], [ID:0, count:1]]
# Sk[2]:[total:2, dist:0, max:],[[ID:2, count:1], [ID:1, count:1]]
# Sk[3]:[total:2, dist:0, max:17 18],[[ID:3, count:1], [ID:2, count:1]]
#
# read 19-th element: 1 65 66 67 68 3
# In UpdateSk()
# [ID:1 65 66 67 68 3, count:1] -> [ID:2, count:1],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:17 18, count:1]
# Sk_head:[total:4, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2]
# e_max:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2]
# Sk_head[1]:[total:4, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# Sk[0]:[total:2, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:4, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
# Sk[2]:[total:2, dist:0, max:],[[ID:2, count:1], [ID:1, count:1]]
# Sk[3]:[total:2, dist:0, max:17 18],[[ID:3, count:1], [ID:2, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2]):
# In UpdateSk()
# [ID:1 3 7, count:1] -> [ID:1, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:3, dist:0, max:17 18]
# local_max_ID:3
# local_max_index:0
# e_max after update:[ID:17 18, count:1]
# e_max:[ID:17 18, count:1]
# Sk_head[3]:[total:3, dist:0, max:17 18]
# Sk[0]:[total:2, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:2, dist:0, max:],[[ID:3, count:1], [ID:0, count:1]]
# Sk[2]:[total:2, dist:0, max:],[[ID:2, count:1], [ID:1, count:1]]
# Sk[3]:[total:3, dist:0, max:17 18],[[ID:3, count:1], [ID:2, count:1], [ID:1, count:1]]
# Top after BringBack:
# 	[[ID:54 1 6 55, count:2], [ID:1 2 3, count:1], [ID:1, count:1], [ID:4 5 6 7, count:1], [ID:1 8, count:1], [ID:9 10, count:1], [ID:11 6 12 13 14 15 16, count:1], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2]]
#
# read 20-th element: 69 11 1 6
# In UpdateSk()
# [ID:69 11 1 6, count:1] -> [ID:1, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:17 18, count:1]
# Sk_head:[total:4, dist:0, max:69 11 1 6]
# local_max_ID:1
# local_max_index:2
# e_max after update:[ID:69 11 1 6, count:2]
# e_max:[ID:69 11 1 6, count:2]
# Sk_head[3]:[total:4, dist:0, max:69 11 1 6]
# Sk[0]:[total:2, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:2, dist:0, max:],[[ID:3, count:1], [ID:0, count:1]]
# Sk[2]:[total:2, dist:0, max:],[[ID:2, count:1], [ID:1, count:1]]
# Sk[3]:[total:4, dist:0, max:69 11 1 6],[[ID:1, count:2], [ID:3, count:1], [ID:2, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:69 11 1 6, count:2]):
# In UpdateSk()
# [ID:11 6 12 13 14 15 16, count:1] -> [ID:3, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:3, dist:0, max:1 25 3]
# local_max_ID:1
# local_max_index:0
# e_max after update:[ID:1 25 3, count:1]
# e_max:[ID:1 25 3, count:1]
# Sk_head[0]:[total:3, dist:0, max:1 25 3]
# Sk[0]:[total:3, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1], [ID:3, count:1]]
# Sk[1]:[total:2, dist:0, max:],[[ID:3, count:1], [ID:0, count:1]]
# Sk[2]:[total:2, dist:0, max:],[[ID:2, count:1], [ID:1, count:1]]
# Sk[3]:[total:2, dist:0, max:],[[ID:3, count:1], [ID:2, count:1]]
# Top after BringBack:
# 	[[ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:1 2 3, count:1], [ID:1, count:1], [ID:4 5 6 7, count:1], [ID:1 8, count:1], [ID:9 10, count:1], [ID:69 11 1 6, count:2]]
#
# read 21-th element: 11 70 6
# In UpdateSk()
# [ID:11 70 6, count:1] -> [ID:2, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:1 25 3, count:1]
# Sk_head:[total:3, dist:0, max:11 70 6]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:11 70 6, count:2]
# e_max:[ID:11 70 6, count:2]
# Sk_head[2]:[total:3, dist:0, max:11 70 6]
# Sk[0]:[total:3, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1], [ID:3, count:1]]
# Sk[1]:[total:2, dist:0, max:],[[ID:3, count:1], [ID:0, count:1]]
# Sk[2]:[total:3, dist:0, max:11 70 6],[[ID:2, count:2], [ID:1, count:1]]
# Sk[3]:[total:2, dist:0, max:],[[ID:3, count:1], [ID:2, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:11 70 6, count:2]):
# In UpdateSk()
# [ID:9 10, count:1] -> [ID:3, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:2, dist:0, max:9 10]
# local_max_ID:3
# local_max_index:1
# e_max after update:[ID:9 10, count:1]
# e_max:[ID:9 10, count:1]
# Sk_head[2]:[total:2, dist:0, max:9 10]
# Sk[0]:[total:3, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1], [ID:3, count:1]]
# Sk[1]:[total:2, dist:0, max:],[[ID:3, count:1], [ID:0, count:1]]
# Sk[2]:[total:2, dist:0, max:9 10],[[ID:1, count:1], [ID:3, count:1]]
# Sk[3]:[total:2, dist:0, max:],[[ID:3, count:1], [ID:2, count:1]]
# Top after BringBack:
# 	[[ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:69 11 1 6, count:2], [ID:1 2 3, count:1], [ID:1, count:1], [ID:4 5 6 7, count:1], [ID:1 8, count:1], [ID:11 70 6, count:2]]
#
# read 22-th element: 6 3 71
# In UpdateSk()
# [ID:6 3 71, count:1] -> [ID:3, count:1],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:9 10, count:1]
# Sk_head:[total:3, dist:0, max:6 3 71]
# local_max_ID:3
# local_max_index:0
# e_max after update:[ID:6 3 71, count:2]
# e_max:[ID:6 3 71, count:2]
# Sk_head[1]:[total:3, dist:0, max:6 3 71]
# Sk[0]:[total:3, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1], [ID:3, count:1]]
# Sk[1]:[total:3, dist:0, max:6 3 71],[[ID:3, count:2], [ID:0, count:1]]
# Sk[2]:[total:2, dist:0, max:9 10],[[ID:1, count:1], [ID:3, count:1]]
# Sk[3]:[total:2, dist:0, max:],[[ID:3, count:1], [ID:2, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:6 3 71, count:2]):
# In UpdateSk()
# [ID:1 8, count:1] -> [ID:2, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:3, dist:0, max:9 10]
# local_max_ID:3
# local_max_index:1
# e_max after update:[ID:9 10, count:1]
# e_max:[ID:9 10, count:1]
# Sk_head[2]:[total:3, dist:0, max:9 10]
# Sk[0]:[total:3, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1], [ID:3, count:1]]
# Sk[1]:[total:1, dist:0, max:],[[ID:0, count:1]]
# Sk[2]:[total:3, dist:0, max:9 10],[[ID:1, count:1], [ID:3, count:1], [ID:2, count:1]]
# Sk[3]:[total:2, dist:0, max:],[[ID:3, count:1], [ID:2, count:1]]
# Top after BringBack:
# 	[[ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:69 11 1 6, count:2], [ID:11 70 6, count:2], [ID:1 2 3, count:1], [ID:1, count:1], [ID:4 5 6 7, count:1], [ID:6 3 71, count:2]]
#
# read 23-th element: 72 6 73
# In UpdateSk()
# [ID:72 6 73, count:1] -> [ID:1, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:9 10, count:1]
# Sk_head:[total:3, dist:0, max:72 6 73]
# local_max_ID:1
# local_max_index:2
# e_max after update:[ID:9 10, count:1]
# e_max:[ID:9 10, count:1]
# Sk_head[3]:[total:3, dist:0, max:72 6 73]
# Sk[0]:[total:3, dist:0, max:1 25 3],[[ID:1, count:1], [ID:0, count:1], [ID:3, count:1]]
# Sk[1]:[total:1, dist:0, max:],[[ID:0, count:1]]
# Sk[2]:[total:3, dist:0, max:9 10],[[ID:1, count:1], [ID:3, count:1], [ID:2, count:1]]
# Sk[3]:[total:3, dist:0, max:72 6 73],[[ID:3, count:1], [ID:2, count:1], [ID:1, count:1]]
#
# read 24-th element: 74
# In UpdateSk()
# [ID:74, count:1] -> [ID:0, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:9 10, count:1]
# Sk_head:[total:4, dist:0, max:74]
# local_max_ID:0
# local_max_index:1
# e_max after update:[ID:74, count:2]
# e_max:[ID:74, count:2]
# Sk_head[0]:[total:4, dist:0, max:74]
# Sk[0]:[total:4, dist:0, max:74],[[ID:0, count:2], [ID:1, count:1], [ID:3, count:1]]
# Sk[1]:[total:1, dist:0, max:],[[ID:0, count:1]]
# Sk[2]:[total:3, dist:0, max:9 10],[[ID:1, count:1], [ID:3, count:1], [ID:2, count:1]]
# Sk[3]:[total:3, dist:0, max:72 6 73],[[ID:3, count:1], [ID:2, count:1], [ID:1, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:74, count:2]):
# In UpdateSk()
# [ID:4 5 6 7, count:1] -> [ID:0, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:3, dist:0, max:4 5 6 7]
# local_max_ID:0
# local_max_index:2
# e_max after update:[ID:4 5 6 7, count:1]
# e_max:[ID:4 5 6 7, count:1]
# Sk_head[0]:[total:3, dist:0, max:4 5 6 7]
# Sk[0]:[total:3, dist:0, max:4 5 6 7],[[ID:1, count:1], [ID:3, count:1], [ID:0, count:1]]
# Sk[1]:[total:1, dist:0, max:],[[ID:0, count:1]]
# Sk[2]:[total:3, dist:0, max:9 10],[[ID:1, count:1], [ID:3, count:1], [ID:2, count:1]]
# Sk[3]:[total:3, dist:0, max:72 6 73],[[ID:3, count:1], [ID:2, count:1], [ID:1, count:1]]
# Top after BringBack:
# 	[[ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:69 11 1 6, count:2], [ID:11 70 6, count:2], [ID:6 3 71, count:2], [ID:1 2 3, count:1], [ID:1, count:1], [ID:74, count:2]]
#
# read 25-th element: 75 76
# In UpdateSk()
# [ID:75 76, count:1] -> [ID:2, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:4 5 6 7, count:1]
# Sk_head:[total:4, dist:0, max:75 76]
# local_max_ID:2
# local_max_index:1
# e_max after update:[ID:75 76, count:2]
# e_max:[ID:75 76, count:2]
# Sk_head[3]:[total:4, dist:0, max:75 76]
# Sk[0]:[total:3, dist:0, max:4 5 6 7],[[ID:1, count:1], [ID:3, count:1], [ID:0, count:1]]
# Sk[1]:[total:1, dist:0, max:],[[ID:0, count:1]]
# Sk[2]:[total:3, dist:0, max:9 10],[[ID:1, count:1], [ID:3, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:1, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:75 76, count:2]):
# In UpdateSk()
# [ID:1, count:1] -> [ID:2, count:1],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:2, dist:0, max:1]
# local_max_ID:2
# local_max_index:1
# e_max after update:[ID:1, count:1]
# e_max:[ID:1, count:1]
# Sk_head[1]:[total:2, dist:0, max:1]
# Sk[0]:[total:3, dist:0, max:4 5 6 7],[[ID:1, count:1], [ID:3, count:1], [ID:0, count:1]]
# Sk[1]:[total:2, dist:0, max:1],[[ID:0, count:1], [ID:2, count:1]]
# Sk[2]:[total:3, dist:0, max:9 10],[[ID:1, count:1], [ID:3, count:1], [ID:2, count:1]]
# Sk[3]:[total:2, dist:0, max:],[[ID:3, count:1], [ID:1, count:1]]
# Top after BringBack:
# 	[[ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:69 11 1 6, count:2], [ID:11 70 6, count:2], [ID:6 3 71, count:2], [ID:74, count:2], [ID:1 2 3, count:1], [ID:75 76, count:2]]
#
# read 26-th element: 6 3 77
# In UpdateSk()
# [ID:6 3 77, count:1] -> [ID:0, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:1, count:1]
# Sk_head:[total:3, dist:0, max:6 3 77]
# local_max_ID:0
# local_max_index:2
# e_max after update:[ID:1, count:1]
# e_max:[ID:1, count:1]
# Sk_head[3]:[total:3, dist:0, max:6 3 77]
# Sk[0]:[total:3, dist:0, max:4 5 6 7],[[ID:1, count:1], [ID:3, count:1], [ID:0, count:1]]
# Sk[1]:[total:2, dist:0, max:1],[[ID:0, count:1], [ID:2, count:1]]
# Sk[2]:[total:3, dist:0, max:9 10],[[ID:1, count:1], [ID:3, count:1], [ID:2, count:1]]
# Sk[3]:[total:3, dist:0, max:6 3 77],[[ID:3, count:1], [ID:1, count:1], [ID:0, count:1]]
#
# read 27-th element: 78 79 80 81
# In UpdateSk()
# [ID:78 79 80 81, count:1] -> [ID:3, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:1, count:1]
# Sk_head:[total:4, dist:0, max:78 79 80 81]
# local_max_ID:3
# local_max_index:1
# e_max after update:[ID:78 79 80 81, count:2]
# e_max:[ID:78 79 80 81, count:2]
# Sk_head[0]:[total:4, dist:0, max:78 79 80 81]
# Sk[0]:[total:4, dist:0, max:78 79 80 81],[[ID:3, count:2], [ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:2, dist:0, max:1],[[ID:0, count:1], [ID:2, count:1]]
# Sk[2]:[total:3, dist:0, max:9 10],[[ID:1, count:1], [ID:3, count:1], [ID:2, count:1]]
# Sk[3]:[total:3, dist:0, max:6 3 77],[[ID:3, count:1], [ID:1, count:1], [ID:0, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:78 79 80 81, count:2]):
# In UpdateSk()
# [ID:1 2 3, count:1] -> [ID:2, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:3, dist:0, max:1 2 3]
# local_max_ID:2
# local_max_index:2
# e_max after update:[ID:1 2 3, count:1]
# e_max:[ID:1 2 3, count:1]
# Sk_head[0]:[total:3, dist:0, max:1 2 3]
# Sk[0]:[total:3, dist:0, max:1 2 3],[[ID:1, count:1], [ID:0, count:1], [ID:2, count:1]]
# Sk[1]:[total:2, dist:0, max:1],[[ID:0, count:1], [ID:2, count:1]]
# Sk[2]:[total:3, dist:0, max:9 10],[[ID:1, count:1], [ID:3, count:1], [ID:2, count:1]]
# Sk[3]:[total:3, dist:0, max:6 3 77],[[ID:3, count:1], [ID:1, count:1], [ID:0, count:1]]
# Top after BringBack:
# 	[[ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:69 11 1 6, count:2], [ID:11 70 6, count:2], [ID:6 3 71, count:2], [ID:74, count:2], [ID:75 76, count:2], [ID:78 79 80 81, count:2]]
#
# read 28-th element: 82 6 83 7 84 85 86 87 88
# In UpdateSk()
# [ID:82 6 83 7 84 85 86 87 88, count:1] -> [ID:3, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:1 2 3, count:1]
# Sk_head:[total:4, dist:0, max:9 10]
# local_max_ID:3
# local_max_index:1
# e_max after update:[ID:9 10, count:2]
# e_max:[ID:9 10, count:2]
# Sk_head[2]:[total:4, dist:0, max:9 10]
# Sk[0]:[total:3, dist:0, max:1 2 3],[[ID:1, count:1], [ID:0, count:1], [ID:2, count:1]]
# Sk[1]:[total:2, dist:0, max:1],[[ID:0, count:1], [ID:2, count:1]]
# Sk[2]:[total:4, dist:0, max:9 10],[[ID:3, count:2], [ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:3, dist:0, max:6 3 77],[[ID:3, count:1], [ID:1, count:1], [ID:0, count:1]]
#
# read 29-th element: 11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137
# In UpdateSk()
# [ID:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count:1] -> [ID:1, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:9 10, count:2]
# Sk_head:[total:4, dist:0, max:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137]
# local_max_ID:1
# local_max_index:1
# e_max after update:[ID:9 10, count:2]
# e_max:[ID:9 10, count:2]
# Sk_head[3]:[total:4, dist:0, max:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137]
# Sk[0]:[total:3, dist:0, max:1 2 3],[[ID:1, count:1], [ID:0, count:1], [ID:2, count:1]]
# Sk[1]:[total:2, dist:0, max:1],[[ID:0, count:1], [ID:2, count:1]]
# Sk[2]:[total:4, dist:0, max:9 10],[[ID:3, count:2], [ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137],[[ID:1, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# read 30-th element: 6 138
# In UpdateSk()
# [ID:6 138, count:1] -> [ID:0, count:1],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:9 10, count:2]
# Sk_head:[total:3, dist:0, max:6 138]
# local_max_ID:0
# local_max_index:0
# e_max after update:[ID:9 10, count:2]
# e_max:[ID:9 10, count:2]
# Sk_head[1]:[total:3, dist:0, max:6 138]
# Sk[0]:[total:3, dist:0, max:1 2 3],[[ID:1, count:1], [ID:0, count:1], [ID:2, count:1]]
# Sk[1]:[total:3, dist:0, max:6 138],[[ID:0, count:2], [ID:2, count:1]]
# Sk[2]:[total:4, dist:0, max:9 10],[[ID:3, count:2], [ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137],[[ID:1, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# read 31-th element: 1 6 139 140 90 141 142 143 144
# In UpdateSk()
# [ID:1 6 139 140 90 141 142 143 144, count:1] -> [ID:3, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:9 10, count:2]
# Sk_head:[total:5, dist:0, max:9 10]
# local_max_ID:3
# local_max_index:0
# e_max after update:[ID:9 10, count:3]
# e_max:[ID:9 10, count:3]
# Sk_head[2]:[total:5, dist:0, max:9 10]
# Sk[0]:[total:3, dist:0, max:1 2 3],[[ID:1, count:1], [ID:0, count:1], [ID:2, count:1]]
# Sk[1]:[total:3, dist:0, max:6 138],[[ID:0, count:2], [ID:2, count:1]]
# Sk[2]:[total:5, dist:0, max:9 10],[[ID:3, count:3], [ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137],[[ID:1, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:9 10, count:3]):
# In UpdateSk()
# [ID:78 79 80 81, count:2] -> [ID:3, count:2],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:5, dist:0, max:78 79 80 81]
# local_max_ID:3
# local_max_index:3
# e_max after update:[ID:78 79 80 81, count:2]
# e_max:[ID:78 79 80 81, count:2]
# Sk_head[0]:[total:5, dist:0, max:78 79 80 81]
# Sk[0]:[total:5, dist:0, max:78 79 80 81],[[ID:3, count:2], [ID:1, count:1], [ID:0, count:1], [ID:2, count:1]]
# Sk[1]:[total:3, dist:0, max:6 138],[[ID:0, count:2], [ID:2, count:1]]
# Sk[2]:[total:2, dist:0, max:],[[ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137],[[ID:1, count:2], [ID:3, count:1], [ID:0, count:1]]
# Top after BringBack:
# 	[[ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:69 11 1 6, count:2], [ID:11 70 6, count:2], [ID:6 3 71, count:2], [ID:74, count:2], [ID:75 76, count:2], [ID:9 10, count:3]]
#
# read 32-th element: 6 3
# In UpdateSk()
# [ID:6 3, count:1] -> [ID:1, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:78 79 80 81, count:2]
# Sk_head:[total:5, dist:0, max:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137]
# local_max_ID:1
# local_max_index:0
# e_max after update:[ID:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count:3]
# e_max:[ID:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count:3]
# Sk_head[3]:[total:5, dist:0, max:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137]
# Sk[0]:[total:5, dist:0, max:78 79 80 81],[[ID:3, count:2], [ID:1, count:1], [ID:0, count:1], [ID:2, count:1]]
# Sk[1]:[total:3, dist:0, max:6 138],[[ID:0, count:2], [ID:2, count:1]]
# Sk[2]:[total:2, dist:0, max:],[[ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:5, dist:0, max:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137],[[ID:1, count:3], [ID:3, count:1], [ID:0, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count:3]):
# In UpdateSk()
# [ID:75 76, count:2] -> [ID:2, count:2],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:4, dist:0, max:75 76]
# local_max_ID:2
# local_max_index:2
# e_max after update:[ID:75 76, count:2]
# e_max:[ID:75 76, count:2]
# Sk_head[3]:[total:4, dist:0, max:75 76]
# Sk[0]:[total:5, dist:0, max:78 79 80 81],[[ID:3, count:2], [ID:1, count:1], [ID:0, count:1], [ID:2, count:1]]
# Sk[1]:[total:3, dist:0, max:6 138],[[ID:0, count:2], [ID:2, count:1]]
# Sk[2]:[total:2, dist:0, max:],[[ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
# Top after BringBack:
# 	[[ID:9 10, count:3], [ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:69 11 1 6, count:2], [ID:11 70 6, count:2], [ID:6 3 71, count:2], [ID:74, count:2], [ID:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count:3]]
#
# read 33-th element: 145 11 146
# In UpdateSk()
# [ID:145 11 146, count:1] -> [ID:3, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:75 76, count:2]
# Sk_head:[total:3, dist:0, max:145 11 146]
# local_max_ID:3
# local_max_index:2
# e_max after update:[ID:75 76, count:2]
# e_max:[ID:75 76, count:2]
# Sk_head[2]:[total:3, dist:0, max:145 11 146]
# Sk[0]:[total:5, dist:0, max:78 79 80 81],[[ID:3, count:2], [ID:1, count:1], [ID:0, count:1], [ID:2, count:1]]
# Sk[1]:[total:3, dist:0, max:6 138],[[ID:0, count:2], [ID:2, count:1]]
# Sk[2]:[total:3, dist:0, max:145 11 146],[[ID:1, count:1], [ID:2, count:1], [ID:3, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# read 34-th element: 147 3
# In UpdateSk()
# [ID:147 3, count:1] -> [ID:2, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:75 76, count:2]
# Sk_head:[total:6, dist:0, max:78 79 80 81]
# local_max_ID:3
# local_max_index:0
# e_max after update:[ID:75 76, count:2]
# e_max:[ID:75 76, count:2]
# Sk_head[0]:[total:6, dist:0, max:78 79 80 81]
# Sk[0]:[total:6, dist:0, max:78 79 80 81],[[ID:3, count:2], [ID:2, count:2], [ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:3, dist:0, max:6 138],[[ID:0, count:2], [ID:2, count:1]]
# Sk[2]:[total:3, dist:0, max:145 11 146],[[ID:1, count:1], [ID:2, count:1], [ID:3, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# read 35-th element: 3 148
# In UpdateSk()
# [ID:3 148, count:1] -> [ID:3, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:75 76, count:2]
# Sk_head:[total:4, dist:0, max:145 11 146]
# local_max_ID:3
# local_max_index:2
# e_max after update:[ID:75 76, count:2]
# e_max:[ID:75 76, count:2]
# Sk_head[2]:[total:4, dist:0, max:145 11 146]
# Sk[0]:[total:6, dist:0, max:78 79 80 81],[[ID:3, count:2], [ID:2, count:2], [ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:3, dist:0, max:6 138],[[ID:0, count:2], [ID:2, count:1]]
# Sk[2]:[total:4, dist:0, max:145 11 146],[[ID:3, count:2], [ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# read 36-th element: 149
# In UpdateSk()
# [ID:149, count:1] -> [ID:3, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:75 76, count:2]
# Sk_head:[total:7, dist:0, max:78 79 80 81]
# local_max_ID:3
# local_max_index:0
# e_max after update:[ID:78 79 80 81, count:3]
# e_max:[ID:78 79 80 81, count:3]
# Sk_head[0]:[total:7, dist:0, max:78 79 80 81]
# Sk[0]:[total:7, dist:0, max:78 79 80 81],[[ID:3, count:3], [ID:2, count:2], [ID:1, count:1], [ID:0, count:1]]
# Sk[1]:[total:3, dist:0, max:6 138],[[ID:0, count:2], [ID:2, count:1]]
# Sk[2]:[total:4, dist:0, max:145 11 146],[[ID:3, count:2], [ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:78 79 80 81, count:3]):
# In UpdateSk()
# [ID:74, count:2] -> [ID:0, count:2],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:6, dist:0, max:74]
# local_max_ID:0
# local_max_index:2
# e_max after update:[ID:74, count:3]
# e_max:[ID:74, count:3]
# Sk_head[0]:[total:6, dist:0, max:74]
# Sk[0]:[total:6, dist:0, max:74],[[ID:0, count:3], [ID:2, count:2], [ID:1, count:1]]
# Sk[1]:[total:3, dist:0, max:6 138],[[ID:0, count:2], [ID:2, count:1]]
# Sk[2]:[total:4, dist:0, max:145 11 146],[[ID:3, count:2], [ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
# Top after BringBack:
# 	[[ID:9 10, count:3], [ID:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count:3], [ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:69 11 1 6, count:2], [ID:11 70 6, count:2], [ID:6 3 71, count:2], [ID:78 79 80 81, count:3]]
#
# read 37-th element: 150
# In UpdateSk()
# [ID:150, count:1] -> [ID:2, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:74, count:3]
# Sk_head:[total:7, dist:0, max:74]
# local_max_ID:0
# local_max_index:0
# e_max after update:[ID:74, count:3]
# e_max:[ID:74, count:3]
# Sk_head[0]:[total:7, dist:0, max:74]
# Sk[0]:[total:7, dist:0, max:74],[[ID:0, count:3], [ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:3, dist:0, max:6 138],[[ID:0, count:2], [ID:2, count:1]]
# Sk[2]:[total:4, dist:0, max:145 11 146],[[ID:3, count:2], [ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:74, count:3]):
# In UpdateSk()
# [ID:6 3 71, count:2] -> [ID:3, count:2],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:5, dist:0, max:6 138]
# local_max_ID:0
# local_max_index:0
# e_max after update:[ID:6 138, count:2]
# e_max:[ID:6 138, count:2]
# Sk_head[1]:[total:5, dist:0, max:6 138]
# Sk[0]:[total:4, dist:0, max:],[[ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:5, dist:0, max:6 138],[[ID:0, count:2], [ID:3, count:2], [ID:2, count:1]]
# Sk[2]:[total:4, dist:0, max:145 11 146],[[ID:3, count:2], [ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
# Top after BringBack:
# 	[[ID:9 10, count:3], [ID:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count:3], [ID:78 79 80 81, count:3], [ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:69 11 1 6, count:2], [ID:11 70 6, count:2], [ID:74, count:3]]
#
# read 38-th element: 1 6
# In UpdateSk()
# [ID:1 6, count:1] -> [ID:3, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:6 138, count:2]
# Sk_head:[total:5, dist:0, max:145 11 146]
# local_max_ID:3
# local_max_index:0
# e_max after update:[ID:145 11 146, count:3]
# e_max:[ID:145 11 146, count:3]
# Sk_head[2]:[total:5, dist:0, max:145 11 146]
# Sk[0]:[total:4, dist:0, max:],[[ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:5, dist:0, max:6 138],[[ID:0, count:2], [ID:3, count:2], [ID:2, count:1]]
# Sk[2]:[total:5, dist:0, max:145 11 146],[[ID:3, count:3], [ID:1, count:1], [ID:2, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:145 11 146, count:3]):
# In UpdateSk()
# [ID:11 70 6, count:2] -> [ID:2, count:2],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:4, dist:0, max:11 70 6]
# local_max_ID:2
# local_max_index:1
# e_max after update:[ID:11 70 6, count:3]
# e_max:[ID:11 70 6, count:3]
# Sk_head[2]:[total:4, dist:0, max:11 70 6]
# Sk[0]:[total:4, dist:0, max:],[[ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:5, dist:0, max:6 138],[[ID:0, count:2], [ID:3, count:2], [ID:2, count:1]]
# Sk[2]:[total:4, dist:0, max:11 70 6],[[ID:2, count:3], [ID:1, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
# Top after BringBack:
# 	[[ID:9 10, count:3], [ID:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count:3], [ID:78 79 80 81, count:3], [ID:74, count:3], [ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:69 11 1 6, count:2], [ID:145 11 146, count:3]]
#
# read 39-th element: 11 3 64
# In UpdateSk()
# [ID:11 3 64, count:1] -> [ID:0, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 70 6, count:3]
# Sk_head:[total:5, dist:0, max:11 70 6]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:11 70 6, count:3]
# e_max:[ID:11 70 6, count:3]
# Sk_head[2]:[total:5, dist:0, max:11 70 6]
# Sk[0]:[total:4, dist:0, max:],[[ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:5, dist:0, max:6 138],[[ID:0, count:2], [ID:3, count:2], [ID:2, count:1]]
# Sk[2]:[total:5, dist:0, max:11 70 6],[[ID:2, count:3], [ID:1, count:1], [ID:0, count:1]]
# Sk[3]:[total:4, dist:0, max:75 76],[[ID:2, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:11 70 6, count:3]):
# In UpdateSk()
# [ID:69 11 1 6, count:2] -> [ID:1, count:2],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:6, dist:0, max:75 76]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:75 76, count:2]
# e_max:[ID:75 76, count:2]
# Sk_head[3]:[total:6, dist:0, max:75 76]
# Sk[0]:[total:4, dist:0, max:],[[ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:5, dist:0, max:6 138],[[ID:0, count:2], [ID:3, count:2], [ID:2, count:1]]
# Sk[2]:[total:2, dist:0, max:],[[ID:1, count:1], [ID:0, count:1]]
# Sk[3]:[total:6, dist:0, max:75 76],[[ID:2, count:2], [ID:1, count:2], [ID:3, count:1], [ID:0, count:1]]
# Top after BringBack:
# 	[[ID:9 10, count:3], [ID:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count:3], [ID:78 79 80 81, count:3], [ID:74, count:3], [ID:145 11 146, count:3], [ID:54 1 6 55, count:2], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2], [ID:11 70 6, count:3]]
#
# read 40-th element: 151 11 6 2 152 153 154 155 156 157 158 159 3
# In UpdateSk()
# [ID:151 11 6 2 152 153 154 155 156 157 158 159 3, count:1] -> [ID:0, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:75 76, count:2]
# Sk_head:[total:3, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3]
# local_max_ID:0
# local_max_index:1
# e_max after update:[ID:75 76, count:2]
# e_max:[ID:75 76, count:2]
# Sk_head[2]:[total:3, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3]
# Sk[0]:[total:4, dist:0, max:],[[ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:5, dist:0, max:6 138],[[ID:0, count:2], [ID:3, count:2], [ID:2, count:1]]
# Sk[2]:[total:3, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3],[[ID:0, count:2], [ID:1, count:1]]
# Sk[3]:[total:6, dist:0, max:75 76],[[ID:2, count:2], [ID:1, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# read 41-th element: 160 27 161 6 91 3 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 7 205 206 207 208 209 210 211 212 213 87 88 214 80
# In UpdateSk()
# [ID:160 27 161 6 91 3 162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 7 205 206 207 208 209 210 211 212 213 87 88 214 80, count:1] -> [ID:2, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:75 76, count:2]
# Sk_head:[total:7, dist:0, max:75 76]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:75 76, count:3]
# e_max:[ID:75 76, count:3]
# Sk_head[3]:[total:7, dist:0, max:75 76]
# Sk[0]:[total:4, dist:0, max:],[[ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:5, dist:0, max:6 138],[[ID:0, count:2], [ID:3, count:2], [ID:2, count:1]]
# Sk[2]:[total:3, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3],[[ID:0, count:2], [ID:1, count:1]]
# Sk[3]:[total:7, dist:0, max:75 76],[[ID:2, count:3], [ID:1, count:2], [ID:3, count:1], [ID:0, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:75 76, count:3]):
# In UpdateSk()
# [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:2] -> [ID:2, count:2],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:7, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# local_max_ID:2
# local_max_index:2
# e_max after update:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:3]
# e_max:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:3]
# Sk_head[1]:[total:7, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# Sk[0]:[total:4, dist:0, max:],[[ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:7, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:3], [ID:0, count:2], [ID:3, count:2]]
# Sk[2]:[total:3, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3],[[ID:0, count:2], [ID:1, count:1]]
# Sk[3]:[total:4, dist:0, max:],[[ID:1, count:2], [ID:3, count:1], [ID:0, count:1]]
# Top after BringBack:
# 	[[ID:9 10, count:3], [ID:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count:3], [ID:78 79 80 81, count:3], [ID:74, count:3], [ID:145 11 146, count:3], [ID:11 70 6, count:3], [ID:54 1 6 55, count:2], [ID:75 76, count:3]]
#
# read 42-th element: 3
# In UpdateSk()
# [ID:3, count:1] -> [ID:2, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:3]
# Sk_head:[total:5, dist:0, max:3]
# local_max_ID:2
# local_max_index:3
# e_max after update:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:3]
# e_max:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:3]
# Sk_head[3]:[total:5, dist:0, max:3]
# Sk[0]:[total:4, dist:0, max:],[[ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:7, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:3], [ID:0, count:2], [ID:3, count:2]]
# Sk[2]:[total:3, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3],[[ID:0, count:2], [ID:1, count:1]]
# Sk[3]:[total:5, dist:0, max:3],[[ID:1, count:2], [ID:3, count:1], [ID:0, count:1], [ID:2, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:3]):
# In UpdateSk()
# [ID:54 1 6 55, count:2] -> [ID:3, count:2],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:5, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3]
# local_max_ID:0
# local_max_index:0
# e_max after update:[ID:151 11 6 2 152 153 154 155 156 157 158 159 3, count:2]
# e_max:[ID:151 11 6 2 152 153 154 155 156 157 158 159 3, count:2]
# Sk_head[2]:[total:5, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3]
# Sk[0]:[total:4, dist:0, max:],[[ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:4, dist:0, max:],[[ID:0, count:2], [ID:3, count:2]]
# Sk[2]:[total:5, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3],[[ID:0, count:2], [ID:3, count:2], [ID:1, count:1]]
# Sk[3]:[total:5, dist:0, max:3],[[ID:1, count:2], [ID:3, count:1], [ID:0, count:1], [ID:2, count:1]]
# Top after BringBack:
# 	[[ID:9 10, count:3], [ID:11 27 1 6 89 90 91 92 93 14 94 95 96 97 98 99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 64 134 135 136 137, count:3], [ID:78 79 80 81, count:3], [ID:74, count:3], [ID:145 11 146, count:3], [ID:11 70 6, count:3], [ID:75 76, count:3], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:3]]
#
# read 43-th element: 11 6 215
# In UpdateSk()
# [ID:11 6 215, count:1] -> [ID:1, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:151 11 6 2 152 153 154 155 156 157 158 159 3, count:2]
# Sk_head:[total:6, dist:0, max:11 6 215]
# local_max_ID:1
# local_max_index:0
# e_max after update:[ID:11 6 215, count:3]
# e_max:[ID:11 6 215, count:3]
# Sk_head[3]:[total:6, dist:0, max:11 6 215]
# Sk[0]:[total:4, dist:0, max:],[[ID:2, count:3], [ID:1, count:1]]
# Sk[1]:[total:4, dist:0, max:],[[ID:0, count:2], [ID:3, count:2]]
# Sk[2]:[total:5, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3],[[ID:0, count:2], [ID:3, count:2], [ID:1, count:1]]
# Sk[3]:[total:6, dist:0, max:11 6 215],[[ID:1, count:3], [ID:3, count:1], [ID:0, count:1], [ID:2, count:1]]
#
# read 44-th element: 11 216 3
# In UpdateSk()
# [ID:11 216 3, count:1] -> [ID:3, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 6 215, count:3]
# Sk_head:[total:5, dist:0, max:11 216 3]
# local_max_ID:3
# local_max_index:2
# e_max after update:[ID:11 6 215, count:3]
# e_max:[ID:11 6 215, count:3]
# Sk_head[0]:[total:5, dist:0, max:11 216 3]
# Sk[0]:[total:5, dist:0, max:11 216 3],[[ID:2, count:3], [ID:1, count:1], [ID:3, count:1]]
# Sk[1]:[total:4, dist:0, max:],[[ID:0, count:2], [ID:3, count:2]]
# Sk[2]:[total:5, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3],[[ID:0, count:2], [ID:3, count:2], [ID:1, count:1]]
# Sk[3]:[total:6, dist:0, max:11 6 215],[[ID:1, count:3], [ID:3, count:1], [ID:0, count:1], [ID:2, count:1]]
#
# read 45-th element: 11 217 1 218 6 219 220 221 222 3 223 135 148 224 225 226 227
# In UpdateSk()
# [ID:11 217 1 218 6 219 220 221 222 3 223 135 148 224 225 226 227, count:1] -> [ID:3, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 6 215, count:3]
# Sk_head:[total:6, dist:0, max:11 216 3]
# local_max_ID:3
# local_max_index:2
# e_max after update:[ID:11 6 215, count:3]
# e_max:[ID:11 6 215, count:3]
# Sk_head[0]:[total:6, dist:0, max:11 216 3]
# Sk[0]:[total:6, dist:0, max:11 216 3],[[ID:2, count:3], [ID:3, count:2], [ID:1, count:1]]
# Sk[1]:[total:4, dist:0, max:],[[ID:0, count:2], [ID:3, count:2]]
# Sk[2]:[total:5, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3],[[ID:0, count:2], [ID:3, count:2], [ID:1, count:1]]
# Sk[3]:[total:6, dist:0, max:11 6 215],[[ID:1, count:3], [ID:3, count:1], [ID:0, count:1], [ID:2, count:1]]
#
# read 46-th element: 69 11 218 6 215 228 229 230 231 232 233 234 235 236 237 90 238 239 240 241 242 243 135 148 244 245
# In UpdateSk()
# [ID:69 11 218 6 215 228 229 230 231 232 233 234 235 236 237 90 238 239 240 241 242 243 135 148 244 245, count:1] -> [ID:1, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 6 215, count:3]
# Sk_head:[total:6, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3]
# local_max_ID:0
# local_max_index:0
# e_max after update:[ID:11 6 215, count:3]
# e_max:[ID:11 6 215, count:3]
# Sk_head[2]:[total:6, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3]
# Sk[0]:[total:6, dist:0, max:11 216 3],[[ID:2, count:3], [ID:3, count:2], [ID:1, count:1]]
# Sk[1]:[total:4, dist:0, max:],[[ID:0, count:2], [ID:3, count:2]]
# Sk[2]:[total:6, dist:0, max:151 11 6 2 152 153 154 155 156 157 158 159 3],[[ID:0, count:2], [ID:3, count:2], [ID:1, count:2]]
# Sk[3]:[total:6, dist:0, max:11 6 215],[[ID:1, count:3], [ID:3, count:1], [ID:0, count:1], [ID:2, count:1]]
#
# read 47-th element: 138 77
# In UpdateSk()
# [ID:138 77, count:1] -> [ID:0, count:1],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 6 215, count:3]
# Sk_head:[total:5, dist:0, max:138 77]
# local_max_ID:0
# local_max_index:0
# e_max after update:[ID:11 6 215, count:3]
# e_max:[ID:11 6 215, count:3]
# Sk_head[1]:[total:5, dist:0, max:138 77]
# Sk[0]:[total:6, dist:0, max:11 216 3],[[ID:2, count:3], [ID:3, count:2], [ID:1, count:1]]
# ...
# Sk[1]:[total:13, dist:0, max:11 6 277],[[ID:3, count:4], [ID:0, count:4], [ID:1, count:4], [ID:2, count:1]]
# Sk[2]:[total:7, dist:0, max:324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339 268 151 340 11 341 27 1 218 314 6 342 343 344 345 346 347 348 56 349 89 350 351 352 303 353 354 355 356 357 154 228 358 359 360 361 362 363 229 364 25 155 365 366 232 233 367 368 369 234 370 371 372 373 241 374 375 376 306 377 378 46 379 380 381 382 47 383 384 385 386 387 388 389 390 391 392 393 394 395 396 397 109 398 7 399 400 401 402 403 404 405 406 407 408 409 410 411 412 413 414 415 416 417 418 207 419 209 87 420 421 422 135 423 77 424 148 425 426 427 428 429 430 431 432 433 434 435 436 437 438 439 440 441 442 443 444 445 446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461 462 463 464 465 466 467 468 469 470 471 472 473 474],[[ID:1, count:4], [ID:0, count:3]]
# Sk[3]:[total:13, dist:0, max:215],[[ID:2, count:5], [ID:3, count:4], [ID:0, count:3], [ID:1, count:1]]
#
# read 94-th element: 487 6 3
# In UpdateSk()
# [ID:487 6 3, count:1] -> [ID:3, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:215, count:5]
# Sk_head:[total:8, dist:0, max:324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339 268 151 340 11 341 27 1 218 314 6 342 343 344 345 346 347 348 56 349 89 350 351 352 303 353 354 355 356 357 154 228 358 359 360 361 362 363 229 364 25 155 365 366 232 233 367 368 369 234 370 371 372 373 241 374 375 376 306 377 378 46 379 380 381 382 47 383 384 385 386 387 388 389 390 391 392 393 394 395 396 397 109 398 7 399 400 401 402 403 404 405 406 407 408 409 410 411 412 413 414 415 416 417 418 207 419 209 87 420 421 422 135 423 77 424 148 425 426 427 428 429 430 431 432 433 434 435 436 437 438 439 440 441 442 443 444 445 446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461 462 463 464 465 466 467 468 469 470 471 472 473 474]
# local_max_ID:1
# local_max_index:0
# e_max after update:[ID:215, count:5]
# e_max:[ID:215, count:5]
# Sk_head[2]:[total:8, dist:0, max:324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339 268 151 340 11 341 27 1 218 314 6 342 343 344 345 346 347 348 56 349 89 350 351 352 303 353 354 355 356 357 154 228 358 359 360 361 362 363 229 364 25 155 365 366 232 233 367 368 369 234 370 371 372 373 241 374 375 376 306 377 378 46 379 380 381 382 47 383 384 385 386 387 388 389 390 391 392 393 394 395 396 397 109 398 7 399 400 401 402 403 404 405 406 407 408 409 410 411 412 413 414 415 416 417 418 207 419 209 87 420 421 422 135 423 77 424 148 425 426 427 428 429 430 431 432 433 434 435 436 437 438 439 440 441 442 443 444 445 446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461 462 463 464 465 466 467 468 469 470 471 472 473 474]
# Sk[0]:[total:12, dist:0, max:11 291 3 292],[[ID:1, count:5], [ID:2, count:4], [ID:0, count:2], [ID:3, count:1]]
# Sk[1]:[total:13, dist:0, max:11 6 277],[[ID:3, count:4], [ID:0, count:4], [ID:1, count:4], [ID:2, count:1]]
# Sk[2]:[total:8, dist:0, max:324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339 268 151 340 11 341 27 1 218 314 6 342 343 344 345 346 347 348 56 349 89 350 351 352 303 353 354 355 356 357 154 228 358 359 360 361 362 363 229 364 25 155 365 366 232 233 367 368 369 234 370 371 372 373 241 374 375 376 306 377 378 46 379 380 381 382 47 383 384 385 386 387 388 389 390 391 392 393 394 395 396 397 109 398 7 399 400 401 402 403 404 405 406 407 408 409 410 411 412 413 414 415 416 417 418 207 419 209 87 420 421 422 135 423 77 424 148 425 426 427 428 429 430 431 432 433 434 435 436 437 438 439 440 441 442 443 444 445 446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461 462 463 464 465 466 467 468 469 470 471 472 473 474],[[ID:1, count:4], [ID:0, count:3], [ID:3, count:1]]
# Sk[3]:[total:13, dist:0, max:215],[[ID:2, count:5], [ID:3, count:4], [ID:0, count:3], [ID:1, count:1]]
#
# read 95-th element: 488 6 307 3 77
# In UpdateSk()
# [ID:488 6 307 3 77, count:1] -> [ID:2, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:215, count:5]
# Sk_head:[total:14, dist:0, max:215]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:215, count:6]
# e_max:[ID:215, count:6]
# Sk_head[3]:[total:14, dist:0, max:215]
# Sk[0]:[total:12, dist:0, max:11 291 3 292],[[ID:1, count:5], [ID:2, count:4], [ID:0, count:2], [ID:3, count:1]]
# Sk[1]:[total:13, dist:0, max:11 6 277],[[ID:3, count:4], [ID:0, count:4], [ID:1, count:4], [ID:2, count:1]]
# Sk[2]:[total:8, dist:0, max:324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339 268 151 340 11 341 27 1 218 314 6 342 343 344 345 346 347 348 56 349 89 350 351 352 303 353 354 355 356 357 154 228 358 359 360 361 362 363 229 364 25 155 365 366 232 233 367 368 369 234 370 371 372 373 241 374 375 376 306 377 378 46 379 380 381 382 47 383 384 385 386 387 388 389 390 391 392 393 394 395 396 397 109 398 7 399 400 401 402 403 404 405 406 407 408 409 410 411 412 413 414 415 416 417 418 207 419 209 87 420 421 422 135 423 77 424 148 425 426 427 428 429 430 431 432 433 434 435 436 437 438 439 440 441 442 443 444 445 446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461 462 463 464 465 466 467 468 469 470 471 472 473 474],[[ID:1, count:4], [ID:0, count:3], [ID:3, count:1]]
# Sk[3]:[total:14, dist:0, max:215],[[ID:2, count:6], [ID:3, count:4], [ID:0, count:3], [ID:1, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:215, count:6]):
# In UpdateSk()
# [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:5] -> [ID:2, count:5],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:18, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# local_max_ID:2
# local_max_index:3
# e_max after update:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:6]
# e_max:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:6]
# Sk_head[1]:[total:18, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# Sk[0]:[total:12, dist:0, max:11 291 3 292],[[ID:1, count:5], [ID:2, count:4], [ID:0, count:2], [ID:3, count:1]]
# Sk[1]:[total:18, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:6], [ID:3, count:4], [ID:0, count:4], [ID:1, count:4]]
# Sk[2]:[total:8, dist:0, max:324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339 268 151 340 11 341 27 1 218 314 6 342 343 344 345 346 347 348 56 349 89 350 351 352 303 353 354 355 356 357 154 228 358 359 360 361 362 363 229 364 25 155 365 366 232 233 367 368 369 234 370 371 372 373 241 374 375 376 306 377 378 46 379 380 381 382 47 383 384 385 386 387 388 389 390 391 392 393 394 395 396 397 109 398 7 399 400 401 402 403 404 405 406 407 408 409 410 411 412 413 414 415 416 417 418 207 419 209 87 420 421 422 135 423 77 424 148 425 426 427 428 429 430 431 432 433 434 435 436 437 438 439 440 441 442 443 444 445 446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461 462 463 464 465 466 467 468 469 470 471 472 473 474],[[ID:1, count:4], [ID:0, count:3], [ID:3, count:1]]
# Sk[3]:[total:8, dist:0, max:],[[ID:3, count:4], [ID:0, count:3], [ID:1, count:1]]
# Top after BringBack:
# 	[[ID:11 6 215, count:8], [ID:78 79 80 81, count:7], [ID:75 76, count:6], [ID:145 11 146, count:6], [ID:27 1 6 3, count:6], [ID:74, count:5], [ID:9 10, count:5], [ID:215, count:6]]
#
# read 96-th element: 6 55
# In UpdateSk()
# [ID:6 55, count:1] -> [ID:0, count:1],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:6]
# Sk_head:[total:19, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# local_max_ID:2
# local_max_index:0
# e_max after update:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:6]
# e_max:[ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:6]
# Sk_head[1]:[total:19, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37]
# Sk[0]:[total:12, dist:0, max:11 291 3 292],[[ID:1, count:5], [ID:2, count:4], [ID:0, count:2], [ID:3, count:1]]
# Sk[1]:[total:19, dist:0, max:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37],[[ID:2, count:6], [ID:0, count:5], [ID:3, count:4], [ID:1, count:4]]
# Sk[2]:[total:8, dist:0, max:324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339 268 151 340 11 341 27 1 218 314 6 342 343 344 345 346 347 348 56 349 89 350 351 352 303 353 354 355 356 357 154 228 358 359 360 361 362 363 229 364 25 155 365 366 232 233 367 368 369 234 370 371 372 373 241 374 375 376 306 377 378 46 379 380 381 382 47 383 384 385 386 387 388 389 390 391 392 393 394 395 396 397 109 398 7 399 400 401 402 403 404 405 406 407 408 409 410 411 412 413 414 415 416 417 418 207 419 209 87 420 421 422 135 423 77 424 148 425 426 427 428 429 430 431 432 433 434 435 436 437 438 439 440 441 442 443 444 445 446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461 462 463 464 465 466 467 468 469 470 471 472 473 474],[[ID:1, count:4], [ID:0, count:3], [ID:3, count:1]]
# Sk[3]:[total:8, dist:0, max:],[[ID:3, count:4], [ID:0, count:3], [ID:1, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:6]):
# In UpdateSk()
# [ID:9 10, count:5] -> [ID:3, count:5],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:13, dist:0, max:9 10]
# local_max_ID:3
# local_max_index:2
# e_max after update:[ID:9 10, count:6]
# e_max:[ID:9 10, count:6]
# Sk_head[2]:[total:13, dist:0, max:9 10]
# Sk[0]:[total:12, dist:0, max:11 291 3 292],[[ID:1, count:5], [ID:2, count:4], [ID:0, count:2], [ID:3, count:1]]
# Sk[1]:[total:13, dist:0, max:],[[ID:0, count:5], [ID:3, count:4], [ID:1, count:4]]
# Sk[2]:[total:13, dist:0, max:9 10],[[ID:3, count:6], [ID:1, count:4], [ID:0, count:3]]
# Sk[3]:[total:8, dist:0, max:],[[ID:3, count:4], [ID:0, count:3], [ID:1, count:1]]
# Top after BringBack:
# 	[[ID:11 6 215, count:8], [ID:78 79 80 81, count:7], [ID:75 76, count:6], [ID:145 11 146, count:6], [ID:27 1 6 3, count:6], [ID:215, count:6], [ID:74, count:5], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:6]]
#
# read 97-th element: 4 1 6 3
# In UpdateSk()
# [ID:4 1 6 3, count:1] -> [ID:1, count:1],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:9 10, count:6]
# Sk_head:[total:14, dist:0, max:9 10]
# local_max_ID:3
# local_max_index:0
# e_max after update:[ID:9 10, count:6]
# e_max:[ID:9 10, count:6]
# Sk_head[2]:[total:14, dist:0, max:9 10]
# Sk[0]:[total:12, dist:0, max:11 291 3 292],[[ID:1, count:5], [ID:2, count:4], [ID:0, count:2], [ID:3, count:1]]
# Sk[1]:[total:13, dist:0, max:],[[ID:0, count:5], [ID:3, count:4], [ID:1, count:4]]
# Sk[2]:[total:14, dist:0, max:9 10],[[ID:3, count:6], [ID:1, count:5], [ID:0, count:3]]
# Sk[3]:[total:8, dist:0, max:],[[ID:3, count:4], [ID:0, count:3], [ID:1, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:9 10, count:6]):
# In UpdateSk()
# [ID:74, count:5] -> [ID:0, count:5],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:17, dist:0, max:74]
# local_max_ID:0
# local_max_index:2
# e_max after update:[ID:74, count:7]
# e_max:[ID:74, count:7]
# Sk_head[0]:[total:17, dist:0, max:74]
# Sk[0]:[total:17, dist:0, max:74],[[ID:0, count:7], [ID:1, count:5], [ID:2, count:4], [ID:3, count:1]]
# Sk[1]:[total:13, dist:0, max:],[[ID:0, count:5], [ID:3, count:4], [ID:1, count:4]]
# Sk[2]:[total:8, dist:0, max:],[[ID:1, count:5], [ID:0, count:3]]
# Sk[3]:[total:8, dist:0, max:],[[ID:3, count:4], [ID:0, count:3], [ID:1, count:1]]
# Top after BringBack:
# 	[[ID:11 6 215, count:8], [ID:78 79 80 81, count:7], [ID:75 76, count:6], [ID:145 11 146, count:6], [ID:27 1 6 3, count:6], [ID:215, count:6], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:6], [ID:9 10, count:6]]
#
# read 98-th element: 145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499
# In UpdateSk()
# [ID:145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499, count:1] -> [ID:0, count:1],send to Sk[3]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:74, count:7]
# Sk_head:[total:9, dist:0, max:145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499]
# local_max_ID:0
# local_max_index:1
# e_max after update:[ID:74, count:7]
# e_max:[ID:74, count:7]
# Sk_head[3]:[total:9, dist:0, max:145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499]
# Sk[0]:[total:17, dist:0, max:74],[[ID:0, count:7], [ID:1, count:5], [ID:2, count:4], [ID:3, count:1]]
# Sk[1]:[total:13, dist:0, max:],[[ID:0, count:5], [ID:3, count:4], [ID:1, count:4]]
# Sk[2]:[total:8, dist:0, max:],[[ID:1, count:5], [ID:0, count:3]]
# Sk[3]:[total:9, dist:0, max:145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499],[[ID:3, count:4], [ID:0, count:4], [ID:1, count:1]]
#
# In BringBack():
#
# In DeleteSK([ID:74, count:7]):
# In UpdateSk()
# [ID:9 10, count:6] -> [ID:3, count:6],send to Sk[2]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:, count:0]
# Sk_head:[total:14, dist:0, max:9 10]
# local_max_ID:3
# local_max_index:2
# e_max after update:[ID:9 10, count:6]
# e_max:[ID:9 10, count:6]
# Sk_head[2]:[total:14, dist:0, max:9 10]
# Sk[0]:[total:10, dist:0, max:],[[ID:1, count:5], [ID:2, count:4], [ID:3, count:1]]
# Sk[1]:[total:13, dist:0, max:],[[ID:0, count:5], [ID:3, count:4], [ID:1, count:4]]
# Sk[2]:[total:14, dist:0, max:9 10],[[ID:3, count:6], [ID:1, count:5], [ID:0, count:3]]
# Sk[3]:[total:9, dist:0, max:145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499],[[ID:3, count:4], [ID:0, count:4], [ID:1, count:1]]
# Top after BringBack:
# 	[[ID:11 6 215, count:8], [ID:78 79 80 81, count:7], [ID:75 76, count:6], [ID:145 11 146, count:6], [ID:27 1 6 3, count:6], [ID:215, count:6], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:6], [ID:74, count:7]]
#
# read 99-th element: 1 6 55
# In UpdateSk()
# [ID:1 6 55, count:1] -> [ID:1, count:1],send to Sk[1]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:9 10, count:6]
# Sk_head:[total:14, dist:0, max:1 6 55]
# local_max_ID:1
# local_max_index:2
# e_max after update:[ID:9 10, count:6]
# e_max:[ID:9 10, count:6]
# Sk_head[1]:[total:14, dist:0, max:1 6 55]
# Sk[0]:[total:10, dist:0, max:],[[ID:1, count:5], [ID:2, count:4], [ID:3, count:1]]
# Sk[1]:[total:14, dist:0, max:1 6 55],[[ID:0, count:5], [ID:1, count:5], [ID:3, count:4]]
# Sk[2]:[total:14, dist:0, max:9 10],[[ID:3, count:6], [ID:1, count:5], [ID:0, count:3]]
# Sk[3]:[total:9, dist:0, max:145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499],[[ID:3, count:4], [ID:0, count:4], [ID:1, count:1]]
#
# read 100-th element: 4 500
# In UpdateSk()
# [ID:4 500, count:1] -> [ID:2, count:1],send to Sk[0]
# In Update_local_max():
# In Update_emax():
# e_max before update:[ID:9 10, count:6]
# Sk_head:[total:11, dist:0, max:4 500]
# local_max_ID:2
# local_max_index:1
# e_max after update:[ID:9 10, count:6]
# e_max:[ID:9 10, count:6]
# Sk_head[0]:[total:11, dist:0, max:4 500]
# Sk[0]:[total:11, dist:0, max:4 500],[[ID:1, count:5], [ID:2, count:5], [ID:3, count:1]]
# Sk[1]:[total:14, dist:0, max:1 6 55],[[ID:0, count:5], [ID:1, count:5], [ID:3, count:4]]
# Sk[2]:[total:14, dist:0, max:9 10],[[ID:3, count:6], [ID:1, count:5], [ID:0, count:3]]
# Sk[3]:[total:9, dist:0, max:145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499],[[ID:3, count:4], [ID:0, count:4], [ID:1, count:1]]
# Sk_head:[[total:11, dist:0, max:4 500], [total:14, dist:0, max:1 6 55], [total:14, dist:0, max:9 10], [total:9, dist:0, max:145 489 490 6 2 491 3 136 492 493 494 495 496 497 498 499]]
# TOP[20]:[[ID:11 6 215, count:8], [ID:78 79 80 81, count:7], [ID:74, count:7], [ID:75 76, count:6], [ID:145 11 146, count:6], [ID:27 1 6 3, count:6], [ID:215, count:6], [ID:11 27 6 3 28 7 29 30 31 32 33 34 35 36 37, count:6]]
# Total memory 320 bytes
# Top:128 bytes, Sketch:96 bytes, Sketch_head:96 bytes.
# Execution time:0.26126933097839355 seconds.
#                                           ID  Count
# 0                                   11 6 215      8
# 1                                78 79 80 81      7
# 2                                         74      7
# 3                                      75 76      6
# 4                                 145 11 146      6
# 5                                   27 1 6 3      6
# 6                                        215      6
# 7  11 27 6 3 28 7 29 30 31 32 33 34 35 36 37      6

# %%
# https://blog.csdn.net/asukasmallriver/article/details/74356771
'''
ncalls：表示函数调用的次数；
tottime：表示指定函数的总的运行时间，除掉函数中调用子函数的运行时间；
percall：（第一个percall）等于 tottime/ncalls；
cumtime：表示该函数及其所有子函数的调用运行的时间，即函数开始调用到返回的时间；
percall：（第二个percall）即函数运行一次的平均时间，等于 cumtime/ncalls；
filename:lineno(function)：每个函数调用的具体信息；
'''

import pstats

# 创建Stats对象
p = pstats.Stats("result.out")

# strip_dirs(): 去掉无关的路径信息
# sort_stats(): 排序，支持的方式和上述的一致
# print_stats(): 打印分析结果，可以指定打印前几行

# 和直接运行cProfile.run("test()")的结果是一样的
p.strip_dirs().sort_stats(-1).print_stats()
# Out:
# Mon Apr  5 23:10:53 2021    result.out
#
#          446188 function calls (409643 primitive calls) in 1.455 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.007    0.007    1.456    1.456 0405.py:1(<module>)
#      1108    0.005    0.000    0.010    0.000 0405.py:116(Update_local_max)
#         1    0.000    0.000    0.000    0.000 0405.py:13(Node)
#      4486    0.001    0.000    0.001    0.000 0405.py:14(__init__)
#      1108    0.008    0.000    0.103    0.000 0405.py:144(Update_emax)
#       157    0.001    0.000    0.087    0.001 0405.py:170(BringBack)
#       157    0.001    0.000    0.003    0.000 0405.py:187(DeleteSk)
#      2373    0.000    0.000    0.000    0.000 0405.py:207(get_emax)
#      3638    0.001    0.000    0.001    0.000 0405.py:209(get_width_depth)
#      4323    0.005    0.000    0.009    0.000 0405.py:212(find)
#      4323    0.002    0.000    0.002    0.000 0405.py:215(<listcomp>)
#      1265    0.005    0.000    0.007    0.000 0405.py:220(position)
#      3481    0.001    0.000    0.001    0.000 0405.py:228(get_fraction)
#         1    0.000    0.000    0.000    0.000 0405.py:23(Head)
#         4    0.000    0.000    0.004    0.001 0405.py:24(__init__)
#         1    0.000    0.000    0.004    0.004 0405.py:247(<listcomp>)
#         1    0.000    0.000    0.000    0.000 0405.py:248(<listcomp>)
#      6648    0.005    0.000    0.450    0.000 0405.py:28(__str__)
#         4    0.000    0.000    0.000    0.000 0405.py:30(__repr__)
#         1    0.000    0.000    0.000    0.000 0405.py:33(Tail)
#      4482    0.004    0.000    0.005    0.000 0405.py:34(__init__)
#      5697    0.002    0.000    0.005    0.000 0405.py:37(__str__)
#     16890    0.006    0.000    0.013    0.000 0405.py:39(__repr__)
#      1108    0.012    0.000    0.566    0.001 0405.py:45(UpdateSk)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(<module>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#      1147    0.004    0.000    0.004    0.000 <frozen importlib._bootstrap>:103(release)
#       483    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#       483    0.001    0.000    0.010    0.000 <frozen importlib._bootstrap>:147(__enter__)
#       483    0.001    0.000    0.004    0.000 <frozen importlib._bootstrap>:151(__exit__)
#      1147    0.004    0.000    0.009    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#       481    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:176(cb)
#       664    0.001    0.000    0.006    0.000 <frozen importlib._bootstrap>:194(_lock_unlock_module)
#     657/9    0.001    0.000    0.847    0.094 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#      4073    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#        19    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:232(_requires_builtin_wrapper)
#       465    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#       465    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:311(__enter__)
#       465    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:318(__exit__)
#      1860    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#       378    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:35(_new_module)
#       480    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:369(__init__)
#       824    0.001    0.000    0.010    0.000 <frozen importlib._bootstrap>:403(cached)
#       739    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:416(parent)
#       465    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#        20    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:433(spec_from_loader)
#       465    0.003    0.000    0.016    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#   465/462    0.001    0.000    0.095    0.000 <frozen importlib._bootstrap>:564(module_from_spec)
#       481    0.001    0.000    0.005    0.000 <frozen importlib._bootstrap>:58(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:622(_load_backward_compatible)
#     466/7    0.003    0.000    0.850    0.121 <frozen importlib._bootstrap>:651(_load_unlocked)
#       479    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:707(find_spec)
#        19    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:728(create_module)
#        19    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:736(exec_module)
#        19    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:753(is_package)
#      1147    0.003    0.000    0.004    0.000 <frozen importlib._bootstrap>:78(acquire)
#       460    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:780(find_spec)
#      1412    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:843(__enter__)
#      1412    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:847(__exit__)
#        13    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:861(_find_spec_legacy)
#       479    0.005    0.000    0.151    0.000 <frozen importlib._bootstrap>:870(_find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:917(_sanity_check)
#     483/8    0.004    0.000    0.855    0.107 <frozen importlib._bootstrap>:936(_find_and_load_unlocked)
#     483/8    0.008    0.000    0.856    0.107 <frozen importlib._bootstrap>:966(_find_and_load)
#         1    0.000    0.000    0.028    0.028 <frozen importlib._bootstrap>:982(_gcd_import)
# 2608/1532    0.003    0.000    0.315    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#        12    0.002    0.000    0.013    0.001 <frozen importlib._bootstrap_external>:106(_write_atomic)
#        56    0.005    0.000    0.010    0.000 <frozen importlib._bootstrap_external>:1067(_path_hooks)
#       857    0.001    0.000    0.012    0.000 <frozen importlib._bootstrap_external>:1080(_path_importer_cache)
#       460    0.003    0.000    0.142    0.000 <frozen importlib._bootstrap_external>:1117(_get_spec)
#       460    0.001    0.000    0.143    0.000 <frozen importlib._bootstrap_external>:1149(find_spec)
#        56    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1196(__init__)
#       448    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1202(<genexpr>)
#       446    0.001    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:1228(_get_spec)
#       780    0.009    0.000    0.127    0.000 <frozen importlib._bootstrap_external>:1233(find_spec)
#        56    0.001    0.000    0.010    0.000 <frozen importlib._bootstrap_external>:1281(_fill_cache)
#        56    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1310(<setcomp>)
#        56    0.000    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:1322(path_hook_for_FileFinder)
#       756    0.004    0.000    0.012    0.000 <frozen importlib._bootstrap_external>:263(cache_from_source)
#       446    0.001    0.000    0.009    0.000 <frozen importlib._bootstrap_external>:361(_get_cached)
#       780    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:37(_relax_case)
#        12    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:373(_calc_mode)
#       378    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:393(_check_name_wrapper)
#       378    0.006    0.000    0.007    0.000 <frozen importlib._bootstrap_external>:430(_validate_bytecode_header)
#        24    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:47(_w_long)
#       366    0.001    0.000    0.072    0.000 <frozen importlib._bootstrap_external>:485(_compile_bytecode)
#        12    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:497(_code_to_bytecode)
#       744    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:52(_r_long)
#       446    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:524(spec_from_file_location)
#      3696    0.004    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:57(_path_join)
#      3696    0.004    0.000    0.006    0.000 <frozen importlib._bootstrap_external>:59(<listcomp>)
#       768    0.003    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:63(_path_split)
#       378    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:669(create_module)
#     378/6    0.002    0.000    0.847    0.141 <frozen importlib._bootstrap_external>:672(exec_module)
#        12    0.000    0.000    0.033    0.003 <frozen importlib._bootstrap_external>:735(source_to_code)
#       378    0.004    0.000    0.255    0.001 <frozen importlib._bootstrap_external>:743(get_code)
#      1808    0.003    0.000    0.122    0.000 <frozen importlib._bootstrap_external>:75(_path_stat)
#       378    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:800(__init__)
#       378    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:825(get_filename)
#       390    0.062    0.000    0.089    0.000 <frozen importlib._bootstrap_external>:830(get_data)
#       378    0.001    0.000    0.025    0.000 <frozen importlib._bootstrap_external>:840(path_stats)
#        12    0.000    0.000    0.016    0.001 <frozen importlib._bootstrap_external>:845(_cache_bytecode)
#       638    0.001    0.000    0.045    0.000 <frozen importlib._bootstrap_external>:85(_path_is_mode_type)
#        12    0.000    0.000    0.015    0.001 <frozen importlib._bootstrap_external>:850(set_data)
#        68    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:908(__init__)
#        68    0.000    0.000    0.075    0.001 <frozen importlib._bootstrap_external>:919(create_module)
#     68/45    0.000    0.000    0.120    0.003 <frozen importlib._bootstrap_external>:927(exec_module)
#       570    0.001    0.000    0.041    0.000 <frozen importlib._bootstrap_external>:94(_path_isfile)
#        68    0.000    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:99(_path_isdir)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#        54    0.000    0.000    0.000    0.000 <string>:12(__new__)
#         1    0.000    0.000    0.000    0.000 <string>:2(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:2(AsyncContextManager)
#         1    0.000    0.000    0.000    0.000 <string>:5(ArgInfo)
#         1    0.000    0.000    0.000    0.000 <string>:5(ArgSpec)
#         1    0.000    0.000    0.000    0.000 <string>:5(Arguments)
#         1    0.000    0.000    0.000    0.000 <string>:5(Attribute)
#         1    0.000    0.000    0.000    0.000 <string>:5(ClosureVars)
#         1    0.000    0.000    0.000    0.000 <string>:5(Components)
#         1    0.000    0.000    0.000    0.000 <string>:5(DecimalTuple)
#         1    0.000    0.000    0.000    0.000 <string>:5(DefragResult)
#         1    0.000    0.000    0.000    0.000 <string>:5(DeprecatedOption)
#         1    0.000    0.000    0.000    0.000 <string>:5(FrameInfo)
#         1    0.000    0.000    0.000    0.000 <string>:5(FullArgSpec)
#         1    0.000    0.000    0.000    0.000 <string>:5(Match)
#         1    0.000    0.000    0.000    0.000 <string>:5(Mismatch)
#         1    0.000    0.000    0.000    0.000 <string>:5(NamedAgg)
#         1    0.000    0.000    0.000    0.000 <string>:5(OutputKey)
#         1    0.000    0.000    0.000    0.000 <string>:5(ParseResult)
#         1    0.000    0.000    0.000    0.000 <string>:5(RegisteredOption)
#         1    0.000    0.000    0.000    0.000 <string>:5(SplitResult)
#         1    0.000    0.000    0.000    0.000 <string>:5(TokenInfo)
#         1    0.000    0.000    0.000    0.000 <string>:5(Traceback)
#         1    0.000    0.000    0.000    0.000 <string>:5(_Instruction)
#         1    0.000    0.000    0.000    0.000 <string>:5(_LoggingWatcher)
#         1    0.000    0.000    0.000    0.000 <string>:5(interface)
#         1    0.000    0.000    0.000    0.000 <string>:5(uname_result)
#         1    0.000    0.000    0.000    0.000 <string>:5(usage)
#         1    0.000    0.000    0.000    0.000 __config__.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 __future__.py:48(<module>)
#         1    0.000    0.000    0.000    0.000 __future__.py:78(_Feature)
#         9    0.000    0.000    0.000    0.000 __future__.py:79(__init__)
#        28    0.000    0.000    0.419    0.015 __init__.py:1(<module>)
#         1    0.000    0.000    0.013    0.013 __init__.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:10(PerformanceWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:1008(FileHandler)
#         1    0.000    0.000    0.000    0.000 __init__.py:103(EmptyDataError)
#         1    0.000    0.000    0.272    0.272 __init__.py:106(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1077(_StderrHandler)
#         1    0.000    0.000    0.028    0.028 __init__.py:108(import_module)
#         1    0.000    0.000    0.000    0.000 __init__.py:1083(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:11(DeprecatedTzFormatWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:110(ParserWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:1101(PlaceHolder)
#         1    0.000    0.000    0.000    0.000 __init__.py:1143(Manager)
#         1    0.000    0.000    0.000    0.000 __init__.py:1148(__init__)
#         1    0.000    0.000    0.022    0.022 __init__.py:124(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1251(Logger)
#         1    0.000    0.000    0.000    0.000 __init__.py:1266(__init__)
#         1    0.000    0.000    0.052    0.052 __init__.py:13(<module>)
#        14    0.000    0.000    0.000    0.000 __init__.py:139(_check_size)
#         1    0.000    0.000    0.010    0.010 __init__.py:15(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:151(MergeError)
#         1    0.000    0.000    0.000    0.000 __init__.py:151(py_object)
#         1    0.000    0.000    0.000    0.000 __init__.py:1574(RootLogger)
#         1    0.000    0.000    0.000    0.000 __init__.py:158(AccessorRegistrationWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:1580(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1588(LoggerAdapter)
#         1    0.000    0.000    0.000    0.000 __init__.py:16(UnsupportedFunctionCall)
#         1    0.000    0.000    0.000    0.000 __init__.py:160(c_short)
#         1    0.000    0.000    0.000    0.000 __init__.py:164(AbstractMethodError)
#         1    0.000    0.000    0.000    0.000 __init__.py:164(c_ushort)
#         1    0.000    0.000    0.000    0.000 __init__.py:168(c_long)
#         1    0.000    0.000    0.000    0.000 __init__.py:172(c_ulong)
#         1    0.000    0.000    0.000    0.000 __init__.py:189(c_float)
#         2    0.000    0.000    0.000    0.000 __init__.py:190(_checkLevel)
#         1    0.000    0.000    0.006    0.006 __init__.py:192(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:193(c_double)
#         1    0.000    0.000    0.000    0.000 __init__.py:1964(NullHandler)
#         1    0.000    0.000    0.000    0.000 __init__.py:197(c_longdouble)
#         3    0.000    0.000    0.011    0.004 __init__.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:206(UTC)
#         1    0.000    0.000    0.000    0.000 __init__.py:207(c_longlong)
#         1    0.000    0.000    0.000    0.000 __init__.py:21(__deprecated_private_func)
#         1    0.000    0.000    0.000    0.000 __init__.py:21(_testing)
#         1    0.000    0.000    0.000    0.000 __init__.py:211(c_ulonglong)
#         1    0.000    0.000    0.000    0.000 __init__.py:218(c_ubyte)
#         1    0.000    0.000    0.000    0.000 __init__.py:219(_acquireLock)
#        40    0.000    0.000    0.000    0.000 __init__.py:221(_get_frame_op_default_axis)
#         1    0.000    0.000    0.000    0.000 __init__.py:225(c_byte)
#         1    0.000    0.000    0.000    0.000 __init__.py:228(_releaseLock)
#         1    0.000    0.000    0.000    0.000 __init__.py:230(c_char)
#         1    0.000    0.000    0.000    0.000 __init__.py:235(c_char_p)
#         1    0.000    0.000    0.000    0.000 __init__.py:239(LogRecord)
#         1    0.000    0.000    0.000    0.000 __init__.py:239(_sanity_check)
#         1    0.000    0.000    0.004    0.004 __init__.py:24(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:24(UnsortedIndexError)
#         1    0.000    0.000    0.000    0.000 __init__.py:241(c_void_p)
#        62    0.000    0.000    0.000    0.000 __init__.py:246(_get_opstr)
#         1    0.000    0.000    0.000    0.000 __init__.py:246(c_bool)
#         1    0.000    0.000    0.000    0.000 __init__.py:251(c_wchar_p)
#         1    0.000    0.000    0.000    0.000 __init__.py:256(c_wchar)
#         1    0.000    0.000    0.000    0.000 __init__.py:259(_reset_cache)
#         1    0.000    0.000    0.013    0.013 __init__.py:26(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:268(Panel)
#         1    0.000    0.000    0.000    0.000 __init__.py:271(SparseDataFrame)
#         1    0.000    0.000    0.000    0.000 __init__.py:274(SparseSeries)
#         1    0.000    0.000    0.000    0.000 __init__.py:277(__numpy)
#         1    0.000    0.000    0.000    0.000 __init__.py:278(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:28(RTLD_for_MKL)
#       212    0.000    0.000    0.000    0.000 __init__.py:28(set_function_name)
#         1    0.000    0.000    0.000    0.000 __init__.py:29(__init__)
#        96    0.000    0.000    0.000    0.000 __init__.py:292(_get_op_name)
#         9    0.000    0.000    0.715    0.079 __init__.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:301(__Datetime)
#         2    0.000    0.000    0.000    0.000 __init__.py:302(loads)
#         1    0.000    0.000    0.000    0.000 __init__.py:306(_CountryTimezoneDict)
#         1    0.000    0.000    0.000    0.000 __init__.py:31(ParserError)
#         1    0.000    0.000    0.000    0.000 __init__.py:311(CDLL)
#         1    0.000    0.000    0.000    0.000 __init__.py:318(__DatetimeSub)
#         1    0.000    0.000    0.008    0.008 __init__.py:32(__enter__)
#         2    0.000    0.000    0.000    0.000 __init__.py:332(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:338(__SparseArray)
#         2    0.000    0.000    0.000    0.000 __init__.py:342(_FuncPtr)
#         1    0.000    0.000    0.000    0.000 __init__.py:347(__SparseArraySub)
#        26    0.001    0.000    0.018    0.001 __init__.py:357(namedtuple)
#         1    0.000    0.000    0.000    0.000 __init__.py:358(__getattr__)
#         3    0.000    0.000    0.000    0.000 __init__.py:36(__deprecate_private_class)
#         1    0.000    0.000    0.000    0.000 __init__.py:365(_CountryNameDict)
#         1    0.000    0.000    0.000    0.000 __init__.py:365(__getitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:371(PyDLL)
#         1    0.000    0.000    0.000    0.000 __init__.py:378(PercentStyle)
#         1    0.000    0.000    0.000    0.000 __init__.py:380(WinDLL)
#         1    0.000    0.000    0.000    0.000 __init__.py:384(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:389(HRESULT)
#         1    0.000    0.000    0.000    0.000 __init__.py:391(_FixedOffset)
#         1    0.000    0.000    0.000    0.000 __init__.py:393(StrFormatStyle)
#         1    0.000    0.000    0.000    0.000 __init__.py:402(OleDLL)
#         1    0.000    0.000    0.000    0.000 __init__.py:402(StringTemplateStyle)
#         1    0.000    0.000    0.006    0.006 __init__.py:41(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:411(LibraryLoader)
#         4    0.000    0.000    0.000    0.000 __init__.py:412(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:415(__getattr__)
#       139    0.000    0.000    0.000    0.000 __init__.py:420(<genexpr>)
#       139    0.000    0.000    0.000    0.000 __init__.py:422(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:426(Formatter)
#         1    0.000    0.000    0.000    0.000 __init__.py:43(__exit__)
#         3    0.000    0.000    0.000    0.000 __init__.py:43(private_class)
#         1    0.000    0.000    0.067    0.067 __init__.py:45(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:45(DtypeWarning)
#         1    0.000    0.000    0.000    0.000 __init__.py:470(__init__)
#         3    0.000    0.000    0.000    0.000 __init__.py:476(PYFUNCTYPE)
#         3    0.000    0.000    0.000    0.000 __init__.py:477(CFunctionType)
#        16    0.000    0.000    0.000    0.000 __init__.py:487(_arith_method_SERIES)
#         3    0.000    0.000    0.014    0.005 __init__.py:5(<module>)
#         6    0.000    0.000    0.000    0.000 __init__.py:511(_comp_method_SERIES)
#         6    0.000    0.000    0.000    0.000 __init__.py:537(_bool_method_SERIES)
#        22    0.000    0.000    0.003    0.000 __init__.py:559(_flex_method_SERIES)
#         1    0.000    0.000    0.002    0.002 __init__.py:57(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:599(BufferingFormatter)
#         1    0.000    0.000    0.000    0.000 __init__.py:641(Filter)
#         1    0.000    0.000    0.000    0.000 __init__.py:678(Filterer)
#         2    0.000    0.000    0.000    0.000 __init__.py:683(__init__)
#         3    0.000    0.000    0.150    0.050 __init__.py:7(<module>)
#         1    0.000    0.000    0.006    0.006 __init__.py:71(<module>)
#         3    0.000    0.000    0.000    0.000 __init__.py:73(CFUNCTYPE)
#        34    0.000    0.000    0.004    0.000 __init__.py:737(_arith_method_FRAME)
#         1    0.000    0.000    0.000    0.000 __init__.py:750(_addHandlerRef)
#         1    0.000    0.000    0.000    0.000 __init__.py:760(Handler)
#         1    0.000    0.000    0.000    0.000 __init__.py:769(__init__)
#         6    0.000    0.000    0.001    0.000 __init__.py:791(_flex_comp_method_FRAME)
#         1    0.000    0.000    0.000    0.000 __init__.py:798(createLock)
#         6    0.000    0.000    0.000    0.000 __init__.py:826(_comp_method_FRAME)
#         1    0.000    0.000    0.000    0.000 __init__.py:87(is_platform_32bit)
#         3    0.000    0.000    0.003    0.001 __init__.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:949(StreamHandler)
#         1    0.000    0.000    0.006    0.006 __init__.py:97(<module>)
#         3    0.000    0.000    0.000    0.000 __init__.py:99(CFunctionType)
#         3    0.000    0.000    0.000    0.000 __init__.py:99(_import_lzma)
#         1    0.000    0.000    0.003    0.003 _add_newdocs.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 _add_newdocs.py:6702(numeric_type_aliases)
#        16    0.000    0.000    0.000    0.000 _add_newdocs.py:6703(type_aliases_gen)
#        19    0.000    0.000    0.000    0.000 _add_newdocs.py:6738(add_newdoc_for_scalar_type)
#        27    0.000    0.000    0.000    0.000 _add_newdocs.py:6743(<genexpr>)
#        34    0.000    0.000    0.000    0.000 _add_newdocs.py:6744(<genexpr>)
#       8/7    0.000    0.000    0.000    0.000 _asarray.py:16(asarray)
#         2    0.000    0.000    0.000    0.000 _asarray.py:223(require)
#         2    0.000    0.000    0.000    0.000 _asarray.py:300(<setcomp>)
#         1    0.000    0.000    0.000    0.000 _asarray.py:5(<module>)
#         1    0.000    0.000    0.015    0.015 _base.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _base.py:338(_BaseExcelReader)
#         1    0.000    0.000    0.000    0.000 _base.py:533(ExcelWriter)
#         1    0.000    0.000    0.004    0.004 _base.py:784(ExcelFile)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:11(getpreferredencoding)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:252(__subclasshook__)
#        13    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:349(__subclasshook__)
#        42    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:406(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:657(get)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:664(__contains__)
#        15    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#         9    0.000    0.000    0.000    0.000 _collections_abc.py:92(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _common.py:1(<module>)
#         6    0.000    0.000    0.000    0.000 _common.py:13(tzname_in_python2)
#         3    0.000    0.000    0.000    0.000 _common.py:132(_validate_fromutc_inputs)
#         1    0.000    0.000    0.000    0.000 _common.py:149(_tzinfo)
#         1    0.000    0.000    0.000    0.000 _common.py:267(tzrangebase)
#         1    0.000    0.000    0.000    0.000 _common.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _common.py:6(weekday)
#         7    0.000    0.000    0.000    0.000 _common.py:9(__init__)
#        43    0.000    0.000    0.000    0.000 _compat_pickle.py:165(<genexpr>)
#        86    0.000    0.000    0.000    0.000 _compat_pickle.py:167(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _compat_pickle.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 _compression.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _compression.py:33(DecompressReader)
#         1    0.000    0.000    0.000    0.000 _compression.py:9(BaseStream)
#         1    0.000    0.000    0.001    0.001 _core.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _core.py:541(PlotAccessor)
#         1    0.000    0.000    0.000    0.000 _datasource.py:144(_FileOpeners)
#         1    0.000    0.000    0.000    0.000 _datasource.py:169(__init__)
#         1    0.000    0.000    0.000    0.000 _datasource.py:272(DataSource)
#         1    0.000    0.000    0.010    0.010 _datasource.py:36(<module>)
#         1    0.000    0.000    0.000    0.000 _datasource.py:626(Repository)
#         1    0.000    0.000    0.016    0.016 _decorators.py:1(<module>)
#         7    0.000    0.000    0.000    0.000 _decorators.py:172(_deprecate_kwarg)
#         3    0.000    0.000    0.000    0.000 _decorators.py:221(rewrite_axis_style_signature)
#         3    0.000    0.000    0.000    0.000 _decorators.py:224(decorate)
#         1    0.000    0.000    0.001    0.001 _decorators.py:24(deprecate)
#         1    0.000    0.000    0.000    0.000 _decorators.py:254(Substitution)
#       161    0.000    0.000    0.000    0.000 _decorators.py:283(__init__)
#       161    0.001    0.000    0.001    0.000 _decorators.py:289(__call__)
#         1    0.000    0.000    0.000    0.000 _decorators.py:301(Appender)
#       432    0.000    0.000    0.000    0.000 _decorators.py:323(__init__)
#       432    0.001    0.000    0.050    0.000 _decorators.py:330(__call__)
#         3    0.000    0.000    0.000    0.000 _decorators.py:338(indent)
#         7    0.000    0.000    0.000    0.000 _decorators.py:99(deprecate_kwarg)
#         1    0.000    0.000    0.014    0.014 _distributor_init.py:10(<module>)
#        18    0.000    0.000    0.000    0.000 _dtype.py:319(_name_includes_bit_suffix)
#        18    0.000    0.000    0.000    0.000 _dtype.py:333(_name_get)
#        34    0.000    0.000    0.000    0.000 _dtype.py:36(_kind_name)
#         4    0.000    0.000    0.000    0.000 _dtype.py:46(__str__)
#         1    0.000    0.000    0.000    0.000 _dtype.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 _dtype_ctypes.py:24(<module>)
#        13    0.000    0.000    0.000    0.000 _dtype_ctypes.py:69(_from_ctypes_scalar)
#        13    0.000    0.000    0.000    0.000 _dtype_ctypes.py:97(dtype_from_ctypes_type)
#         1    0.000    0.000    0.000    0.000 _endian.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _endian.py:23(_swapped_meta)
#         1    0.000    0.000    0.000    0.000 _endian.py:46(BigEndianStructure)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:101(_UFuncOutputCastingError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:120(TooHardError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:125(AxisError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:143(_ArrayMemoryError)
#         6    0.000    0.000    0.000    0.000 _exceptions.py:17(_display_as_base)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:34(UFuncTypeError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:40(_UFuncBinaryResolutionError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:56(_UFuncNoLoopError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:7(<module>)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:74(_UFuncCastingError)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:83(_UFuncInputCastingError)
#         1    0.000    0.000    0.000    0.000 _factories.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _factories.py:13(__call__)
#         1    0.000    0.000    0.000    0.000 _factories.py:19(_TzFactory)
#         1    0.000    0.000    0.000    0.000 _factories.py:25(_TzOffsetFactory)
#         1    0.000    0.000    0.000    0.000 _factories.py:26(__init__)
#         1    0.000    0.000    0.000    0.000 _factories.py:55(_TzStrFactory)
#         1    0.000    0.000    0.000    0.000 _factories.py:56(__init__)
#         1    0.000    0.000    0.000    0.000 _factories.py:8(_TzSingleton)
#         1    0.000    0.000    0.000    0.000 _factories.py:9(__init__)
#         1    0.000    0.000    0.000    0.000 _globals.py:17(<module>)
#         1    0.000    0.000    0.000    0.000 _globals.py:32(ModuleDeprecationWarning)
#         1    0.000    0.000    0.000    0.000 _globals.py:46(VisibleDeprecationWarning)
#         1    0.000    0.000    0.000    0.000 _globals.py:59(_NoValueType)
#         1    0.000    0.000    0.000    0.000 _globals.py:67(__new__)
#         9    0.000    0.000    0.000    0.000 _globals.py:77(__repr__)
#        90    0.000    0.000    0.000    0.000 _inspect.py:133(strseq)
#        40    0.000    0.000    0.000    0.000 _inspect.py:142(formatargspec)
#        15    0.000    0.000    0.000    0.000 _inspect.py:144(<lambda>)
#        16    0.000    0.000    0.000    0.000 _inspect.py:145(<lambda>)
#        59    0.000    0.000    0.000    0.000 _inspect.py:146(<lambda>)
#       616    0.000    0.000    0.000    0.000 _inspect.py:15(ismethod)
#       616    0.000    0.000    0.000    0.000 _inspect.py:28(isfunction)
#       612    0.000    0.000    0.000    0.000 _inspect.py:43(iscode)
#       612    0.001    0.000    0.002    0.000 _inspect.py:67(getargs)
#         1    0.000    0.000    0.000    0.000 _inspect.py:7(<module>)
#       616    0.001    0.000    0.003    0.000 _inspect.py:98(getargspec)
#         1    0.000    0.000    0.000    0.000 _internal.py:206(dummy_ctype)
#         1    0.000    0.000    0.000    0.000 _internal.py:218(_getintp_ctype)
#         1    0.000    0.000    0.000    0.000 _internal.py:241(_missing_ctypes)
#         1    0.000    0.000    0.000    0.000 _internal.py:245(c_void_p)
#         1    0.000    0.000    0.000    0.000 _internal.py:250(_ctypes)
#         1    0.000    0.000    0.000    0.000 _internal.py:526(_Stream)
#         1    0.000    0.000    0.015    0.015 _internal.py:6(<module>)
#        50    0.000    0.000    0.000    0.000 _internal.py:784(_ufunc_doc_signature_formatter)
#        78    0.000    0.000    0.000    0.000 _internal.py:795(<genexpr>)
#        21    0.000    0.000    0.000    0.000 _internal.py:830(npy_ctypes_check)
#         1    0.000    0.000    0.000    0.000 _internal.py:848(recursive)
#         1    0.000    0.000    0.000    0.000 _iotools.py:176(LineSplitter)
#         1    0.000    0.000    0.000    0.000 _iotools.py:276(NameValidator)
#         1    0.000    0.000    0.000    0.000 _iotools.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _iotools.py:470(ConverterError)
#         1    0.000    0.000    0.000    0.000 _iotools.py:478(ConverterLockError)
#         1    0.000    0.000    0.000    0.000 _iotools.py:486(ConversionWarning)
#         1    0.000    0.000    0.000    0.000 _iotools.py:499(StringConverter)
#         1    0.000    0.000    0.004    0.004 _json.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _json.py:103(Writer)
#         1    0.000    0.000    0.000    0.000 _json.py:1040(FrameParser)
#         1    0.000    0.000    0.000    0.000 _json.py:171(SeriesWriter)
#         1    0.000    0.000    0.000    0.000 _json.py:203(FrameWriter)
#         1    0.000    0.000    0.000    0.000 _json.py:249(JSONTableWriter)
#         1    0.000    0.000    0.000    0.000 _json.py:615(JsonReader)
#         1    0.000    0.000    0.000    0.000 _json.py:791(Parser)
#         1    0.000    0.000    0.000    0.000 _json.py:996(SeriesParser)
#         2    0.000    0.000    0.000    0.000 _methods.py:44(_any)
#         1    0.000    0.000    0.001    0.001 _methods.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 _misc.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _misc.py:423(_Options)
#         1    0.000    0.000    0.000    0.000 _misc.py:436(__init__)
#         1    0.000    0.000    0.002    0.002 _normalize.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 _odfreader.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _odfreader.py:11(_ODFReader)
#         1    0.000    0.000    0.000    0.000 _openpyxl.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _openpyxl.py:12(_OpenpyxlWriter)
#         1    0.000    0.000    0.000    0.000 _openpyxl.py:475(_OpenpyxlReader)
#         1    0.000    0.000    0.000    0.000 _optional.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _optional.py:36(_get_version)
#         1    0.000    0.000    0.028    0.028 _optional.py:47(import_optional_dependency)
#         1    0.000    0.000    0.000    0.000 _parser.py:1377(_tzparser)
#         1    0.000    0.000    0.000    0.000 _parser.py:1379(_result)
#         1    0.000    0.000    0.000    0.000 _parser.py:1384(_attr)
#         1    0.000    0.000    0.000    0.000 _parser.py:1595(ParserError)
#         1    0.000    0.000    0.000    0.000 _parser.py:1607(UnknownTimezoneWarning)
#         1    0.000    0.000    0.000    0.000 _parser.py:225(_resultbase)
#         1    0.000    0.000    0.000    0.000 _parser.py:247(parserinfo)
#         1    0.000    0.000    0.001    0.001 _parser.py:30(<module>)
#         1    0.000    0.000    0.000    0.000 _parser.py:300(__init__)
#         7    0.000    0.000    0.000    0.000 _parser.py:315(_convert)
#         1    0.000    0.000    0.000    0.000 _parser.py:400(_ymd)
#         1    0.000    0.000    0.000    0.000 _parser.py:574(parser)
#         1    0.000    0.000    0.000    0.000 _parser.py:575(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:58(_timelex)
#         1    0.000    0.000    0.000    0.000 _parser.py:667(_result)
#         1    0.000    0.000    0.021    0.021 _pickle.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 _pocketfft.py:29(<module>)
#         1    0.000    0.000    0.000    0.000 _polybase.py:19(ABCPolyBase)
#         1    0.000    0.000    0.000    0.000 _polybase.py:8(<module>)
#         1    0.000    0.000    0.001    0.001 _print_versions.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _pytesttester.py:16(PytestTester)
#         1    0.000    0.000    0.000    0.000 _pytesttester.py:21(__init__)
#         1    0.000    0.000    0.000    0.000 _pytesttester.py:29(<module>)
#         1    0.000    0.000    0.000    0.000 _pytesttester.py:47(PytestTester)
#         1    0.000    0.000    0.000    0.000 _pytesttester.py:5(<module>)
#        10    0.000    0.000    0.000    0.000 _pytesttester.py:77(__init__)
#         1    0.000    0.000    0.000    0.000 _pyxlsb.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _pyxlsb.py:9(_PyxlsbReader)
#         1    0.000    0.000    0.000    0.000 _ranges.py:4(<module>)
#        36    0.000    0.000    0.000    0.000 _string_helpers.py:16(english_lower)
#        14    0.000    0.000    0.000    0.000 _string_helpers.py:44(english_upper)
#         1    0.000    0.000    0.000    0.000 _string_helpers.py:5(<module>)
#        14    0.000    0.000    0.000    0.000 _string_helpers.py:72(english_capitalize)
#         1    0.000    0.000    0.000    0.000 _string_helpers.py:9(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _table_schema.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 _tester.py:3(<module>)
#         1    0.000    0.000    0.002    0.002 _testing.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _testing.py:2141(optional_args)
#         1    0.000    0.000    0.000    0.000 _testing.py:2504(RNGContext)
#         1    0.000    0.000    0.000    0.000 _testing.py:2630(SubclassedSeries)
#         1    0.000    0.000    0.000    0.000 _testing.py:2642(SubclassedDataFrame)
#         1    0.000    0.000    0.000    0.000 _testing.py:2654(SubclassedCategorical)
#         1    0.000    0.000    0.000    0.000 _testing.py:80(set_testing_mode)
#         6    0.000    0.000    0.000    0.000 _type_aliases.py:113(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _type_aliases.py:115(_add_aliases)
#         1    0.000    0.000    0.000    0.000 _type_aliases.py:154(_add_integer_aliases)
#         1    0.000    0.000    0.000    0.000 _type_aliases.py:187(_set_up_aliases)
#        30    0.000    0.000    0.000    0.000 _type_aliases.py:238(_add_array_type)
#         1    0.000    0.000    0.001    0.001 _type_aliases.py:24(<module>)
#         1    0.000    0.000    0.000    0.000 _type_aliases.py:246(_set_array_types)
#         1    0.000    0.000    0.000    0.000 _type_aliases.py:36(TypeNADict)
#         1    0.000    0.000    0.000    0.000 _type_aliases.py:63(<setcomp>)
#        16    0.000    0.000    0.000    0.000 _type_aliases.py:66(_bits_of)
#        32    0.000    0.000    0.000    0.000 _type_aliases.py:68(<genexpr>)
#        16    0.000    0.000    0.000    0.000 _type_aliases.py:79(bitname)
#         1    0.000    0.000    0.000    0.000 _type_aliases.py:95(_add_types)
#         1    0.000    0.000    0.003    0.003 _typing.py:1(<module>)
#         8    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:36(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:368(_unspecified)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:375(errstate)
#         8    0.000    0.000    0.000    0.000 _ufunc_config.py:39(seterr)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:441(__enter__)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:452(_setdef)
#         1    0.000    0.000    0.000    0.000 _ufunc_config.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 _util.py:1(<module>)
#         3    0.000    0.000    0.000    0.000 _util.py:8(register_writer)
#         1    0.000    0.000    0.001    0.001 _validators.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 _version.py:18(NumpyVersion)
#         1    0.000    0.000    0.000    0.000 _version.py:20(get_versions)
#         1    0.000    0.000    0.000    0.000 _version.py:22(get_versions)
#         1    0.000    0.000    0.000    0.000 _version.py:4(<module>)
#         3    0.000    0.000    0.007    0.002 _version.py:7(<module>)
#       137    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#       137    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#       137    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#       856    0.002    0.000    0.002    0.000 _weakrefset.py:36(__init__)
#       137    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#       237    0.000    0.000    0.001    0.000 _weakrefset.py:58(__iter__)
#       454    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#       158    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#         1    0.000    0.000    0.000    0.000 _xlrd.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _xlrd.py:10(_XlrdReader)
#         1    0.000    0.000    0.002    0.002 _xlsxwriter.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _xlsxwriter.py:160(_XlsxWriter)
#         1    0.000    0.000    0.000    0.000 _xlsxwriter.py:7(_XlsxStyler)
#         1    0.000    0.000    0.000    0.000 _xlwt.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _xlwt.py:7(_XlwtWriter)
#       263    0.004    0.000    0.024    0.000 abc.py:132(__new__)
#       263    0.001    0.000    0.004    0.000 abc.py:135(<setcomp>)
#        17    0.000    0.000    0.001    0.000 abc.py:151(register)
#        18    0.000    0.000    0.001    0.000 abc.py:180(__instancecheck__)
#   250/110    0.001    0.000    0.004    0.000 abc.py:196(__subclasscheck__)
#        99    0.000    0.000    0.000    0.000 abc.py:9(abstractmethod)
#         1    0.000    0.000    0.007    0.007 accessor.py:1(<module>)
#        16    0.000    0.000    0.000    0.000 accessor.py:118(delegate_names)
#         1    0.000    0.000    0.000    0.000 accessor.py:13(DirNamesMixin)
#         1    0.000    0.000    0.000    0.000 accessor.py:14(BaseAccessor)
#        16    0.000    0.000    0.001    0.000 accessor.py:146(add_delegate_accessors)
#         1    0.000    0.000    0.000    0.000 accessor.py:159(CachedAccessor)
#         8    0.000    0.000    0.000    0.000 accessor.py:179(__init__)
#         1    0.000    0.000    0.000    0.000 accessor.py:187(SparseFrameAccessor)
#         1    0.000    0.000    0.000    0.000 accessor.py:25(SparseAccessor)
#         1    0.000    0.000    0.000    0.000 accessor.py:49(PandasDelegate)
#         1    0.000    0.000    0.001    0.001 accessor.py:6(<module>)
#        16    0.000    0.000    0.001    0.000 accessor.py:63(_add_delegate_accessors)
#       118    0.000    0.000    0.000    0.000 accessor.py:83(_create_delegator_property)
#        67    0.000    0.000    0.000    0.000 accessor.py:97(_create_delegator_method)
#         1    0.000    0.000    0.000    0.000 accessors.py:120(DatetimeProperties)
#         1    0.000    0.000    0.000    0.000 accessors.py:191(TimedeltaProperties)
#         1    0.000    0.000    0.000    0.000 accessors.py:25(Properties)
#         1    0.000    0.000    0.000    0.000 accessors.py:282(PeriodProperties)
#         1    0.000    0.000    0.001    0.001 accessors.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 accessors.py:303(CombinedDatetimelikeProperties)
#         1    0.000    0.000    0.000    0.000 algorithms.py:1073(SelectN)
#         1    0.000    0.000    0.000    0.000 algorithms.py:1099(SelectNSeries)
#         1    0.000    0.000    0.000    0.000 algorithms.py:1165(SelectNFrame)
#        12    0.000    0.000    0.000    0.000 algorithms.py:1275(_view_wrapper)
#         1    0.000    0.000    0.034    0.034 algorithms.py:4(<module>)
#         1    0.000    0.000    0.001    0.001 align.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 align.py:51(_filter_special_cases)
#         1    0.000    0.000    0.035    0.035 api.py:1(<module>)
#         6    0.000    0.000    0.423    0.071 api.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 argparse.py:1005(_HelpAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:1024(_VersionAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:1050(_SubParsersAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:1052(_ChoicesPseudoAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:109(_AttributeHolder)
#         1    0.000    0.000    0.000    0.000 argparse.py:1146(FileType)
#         1    0.000    0.000    0.000    0.000 argparse.py:1200(Namespace)
#         1    0.000    0.000    0.000    0.000 argparse.py:1220(_ActionsContainer)
#         1    0.000    0.000    0.000    0.000 argparse.py:150(HelpFormatter)
#         1    0.000    0.000    0.000    0.000 argparse.py:1527(_ArgumentGroup)
#         1    0.000    0.000    0.000    0.000 argparse.py:1561(_MutuallyExclusiveGroup)
#         1    0.000    0.000    0.000    0.000 argparse.py:1581(ArgumentParser)
#         1    0.000    0.000    0.000    0.000 argparse.py:200(_Section)
#         1    0.000    0.000    0.001    0.001 argparse.py:62(<module>)
#         1    0.000    0.000    0.000    0.000 argparse.py:637(RawDescriptionHelpFormatter)
#         1    0.000    0.000    0.000    0.000 argparse.py:648(RawTextHelpFormatter)
#         1    0.000    0.000    0.000    0.000 argparse.py:659(ArgumentDefaultsHelpFormatter)
#         1    0.000    0.000    0.000    0.000 argparse.py:676(MetavarTypeHelpFormatter)
#         1    0.000    0.000    0.000    0.000 argparse.py:709(ArgumentError)
#         1    0.000    0.000    0.000    0.000 argparse.py:729(ArgumentTypeError)
#         1    0.000    0.000    0.000    0.000 argparse.py:738(Action)
#         1    0.000    0.000    0.000    0.000 argparse.py:829(_StoreAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:864(_StoreConstAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:887(_StoreTrueAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:904(_StoreFalseAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:921(_AppendAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:958(_AppendConstAction)
#         1    0.000    0.000    0.000    0.000 argparse.py:984(_CountAction)
#         3    0.000    0.000    0.000    0.000 array.py:1363(_create_unary_method)
#        17    0.000    0.000    0.000    0.000 array.py:1374(_create_arithmetic_method)
#         8    0.000    0.000    0.000    0.000 array.py:1417(_create_comparison_method)
#         1    0.000    0.000    0.000    0.000 array.py:1455(_add_unary_ops)
#         1    0.000    0.000    0.000    0.000 array.py:1461(_add_comparison_ops)
#         1    0.000    0.000    0.000    0.000 array.py:195(SparseArray)
#         1    0.000    0.000    0.006    0.006 array.py:3(<module>)
#        34    0.000    0.000    0.000    0.000 array_ops.py:119(define_na_arithmetic_op)
#         1    0.000    0.000    0.006    0.006 array_ops.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 arraypad.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1143(IntegerFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1156(BoolFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1166(ComplexFloatingFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1195(_TimelikeFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1221(DatetimeFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1253(TimedeltaFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1258(SubArrayFormat)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1268(StructuredVoidFormat)
#        15    0.000    0.000    0.000    0.000 arrayprint.py:1482(_guarded_repr_or_str)
#        15    0.000    0.000    0.000    0.000 arrayprint.py:1489(_array_str_implementation)
#         2    0.000    0.000    0.000    0.000 arrayprint.py:1562(set_string_function)
#         2    0.000    0.000    0.000    0.000 arrayprint.py:464(_recursive_guard)
#         2    0.000    0.000    0.000    0.000 arrayprint.py:474(decorating_function)
#        15    0.000    0.000    0.000    0.000 arrayprint.py:477(wrapper)
#         1    0.000    0.000    0.001    0.001 arrayprint.py:5(<module>)
# ...
#       460    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#      3040    0.001    0.000    0.001    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _locale._getdefaultlocale}
#         2    0.000    0.000    0.000    0.000 {built-in method _locale.setlocale}
#        52    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#       172    0.000    0.000    0.000    0.000 {built-in method _sre.getlower}
#        24    0.000    0.000    0.000    0.000 {built-in method _struct.calcsize}
#       108    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#       112    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread._set_sentinel}
#       968    0.004    0.000    0.004    0.000 {built-in method _thread.allocate_lock}
#      2310    0.001    0.000    0.001    0.000 {built-in method _thread.get_ident}
#         6    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#   914/903    0.021    0.000    0.117    0.000 {built-in method builtins.__build_class__}
#    372/49    0.001    0.000    0.356    0.007 {built-in method builtins.__import__}
#        72    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#       177    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#      1419    0.001    0.000    0.006    0.000 {built-in method builtins.any}
#        84    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       472    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#       373    0.051    0.000    0.051    0.000 {built-in method builtins.compile}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.delattr}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.dir}
#        45    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#     723/1    0.016    0.000    1.456    1.456 {built-in method builtins.exec}
#     15658    0.008    0.000    0.008    0.000 {built-in method builtins.getattr}
#       359    0.000    0.000    0.000    0.000 {built-in method builtins.globals}
#      7475    0.006    0.000    0.006    0.000 {built-in method builtins.hasattr}
#   695/664    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        27    0.000    0.000    0.000    0.000 {built-in method builtins.id}
# 26075/26007    0.006    0.000    0.007    0.000 {built-in method builtins.isinstance}
# 3621/3114    0.001    0.000    0.005    0.000 {built-in method builtins.issubclass}
# 17444/17268    0.005    0.000    0.442    0.000 {built-in method builtins.len}
#        26    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       729    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        54    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#       516    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#     15880    0.036    0.000    0.036    0.000 {built-in method builtins.print}
#        85    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#      6661    0.003    0.000    0.003    0.000 {built-in method builtins.round}
#      4165    0.003    0.000    0.003    0.000 {built-in method builtins.setattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#       745    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         2    0.000    0.000    0.000    0.000 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method maketrans}
#        12    0.001    0.000    0.001    0.000 {built-in method marshal.dumps}
#       366    0.069    0.000    0.069    0.000 {built-in method marshal.loads}
#         4    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 {built-in method math.exp}
#      6658    0.003    0.000    0.003    0.000 {built-in method math.log}
#         1    0.000    0.000    0.000    0.000 {built-in method math.sqrt}
#         1    0.007    0.007    0.007    0.007 {built-in method mkl._py_mkl_service.get_version}
#      3324    0.003    0.000    0.003    0.000 {built-in method mmh3.hash}
#         1    0.000    0.000    0.000    0.000 {built-in method nt._isdir}
#      1219    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#       154    0.000    0.000    0.000    0.000 {built-in method nt.getcwd}
#        56    0.007    0.000    0.007    0.000 {built-in method nt.listdir}
#        12    0.003    0.000    0.003    0.000 {built-in method nt.open}
#         4    0.000    0.000    0.000    0.000 {built-in method nt.putenv}
#        12    0.005    0.000    0.005    0.000 {built-in method nt.replace}
#      1808    0.120    0.000    0.120    0.000 {built-in method nt.stat}
#        12    0.003    0.000    0.003    0.000 {built-in method nt.unlink}
#         1    0.000    0.000    0.000    0.000 {built-in method nt.urandom}
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#   130/128    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#       298    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.add_docstring}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.set_string_function}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.set_typeDict}
#        12    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        18    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.writers.word_len}
#       279    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getdefaultencoding}
#         6    0.000    0.000    0.000    0.000 {built-in method sys.getsizeof}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getwindowsversion}
#         1    0.000    0.000    0.000    0.000 {built-in method time.localtime}
#         3    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {built-in method utcfromtimestamp}
#         1    0.000    0.000    0.000    0.000 {built-in method winreg.ConnectRegistry}
#         1    0.000    0.000    0.000    0.000 {built-in method winreg.OpenKey}
#         1    0.000    0.000    0.000    0.000 {function Random.seed at 0x0000020BA41DA840}
#         2    0.000    0.000    0.000    0.000 {method 'Close' of 'PyHKEY' objects}
#       278    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#       153    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#        53    0.000    0.000    0.000    0.000 {method '__subclasshook__' of 'object' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#      1776    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#      7096    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        57    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cast' of 'memoryview' objects}
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'collections.OrderedDict' objects}
#         8    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'mappingproxy' objects}
#        60    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      6652    0.410    0.000    0.410    0.000 {method 'count' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        16    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'end' of '_sre.SRE_Match' objects}
#      2015    0.001    0.000    0.001    0.000 {method 'endswith' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'expandtabs' of 'str' objects}
#        36    0.000    0.000    0.000    0.000 {method 'extend' of 'bytearray' objects}
#       267    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#       374    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#       500    0.020    0.000    0.020    0.000 {method 'findall' of '_sre.SRE_Pattern' objects}
# 43150/13911    0.041    0.000    0.494    0.000 {method 'format' of 'str' objects}
#      1316    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#        35    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'groups' of '_sre.SRE_Match' objects}
#      4323    0.002    0.000    0.002    0.000 {method 'index' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       183    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#        28    0.000    0.000    0.000    0.000 {method 'isupper' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#       348    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#      5227    0.002    0.000    0.003    0.000 {method 'join' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#      1280    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        27    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#       267    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#         3    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#       631    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#        50    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#       231    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       390    0.027    0.000    0.027    0.000 {method 'read' of '_io.FileIO' objects}
#      1000    0.001    0.000    0.001    0.000 {method 'readline' of '_io.TextIOWrapper' objects}
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         7    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#       149    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#       130    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#      2937    0.001    0.000    0.001    0.000 {method 'rpartition' of 'str' objects}
#       768    0.001    0.000    0.001    0.000 {method 'rsplit' of 'str' objects}
#      8152    0.002    0.000    0.002    0.000 {method 'rstrip' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'search' of '_sre.SRE_Pattern' objects}
#        40    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        27    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#      2118    0.004    0.000    0.004    0.000 {method 'sort' of 'list' objects}
#        17    0.000    0.000    0.000    0.000 {method 'split' of '_sre.SRE_Pattern' objects}
#        81    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#     22960    0.005    0.000    0.005    0.000 {method 'startswith' of 'str' objects}
#        38    0.000    0.000    0.000    0.000 {method 'strftime' of 'datetime.date' objects}
#      1577    0.001    0.000    0.001    0.000 {method 'strip' of 'str' objects}
#       797    0.024    0.000    0.024    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#        24    0.000    0.000    0.000    0.000 {method 'to_bytes' of 'int' objects}
#         2    0.000    0.000    0.000    0.000 {method 'tolist' of 'memoryview' objects}
#         2    0.000    0.000    0.000    0.000 {method 'toordinal' of 'datetime.date' objects}
#        19    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#        52    0.000    0.000    0.000    0.000 {method 'translate' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#       850    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        46    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        17    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.generic' objects}
#         4    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#        12    0.002    0.000    0.002    0.000 {method 'write' of '_io.FileIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'writerow' of '_csv.writer' objects}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.clean_index_list}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_datetimelike_array}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.to_object_array}
#         7    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.offsets.apply_index_wraps}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.writers.write_csv_rows}
#      3324    0.001    0.000    0.001    0.000 {spookyhash.hash32}

# %%
# 按照函数名排序，只打印前3行函数的信息, 参数还可为小数,表示前百分之几的函数信息 
p.strip_dirs().sort_stats("name").print_stats(3)
# Out:
# Mon Apr  5 23:10:53 2021    result.out
#
#          446188 function calls (409643 primitive calls) in 1.455 seconds
#
#    Ordered by: function name
#    List reduced from 2459 to 3 due to restriction <3>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1195    0.011    0.000    0.011    0.000 {built-in method __new__ of type object at 0x0000000063A2C3F0}
#         3    0.000    0.000    0.000    0.000 {built-in method _csv.register_dialect}
#         1    0.000    0.000    0.000    0.000 {built-in method _csv.writer}

# %%
# 按照运行时间和函数名进行排序
p.strip_dirs().sort_stats("cumulative", "name").print_stats(0.5)
# Out:
# Mon Apr  5 23:10:53 2021    result.out
#
#          446188 function calls (409643 primitive calls) in 1.455 seconds
#
#    Ordered by: cumulative time, function name
#    List reduced from 2459 to 1230 due to restriction <0.5>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     723/1    0.016    0.000    1.456    1.456 {built-in method builtins.exec}
#         1    0.007    0.007    1.456    1.456 0405.py:1(<module>)
#     483/8    0.008    0.000    0.856    0.107 <frozen importlib._bootstrap>:966(_find_and_load)
#     483/8    0.004    0.000    0.855    0.107 <frozen importlib._bootstrap>:936(_find_and_load_unlocked)
#     466/7    0.003    0.000    0.850    0.121 <frozen importlib._bootstrap>:651(_load_unlocked)
#     657/9    0.001    0.000    0.847    0.094 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#     378/6    0.002    0.000    0.847    0.141 <frozen importlib._bootstrap_external>:672(exec_module)
#         9    0.000    0.000    0.715    0.079 __init__.py:3(<module>)
#      1108    0.012    0.000    0.566    0.001 0405.py:45(UpdateSk)
# 43150/13911    0.041    0.000    0.494    0.000 {method 'format' of 'str' objects}
#      6648    0.005    0.000    0.450    0.000 0405.py:28(__str__)
# 17444/17268    0.005    0.000    0.442    0.000 {built-in method builtins.len}
#      6652    0.004    0.000    0.437    0.000 hll.py:136(__len__)
#      6652    0.014    0.000    0.429    0.000 hll.py:143(card)
#         6    0.000    0.000    0.423    0.071 api.py:3(<module>)
#        28    0.000    0.000    0.419    0.015 __init__.py:1(<module>)
#      6652    0.410    0.000    0.410    0.000 {method 'count' of 'list' objects}
#    372/49    0.001    0.000    0.356    0.007 {built-in method builtins.__import__}
# 2608/1532    0.003    0.000    0.315    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         1    0.000    0.000    0.272    0.272 __init__.py:106(<module>)
#       378    0.004    0.000    0.255    0.001 <frozen importlib._bootstrap_external>:743(get_code)
#         1    0.000    0.000    0.151    0.151 generic.py:7(<module>)
#       479    0.005    0.000    0.151    0.000 <frozen importlib._bootstrap>:870(_find_spec)
#         3    0.000    0.000    0.150    0.050 __init__.py:7(<module>)
#       460    0.001    0.000    0.143    0.000 <frozen importlib._bootstrap_external>:1149(find_spec)
#       460    0.003    0.000    0.142    0.000 <frozen importlib._bootstrap_external>:1117(_get_spec)
#         1    0.000    0.000    0.133    0.133 frame.py:10(<module>)
#       780    0.009    0.000    0.127    0.000 <frozen importlib._bootstrap_external>:1233(find_spec)
#      1808    0.003    0.000    0.122    0.000 <frozen importlib._bootstrap_external>:75(_path_stat)
#      1808    0.120    0.000    0.120    0.000 {built-in method nt.stat}
#     68/45    0.000    0.000    0.120    0.003 <frozen importlib._bootstrap_external>:927(exec_module)
#     68/45    0.022    0.000    0.119    0.003 {built-in method _imp.exec_dynamic}
#   914/903    0.021    0.000    0.117    0.000 {built-in method builtins.__build_class__}
#      1108    0.008    0.000    0.103    0.000 0405.py:144(Update_emax)
#   465/462    0.001    0.000    0.095    0.000 <frozen importlib._bootstrap>:564(module_from_spec)
#       390    0.062    0.000    0.089    0.000 <frozen importlib._bootstrap_external>:830(get_data)
#       157    0.001    0.000    0.087    0.001 0405.py:170(BringBack)
#        68    0.000    0.000    0.075    0.001 <frozen importlib._bootstrap_external>:919(create_module)
#        68    0.072    0.001    0.075    0.001 {built-in method _imp.create_dynamic}
#       366    0.001    0.000    0.072    0.000 <frozen importlib._bootstrap_external>:485(_compile_bytecode)
#         2    0.000    0.000    0.071    0.036 generic.py:1(<module>)
#       366    0.069    0.000    0.069    0.000 {built-in method marshal.loads}
#         1    0.000    0.000    0.067    0.067 __init__.py:45(<module>)
# 1145/1037    0.002    0.000    0.063    0.000 typing.py:676(inner)
#       500    0.005    0.000    0.054    0.000 textwrap.py:414(dedent)
#         1    0.000    0.000    0.052    0.052 __init__.py:13(<module>)
#       373    0.051    0.000    0.051    0.000 {built-in method builtins.compile}
#       432    0.001    0.000    0.050    0.000 _decorators.py:330(__call__)
#       638    0.001    0.000    0.045    0.000 <frozen importlib._bootstrap_external>:85(_path_is_mode_type)
#         1    0.000    0.000    0.042    0.042 series.py:3(<module>)
#       570    0.001    0.000    0.041    0.000 <frozen importlib._bootstrap_external>:94(_path_isfile)
#       170    0.002    0.000    0.039    0.000 typing.py:1099(__getitem__)
#       217    0.005    0.000    0.037    0.000 typing.py:922(__new__)
#     15880    0.036    0.000    0.036    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.035    0.035 api.py:1(<module>)
#         1    0.000    0.000    0.034    0.034 algorithms.py:4(<module>)
#        12    0.000    0.000    0.033    0.003 <frozen importlib._bootstrap_external>:735(source_to_code)
#         1    0.000    0.000    0.033    0.033 boolean.py:1(<module>)
#         1    0.000    0.000    0.030    0.030 nanops.py:1(<module>)
#         1    0.000    0.000    0.028    0.028 _optional.py:47(import_optional_dependency)
#         1    0.000    0.000    0.028    0.028 __init__.py:108(import_module)
#         1    0.000    0.000    0.028    0.028 <frozen importlib._bootstrap>:982(_gcd_import)
#       390    0.027    0.000    0.027    0.000 {method 'read' of '_io.FileIO' objects}
#         2    0.000    0.000    0.027    0.014 interval.py:1(<module>)
#       595    0.001    0.000    0.027    0.000 re.py:286(_compile)
#         2    0.000    0.000    0.026    0.013 generic.py:10342(_add_series_or_dataframe_operations)
#       316    0.001    0.000    0.026    0.000 overrides.py:166(decorator)
#       378    0.001    0.000    0.025    0.000 <frozen importlib._bootstrap_external>:840(path_stats)
#        52    0.000    0.000    0.025    0.000 re.py:231(compile)
#        52    0.000    0.000    0.025    0.000 sre_compile.py:557(compile)
#         3    0.000    0.000    0.025    0.008 datetimes.py:1(<module>)
#       263    0.004    0.000    0.024    0.000 abc.py:132(__new__)
#       797    0.024    0.000    0.024    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#       227    0.000    0.000    0.022    0.000 typing.py:133(__new__)
#         1    0.000    0.000    0.022    0.022 __init__.py:124(<module>)
#         1    0.000    0.000    0.022    0.022 base.py:7(<module>)
#         1    0.000    0.000    0.021    0.021 _pickle.py:1(<module>)
#       500    0.020    0.000    0.020    0.000 {method 'findall' of '_sre.SRE_Pattern' objects}
#         2    0.000    0.000    0.020    0.010 base.py:1(<module>)
#       168    0.001    0.000    0.020    0.000 typing.py:790(__getitem__)
#         1    0.000    0.000    0.020    0.020 multiarray.py:7(<module>)
#         1    0.000    0.000    0.019    0.019 ewm.py:1(<module>)
#        26    0.001    0.000    0.018    0.001 __init__.py:357(namedtuple)
#         1    0.000    0.000    0.017    0.017 overrides.py:1(<module>)
#         1    0.000    0.000    0.017    0.017 dtypes.py:1(<module>)
#         1    0.000    0.000    0.016    0.016 _decorators.py:1(<module>)
#       465    0.003    0.000    0.016    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#       169    0.002    0.000    0.016    0.000 typing.py:732(__new__)
#        12    0.000    0.000    0.016    0.001 <frozen importlib._bootstrap_external>:845(_cache_bytecode)
#         1    0.000    0.000    0.015    0.015 _internal.py:6(<module>)
#         1    0.000    0.000    0.015    0.015 _base.py:1(<module>)
#        12    0.000    0.000    0.015    0.001 <frozen importlib._bootstrap_external>:850(set_data)
#         1    0.000    0.000    0.015    0.015 index_tricks.py:1(<module>)
#         1    0.000    0.000    0.014    0.014 npyio.py:1(<module>)
#         1    0.000    0.000    0.014    0.014 platform.py:10(<module>)
#         1    0.000    0.000    0.014    0.014 eval.py:5(<module>)
#         1    0.000    0.000    0.014    0.014 _distributor_init.py:10(<module>)
#         3    0.000    0.000    0.014    0.005 __init__.py:5(<module>)
#     16890    0.006    0.000    0.013    0.000 0405.py:39(__repr__)
#        12    0.002    0.000    0.013    0.001 <frozen importlib._bootstrap_external>:106(_write_atomic)
#         1    0.000    0.000    0.013    0.013 main.py:1(<module>)
#         1    0.000    0.000    0.013    0.013 case.py:1(<module>)
#         1    0.000    0.000    0.013    0.013 __init__.py:26(<module>)
#         1    0.000    0.000    0.013    0.013 __init__.py:10(<module>)
#         3    0.000    0.000    0.012    0.004 numeric.py:1(<module>)
#        52    0.000    0.000    0.012    0.000 sre_parse.py:844(parse)
#        52    0.000    0.000    0.012    0.000 sre_compile.py:542(_code)
#       756    0.004    0.000    0.012    0.000 <frozen importlib._bootstrap_external>:263(cache_from_source)
#       857    0.001    0.000    0.012    0.000 <frozen importlib._bootstrap_external>:1080(_path_importer_cache)
#         1    0.000    0.000    0.011    0.011 groupby.py:8(<module>)
#         3    0.000    0.000    0.011    0.004 __init__.py:2(<module>)
#         2    0.000    0.000    0.011    0.006 categorical.py:1(<module>)
#         1    0.000    0.000    0.011    0.011 py3k.py:12(<module>)
#       367    0.004    0.000    0.011    0.000 typing.py:613(_remove_dups_flatten)
#         1    0.000    0.000    0.011    0.011 rolling.py:4(<module>)
#       297    0.000    0.000    0.011    0.000 re.py:184(sub)
#         1    0.000    0.000    0.011    0.011 typing.py:1(<module>)
#      1195    0.011    0.000    0.011    0.000 {built-in method __new__ of type object at 0x0000000063A2C3F0}
#      3696    0.004    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:57(_path_join)
#         1    0.000    0.000    0.010    0.010 format.py:4(<module>)
#      1108    0.005    0.000    0.010    0.000 0405.py:116(Update_local_max)
#        56    0.005    0.000    0.010    0.000 <frozen importlib._bootstrap_external>:1067(_path_hooks)
#       483    0.001    0.000    0.010    0.000 <frozen importlib._bootstrap>:147(__enter__)
#    148/52    0.001    0.000    0.010    0.000 sre_parse.py:407(_parse_sub)
#         1    0.000    0.000    0.010    0.010 inspect.py:27(<module>)
#         1    0.000    0.000    0.010    0.010 datetimelike.py:1(<module>)
#    320/52    0.003    0.000    0.010    0.000 sre_compile.py:64(_compile)
#        56    0.001    0.000    0.010    0.000 <frozen importlib._bootstrap_external>:1281(_fill_cache)
#    166/55    0.004    0.000    0.010    0.000 sre_parse.py:470(_parse)
#         1    0.000    0.000    0.010    0.010 _datasource.py:36(<module>)
#         1    0.000    0.000    0.010    0.010 __init__.py:15(<module>)
#       824    0.001    0.000    0.010    0.000 <frozen importlib._bootstrap>:403(cached)
#         4    0.000    0.000    0.009    0.002 methods.py:159(_create_methods)
#      4323    0.005    0.000    0.009    0.000 0405.py:212(find)
#      1147    0.004    0.000    0.009    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#        68    0.000    0.000    0.009    0.000 typing.py:843(__getitem__)
#       446    0.001    0.000    0.009    0.000 <frozen importlib._bootstrap_external>:361(_get_cached)
#         1    0.000    0.000    0.008    0.008 shutil.py:5(<module>)
# 2831/2773    0.006    0.000    0.008    0.000 typing.py:1164(__setattr__)
#         1    0.000    0.000    0.008    0.008 __init__.py:32(__enter__)
#        30    0.000    0.000    0.008    0.000 typing.py:1240(__getitem__)
#     15658    0.008    0.000    0.008    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.008    0.008 defmatrix.py:1(<module>)
#         1    0.000    0.000    0.008    0.008 frame.py:319(DataFrame)
#         1    0.000    0.000    0.008    0.008 subprocess.py:42(<module>)
#         2    0.000    0.000    0.008    0.004 methods.py:132(add_flex_arithmetic_methods)
#   201/191    0.000    0.000    0.008    0.000 typing.py:805(_subs_tree)
#       378    0.006    0.000    0.007    0.000 <frozen importlib._bootstrap_external>:430(_validate_bytecode_header)
#         1    0.000    0.000    0.007    0.007 accessor.py:1(<module>)
#         3    0.000    0.000    0.007    0.002 _version.py:7(<module>)
#        56    0.007    0.000    0.007    0.000 {built-in method nt.listdir}
#      1265    0.005    0.000    0.007    0.000 0405.py:220(position)
#         1    0.000    0.000    0.007    0.007 engines.py:3(<module>)
#         2    0.000    0.000    0.007    0.003 shape_base.py:1(<module>)
# 26075/26007    0.006    0.000    0.007    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.007    0.007 generic.py:151(NDFrame)
#         1    0.007    0.007    0.007    0.007 {built-in method mkl._py_mkl_service.get_version}
#         1    0.000    0.000    0.006    0.006 pytables.py:4(<module>)
#      1419    0.001    0.000    0.006    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.006    0.006 secrets.py:7(<module>)
#         1    0.000    0.000    0.006    0.006 __init__.py:41(<module>)
#         1    0.000    0.000    0.006    0.006 __init__.py:71(<module>)
#         1    0.000    0.000    0.006    0.006 __init__.py:97(<module>)
#         1    0.000    0.000    0.006    0.006 array_ops.py:4(<module>)
#      7475    0.006    0.000    0.006    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.006    0.006 array.py:3(<module>)
#         1    0.000    0.000    0.006    0.006 financial.py:12(<module>)
#         1    0.000    0.000    0.006    0.006 __init__.py:192(<module>)
#      3696    0.004    0.000    0.006    0.000 <frozen importlib._bootstrap_external>:59(<listcomp>)
#         1    0.000    0.000    0.006    0.006 pathlib.py:1(<module>)
#       664    0.001    0.000    0.006    0.000 <frozen importlib._bootstrap>:194(_lock_unlock_module)
#         1    0.000    0.000    0.005    0.005 threading.py:1(<module>)
#         1    0.000    0.000    0.005    0.005 tz.py:9(<module>)
#         4    0.000    0.000    0.005    0.001 common.py:1(<module>)
#         1    0.000    0.000    0.005    0.005 linalg.py:10(<module>)
#         1    0.000    0.000    0.005    0.005 blocks.py:1(<module>)
#      4482    0.004    0.000    0.005    0.000 0405.py:34(__init__)
#        56    0.000    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:1322(path_hook_for_FileFinder)
#      5697    0.002    0.000    0.005    0.000 0405.py:37(__str__)
#         1    0.001    0.001    0.005    0.005 series.py:122(Series)
#         1    0.000    0.000    0.005    0.005 expr.py:2(<module>)
#        68    0.000    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:99(_path_isdir)
#     22960    0.005    0.000    0.005    0.000 {method 'startswith' of 'str' objects}
#   485/332    0.001    0.000    0.005    0.000 typing.py:580(_subs_tree)
#      1035    0.002    0.000    0.005    0.000 enum.py:801(__and__)
#         1    0.000    0.000    0.005    0.005 ops.py:7(<module>)
#       481    0.001    0.000    0.005    0.000 <frozen importlib._bootstrap>:58(__init__)
#       446    0.001    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:1228(_get_spec)
#         1    0.000    0.000    0.005    0.005 datetimelike.py:3(<module>)
# 3621/3114    0.001    0.000    0.005    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.005    0.005 hashing.py:3(<module>)
#       768    0.003    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:63(_path_split)
#        12    0.005    0.000    0.005    0.000 {built-in method nt.replace}
#         1    0.000    0.000    0.005    0.005 indexing.py:1(<module>)
#       286    0.001    0.000    0.004    0.000 overrides.py:72(verify_matching_signatures)
#         1    0.000    0.000    0.004    0.004 _base.py:784(ExcelFile)
#       792    0.002    0.000    0.004    0.000 typing.py:354(_type_check)
#      1874    0.001    0.000    0.004    0.000 typing.py:646(<genexpr>)
#        34    0.000    0.000    0.004    0.000 __init__.py:737(_arith_method_FRAME)
#         1    0.000    0.000    0.004    0.004 0405.py:247(<listcomp>)
#         4    0.000    0.000    0.004    0.001 0405.py:24(__init__)
#         1    0.000    0.000    0.004    0.004 traceback.py:1(<module>)
#         4    0.000    0.000    0.004    0.001 hll.py:72(__init__)
#         1    0.000    0.000    0.004    0.004 generic.py:3042(to_csv)
#      2310    0.001    0.000    0.004    0.000 enum.py:265(__call__)
#         4    0.004    0.001    0.004    0.001 hll.py:91(<listcomp>)
#         1    0.000    0.000    0.004    0.004 version.py:27(<module>)
#         1    0.000    0.000    0.004    0.004 __init__.py:24(<module>)
#       589    0.002    0.000    0.004    0.000 functools.py:44(update_wrapper)
#         1    0.000    0.000    0.004    0.004 runner.py:1(<module>)
#         1    0.000    0.000    0.004    0.004 _json.py:1(<module>)
#         1    0.000    0.000    0.004    0.004 frequencies.py:1(<module>)
#      1147    0.004    0.000    0.004    0.000 <frozen importlib._bootstrap>:103(release)
#         1    0.000    0.000    0.004    0.004 fromnumeric.py:3(<module>)
#         1    0.000    0.000    0.004    0.004 frozen.py:8(<module>)
#         1    0.000    0.000    0.004    0.004 config.py:49(<module>)
#   932/658    0.001    0.000    0.004    0.000 typing.py:553(_replace_arg)
#         1    0.000    0.000    0.004    0.004 testing.py:3(<module>)
#   250/110    0.001    0.000    0.004    0.000 abc.py:196(__subclasscheck__)
#         1    0.000    0.000    0.004    0.004 result.py:1(<module>)
#   317/268    0.001    0.000    0.004    0.000 typing.py:1083(_subs_tree)
#       968    0.004    0.000    0.004    0.000 {built-in method _thread.allocate_lock}
#       483    0.001    0.000    0.004    0.000 <frozen importlib._bootstrap>:151(__exit__)
#       263    0.001    0.000    0.004    0.000 abc.py:135(<setcomp>)
#         1    0.000    0.000    0.004    0.004 linecache.py:6(<module>)
#      2118    0.004    0.000    0.004    0.000 {method 'sort' of 'list' objects}
#      1147    0.003    0.000    0.004    0.000 <frozen importlib._bootstrap>:78(acquire)
#         1    0.000    0.000    0.004    0.004 defchararray.py:17(<module>)
#         1    0.000    0.000    0.004    0.004 numerictypes.py:81(<module>)
#         1    0.000    0.000    0.003    0.003 fractions.py:4(<module>)
#      6661    0.003    0.000    0.003    0.000 {built-in method builtins.round}
#         1    0.000    0.000    0.003    0.003 scimath.py:17(<module>)
#         3    0.000    0.000    0.003    0.001 __init__.py:9(<module>)
#         1    0.000    0.000    0.003    0.003 integer.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 _pocketfft.py:29(<module>)
#         2    0.000    0.000    0.003    0.002 function_base.py:1(<module>)
#        36    0.000    0.000    0.003    0.000 typing.py:1314(__getitem__)
#         1    0.000    0.000    0.003    0.003 decoder.py:2(<module>)
#      6658    0.003    0.000    0.003    0.000 {built-in method math.log}
#         1    0.000    0.000    0.003    0.003 strings.py:1(<module>)
#       465    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:318(__exit__)
#       126    0.000    0.000    0.003    0.000 sre_compile.py:223(_compile_charset)
#         1    0.000    0.000    0.003    0.003 printing.py:3(<module>)
#         1    0.000    0.000    0.003    0.003 difflib.py:27(<module>)
#        10    0.000    0.000    0.003    0.000 typing.py:1334(__getitem_inner__)
#         1    0.000    0.000    0.003    0.003 category.py:1(<module>)
#       446    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:524(spec_from_file_location)
#         1    0.000    0.000    0.003    0.003 parsers.py:3(<module>)
#       616    0.001    0.000    0.003    0.000 _inspect.py:98(getargspec)
#       157    0.001    0.000    0.003    0.000 0405.py:187(DeleteSk)
#         1    0.000    0.000    0.003    0.003 ops.py:2(<module>)
#        12    0.003    0.000    0.003    0.000 {built-in method nt.unlink}
#         1    0.000    0.000    0.003    0.003 strings.py:2028(StringMethods)
#      3324    0.003    0.000    0.003    0.000 {built-in method mmh3.hash}
#         1    0.000    0.000    0.003    0.003 hmac.py:4(<module>)
#         1    0.000    0.000    0.003    0.003 _add_newdocs.py:10(<module>)
#      5227    0.002    0.000    0.003    0.000 {method 'join' of 'str' objects}
#         2    0.000    0.000    0.003    0.001 missing.py:3(<module>)
#         1    0.000    0.000    0.003    0.003 dis.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 _typing.py:1(<module>)
#    358/66    0.000    0.000    0.003    0.000 typing.py:1145(__subclasscheck__)
#      2308    0.002    0.000    0.003    0.000 enum.py:515(__new__)
#         1    0.000    0.000    0.003    0.003 hll.py:3(<module>)
#         2    0.000    0.000    0.003    0.001 period.py:1(<module>)
#         1    0.000    0.000    0.003    0.003 core.py:21(<module>)
#         2    0.000    0.000    0.003    0.001 generic.py:10105(_add_numeric_operations)
#      4165    0.003    0.000    0.003    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.003    0.003 decimal.py:2(<module>)
#       273    0.000    0.000    0.003    0.000 function_base.py:460(add_newdoc)
#        22    0.000    0.000    0.003    0.000 __init__.py:559(_flex_method_SERIES)
#        12    0.003    0.000    0.003    0.000 {built-in method nt.open}
#         1    0.000    0.000    0.002    0.002 polynomial.py:57(<module>)
#         1    0.000    0.000    0.002    0.002 categorical.py:209(Categorical)
#         1    0.000    0.000    0.002    0.002 tokenize.py:21(<module>)
#         1    0.000    0.000    0.002    0.002 string.py:15(<module>)
#         1    0.000    0.000    0.002    0.002 win.py:8(<module>)
#         1    0.000    0.000    0.002    0.002 _testing.py:1(<module>)
#         1    0.000    0.000    0.002    0.002 rolling.py:1802(Rolling)
#         1    0.000    0.000    0.002    0.002 pickle.py:24(<module>)
#         1    0.000    0.000    0.002    0.002 __init__.py:57(<module>)
#         1    0.000    0.000    0.002    0.002 offsets.py:1(<module>)
#      4323    0.002    0.000    0.002    0.000 0405.py:215(<listcomp>)
#         1    0.000    0.000    0.002    0.002 stata.py:11(<module>)
#       126    0.002    0.000    0.002    0.000 sre_compile.py:250(_optimize_charset)
#         2    0.000    0.000    0.002    0.001 methods.py:72(add_special_arithmetic_methods)
#      4323    0.002    0.000    0.002    0.000 {method 'index' of 'list' objects}
#      4073    0.002    0.000    0.002    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#         1    0.000    0.000    0.002    0.002 hashlib.py:54(<module>)
#         1    0.000    0.000    0.002    0.002 csvs.py:157(save)
#       542    0.000    0.000    0.002    0.000 typing.py:800(<genexpr>)
#         1    0.000    0.000    0.002    0.002 bz2.py:5(<module>)
#         1    0.000    0.000    0.002    0.002 indexers.py:1(<module>)
#         1    0.000    0.000    0.002    0.002 version.py:267(LooseVersion)
#         1    0.000    0.000    0.002    0.002 _normalize.py:4(<module>)
#         1    0.000    0.000    0.002    0.002 type_check.py:3(<module>)
#         1    0.000    0.000    0.002    0.002 version.py:93(StrictVersion)
#         1    0.000    0.000    0.002    0.002 pivot.py:1(<module>)
#      8152    0.002    0.000    0.002    0.000 {method 'rstrip' of 'str' objects}
#      1794    0.001    0.000    0.002    0.000 sre_parse.py:253(get)
#         1    0.000    0.000    0.002    0.002 base.py:57(ExtensionArray)
#         1    0.000    0.000    0.002    0.002 config_init.py:11(<module>)
#       372    0.000    0.000    0.002    0.000 typing.py:342(_type_vars)
#        98    0.000    0.000    0.002    0.000 common.py:24(wrapper)
#         1    0.000    0.000    0.002    0.002 scanner.py:2(<module>)
#        54    0.000    0.000    0.002    0.000 config.py:730(inner)
#         1    0.000    0.000    0.002    0.002 rolling.py:1140(_Rolling_and_Expanding)
#         1    0.000    0.000    0.002    0.002 bench.py:1(<module>)
#         1    0.000    0.000    0.002    0.002 parse.py:28(<module>)
#         1    0.000    0.000    0.002    0.002 utils.py:4(<module>)
#       612    0.001    0.000    0.002    0.000 _inspect.py:67(getargs)
#         1    0.000    0.000    0.002    0.002 groupby.py:1034(GroupBy)
#        12    0.002    0.000    0.002    0.000 {method 'write' of '_io.FileIO' objects}
#         2    0.000    0.000    0.002    0.001 frame.py:414(__init__)
#        52    0.000    0.000    0.002    0.000 sre_compile.py:482(_compile_info)
#         1    0.000    0.000    0.002    0.002 base.py:177(Index)
#         1    0.000    0.000    0.002    0.002 _xlsxwriter.py:1(<module>)
#         1    0.000    0.000    0.002    0.002 construction.py:6(<module>)
#        54    0.001    0.000    0.002    0.000 config.py:413(register_option)
#         1    0.000    0.000    0.002    0.002 expanding.py:1(<module>)
#        98    0.000    0.000    0.002    0.000 common.py:30(_unpack_zerodim_and_defer)
#         1    0.000    0.000    0.002    0.002 multi.py:1(<module>)
#         1    0.000    0.000    0.002    0.002 cast.py:1(<module>)
#         1    0.001    0.001    0.002    0.002 interval.py:154(IntervalIndex)
#       119    0.000    0.000    0.002    0.000 enum.py:795(__or__)
#      6652    0.002    0.000    0.002    0.000 hll.py:24(get_treshold)
#       856    0.002    0.000    0.002    0.000 _weakrefset.py:36(__init__)
#        23    0.000    0.000    0.002    0.000 overrides.py:206(decorator)
#      2192    0.002    0.000    0.002    0.000 sre_parse.py:232(__next)
#       424    0.000    0.000    0.002    0.000 typing.py:1107(<genexpr>)
#        12    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:497(_code_to_bytecode)
#         1    0.000    0.000    0.002    0.002 expanding.py:10(Expanding)
#         1    0.000    0.000    0.002    0.002 scope.py:3(<module>)
#       481    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:176(cb)
#         1    0.000    0.000    0.002    0.002 category.py:38(CategoricalIndex)
#         1    0.000    0.000    0.001    0.001 lzma.py:9(<module>)
#       768    0.001    0.000    0.001    0.000 {method 'rsplit' of 'str' objects}
#         1    0.000    0.000    0.001    0.001 managers.py:1(<module>)
#       217    0.001    0.000    0.001    0.000 typing.py:852(_next_in_mro)
#         1    0.000    0.000    0.001    0.001 generic.py:148(SeriesGroupBy)
#   426/372    0.001    0.000    0.001    0.000 typing.py:336(_get_type_vars)
#         1    0.000    0.000    0.001    0.001 merge.py:3(<module>)
#         1    0.000    0.000    0.001    0.001 multi.py:146(MultiIndex)
#         3    0.000    0.000    0.001    0.000 base.py:5116(_add_logical_methods)
#         1    0.000    0.000    0.001    0.001 common.py:314(get_handle)
#   535/270    0.001    0.000    0.001    0.000 sre_parse.py:173(getwidth)
#       170    0.001    0.000    0.001    0.000 typing.py:896(_no_slots_copy)
#         1    0.000    0.000    0.001    0.001 period.py:61(PeriodArray)
#        12    0.001    0.000    0.001    0.000 {built-in method marshal.dumps}
#         2    0.000    0.000    0.001    0.001 concat.py:3(<module>)
#      18/6    0.000    0.000    0.001    0.000 typing.py:875(__extrahook__)
#         1    0.000    0.000    0.001    0.001 datetimelike.py:397(DatetimeLikeArrayMixin)
#         6    0.000    0.000    0.001    0.000 __init__.py:791(_flex_comp_method_FRAME)
#         1    0.000    0.000    0.001    0.001 random.py:38(<module>)
#         1    0.000    0.000    0.001    0.001 loader.py:1(<module>)
#        45    0.000    0.000    0.001    0.000 typing.py:222(__init__)
#         1    0.000    0.000    0.001    0.001 base.py:3(<module>)
#         1    0.000    0.000    0.001    0.001 string.py:65(__init__)
#         3    0.000    0.000    0.001    0.000 expr.py:250(disallowed)
#         1    0.000    0.000    0.001    0.001 pytables.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 autotimeit.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 grouper.py:4(<module>)
#         1    0.000    0.000    0.001    0.001 wintypes.py:2(<module>)
#        12    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:373(_calc_mode)
#         1    0.000    0.000    0.001    0.001 interval.py:120(IntervalArray)
#       744    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:52(_r_long)
#      1287    0.001    0.000    0.001    0.000 sre_parse.py:163(__getitem__)
#      2937    0.001    0.000    0.001    0.000 {method 'rpartition' of 'str' objects}
#         1    0.000    0.000    0.001    0.001 twodim_base.py:3(<module>)
#         1    0.000    0.000    0.001    0.001 polynomial.py:4(<module>)
#        19    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:728(create_module)
#         1    0.000    0.000    0.001    0.001 align.py:2(<module>)
#         1    0.000    0.000    0.001    0.001 pytables.py:3110(Table)
#         1    0.000    0.000    0.001    0.001 nanfunctions.py:22(<module>)
#         1    0.000    0.000    0.001    0.001 rolling.py:772(Window)
#      3324    0.001    0.000    0.001    0.000 {spookyhash.hash32}
#        52    0.000    0.000    0.001    0.000 sre_parse.py:828(fix_flags)
#         4    0.000    0.000    0.001    0.000 base.py:1088(_add_arithmetic_ops)
#      1412    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:847(__exit__)
#       242    0.000    0.000    0.001    0.000 re.py:169(match)
#        19    0.001    0.000    0.001    0.000 {built-in method _imp.create_builtin}
#         3    0.000    0.000    0.001    0.000 warnings.py:119(filterwarnings)
#         1    0.000    0.000    0.001    0.001 pickle.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 encoder.py:2(<module>)
#         1    0.000    0.000    0.001    0.001 format.py:527(DataFrameFormatter)
#         1    0.000    0.000    0.001    0.001 accessor.py:6(<module>)
#       739    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:416(parent)
#        56    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1196(__init__)
#         1    0.000    0.000    0.001    0.001 groupby.py:357(_GroupBy)
#         1    0.000    0.000    0.001    0.001 _parser.py:30(<module>)
#      4486    0.001    0.000    0.001    0.000 0405.py:14(__init__)
#         2    0.000    0.000    0.001    0.000 timedeltas.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 numpy_.py:1(<module>)
#      7096    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.001    0.001 numba_.py:1(<module>)
#         1    0.001    0.001    0.001    0.001 string.py:77(Template)
#         1    0.000    0.000    0.001    0.001 utils.py:1(<module>)
#       226    0.000    0.000    0.001    0.000 typing.py:1025(_abc_negative_cache)
#         1    0.000    0.000    0.001    0.001 _type_aliases.py:24(<module>)
#      1412    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:843(__enter__)
#      1000    0.001    0.000    0.001    0.000 {method 'readline' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.001    0.001 rolling.py:59(_Window)
#        12    0.000    0.000    0.001    0.000 generic.py:11188(_make_stat_function)
#         1    0.000    0.000    0.001    0.001 docstrings.py:3(<module>)
#         1    0.000    0.000    0.001    0.001 argparse.py:62(<module>)
#         1    0.000    0.000    0.001    0.001 common.py:5(<module>)
#         6    0.000    0.000    0.001    0.000 base.py:5203(_make_logical_function)
#         1    0.000    0.000    0.001    0.001 ops.py:59(BaseGrouper)
#         1    0.000    0.000    0.001    0.001 base.py:590(IndexOpsMixin)
#        24    0.001    0.000    0.001    0.000 generic.py:6(create_pandas_abc_type)
#         1    0.000    0.000    0.001    0.001 _print_versions.py:1(<module>)
#         1    0.001    0.001    0.001    0.001 stata.py:2815(StataWriter117)
#       161    0.001    0.000    0.001    0.000 _decorators.py:289(__call__)
#       480    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:369(__init__)
#      2015    0.001    0.000    0.001    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.001    0.001 datetimelike.py:260(TimelikeOps)
#         1    0.000    0.000    0.001    0.001 csvs.py:34(__init__)
#        16    0.000    0.000    0.001    0.000 accessor.py:146(add_delegate_accessors)
#         1    0.000    0.000    0.001    0.001 construction.py:56(arrays_to_mgr)
#         1    0.000    0.000    0.001    0.001 missing.py:23(<module>)
#         1    0.000    0.000    0.001    0.001 getlimits.py:96(_register_known_types)
#        14    0.000    0.000    0.001    0.000 expr.py:166(_filter_nodes)
#       366    0.001    0.000    0.001    0.000 {built-in method _imp._fix_co_filename}
#       460    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:780(find_spec)
#        16    0.000    0.000    0.001    0.000 accessor.py:63(_add_delegate_accessors)
#         1    0.000    0.000    0.001    0.001 fnmatch.py:11(<module>)
#       378    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:393(_check_name_wrapper)
#      3040    0.001    0.000    0.001    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.001    0.001 datetime.py:5(<module>)
#         1    0.000    0.000    0.001    0.001 parsing.py:2(<module>)
#         8    0.000    0.000    0.001    0.000 enum.py:758(_missing_)
#      3638    0.001    0.000    0.001    0.000 0405.py:209(get_width_depth)
#         1    0.000    0.000    0.001    0.001 _methods.py:5(<module>)
#        74    0.000    0.000    0.001    0.000 sre_parse.py:96(closegroup)
#      1050    0.001    0.000    0.001    0.000 typing.py:1089(__eq__)
#         8    0.000    0.000    0.001    0.000 enum.py:765(_create_pseudo_member_)
#      3481    0.001    0.000    0.001    0.000 0405.py:228(get_fraction)
#         1    0.000    0.000    0.001    0.001 _decorators.py:24(deprecate)
#       237    0.000    0.000    0.001    0.000 _weakrefset.py:58(__iter__)
#       378    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:35(_new_module)
#      1577    0.001    0.000    0.001    0.000 {method 'strip' of 'str' objects}
#       126    0.000    0.000    0.001    0.000 expr.py:168(<genexpr>)
#        13    0.000    0.000    0.001    0.000 nanops.py:51(__init__)
#         1    0.000    0.000    0.001    0.001 dtypes.py:164(CategoricalDtype)
#       173    0.000    0.000    0.001    0.000 typing.py:206(__new__)
#         8    0.000    0.000    0.001    0.000 generic.py:11243(_make_cum_function)
#        18    0.000    0.000    0.001    0.000 abc.py:180(__instancecheck__)
#         1    0.000    0.000    0.001    0.001 arraysetops.py:27(<module>)
#         1    0.000    0.000    0.001    0.001 _core.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 numeric.py:376(Float64Index)
#         1    0.000    0.000    0.001    0.001 relativedelta.py:2(<module>)
#        34    0.000    0.000    0.001    0.000 nanops.py:53(<genexpr>)
#         1    0.000    0.000    0.001    0.001 six.py:21(<module>)
#         1    0.000    0.000    0.001    0.001 merge.py:546(_MergeOperation)
#      3040    0.001    0.000    0.001    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.001    0.001 range.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 chainmap.py:1(<module>)
#       479    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:707(find_spec)
#         6    0.000    0.000    0.001    0.000 base.py:1107(_add_comparison_ops)
#       465    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:311(__enter__)
#         8    0.000    0.000    0.001    0.000 enum.py:837(_decompose)
#        31    0.000    0.000    0.001    0.000 common.py:1844(pandas_dtype)
#         1    0.000    0.000    0.001    0.001 dtypes.py:609(DatetimeTZDtype)
#         1    0.000    0.000    0.001    0.001 pytables.py:242(FilterBinOp)
#       582    0.001    0.000    0.001    0.000 functools.py:74(wraps)
#         1    0.000    0.000    0.001    0.001 base.py:11(ExtensionDtype)
#         1    0.000    0.000    0.001    0.001 melt.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 base.py:5(<module>)
#       780    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:37(_relax_case)
#         1    0.000    0.000    0.001    0.001 pytables.py:455(HDFStore)
#         1    0.000    0.000    0.001    0.001 html.py:5(<module>)
#         1    0.000    0.000    0.001    0.001 numpy_.py:102(PandasArray)
#         1    0.000    0.000    0.001    0.001 calendar.py:6(<module>)
#         6    0.000    0.000    0.001    0.000 getlimits.py:37(__init__)
#         1    0.000    0.000    0.001    0.001 ewm.py:30(EWM)
#         1    0.000    0.000    0.001    0.001 csvs.py:3(<module>)
#         1    0.000    0.000    0.001    0.001 csvs.py:308(_save)
#         3    0.000    0.000    0.001    0.000 enum.py:124(__new__)
#      2310    0.001    0.000    0.001    0.000 {built-in method _thread.get_ident}
#      1275    0.000    0.000    0.001    0.000 typing.py:651(<genexpr>)
#         3    0.000    0.000    0.001    0.000 util.py:1(<module>)
#         4    0.000    0.000    0.001    0.000 missing.py:49(isna)
#        17    0.000    0.000    0.001    0.000 abc.py:151(register)
#         4    0.000    0.000    0.001    0.000 missing.py:132(_isna_new)
#       239    0.000    0.000    0.001    0.000 typing.py:168(__new__)
#        36    0.001    0.000    0.001    0.000 {built-in method _ctypes.POINTER}
#         1    0.000    0.000    0.001    0.001 accessors.py:3(<module>)
#         1    0.000    0.000    0.001    0.001 arrayprint.py:5(<module>)
#         1    0.000    0.000    0.001    0.001 gbq.py:1(<module>)
#      1316    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.001    0.001 _validators.py:4(<module>)
#      1860    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#         1    0.000    0.000    0.000    0.000 csvs.py:325(_save_chunk)
#         4    0.000    0.000    0.000    0.000 methods.py:225(_add_methods)
#        52    0.000    0.000    0.000    0.000 core.py:900(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 period.py:82(PeriodIndex)
#       745    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         1    0.000    0.000    0.000    0.000 managers.py:1667(create_block_manager_from_arrays)
#         1    0.000    0.000    0.000    0.000 datetimes.py:82(DatetimeIndex)
#         1    0.000    0.000    0.000    0.000 csvs.py:33(CSVFormatter)
#        44    0.000    0.000    0.000    0.000 core.py:145(get_object_signature)
#         1    0.000    0.000    0.000    0.000 signal.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 isoparser.py:9(<module>)
#        58    0.000    0.000    0.000    0.000 strings.py:1943(_forbid_nonstring_types)
#         1    0.000    0.000    0.000    0.000 mask_ops.py:3(<module>)
#        41    0.000    0.000    0.000    0.000 dtypes.py:75(find)
#       797    0.000    0.000    0.000    0.000 sre_parse.py:248(match)
#       267    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        36    0.000    0.000    0.000    0.000 docstrings.py:7(_make_flex_doc)
#      1775    0.000    0.000    0.000    0.000 typing.py:1096(__hash__)
#         2    0.000    0.000    0.000    0.000 common.py:226(get_compression_method)
#         1    0.000    0.000    0.000    0.000 dtypes.py:108(PandasExtensionDtype)
#         2    0.000    0.000    0.000    0.000 typing.py:1156(__instancecheck__)
#   695/664    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 opcode.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 accessor.py:13(DirNamesMixin)
#         1    0.000    0.000    0.000    0.000 numbers.py:6(<module>)
#         1    0.000    0.000    0.000    0.000 extras.py:10(<module>)
#         2    0.000    0.000    0.000    0.000 base.py:993(to_native_types)
#         7    0.000    0.000    0.000    0.000 enum.py:855(<listcomp>)
#         2    0.000    0.000    0.000    0.000 enum.py:602(_convert)
#        17    0.000    0.000    0.000    0.000 array.py:1374(_create_arithmetic_method)
#       460    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#        26    0.000    0.000    0.000    0.000 core.py:6660(__init__)
#         1    0.000    0.000    0.000    0.000 csv.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 _odfreader.py:1(<module>)
#       376    0.000    0.000    0.000    0.000 generic.py:10(_check)
#       770    0.000    0.000    0.000    0.000 typing.py:971(<genexpr>)
#         1    0.000    0.000    0.000    0.000 isoparser.py:42(isoparser)
#         1    0.000    0.000    0.000    0.000 ufunclike.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 pytables.py:2464(Fixed)
#         1    0.000    0.000    0.000    0.000 stata.py:3179(StataWriterUTF8)
#         2    0.000    0.000    0.000    0.000 base.py:1024(_format_native_types)
#         1    0.000    0.000    0.000    0.000 extension.py:3(<module>)
#        26    0.000    0.000    0.000    0.000 core.py:6665(getdoc)
#        16    0.000    0.000    0.000    0.000 __init__.py:487(_arith_method_SERIES)
#         1    0.000    0.000    0.000    0.000 generic.py:812(DataFrameGroupBy)
#         1    0.000    0.000    0.000    0.000 dtype.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:128(AttributesMixin)
#   130/128    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         1    0.000    0.000    0.000    0.000 range.py:36(RangeIndex)
#       273    0.000    0.000    0.000    0.000 function_base.py:446(_add_docstring)
#       378    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:800(__init__)
#         1    0.000    0.000    0.000    0.000 format.py:451(TableFormatter)
#        16    0.000    0.000    0.000    0.000 integer.py:609(_create_arithmetic_method)
#         4    0.000    0.000    0.000    0.000 base.py:5111(_add_numeric_methods)
#        56    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1310(<setcomp>)
#      1219    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         1    0.000    0.000    0.000    0.000 generic.py:4718(head)
#         1    0.000    0.000    0.000    0.000 dtypes.py:780(PeriodDtype)
#       850    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        38    0.000    0.000    0.000    0.000 {method 'strftime' of 'datetime.date' objects}
#         1    0.000    0.000    0.000    0.000 ctypeslib.py:51(<module>)
#       616    0.000    0.000    0.000    0.000 _inspect.py:15(ismethod)
#         1    0.000    0.000    0.000    0.000 managers.py:61(BlockManager)
#      2373    0.000    0.000    0.000    0.000 0405.py:207(get_emax)
#         1    0.000    0.000    0.000    0.000 indexing.py:1754(__getitem__)
#       483    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#         1    0.000    0.000    0.000    0.000 sql.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 indexing.py:2116(_getitem_axis)
#         2    0.000    0.000    0.000    0.000 enum.py:364(_create_)
#         1    0.000    0.000    0.000    0.000 indexing.py:1742(_get_slice_axis)
#       465    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#        24    0.000    0.000    0.000    0.000 contextlib.py:129(contextmanager)
#         1    0.000    0.000    0.000    0.000 dispatch.py:3(<module>)
#      1776    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        82    0.000    0.000    0.000    0.000 typing.py:1255(<genexpr>)
#         1    0.000    0.000    0.000    0.000 array.py:195(SparseArray)
#         1    0.000    0.000    0.000    0.000 helper.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 timedeltas.py:49(TimedeltaIndex)
#       267    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.000    0.000 pickle.py:181(<listcomp>)
#         8    0.000    0.000    0.000    0.000 base.py:5293(ensure_index)
#         1    0.000    0.000    0.000    0.000 zipfile.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 _odfreader.py:11(_ODFReader)
#       432    0.000    0.000    0.000    0.000 _decorators.py:323(__init__)
#        19    0.000    0.000    0.000    0.000 typing.py:498(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:1700(form_blocks)
#         4    0.000    0.000    0.000    0.000 generic.py:11140(_make_min_count_stat_function)
#       607    0.000    0.000    0.000    0.000 sre_parse.py:171(append)
#         1    0.000    0.000    0.000    0.000 dtype.py:23(SparseDtype)
#      1280    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 expr.py:303(BaseExprVisitor)
#         1    0.000    0.000    0.000    0.000 dtypes.py:45(Registry)
#       144    0.000    0.000    0.000    0.000 sre_compile.py:388(_simple)
#         1    0.000    0.000    0.000    0.000 blocks.py:91(Block)
#       474    0.000    0.000    0.000    0.000 sre_parse.py:285(tell)
#         1    0.000    0.000    0.000    0.000 dates.py:3(<module>)
#         4    0.000    0.000    0.000    0.000 core.py:122(doc_note)
#       454    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#         1    0.000    0.000    0.000    0.000 indexing.py:630(_slice)
#         1    0.000    0.000    0.000    0.000 generic.py:3607(_slice)
#         1    0.000    0.000    0.000    0.000 extension.py:194(ExtensionIndex)
#         4    0.000    0.000    0.000    0.000 generic.py:11338(_make_logical_function)
#       118    0.000    0.000    0.000    0.000 accessor.py:83(_create_delegator_property)
#         1    0.000    0.000    0.000    0.000 _iotools.py:3(<module>)
#         2    0.000    0.000    0.000    0.000 managers.py:122(__init__)
#         4    0.000    0.000    0.000    0.000 re.py:204(split)
#         6    0.000    0.000    0.000    0.000 categorical.py:65(_cat_compare_op)
#         1    0.000    0.000    0.000    0.000 histograms.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 construction.py:300(_homogenize)
#         1    0.000    0.000    0.000    0.000 pytables.py:4574(AppendableMultiFrameTable)
#         1    0.000    0.000    0.000    0.000 ast.py:26(<module>)
#       139    0.000    0.000    0.000    0.000 __init__.py:422(<genexpr>)
#        54    0.000    0.000    0.000    0.000 sre_parse.py:223(__init__)
#         2    0.000    0.000    0.000    0.000 construction.py:388(sanitize_array)
#         1    0.000    0.000    0.000    0.000 _polybase.py:8(<module>)
#       336    0.000    0.000    0.000    0.000 typing.py:256(__hash__)
#       729    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         3    0.000    0.000    0.000    0.000 _decorators.py:224(decorate)
#         1    0.000    0.000    0.000    0.000 managers.py:740(get_slice)
#         1    0.000    0.000    0.000    0.000 construction.py:437(to_arrays)
#       154    0.000    0.000    0.000    0.000 {built-in method nt.getcwd}
#        30    0.000    0.000    0.000    0.000 getlimits.py:43(<lambda>)
#        26    0.000    0.000    0.000    0.000 core.py:927(__init__)
#       195    0.000    0.000    0.000    0.000 typing.py:866(_make_subclasshook)
#         6    0.000    0.000    0.000    0.000 generic.py:11221(_make_stat_function_ddof)
#       174    0.000    0.000    0.000    0.000 typing.py:1047(_get_type_vars)
#         8    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         2    0.000    0.000    0.000    0.000 blocks.py:673(to_native_types)
#       2/1    0.000    0.000    0.000    0.000 base.py:276(__new__)
#         1    0.000    0.000    0.000    0.000 construction.py:488(_list_to_arrays)
#         4    0.000    0.000    0.000    0.000 missing.py:225(_isna_ndarraylike)
#         1    0.000    0.000    0.000    0.000 groupby.py:1335(_add_numeric_operations)
#         1    0.000    0.000    0.000    0.000 hermite.py:60(<module>)
#       616    0.000    0.000    0.000    0.000 _inspect.py:28(isfunction)
# ...
#         1    0.000    0.000    0.000    0.000 bench_detailed.py:1(<module>)
#        19    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:736(exec_module)
#         5    0.000    0.000    0.000    0.000 config.py:773(is_instance_factory)
#         1    0.000    0.000    0.000    0.000 format.py:163(<module>)
#         1    0.000    0.000    0.000    0.000 inference.py:1(<module>)
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         2    0.000    0.000    0.000    0.000 enum.py:623(<listcomp>)
#        58    0.000    0.000    0.000    0.000 methods.py:218(<lambda>)
#         2    0.000    0.000    0.000    0.000 blocks.py:275(make_block_same_class)
#         1    0.000    0.000    0.000    0.000 _dtype.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 feather_format.py:1(<module>)
#        16    0.000    0.000    0.000    0.000 enum.py:20(_is_descriptor)
#         9    0.000    0.000    0.000    0.000 common.py:403(is_datetime64tz_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:131(SelectionMixin)
#         1    0.000    0.000    0.000    0.000 machar.py:7(<module>)
#        59    0.000    0.000    0.000    0.000 _inspect.py:146(<lambda>)
#         2    0.000    0.000    0.000    0.000 nanops.py:822(_nanminmax)
#         1    0.000    0.000    0.000    0.000 _version.py:22(get_versions)
#         3    0.000    0.000    0.000    0.000 enum.py:462(_find_new_)
#        78    0.000    0.000    0.000    0.000 _internal.py:795(<genexpr>)
#         2    0.000    0.000    0.000    0.000 common.py:608(is_excluded_dtype)
#         2    0.000    0.000    0.000    0.000 cast.py:1088(maybe_castable)
#         1    0.000    0.000    0.000    0.000 _version.py:20(get_versions)
#         3    0.000    0.000    0.000    0.000 parse.py:361(urlparse)
#         1    0.000    0.000    0.000    0.000 range.py:83(__new__)
#         1    0.000    0.000    0.000    0.000 result.py:24(TestResult)
#         1    0.000    0.000    0.000    0.000 _iotools.py:499(StringConverter)
#         2    0.000    0.000    0.000    0.000 core.py:6541(__init__)
#       159    0.000    0.000    0.000    0.000 expr.py:230(_node_not_implemented)
#         1    0.000    0.000    0.000    0.000 sql.py:1048(SQLDatabase)
#         1    0.000    0.000    0.000    0.000 indexing.py:743(_convert_slice_indexer)
#        20    0.000    0.000    0.000    0.000 dtypes.py:334(construct_from_string)
#         1    0.000    0.000    0.000    0.000 token.py:74(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 core.py:6376(__array_finalize__)
#        15    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#         2    0.000    0.000    0.000    0.000 common.py:1282(needs_i8_conversion)
#        90    0.000    0.000    0.000    0.000 _inspect.py:133(strseq)
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#        52    0.000    0.000    0.000    0.000 {method 'translate' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         7    0.000    0.000    0.000    0.000 ntpath.py:122(splitdrive)
#         4    0.000    0.000    0.000    0.000 base.py:5091(_add_numeric_methods_unary)
#         2    0.000    0.000    0.000    0.000 os.py:678(__delitem__)
#         1    0.000    0.000    0.000    0.000 csvs.py:228(_save_header)
#         8    0.000    0.000    0.000    0.000 common.py:542(is_categorical_dtype)
#         4    0.000    0.000    0.000    0.000 warnings.py:159(_add_filter)
#        12    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        54    0.000    0.000    0.000    0.000 six.py:177(_add_module)
#        13    0.000    0.000    0.000    0.000 mixins.py:48(_numeric_methods)
#         1    0.000    0.000    0.000    0.000 _factories.py:26(__init__)
#        36    0.000    0.000    0.000    0.000 _string_helpers.py:16(english_lower)
#         1    0.000    0.000    0.000    0.000 indexers.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 linalg.py:82(_determine_error_states)
#         2    0.000    0.000    0.000    0.000 sre_compile.py:381(_bytes_to_codes)
#         1    0.000    0.000    0.000    0.000 numeric.py:159(ones)
#         1    0.000    0.000    0.000    0.000 {built-in method winreg.OpenKey}
#         1    0.000    0.000    0.000    0.000 boolean.py:198(BooleanArray)
#         1    0.000    0.000    0.000    0.000 polynomial.py:1442(Polynomial)
#         1    0.000    0.000    0.000    0.000 utils.py:133(_get_indent)
#        20    0.000    0.000    0.000    0.000 methods.py:89(_wrap_inplace_method)
#         6    0.000    0.000    0.000    0.000 common.py:613(<genexpr>)
#       359    0.000    0.000    0.000    0.000 {built-in method builtins.globals}
#         1    0.000    0.000    0.000    0.000 {built-in method winreg.ConnectRegistry}
#        30    0.000    0.000    0.000    0.000 getlimits.py:19(_fr0)
#         1    0.000    0.000    0.000    0.000 typing.py:686(_Union)
#         3    0.000    0.000    0.000    0.000 six.py:91(__get__)
#        20    0.000    0.000    0.000    0.000 tokenize.py:112(group)
#         1    0.000    0.000    0.000    0.000 tz.py:41(tzutc)
#         1    0.000    0.000    0.000    0.000 _common.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 argparse.py:150(HelpFormatter)
#        17    0.000    0.000    0.000    0.000 getlimits.py:521(max)
#         7    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        84    0.000    0.000    0.000    0.000 overrides.py:105(decorator)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         1    0.000    0.000    0.000    0.000 __future__.py:48(<module>)
#        47    0.000    0.000    0.000    0.000 six.py:105(__init__)
#       8/7    0.000    0.000    0.000    0.000 _asarray.py:16(asarray)
#         2    0.000    0.000    0.000    0.000 ntpath.py:75(join)
#         2    0.000    0.000    0.000    0.000 blocks.py:2591(__init__)
#         1    0.000    0.000    0.000    0.000 indexing.py:569(_NDFrameIndexer)
#         1    0.000    0.000    0.000    0.000 common.py:40(is_url)
#         1    0.000    0.000    0.000    0.000 integer.py:256(IntegerArray)
#         4    0.000    0.000    0.000    0.000 os.py:664(__getitem__)
#         3    0.000    0.000    0.000    0.000 enum.py:160(<setcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:358(__getattr__)
#         1    0.000    0.000    0.000    0.000 offsets.py:2678(Day)
#        24    0.000    0.000    0.000    0.000 tokenize.py:148(<listcomp>)
#        26    0.000    0.000    0.000    0.000 inference.py:358(is_hashable)
#         1    0.000    0.000    0.000    0.000 offsets.py:658(BusinessHourMixin)
#         1    0.000    0.000    0.000    0.000 argparse.py:1050(_SubParsersAction)
#         3    0.000    0.000    0.000    0.000 platform.py:1224(python_implementation)
#        15    0.000    0.000    0.000    0.000 dtypes.py:64(register)
#         4    0.000    0.000    0.000    0.000 common.py:987(is_datetime64_any_dtype)
#         6    0.000    0.000    0.000    0.000 base.py:5393(maybe_extract_name)
#         1    0.000    0.000    0.000    0.000 config.py:230(__call__)
#         9    0.000    0.000    0.000    0.000 _collections_abc.py:92(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 result.py:12(failfast)
#         2    0.000    0.000    0.000    0.000 {built-in method _locale.setlocale}
#         1    0.000    0.000    0.000    0.000 frequencies.py:300(_FrequencyInferer)
#         1    0.000    0.000    0.000    0.000 __init__.py:21(__deprecated_private_func)
#         2    0.000    0.000    0.000    0.000 managers.py:1828(_stack_arrays)
#         1    0.000    0.000    0.000    0.000 _type_aliases.py:246(_set_array_types)
#         2    0.000    0.000    0.000    0.000 _asarray.py:223(require)
#       112    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#         1    0.000    0.000    0.000    0.000 localization.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 pprint.py:98(PrettyPrinter)
#         1    0.000    0.000    0.000    0.000 datetime.py:1949(timezone)
#         2    0.000    0.000    0.000    0.000 numeric.py:283(full)
#         1    0.000    0.000    0.000    0.000 base.py:5024(_add_comparison_methods)
#       257    0.000    0.000    0.000    0.000 hmac.py:10(<genexpr>)
#         2    0.000    0.000    0.000    0.000 random.py:87(__init__)
#         5    0.000    0.000    0.000    0.000 managers.py:163(shape)
#         1    0.000    0.000    0.000    0.000 _pytesttester.py:29(<module>)
#         1    0.000    0.000    0.000    0.000 _factories.py:56(__init__)
#         6    0.000    0.000    0.000    0.000 boolean.py:587(_create_logical_method)
#         1    0.000    0.000    0.000    0.000 calendar.py:50(_localized_month)
#         5    0.000    0.000    0.000    0.000 getlimits.py:508(min)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.writers.write_csv_rows}
#         7    0.000    0.000    0.000    0.000 core.py:2562(_arraymethod)
#         1    0.000    0.000    0.000    0.000 config.py:101(_get_option)
#        28    0.000    0.000    0.000    0.000 signal.py:10(<lambda>)
#         1    0.000    0.000    0.000    0.000 orc.py:1(<module>)
#       108    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#         1    0.000    0.000    0.000    0.000 common.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:415(__getattr__)
#         4    0.000    0.000    0.000    0.000 common.py:339(is_categorical)
#        21    0.000    0.000    0.000    0.000 _internal.py:830(npy_ctypes_check)
#        84    0.000    0.000    0.000    0.000 overrides.py:94(set_module)
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 methods.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 offsets.py:2698(Milli)
#         1    0.000    0.000    0.000    0.000 _exceptions.py:1(<module>)
#       257    0.000    0.000    0.000    0.000 hmac.py:11(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#        34    0.000    0.000    0.000    0.000 _add_newdocs.py:6744(<genexpr>)
#        27    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.to_object_array}
#         1    0.000    0.000    0.000    0.000 typing.py:907(GenericMeta)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:657(get)
#         2    0.000    0.000    0.000    0.000 base.py:3638(values)
#         1    0.000    0.000    0.000    0.000 threading.py:757(__init__)
#         1    0.000    0.000    0.000    0.000 _misc.py:423(_Options)
#         3    0.000    0.000    0.000    0.000 platform.py:1117(_sys_version)
#         4    0.000    0.000    0.000    0.000 sre_parse.py:257(getwhile)
#         2    0.000    0.000    0.000    0.000 os.py:720(<lambda>)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#        57    0.000    0.000    0.000    0.000 config.py:729(wrap)
#         1    0.000    0.000    0.000    0.000 offsets.py:1825(QuarterOffset)
#         3    0.000    0.000    0.000    0.000 datetime.py:1368(__new__)
#         1    0.000    0.000    0.000    0.000 tz.py:132(tzoffset)
#         3    0.000    0.000    0.000    0.000 base.py:1186(name)
#        25    0.000    0.000    0.000    0.000 enum.py:28(_is_dunder)
#        24    0.000    0.000    0.000    0.000 {built-in method _struct.calcsize}
#         2    0.000    0.000    0.000    0.000 core.py:2912(_update_from)
#         1    0.000    0.000    0.000    0.000 offsets.py:2683(Hour)
#        84    0.000    0.000    0.000    0.000 lazy.py:149(lazy)
#         2    0.000    0.000    0.000    0.000 decoder.py:345(raw_decode)
#         1    0.000    0.000    0.000    0.000 __init__.py:1083(__init__)
#         1    0.000    0.000    0.000    0.000 numpy_.py:26(PandasDtype)
#         6    0.000    0.000    0.000    0.000 boolean.py:633(_create_comparison_method)
#         3    0.000    0.000    0.000    0.000 ufunclike.py:60(_fix_and_maybe_deprecate_out_named_y)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:784(_parse_flags)
#         1    0.000    0.000    0.000    0.000 reduce.py:1(<module>)
#       135    0.000    0.000    0.000    0.000 six.py:88(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:329(_verify_integrity)
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         1    0.000    0.000    0.000    0.000 lazy.py:118(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _testing.py:80(set_testing_mode)
#        19    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#         1    0.000    0.000    0.000    0.000 contextlib.py:48(__call__)
#         1    0.000    0.000    0.000    0.000 tz.py:1545(__init__)
#        34    0.000    0.000    0.000    0.000 array_ops.py:119(define_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 sql.py:1553(SQLiteDatabase)
#         1    0.000    0.000    0.000    0.000 _openpyxl.py:475(_OpenpyxlReader)
#         1    0.000    0.000    0.000    0.000 __init__.py:769(__init__)
#         3    0.000    0.000    0.000    0.000 pathlib.py:390(_wrap_binary_strfunc)
#         3    0.000    0.000    0.000    0.000 common.py:88(stringify_path)
#         1    0.000    0.000    0.000    0.000 base.py:5463(_maybe_cast_data_without_dtype)
#         3    0.000    0.000    0.000    0.000 threading.py:74(RLock)
#        24    0.000    0.000    0.000    0.000 typing.py:889(__extrahook__)
#         2    0.000    0.000    0.000    0.000 common.py:1435(is_bool_dtype)
#         1    0.000    0.000    0.000    0.000 lazy.py:172(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base64.py:3(<module>)
#        24    0.000    0.000    0.000    0.000 function.py:36(__init__)
#         8    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#        24    0.000    0.000    0.000    0.000 {method 'to_bytes' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 warnings.py:143(simplefilter)
#         1    0.000    0.000    0.000    0.000 decorators.py:15(<module>)
#         3    0.000    0.000    0.000    0.000 ufunclike.py:43(_fix_out_named_y)
#        26    0.000    0.000    0.000    0.000 typing.py:769(_get_type_vars)
#         4    0.000    0.000    0.000    0.000 fractions.py:294(_operator_fallbacks)
#         1    0.000    0.000    0.000    0.000 pytables.py:24(PyTablesScope)
#         8    0.000    0.000    0.000    0.000 os.py:734(encodekey)
#         1    0.000    0.000    0.000    0.000 random.py:96(seed)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         3    0.000    0.000    0.000    0.000 parse.py:394(urlsplit)
#        10    0.000    0.000    0.000    0.000 string_.py:271(_create_arithmetic_method)
#         1    0.000    0.000    0.000    0.000 <string>:5(_Instruction)
#         1    0.000    0.000    0.000    0.000 offsets.py:2688(Minute)
#         1    0.000    0.000    0.000    0.000 _add_newdocs.py:6702(numeric_type_aliases)
#         1    0.000    0.000    0.000    0.000 grouper.py:35(Grouper)
#         1    0.000    0.000    0.000    0.000 tzfile.py:4(<module>)
#         1    0.000    0.000    0.000    0.000 _common.py:149(_tzinfo)
#        12    0.000    0.000    0.000    0.000 opcode.py:43(name_op)
#         1    0.000    0.000    0.000    0.000 ops.py:67(Term)
#         1    0.000    0.000    0.000    0.000 typing.py:1237(TupleMeta)
#         2    0.000    0.000    0.000    0.000 common.py:219(asarray_tuplesafe)
#         8    0.000    0.000    0.000    0.000 config.py:802(<listcomp>)
#         1    0.000    0.000    0.000    0.000 typing.py:1290(CallableMeta)
#         1    0.000    0.000    0.000    0.000 offsets.py:1536(Week)
#         1    0.000    0.000    0.000    0.000 dtypes.py:221(__init__)

# %%
# 如果想知道有哪些函数调用了sum_num
p.print_callers(0.5, "sum_num")
# Out:
#    Ordered by: cumulative time, function name
#    List reduced from 2459 to 18 due to restriction <'test'>
#
# Function                                 called...
#                                              ncalls  tottime  cumtime
# testing.py:3(<module>)                   ->       1    0.000    0.004  <frozen importlib._bootstrap>:966(_find_and_load)
#                                                   1    0.000    0.000  <frozen importlib._bootstrap>:997(_handle_fromlist)
# _testing.py:1(<module>)                  ->       3    0.000    0.000  <frozen importlib._bootstrap>:194(_lock_unlock_module)
#                                                   1    0.000    0.002  <frozen importlib._bootstrap>:966(_find_and_load)
#                                                  17    0.000    0.000  <frozen importlib._bootstrap>:997(_handle_fromlist)
#                                                   1    0.000    0.000  __init__.py:99(_import_lzma)
#                                                   1    0.000    0.000  _testing.py:80(set_testing_mode)
#                                                   1    0.000    0.000  _testing.py:2141(optional_args)
#                                                   8    0.000    0.000  contextlib.py:129(contextmanager)
#                                                   9    0.000    0.000  typing.py:676(inner)
#                                                   4    0.000    0.000  {built-in method builtins.__build_class__}
#                                                   2    0.000    0.000  {built-in method numpy.array}
#                                                   1    0.000    0.000  {method 'join' of 'str' objects}
# nosetester.py:6(<module>)                ->       1    0.000    0.000  <frozen importlib._bootstrap>:194(_lock_unlock_module)
#                                                   1    0.000    0.000  <frozen importlib._bootstrap>:416(parent)
#                                                   3    0.000    0.000  <frozen importlib._bootstrap>:997(_handle_fromlist)
#                                                   1    0.000    0.000  {built-in method builtins.__build_class__}
# _pytesttester.py:5(<module>)             ->       1    0.000    0.000  <frozen importlib._bootstrap>:997(_handle_fromlist)
#                                                   1    0.000    0.000  {built-in method builtins.__build_class__}
# _tester.py:3(<module>)                   ->       2    0.000    0.000  ntpath.py:241(dirname)
# _pytesttester.py:29(<module>)            ->       1    0.000    0.000  <frozen importlib._bootstrap>:997(_handle_fromlist)
#                                                   1    0.000    0.000  {built-in method builtins.__build_class__}
# _testing.py:80(set_testing_mode)         ->       1    0.000    0.000  _collections_abc.py:657(get)
# _testing.py:2141(optional_args)          ->       1    0.000    0.000  functools.py:44(update_wrapper)
#                                                   1    0.000    0.000  functools.py:74(wraps)
# _pytesttester.py:77(__init__)            ->
# nosetester.py:115(NoseTester)            ->
# _testing.py:2630(SubclassedSeries)       ->
# _testing.py:2642(SubclassedDataFrame)    ->
# _testing.py:2504(RNGContext)             ->
# _pytesttester.py:16(PytestTester)        ->
# __init__.py:21(_testing)                 ->
# _testing.py:2654(SubclassedCategorical)  ->
# _pytesttester.py:21(__init__)            ->
# _pytesttester.py:47(PytestTester)        ->

# %%
# 查看test()函数中调用了哪些函数
p.print_callees("test")
# Out:
#    Ordered by: cumulative time, function name
#    List reduced from 2459 to 18 due to restriction <'test'>
#
# Function                                 called...
#                                              ncalls  tottime  cumtime
# testing.py:3(<module>)                   ->       1    0.000    0.004  <frozen importlib._bootstrap>:966(_find_and_load)
#                                                   1    0.000    0.000  <frozen importlib._bootstrap>:997(_handle_fromlist)
# _testing.py:1(<module>)                  ->       3    0.000    0.000  <frozen importlib._bootstrap>:194(_lock_unlock_module)
#                                                   1    0.000    0.002  <frozen importlib._bootstrap>:966(_find_and_load)
#                                                  17    0.000    0.000  <frozen importlib._bootstrap>:997(_handle_fromlist)
#                                                   1    0.000    0.000  __init__.py:99(_import_lzma)
#                                                   1    0.000    0.000  _testing.py:80(set_testing_mode)
#                                                   1    0.000    0.000  _testing.py:2141(optional_args)
#                                                   8    0.000    0.000  contextlib.py:129(contextmanager)
#                                                   9    0.000    0.000  typing.py:676(inner)
#                                                   4    0.000    0.000  {built-in method builtins.__build_class__}
#                                                   2    0.000    0.000  {built-in method numpy.array}
#                                                   1    0.000    0.000  {method 'join' of 'str' objects}
# nosetester.py:6(<module>)                ->       1    0.000    0.000  <frozen importlib._bootstrap>:194(_lock_unlock_module)
#                                                   1    0.000    0.000  <frozen importlib._bootstrap>:416(parent)
#                                                   3    0.000    0.000  <frozen importlib._bootstrap>:997(_handle_fromlist)
#                                                   1    0.000    0.000  {built-in method builtins.__build_class__}
# _pytesttester.py:5(<module>)             ->       1    0.000    0.000  <frozen importlib._bootstrap>:997(_handle_fromlist)
#                                                   1    0.000    0.000  {built-in method builtins.__build_class__}
# _tester.py:3(<module>)                   ->       2    0.000    0.000  ntpath.py:241(dirname)
# _pytesttester.py:29(<module>)            ->       1    0.000    0.000  <frozen importlib._bootstrap>:997(_handle_fromlist)
#                                                   1    0.000    0.000  {built-in method builtins.__build_class__}
# _testing.py:80(set_testing_mode)         ->       1    0.000    0.000  _collections_abc.py:657(get)
# _testing.py:2141(optional_args)          ->       1    0.000    0.000  functools.py:44(update_wrapper)
#                                                   1    0.000    0.000  functools.py:74(wraps)
# _pytesttester.py:77(__init__)            ->
# nosetester.py:115(NoseTester)            ->
# _testing.py:2630(SubclassedSeries)       ->
# _testing.py:2642(SubclassedDataFrame)    ->
# _testing.py:2504(RNGContext)             ->
# _pytesttester.py:16(PytestTester)        ->
# __init__.py:21(_testing)                 ->
# _testing.py:2654(SubclassedCategorical)  ->
# _pytesttester.py:21(__init__)            ->
# _pytesttester.py:47(PytestTester)        ->
