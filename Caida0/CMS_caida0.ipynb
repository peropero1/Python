# %% [markdown]
# ## Ground Truth

# %%
path="..\\Caida0\\"
groundtruth='caida_0_ground_truth.csv'
grtruth=pd.read_csv(os.path.join(path,groundtruth),nrows=size)
grtruth.head(50)
# Out:
#                                                 Element  Count
# 0           b'\xd2\x1d9\xfa\x00P\x0f\x13I\x9a\xf89\x06'  16889
# 1        b'E.\x1c)\xa4\xb2\x89\xb6\x06\xba\xd2\xad\x06'  11647
# 2                 b'V+x\xe8\x00Po\xcd\xe4\xde\xccw\x06'  10113
# 3        b'\xb7\xf6h\xd0\xc1\x8b+\xfc\xe1\x08\x00P\x06'   8993
# 4          b'\x01l|\xff\x8f\r\x01l\xc5\xc8\x01\xbb\x06'   8418
# 5              b'\x99\xc1\xe9Z\x00P+\xfc\xe0=\xe7%\x06'   6594
# 6     b'c\x0f\xb2\xd4\x80\xd2\x01`\x8d\x12\x01\xbb\x06'   6244
# 7        b'\x01l|\xec\xcc\x1b\x01l\xc5\xc8\x01\xbb\x06'   5420
# 8           b'E\x0c\xd5\xf7\xd7(\xdd.\xdc\xec\x00P\x06'   5194
# 9        b'E\x0c\xd5\xf5\xa4\x14\xdd.\xdc\xec\x00P\x06'   5044
# 10       b'\x01l$\xce\x0e\xad\x01l\xc5\xc6\x01\xbb\x06'   4444
# 11       b'\xdd\x01b\xdf\xd5\xce\xdd.\xdc\xf1\x00P\x06'   4246
# 12          b'~.~\x13\xa5\xb3+\xfc\xe2\x05\x01\xbb\x06'   4081
# 13      b'\r\xe1\x94\xb7\xc2>\x01`\xdf\x92\x01\xbb\x06'   4081
# 14    b'\xcf\x88\xee\xa0\x17\x01\x01`\xa6\xcc\x01\xb...   4054
# 15             b'\x800\xeeP <\x01`\xa6\xc7\x01\xbb\x06'   3972
# 16    b'\x05\x06\x1b\xd0\xcb\xa4h\xef\x88\xf3\x1f\x9...   3767
# 17             b'\x82+!!\xa5s\x01`\x92\xe5\x01\xbb\x06'   3639
# 18       b'E\x0c\xd5\xf4\xb9\xf6\xdd.\xdc\xf0\x00P\x06'   3588
# 19                b'ur=\xf2\xc1@+\xfc\xe2\x06\x00P\x06'   3584
# 20       b'OZ\x0e\xae\xdc\xf1o\xcd\x19\xf0\x1f\x90\x11'   3425
# 21       b'e\x86\xc2d\xfd\x84h\xef\x88\x96\x1f\x90\x11'   3419
# 22      b'\r\x01W\xaa\xcdL\x03\xff\x02\x82\x01\xbb\x06'   3407
# 23       b'I\x95\xba\xfb\xcc\xcco\xcd\xe4r\x1f\x90\x11'   3292
# 24          b'\x80-\xe5dw\xd1\x01`\xa6\xec\x01\xbb\x06'   3284
# 25             b'\xdc\x90\xcd\x9d\xceM\x01:!6\x00P\x06'   3231
# 26             b'\x01l|\xecJ\x97\x01l\xc3i\x01\xbb\x06'   3134
# 27             b'h8\xc7i\xe9Wh\xef\x88\xe3\x1f\x90\x11'   3123
# 28       b'\xd2\x1e\xbeu\x01\xbb+\xfc\xe0.\x92\xd5\x06'   3121
# 29                b'p\xe01\xdd\xd2P\x01`\xe64\x00P\x06'   3033
# ...                                                 ...    ...
# 994         b'\x80\x1d%\x14(\xa5\x01`\xa7O\x01\xbb\x06'    314
# 995      b'w\xfa\x15P\x81\xd9\x01`\xa6\xd5\x01\xbb\x06'    314
# 996            b'lw\x07s \x91\x01`\x97\xec\x01\xbb\x06'    313
# 997            b"h\xd1uD\x1e\xc8\xc7\xd6\xfeA\xf3'\x11"    313
# 998         b'+\x95L\xd5\xc9\xe0\xdd.\xdc\xec\x00P\x06'    313
# 999      b'\xa9\xb5\x10\xe3J\x06o\xcd\xe4\xb9\xdci\x11'    313
# 1000        b'\xd8\xe2\x98~\x00Pf\x00\xd6\xca\xbey\x06'    312
# 1001           b'q\xa2\x13\x0bq\xf9+\xfc\xe2%\x00P\x06'    312
# 1002     b'\x15\xbe^\xe7\x94\x1b+\xfc\xe05\x01\xbb\x06'    312
# 1003                b'sQ\\\x12Ix\x01`\xe7@\x01\xbb\x06'    312
# 1004  b'\xd2\xdc\xa4\x0b\xe9\xa3\x01`\xe7\xa6\x01\xb...    311
# 1005        b'c\x02A\x15\x00P+\x93\xfc\x1a\xa3\x8e\x06'    311
# 1006           b'lw\x0e\xe1&W\x01`\xa4\x92\x01\xbb\x06'    311
# 1007        b'\x1c\xee\xc0Y\xc4\xe8+\xef\xc0Z\x00P\x06'    310
# 1008  b'\xb7\xd0\x17\x98\xc0\n\x93K\xcb\x8e\xe5\x0c\...    310
# 1009     b'+\x13\x0f\x8f\xbc\xd8\xdd.\xdc\xf2\x00P\x06'    309
# 1010        b"'\xc6\x1bV\xfe\x11\x01Q\x9b\xe5\x00P\x06"    309
# 1011     b'o%\x9d\xbb\x93\x0co\xcd\x19\xf2\xc9\x01\x06'    309
# 1012           b'x\xb2P\x8f9H\x01`\xa6\xad\x01\xbb\x06'    309
# 1013  b'\xd8\x1en\xff\x01\xbbI\xf0\xa7\x8c\x82\xb8\x06'    308
# 1014         b'\x01`\\\xc6\x01\xbb\xd187\xf0\xed\r\x06'    308
# 1015        b'$\x8a\x1c\xcd%\xae\x01`\xc0\xf8\x00P\x06'    308
# 1016              b'lw\x05l+\x99\x01`\x9bx\x01\xbb\x06'    308
# 1017           b'~N\xcf\x19\xd26\x01`\x95\x11\x00P\x06'    308
# 1018        b'w\xe6F\xd23\x1e\x01`\xa6\xdf\x01\xbb\x06'    308
# 1019     b'lw\x1f\xb9\xbb\xda\x01`\x91\xe6\x01\xbb\x06'    307
# 1020           b'f(j\x8e\xb2uo\xcd\xe4\x9c\x93\xb2\x11'    307
# 1021     b'lw\x01\xf1\xb9\xe6\x01`\xf7\xb9\x01\xbb\x06'    306
# 1022          b'lw\x03\xba\x12a\x01`\xe6\r\x01\xbb\x06'    306
# 1023        b'\x01l$\xff\xb4\xec\x01`\x9bx\x01\xbb\x06'    305
#
# [1024 rows x 2 columns]

# %% [markdown]
# ## full version, counting and estimate frequency for all arriving elements

# %%
# count-min sketch webdocs, top-1024, cms 1024*4, full read
import sys
import os
import time
from probables import (CountMinSketch)
import pandas as pd

def find(e,element_list):
    # return index of e in element_list
    try:
        index=[ele[0] for ele in element_list].index(e)
    except:
        index=-99
    return index


start=time.time()
Top=[]
w=256
d=8

size=256
item_count=100
cms = CountMinSketch(width=w, depth=d)

filename='caida_0.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)

# if os.path.exists(os.path.join(datapath,datali)):
if os.path.exists(src_data):
    with open(src_data,'rb') as file:
        while True:
            line=str(file.read(13))
            if len(line)<13:
                print('EOF')
                break
            else:
                #item_count-=1
                #print("read {}th element: {}".format(item_count,line[:10]))
                cms.add(line)
                count=cms.check(line)
                #rint("count of {}:{}".format(line,count))
                index=find(line,Top)
                #print("index:{}".format(index))
                #print("id of iindex:{}".format(id(index)))
                if index >=0:
                    Top[index][1]=count
                else:
                    # e not in Top
                    if len(Top)<size:
                        # Top is not full
                        Top.append([line,count])
                        index=len(Top)-1
                        #print("id of iindex:{}".format(id(index)))
                    else:
                        # Top if full
                        if count< Top[-1][1]:
                            pass
                        else:
                            Top.append([line,count])
                            Top=sorted(Top,key = lambda Top:Top[1],reverse=True)
                            Top.pop()
                            #rint("Top after pop:{}\n".format(Top))
                Top=sorted(Top,key = lambda Top:Top[1],reverse=True)
                #rint("Top after insert:{}\n".format(Top))
    end=time.time()
    print(Top[:50],len(Top))
    print("Total memory {3} bytes :Top-{0} with size {1} bytes\
          + CMS with size {2} bytes.".format(len(Top),sys.getsizeof(Top),
          sys.getsizeof(cms._bins),sys.getsizeof(cms)+sys.getsizeof(Top)))
    print("Execution time:{} seconds.".format(str(end-start)))
else:
    print("file doesn't exist")

#====================Top to csv=============================
templi=[[i[0],i[1]] for i in Top]
'''
templi=[]
for i in Top:
    templi.append([i[0],i[1]])
'''

df=pd.DataFrame(templi,columns=['ID', 'Count'])
name="CMS_caida0_distinct"+'_'+str(size)+'_'+str(d)+'_'+str(w)
final=name+".csv"
df.to_csv(final,index=False)

# ====================precision====================
path="..\\Caida0\\"
groundtruth='caida_0_ground_truth.csv'
grtruth=pd.read_csv(os.path.join(path,groundtruth))
    # compare with Top-k and groundtruth[k]
My_result=pd.read_csv(os.path.join(path,final))

# precision
gt_set=set(grtruth['Element'][:size])
my_set=set(My_result['ID'])
precision=len(gt_set & my_set)/len(my_set)
    # &: set 交集運算
    # precision= tp/tp+fp=tp/size
print("Precision: {}".format(precision))


# ====================ARE/AAE for all====================
gt_dict=dict(grtruth.values.tolist())
top_are=0
top_aae=0
all_are=0
all_aae=0

read=0
startx=time.time()

for item in grtruth['Element']:
    count=cms.check(str(item))    
    if read<size:
        top_are+=abs(count-gt_dict[item])/gt_dict[item]
        top_aae+=abs(count-gt_dict[item])
        read+=1
    all_are+=abs(count-gt_dict[item])/gt_dict[item]
    all_aae+=abs(count-gt_dict[item])
endx=time.time()
distinct=len(gt_dict)
top_are/=size
all_are/=distinct
all_aae/=distinct 
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.3f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.3f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx))
# Out:
# EOF
# [["b'\\xd2\\x1d9\\xfa\\x00P\\x0f\\x13I\\x9a\\xf89\\x06'", 23862], ["b'E.\\x1c)\\xa4\\xb2\\x89\\xb6\\x06\\xba\\xd2\\xad\\x06'", 18885], ["b'V+x\\xe8\\x00Po\\xcd\\xe4\\xde\\xccw\\x06'", 17609], ["b'\\xb7\\xf6h\\xd0\\xc1\\x8b+\\xfc\\xe1\\x08\\x00P\\x06'", 14967], ["b'\\x01l|\\xff\\x8f\\r\\x01l\\xc5\\xc8\\x01\\xbb\\x06'", 13891], ["b'c\\x0f\\xb2\\xd4\\x80\\xd2\\x01`\\x8d\\x12\\x01\\xbb\\x06'", 13298], ["b'\\x01l|\\xec\\xcc\\x1b\\x01l\\xc5\\xc8\\x01\\xbb\\x06'", 13186], ["b'E\\x0c\\xd5\\xf7\\xd7(\\xdd.\\xdc\\xec\\x00P\\x06'", 12779], ["b'E\\x0c\\xd5\\xf5\\xa4\\x14\\xdd.\\xdc\\xec\\x00P\\x06'", 12412], ["b'\\xdd\\x01b\\xdf\\xd5\\xce\\xdd.\\xdc\\xf1\\x00P\\x06'", 11438], ["b'\\xd2\\x1e\\xbeu\\x01\\xbb+\\xfc\\xe0.\\x92\\xd5\\x06'", 11194], ["b'\\r\\xe1\\x94\\xb7\\xc2>\\x01`\\xdf\\x92\\x01\\xbb\\x06'", 10938], ["b'\\x99\\xc1\\xe9Z\\x00P+\\xfc\\xe0=\\xe7%\\x06'", 10871], ["b'\\x01l$\\xce\\x0e\\xad\\x01l\\xc5\\xc6\\x01\\xbb\\x06'", 10827], ["b'\\x7f\\x1a>\\xb1/<\\x03\\xf9\\x9f\\x90\\x01\\xbb\\x06'", 10772], ["b'\\xcf\\x88\\xee\\xa0\\x17\\x01\\x01`\\xa6\\xcc\\x01\\xbb\\x06'", 10618], ['b"\'&\\xec\\xc2\\xd0\\xeao\\xcd\\xe4\\x84\\x1f\\x90\\x11"', 10543], ["b'\\x800\\xeeP <\\x01`\\xa6\\xc7\\x01\\xbb\\x06'", 10509], ["b'$\\
# Total memory 2520 bytes :Top-256 with size 2416 bytes          + CMS with size 104 bytes.
# Execution time:923.8556740283966 seconds.
# Precision: 0.3203125
# Top_ARE: 4.036141
# Top_AAE: 1706615.000
# all_ARE: 3262.165956
# all_AAE: 6689.585
# Estimate time:  20.677 seconds.

# %%
# Out:
# 16448

# %% [markdown]
# ## count and compare error after read all elements

# %%
# count-min sketch webdocs, top-1024, cms 1024*4, full read
import sys
import os
import time
from probables import (CountMinSketch)
import pandas as pd

start=time.time()
topk=[]
w=128
d=4
size=256

item_count=0
cms = CountMinSketch(width=w, depth=d)

filename='caida_0.dat'
filepath="..\\dataset\\"
src_data=os.path.join(filepath,filename)

# if os.path.exists(os.path.join(datapath,datali)):
if os.path.exists(src_data):
    with open(src_data,'rb') as file:
        while True:
            line=str(file.read(13))
            if len(line)<13:
                print('EOF')
                break
            else:
                # item_count+=1
                # print("read {}th element: {}".format(item_count,element))
                cms.add(line)
    end=time.time()
    print("Execution time:{} seconds.".format(str(end-start)))
    print("Total memory {} bytes.".format(sys.getsizeof(cms._bins)))
else:
    print("file doesn't exist")    
    

#==================== count and check error of top k=============================
path="..\\Caida0\\"
groundtruth='caida_0_ground_truth.csv'
grtruth=pd.read_csv(os.path.join(path,groundtruth))
gli = grtruth.values.tolist()

gt_dict=dict(grtruth.values.tolist())
top_are=0
top_aae=0
all_are=0
all_aae=0

read=0
startx=time.time()
for item in grtruth['Element']:
    count=cms.check(str(item))    
    if read<size:
        top_are+=abs(count-gt_dict[item])/gt_dict[item]
        top_aae+=abs(count-gt_dict[item])
        read+=1
    all_are+=abs(count-gt_dict[item])/gt_dict[item]
    all_aae+=abs(count-gt_dict[item])
endx=time.time() 
distinct=len(gt_dict)
top_are/=256
all_are/=distinct
all_aae/=distinct 
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.3f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.3f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx))
# Out:
# EOF
# Execution time:221.2558970451355 seconds.
# Total memory 4160 bytes.
# Top_ARE: 2415.749480
# Top_AAE: 4002099.000
# all_ARE: 7654.682936
# all_AAE: 15692.637
# Estimate time:  16.880 seconds.

# %%
#==================== count and check error of top k=============================
path="..\\Caida0\\"
groundtruth='caida_0_ground_truth.csv'
grtruth=pd.read_csv(os.path.join(path,groundtruth))
gli = grtruth.values.tolist()

gt_dict=dict(grtruth.values.tolist())
top_are=0
top_aae=0
all_are=0
all_aae=0
read=0

startx=time.time()
for item in grtruth['Element']:
    count=cms.check(str(item))    
    if read<256:
        top_are+=abs(count-gt_dict[item])/gt_dict[item]
        top_aae+=abs(count-gt_dict[item])
        read+=1
    all_are+=abs(count-gt_dict[item])/gt_dict[item]
    all_aae+=abs(count-gt_dict[item])
endx=time.time() 

distinct=len(gt_dict)
top_are/=256
all_are/=distinct
all_aae/=distinct 
print("Top_ARE: {:8.6f}".format(top_are))
print("Top_AAE: {:8.3f}".format(top_aae))
print("all_ARE: {:8.6f}".format(all_are))
print("all_AAE: {:8.3f}".format(all_aae))
print("Estimate time:{:8.3f} seconds.".format(endx-startx))
# Out:
# Top_ARE: 9.436521
# Top_AAE: 4002099.000
# all_ARE: 7654.682936
# all_AAE: 15692.637
# Estimate time:  16.753 seconds.
